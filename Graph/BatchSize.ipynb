# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
btc = ['LSTM BTC', 'BiLSTM BTC']
btc1 = [444.86, 370.99]
btc2 = [372.72, 355.46]
btc3 = [944.48, 667.31]

eth = ['LSTM ETH', 'BiLSTM ETH']
eth1 = [18.450, 21.510]
eth2 = [43.327, 40.901]
eth3 = [34.396, 32.050]

ltc = ['LSTM LTC', 'BiLSTM LTC']
ltc1 = [0.701, 0.750]
ltc2 = [0.820, 0.861]
ltc3 = [3.139, 2.941]

# Positions of bars on x-axis
x = np.arange(len(btc))

# Width of bars
width = 0.2

fig, axs = plt.subplots(ncols=3, nrows=3)
fig.set_figwidth(12)
fig.set_figheight(12)
axs[0,0].bar(x - width, btc1, width, label='Batch size 32')
axs[0,0].bar(x, btc2, width, label='Batch size 64')
axs[0,0].bar(x + width, btc3, width, label='Batch size 128')
axs[0,0].set_xticks(x)
axs[0,0].set_xticklabels(btc)

axs[0,1].bar(x - width, eth1, width)
axs[0,1].bar(x, eth2, width)
axs[0,1].bar(x + width, eth3, width)
axs[0,1].set_xticks(x)
axs[0,1].set_xticklabels(eth)

axs[0,2].bar(x - width, ltc1, width)
axs[0,2].bar(x, ltc2, width)
axs[0,2].bar(x + width, ltc3, width)
axs[0,2].set_xticks(x)
axs[0,2].set_xticklabels(ltc)
axs[0,0].set_ylabel('RMSE')

# Adding legend
fig.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, 0.05))

# fig.suptitle('Perbandingan RMSE BTC, ETH, dan LTC Berdasarkan Batch Size', fontsize=16)
for row in axs:
    for ax in row:
        for rect in ax.containers:
            ax.bar_label(rect, label_type='edge')
        
# Data
btc = ['LSTM BTC', 'BiLSTM BTC']
btc1 = [393.71, 311.44]
btc2 = [328.85, 308.64]
btc3 = [884.18, 587.679]

eth = ['LSTM ETH', 'BiLSTM ETH']
eth1 = [13.785, 16.568]
eth2 = [38.768, 36.685]
eth3 = [29.336, 26.550]

ltc = ['LSTM LTC', 'BiLSTM LTC']
ltc1 = [0.506, 0.527]
ltc2 = [0.619, 0.642]
ltc3 = [3.007, 2.770]

# Positions of bars on x-axis
x = np.arange(len(btc))

axs[1,0].bar(x - width, btc1, width)
axs[1,0].bar(x, btc2, width)
axs[1,0].bar(x + width, btc3, width)
axs[1,0].set_xticks(x)
axs[1,0].set_xticklabels(btc)

axs[1,1].bar(x - width, eth1, width)
axs[1,1].bar(x, eth2, width)
axs[1,1].bar(x + width, eth3, width)
axs[1,1].set_xticks(x)
axs[1,1].set_xticklabels(eth)

axs[1,2].bar(x - width, ltc1, width)
axs[1,2].bar(x, ltc2, width)
axs[1,2].bar(x + width, ltc3, width)
axs[1,2].set_xticks(x)
axs[1,2].set_xticklabels(ltc)
axs[1,0].set_ylabel('MAE')

# fig.suptitle('Perbandingan BTC, ETH, dan LTC Berdasarkan Batch Size', fontsize=16)

for row in axs:
    for ax in row:
        for rect in ax.containers:
            ax.bar_label(rect, label_type='edge')
            
x = np.arange(len(btc))

# Data
btc = ['LSTM BTC', 'BiLSTM BTC']
btc1 = [2.037, 1.584]
btc2 = [1.715, 1.604]
btc3 = [4.352, 2.890]

eth = ['LSTM ETH', 'BiLSTM ETH']
eth1 = [0.974, 1.189]
eth2 = [2.993, 2.809]
eth3 = [2.259, 2.029]

ltc = ['LSTM LTC', 'BiLSTM LTC']
ltc1 = [0.851, 0.884]
ltc2 = [1.053, 1.087]
ltc3 = [5.284, 4.843]

axs[2,0].bar(x - width, btc1, width)
axs[2,0].bar(x, btc2, width)
axs[2,0].bar(x + width, btc3, width)
axs[2,0].set_xticks(x)
axs[2,0].set_xticklabels(btc)

axs[2,1].bar(x - width, eth1, width)
axs[2,1].bar(x, eth2, width)
axs[2,1].bar(x + width, eth3, width)
axs[2,1].set_xticks(x)
axs[2,1].set_xticklabels(eth)

axs[2,2].bar(x - width, ltc1, width)
axs[2,2].bar(x, ltc2, width)
axs[2,2].bar(x + width, ltc3, width)
axs[2,2].set_xticks(x)
axs[2,2].set_xticklabels(ltc)
axs[2,0].set_ylabel('MAE')

# fig.suptitle('Perbandingan MAPE BTC, ETH, dan LTC Berdasarkan Batch Size', fontsize=16)

for row in axs:
    for ax in row:
        for rect in ax.containers:
            ax.bar_label(rect, label_type='edge')

# plt.show()
fig.savefig('../../Skripsi/img/batchSizeCompare.png', dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
bs_32 = [1.363, 1.208, 1.0462, 1.350, 1.221, 1.0172, 1.801, 1.381, 0.8973, 1.954, 0.944, 0.7257, 1.757, 0.806, 0.7510, 2.646, 0.868, 0.7896, 2.186, 0.773, 0.8318, 2.502, 0.792, 0.8355, 2.772, 0.772, 0.7649, 1.250, 1.289, 1.2342, 1.311, 1.629, 1.1316, 1.287, 1.599, 0.9823, 0.939, 1.069, 0.8462, 1.237, 1.167, 0.7323, 1.378, 1.033, 0.7360, 2.182, 1.045, 0.8099, 2.358, 0.868, 0.7428, 2.313, 1.003, 0.7407]
bs_64 = [1.581, 2.896, 1.1272, 1.697, 2.805, 1.3613, 1.874, 3.353, 1.2323, 1.565, 3.010, 0.8762, 1.666, 2.797, 0.9546, 1.782, 2.840, 1.0221, 1.437, 2.707, 0.9193, 1.377, 3.092, 1.0363, 2.459, 3.433, 0.9448, 1.345, 2.787, 1.2262, 1.641, 3.029, 1.4497, 1.793, 3.177, 1.2805, 1.412, 2.536, 1.0085, 1.620, 2.618, 1.0076, 1.779, 2.837, 0.9950, 1.455, 2.533, 1.0063, 1.421, 2.608, 0.9286, 1.973, 3.155, 0.8804]
bs_128 = [7.411, 2.103, 6.7022, 4.812, 3.558, 6.8512, 3.792, 3.469, 6.1902, 1.584, 1.768, 6.4445, 4.695, 4.100, 5.2649, 9.399, 0.885, 6.9361, 2.789, 1.827, 0.8499, 3.342, 1.086, 4.1581, 1.348, 1.533, 4.1552, 4.281, 2.869, 13.2059, 0.715, 2.394, 5.8930, 2.202, 3.664, 0.9943, 9.625, 1.898, 6.9806, 0.534, 1.744, 7.3173, 1.524, 1.827, 0.9328, 3.652, 2.044, 3.1994, 2.414, 0.914, 4.1880, 1.063, 0.911, 0.8735]

# Combine the data into a list
data = [bs_32, bs_64, bs_128]

labels = ['32', '64', '128']
fig, ax = plt.subplots()
ax.boxplot(data, labels=labels)

# Set the title and axis labels
# ax.set_title('Boxplot Perbandingan MAPE')
ax.set_xlabel('Batch Size')
ax.set_ylabel('MAPE')

# Show the plot
plt.show()
fig.savefig('../../Skripsi/img/boxplotMAPECompare.png', dpi=300)
