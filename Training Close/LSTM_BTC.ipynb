# %%
from Skripsi import Preprocessing
from Skripsi import Evaluation
from Skripsi import LSTMUnit
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import pandas as pd
from openpyxl.workbook import Workbook

# %%
btc_dfd = pd.read_csv('../Dataset/Binance_BTCUSDT_1h.csv')
btc_dfd
# Out:
#                 Unix                 Date   Symbol      Open      High  \
# 0      1672527600000  2022-12-31 23:00:00  BTCUSDT  16520.28  16551.24
# 1      1672524000000  2022-12-31 22:00:00  BTCUSDT  16548.28  16567.49
# 2      1672520400000  2022-12-31 21:00:00  BTCUSDT  16568.19  16571.64
# 3      1672516800000  2022-12-31 20:00:00  BTCUSDT  16570.14  16574.97
# 4      1672513200000  2022-12-31 19:00:00  BTCUSDT  16577.78  16590.06
# ...              ...                  ...      ...       ...       ...
# 26269  1577851200000  2020-01-01 04:00:00  BTCUSDT   7225.00   7230.00
# 26270  1577847600000  2020-01-01 03:00:00  BTCUSDT   7242.66   7245.00
# 26271  1577844000000  2020-01-01 02:00:00  BTCUSDT   7215.52   7244.87
# 26272  1577840400000  2020-01-01 01:00:00  BTCUSDT   7176.47   7230.00
# 26273  1577836800000  2020-01-01 00:00:00  BTCUSDT   7195.24   7196.25
#
#             Low     Close   Volume BTC   Volume USDT  tradecount
# 0      16487.74  16542.40  4973.433070  8.217183e+07      152632
# 1      16470.00  16520.81  6695.136250  1.106669e+08      153933
# 2      16544.12  16548.28  3618.773890  5.992803e+07      105065
# 3      16564.09  16568.60  2622.143550  4.344849e+07       90705
# 4      16565.10  16570.14  4044.433590  6.704605e+07      116587
# ...         ...       ...          ...           ...         ...
# 26269   7215.03   7217.27   467.812578  3.379094e+06        5896
# 26270   7220.00   7225.01   783.724867  5.667367e+06        8337
# 26271   7211.41   7242.85   655.156809  4.736719e+06        7466
# 26272   7175.71   7216.27   883.052603  6.365953e+06        9033
# 26273   7175.46   7177.02   511.814901  3.675857e+06        7640
#
# [26274 rows x 10 columns]

# %%
df = Preprocessing.feature_selection(btc_dfd)
df
# Out:
#           Close
# 0       7177.02
# 1       7216.27
# 2       7242.85
# 3       7225.01
# 4       7217.27
# ...         ...
# 26269  16570.14
# 26270  16568.60
# 26271  16548.28
# 26272  16520.81
# 26273  16542.40
#
# [26274 rows x 1 columns]

# %%
df_no_dup = Preprocessing.handle_duplicate(df)
df_no_dup
# Out:
# duplicate ok
#           Close
# 0       7177.02
# 1       7216.27
# 2       7242.85
# 3       7225.01
# 4       7217.27
# ...         ...
# 26269  16570.14
# 26270  16568.60
# 26271  16548.28
# 26272  16520.81
# 26273  16542.40
#
# [26106 rows x 1 columns]

# %%
miss = Preprocessing.handle_missing_value(df_no_dup)
miss
# Out:
# No missing value
# False

# %%
x, scaler = Preprocessing.minmax_scale(df_no_dup)
x
# Out:
# array([[0.04722846],
#        [0.04783696],
#        [0.04824904],
#        ...,
#        [0.19251245],
#        [0.19208658],
#        [0.19242129]])

# %%
train, test = Preprocessing.splitting_data(x)
train
# Out:
# array([[0.04722846],
#        [0.04783696],
#        [0.04824904],
#        ...,
#        [0.38606857],
#        [0.38299135],
#        [0.38420385]])

# %%
test
# Out:
# array([[0.38958251],
#        [0.39058727],
#        [0.38225758],
#        ...,
#        [0.19251245],
#        [0.19208658],
#        [0.19242129]])

# %%
train_X, train_y = Preprocessing.create_dataset(train,5)
test_X, test_y = Preprocessing.create_dataset(test,5)

# %%
train_X
# Out:
# array([[[0.04722846],
#         [0.04783696],
#         [0.04824904],
#         [0.04797246],
#         [0.04785247]],
#
#        [[0.04783696],
#         [0.04824904],
#         [0.04797246],
#         [0.04785247],
#         [0.04796006]],
#
#        [[0.04824904],
#         [0.04797246],
#         [0.04785247],
#         [0.04796006],
#         [0.04798192]],
#
#        ...,
#
#        [[0.38442601],
#         [0.38245246],
#         [0.38515838],
#         [0.38544456],
#         [0.38463778]],
#
#        [[0.38245246],
#         [0.38515838],
#         [0.38544456],
#         [0.38463778],
#         [0.38606857]],
#
#        [[0.38515838],
#         [0.38544456],
#         [0.38463778],
#         [0.38606857],
#         [0.38299135]]])

# %%
train_y
# Out:
# array([0.04796006, 0.04798192, 0.04773712, ..., 0.38606857, 0.38299135,
#        0.38420385])

# %%
test_X
# Out:
# array([[[0.38958251],
#         [0.39058727],
#         [0.38225758],
#         [0.38323475],
#         [0.38142925]],
#
#        [[0.39058727],
#         [0.38225758],
#         [0.38323475],
#         [0.38142925],
#         [0.37606749]],
#
#        [[0.38225758],
#         [0.38323475],
#         [0.38142925],
#         [0.37606749],
#         [0.37728495]],
#
#        ...,
#
#        [[0.19332032],
#         [0.19303645],
#         [0.19296994],
#         [0.19285135],
#         [0.19282747]],
#
#        [[0.19303645],
#         [0.19296994],
#         [0.19285135],
#         [0.19282747],
#         [0.19251245]],
#
#        [[0.19296994],
#         [0.19285135],
#         [0.19282747],
#         [0.19251245],
#         [0.19208658]]])

# %%
test_y
# Out:
# array([0.37606749, 0.37728495, 0.38369286, ..., 0.19251245, 0.19208658,
#        0.19242129])

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (20879, 5, 1) (20879,) (5217, 5, 1) (5217,)

# %% [markdown]
# ## Model Training

# %%
hyperparams = []
batch = [32, 64, 128]
epoch = [25, 50, 100]
neuron = [50, 60, 100]
for j in batch:
    for k in epoch:
        for l in neuron:
            hyperparams.append((j,k,l))
hyperparams
# Out:
# [(32, 25, 50),
#  (32, 25, 60),
#  (32, 25, 100),
#  (32, 50, 50),
#  (32, 50, 60),
#  (32, 50, 100),
#  (32, 100, 50),
#  (32, 100, 60),
#  (32, 100, 100),
#  (64, 25, 50),
#  (64, 25, 60),
#  (64, 25, 100),
#  (64, 50, 50),
#  (64, 50, 60),
#  (64, 50, 100),
#  (64, 100, 50),
#  (64, 100, 60),
#  (64, 100, 100),
#  (128, 25, 50),
#  (128, 25, 60),
#  (128, 25, 100),
#  (128, 50, 50),
#  (128, 50, 60),
#  (128, 50, 100),
#  (128, 100, 50),
#  (128, 100, 60),
#  (128, 100, 100)]

# %%
hyperparam1 = hyperparams[:9]
hyperparam2 = hyperparams[9:18]
hyperparam3 = hyperparams[18:27]
hyperparam1
# Out:
# [(32, 25, 50),
#  (32, 25, 60),
#  (32, 25, 100),
#  (32, 50, 50),
#  (32, 50, 60),
#  (32, 50, 100),
#  (32, 100, 50),
#  (32, 100, 60),
#  (32, 100, 100)]

# %%
hyperparam2
# Out:
# [(64, 25, 50),
#  (64, 25, 60),
#  (64, 25, 100),
#  (64, 50, 50),
#  (64, 50, 60),
#  (64, 50, 100),
#  (64, 100, 50),
#  (64, 100, 60),
#  (64, 100, 100)]

# %%
hyperparam3
# Out:
# [(128, 25, 50),
#  (128, 25, 60),
#  (128, 25, 100),
#  (128, 50, 50),
#  (128, 50, 60),
#  (128, 50, 100),
#  (128, 100, 50),
#  (128, 100, 60),
#  (128, 100, 100)]

# %%
lstms1 = []
models1 = []
for batch, epoch, neuron in hyperparam1:
    model, lstm = LSTMUnit.train_lstm(train_X, train_y, test_X, test_y, neuron, epoch, batch)
    lstms1.append(lstm)
    models1.append(model)
# Out:
# Metal device set to: Apple M1
# 2023-04-02 18:16:29.641438: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-04-02 18:16:29.641917: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/25
# 2023-04-02 18:16:30.145054: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-04-02 18:16:30.571486: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:16:30.665291: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:16:30.865121: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:16:36.087702: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:16:36.117239: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 653/653 - 7s - loss: 3.1242e-04 - val_loss: 0.0026 - 7s/epoch - 11ms/step
# Epoch 2/25
# 653/653 - 5s - loss: 4.6383e-04 - val_loss: 0.0018 - 5s/epoch - 8ms/step
# Epoch 3/25
# 653/653 - 5s - loss: 6.3406e-04 - val_loss: 0.0023 - 5s/epoch - 8ms/step
# Epoch 4/25
# 653/653 - 5s - loss: 0.0012 - val_loss: 0.0044 - 5s/epoch - 7ms/step
# Epoch 5/25
# 653/653 - 5s - loss: 0.0012 - val_loss: 0.0040 - 5s/epoch - 8ms/step
# Epoch 6/25
# 653/653 - 5s - loss: 0.0011 - val_loss: 0.0033 - 5s/epoch - 8ms/step
# Epoch 7/25
# 653/653 - 5s - loss: 8.6525e-04 - val_loss: 0.0025 - 5s/epoch - 8ms/step
# Epoch 8/25
# 653/653 - 5s - loss: 6.8789e-04 - val_loss: 0.0018 - 5s/epoch - 8ms/step
# Epoch 9/25
# 653/653 - 5s - loss: 5.3567e-04 - val_loss: 0.0012 - 5s/epoch - 8ms/step
# Epoch 10/25
# 653/653 - 5s - loss: 4.2573e-04 - val_loss: 7.7258e-04 - 5s/epoch - 8ms/step
# Epoch 11/25
# 653/653 - 6s - loss: 3.5044e-04 - val_loss: 5.0967e-04 - 6s/epoch - 9ms/step
# Epoch 12/25
# 653/653 - 5s - loss: 3.0579e-04 - val_loss: 3.7699e-04 - 5s/epoch - 8ms/step
# Epoch 13/25
# 653/653 - 5s - loss: 2.8235e-04 - val_loss: 3.1878e-04 - 5s/epoch - 8ms/step
# Epoch 14/25
# 653/653 - 5s - loss: 2.7557e-04 - val_loss: 3.1529e-04 - 5s/epoch - 8ms/step
# Epoch 15/25
# 653/653 - 5s - loss: 2.7470e-04 - val_loss: 3.0788e-04 - 5s/epoch - 8ms/step
# Epoch 16/25
# 653/653 - 5s - loss: 2.6830e-04 - val_loss: 2.9337e-04 - 5s/epoch - 8ms/step
# Epoch 17/25
# 653/653 - 5s - loss: 2.5889e-04 - val_loss: 2.7288e-04 - 5s/epoch - 8ms/step
# Epoch 18/25
# 653/653 - 5s - loss: 2.4478e-04 - val_loss: 2.3882e-04 - 5s/epoch - 7ms/step
# Epoch 19/25
# 653/653 - 5s - loss: 2.3182e-04 - val_loss: 2.1768e-04 - 5s/epoch - 8ms/step
# Epoch 20/25
# 653/653 - 5s - loss: 2.2072e-04 - val_loss: 1.9266e-04 - 5s/epoch - 8ms/step
# Epoch 21/25
# 653/653 - 5s - loss: 2.1093e-04 - val_loss: 1.7730e-04 - 5s/epoch - 8ms/step
# Epoch 22/25
# 653/653 - 5s - loss: 2.0325e-04 - val_loss: 1.6505e-04 - 5s/epoch - 8ms/step
# Epoch 23/25
# 653/653 - 5s - loss: 1.9615e-04 - val_loss: 1.5414e-04 - 5s/epoch - 8ms/step
# Epoch 24/25
# 653/653 - 5s - loss: 1.8987e-04 - val_loss: 1.4756e-04 - 5s/epoch - 8ms/step
# Epoch 25/25
# 653/653 - 5s - loss: 1.8409e-04 - val_loss: 1.3731e-04 - 5s/epoch - 8ms/step
# Epoch 1/25
# 2023-04-02 18:18:39.588369: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:18:39.670598: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:18:39.741003: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:18:44.657057: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:18:44.687405: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 653/653 - 6s - loss: 2.6421e-04 - val_loss: 0.0023 - 6s/epoch - 10ms/step
# Epoch 2/25
# 653/653 - 5s - loss: 3.6035e-04 - val_loss: 0.0023 - 5s/epoch - 8ms/step
# Epoch 3/25
# 653/653 - 5s - loss: 4.9908e-04 - val_loss: 0.0019 - 5s/epoch - 8ms/step
# Epoch 4/25
# 653/653 - 5s - loss: 7.3851e-04 - val_loss: 0.0032 - 5s/epoch - 8ms/step
# Epoch 5/25
# 653/653 - 5s - loss: 0.0013 - val_loss: 0.0050 - 5s/epoch - 8ms/step
# Epoch 6/25
# 653/653 - 5s - loss: 0.0014 - val_loss: 0.0045 - 5s/epoch - 8ms/step
# Epoch 7/25
# 653/653 - 5s - loss: 0.0012 - val_loss: 0.0036 - 5s/epoch - 8ms/step
# Epoch 8/25
# 653/653 - 5s - loss: 9.0471e-04 - val_loss: 0.0027 - 5s/epoch - 8ms/step
# Epoch 9/25
# 653/653 - 5s - loss: 7.0455e-04 - val_loss: 0.0019 - 5s/epoch - 8ms/step
# Epoch 10/25
# 653/653 - 5s - loss: 5.3481e-04 - val_loss: 0.0013 - 5s/epoch - 8ms/step
# Epoch 11/25
# 653/653 - 6s - loss: 4.0680e-04 - val_loss: 7.7123e-04 - 6s/epoch - 9ms/step
# Epoch 12/25
# 653/653 - 5s - loss: 3.1932e-04 - val_loss: 4.6149e-04 - 5s/epoch - 8ms/step
# Epoch 13/25
# 653/653 - 5s - loss: 2.6868e-04 - val_loss: 3.0871e-04 - 5s/epoch - 8ms/step
# Epoch 14/25
# 653/653 - 5s - loss: 2.4340e-04 - val_loss: 2.5018e-04 - 5s/epoch - 8ms/step
# Epoch 15/25
# 653/653 - 5s - loss: 2.3654e-04 - val_loss: 2.4790e-04 - 5s/epoch - 8ms/step
# Epoch 16/25
# 653/653 - 5s - loss: 2.4155e-04 - val_loss: 2.6664e-04 - 5s/epoch - 8ms/step
# Epoch 17/25
# 653/653 - 5s - loss: 2.4652e-04 - val_loss: 2.7003e-04 - 5s/epoch - 8ms/step
# Epoch 18/25
# 653/653 - 5s - loss: 2.4190e-04 - val_loss: 2.6196e-04 - 5s/epoch - 8ms/step
# Epoch 19/25
# 653/653 - 5s - loss: 2.3178e-04 - val_loss: 2.2778e-04 - 5s/epoch - 8ms/step
# Epoch 20/25
# 653/653 - 5s - loss: 2.1648e-04 - val_loss: 1.9854e-04 - 5s/epoch - 8ms/step
# Epoch 21/25
# 653/653 - 5s - loss: 2.0258e-04 - val_loss: 1.6666e-04 - 5s/epoch - 8ms/step
# Epoch 22/25
# 653/653 - 5s - loss: 1.9018e-04 - val_loss: 1.4454e-04 - 5s/epoch - 8ms/step
# Epoch 23/25
# 653/653 - 5s - loss: 1.8075e-04 - val_loss: 1.3067e-04 - 5s/epoch - 8ms/step
# Epoch 24/25
# 653/653 - 5s - loss: 1.7408e-04 - val_loss: 1.2173e-04 - 5s/epoch - 8ms/step
# Epoch 25/25
# 653/653 - 5s - loss: 1.6998e-04 - val_loss: 1.2186e-04 - 5s/epoch - 8ms/step
# Epoch 1/25
# 2023-04-02 18:20:52.881079: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:20:52.963445: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:20:53.066521: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:20:57.639318: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:20:57.669497: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 653/653 - 6s - loss: 3.4295e-04 - val_loss: 0.0035 - 6s/epoch - 9ms/step
# Epoch 2/25
# 653/653 - 5s - loss: 4.5605e-04 - val_loss: 0.0029 - 5s/epoch - 8ms/step
# Epoch 3/25
# 653/653 - 5s - loss: 5.7349e-04 - val_loss: 0.0022 - 5s/epoch - 8ms/step
# Epoch 4/25
# 653/653 - 5s - loss: 8.0665e-04 - val_loss: 0.0035 - 5s/epoch - 8ms/step
# Epoch 5/25
# 653/653 - 5s - loss: 0.0012 - val_loss: 0.0060 - 5s/epoch - 8ms/step
# Epoch 6/25
# 653/653 - 5s - loss: 0.0018 - val_loss: 0.0063 - 5s/epoch - 8ms/step
# Epoch 7/25
# 653/653 - 5s - loss: 0.0017 - val_loss: 0.0056 - 5s/epoch - 7ms/step
# Epoch 8/25
# 653/653 - 5s - loss: 0.0014 - val_loss: 0.0043 - 5s/epoch - 8ms/step
# Epoch 9/25
# 653/653 - 5s - loss: 0.0011 - val_loss: 0.0030 - 5s/epoch - 8ms/step
# Epoch 10/25
# 653/653 - 5s - loss: 8.3328e-04 - val_loss: 0.0020 - 5s/epoch - 8ms/step
# Epoch 11/25
# 653/653 - 5s - loss: 6.1097e-04 - val_loss: 0.0012 - 5s/epoch - 8ms/step
# Epoch 12/25
# 653/653 - 5s - loss: 4.5061e-04 - val_loss: 6.9607e-04 - 5s/epoch - 8ms/step
# Epoch 13/25
# 653/653 - 6s - loss: 3.4608e-04 - val_loss: 3.6778e-04 - 6s/epoch - 9ms/step
# Epoch 14/25
# 653/653 - 5s - loss: 2.8335e-04 - val_loss: 1.9636e-04 - 5s/epoch - 7ms/step
# Epoch 15/25
# 653/653 - 5s - loss: 2.4909e-04 - val_loss: 1.2604e-04 - 5s/epoch - 8ms/step
# Epoch 16/25
# 653/653 - 5s - loss: 2.3339e-04 - val_loss: 1.1006e-04 - 5s/epoch - 8ms/step
# Epoch 17/25
# 653/653 - 5s - loss: 2.2680e-04 - val_loss: 1.1076e-04 - 5s/epoch - 8ms/step
# Epoch 18/25
# 653/653 - 5s - loss: 2.2408e-04 - val_loss: 1.1810e-04 - 5s/epoch - 8ms/step
# Epoch 19/25
# 653/653 - 5s - loss: 2.2170e-04 - val_loss: 1.2550e-04 - 5s/epoch - 8ms/step
# Epoch 20/25
# 653/653 - 5s - loss: 2.1681e-04 - val_loss: 1.2623e-04 - 5s/epoch - 7ms/step
# Epoch 21/25
# 653/653 - 5s - loss: 2.0956e-04 - val_loss: 1.2070e-04 - 5s/epoch - 8ms/step
# Epoch 22/25
# 653/653 - 5s - loss: 2.0152e-04 - val_loss: 1.1220e-04 - 5s/epoch - 7ms/step
# Epoch 23/25
# 653/653 - 5s - loss: 1.9071e-04 - val_loss: 1.0093e-04 - 5s/epoch - 7ms/step
# Epoch 24/25
# 653/653 - 5s - loss: 1.8011e-04 - val_loss: 9.1111e-05 - 5s/epoch - 7ms/step
# Epoch 25/25
# 653/653 - 5s - loss: 1.7143e-04 - val_loss: 8.5439e-05 - 5s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-02 18:22:58.863521: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:22:58.940375: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:22:59.012765: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:23:03.795763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:23:03.826454: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 653/653 - 6s - loss: 2.9869e-04 - val_loss: 0.0025 - 6s/epoch - 9ms/step
# Epoch 2/50
# 653/653 - 5s - loss: 4.2162e-04 - val_loss: 0.0020 - 5s/epoch - 8ms/step
# Epoch 3/50
# 653/653 - 5s - loss: 5.6352e-04 - val_loss: 0.0020 - 5s/epoch - 8ms/step
# Epoch 4/50
# 653/653 - 5s - loss: 9.4894e-04 - val_loss: 0.0042 - 5s/epoch - 8ms/step
# Epoch 5/50
# 653/653 - 5s - loss: 0.0013 - val_loss: 0.0045 - 5s/epoch - 8ms/step
# Epoch 6/50
# 653/653 - 5s - loss: 0.0012 - val_loss: 0.0037 - 5s/epoch - 8ms/step
# Epoch 7/50
# 653/653 - 5s - loss: 9.4633e-04 - val_loss: 0.0029 - 5s/epoch - 8ms/step
# Epoch 8/50
# 653/653 - 6s - loss: 7.5996e-04 - val_loss: 0.0021 - 6s/epoch - 9ms/step
# Epoch 9/50
# 653/653 - 5s - loss: 5.9425e-04 - val_loss: 0.0014 - 5s/epoch - 8ms/step
# Epoch 10/50
# 653/653 - 5s - loss: 4.6153e-04 - val_loss: 9.3248e-04 - 5s/epoch - 8ms/step
# Epoch 11/50
# 653/653 - 5s - loss: 3.6811e-04 - val_loss: 5.8401e-04 - 5s/epoch - 8ms/step
# Epoch 12/50
# 653/653 - 5s - loss: 3.0811e-04 - val_loss: 3.8499e-04 - 5s/epoch - 8ms/step
# Epoch 13/50
# 653/653 - 5s - loss: 2.7460e-04 - val_loss: 2.9464e-04 - 5s/epoch - 8ms/step
# Epoch 14/50
# 653/653 - 5s - loss: 2.5916e-04 - val_loss: 2.5889e-04 - 5s/epoch - 8ms/step
# Epoch 15/50
# 653/653 - 5s - loss: 2.5533e-04 - val_loss: 2.5397e-04 - 5s/epoch - 8ms/step
# Epoch 16/50
# 653/653 - 5s - loss: 2.5591e-04 - val_loss: 2.5627e-04 - 5s/epoch - 8ms/step
# Epoch 17/50
# 653/653 - 5s - loss: 2.5224e-04 - val_loss: 2.4111e-04 - 5s/epoch - 8ms/step
# Epoch 18/50
# 653/653 - 5s - loss: 2.4149e-04 - val_loss: 2.2113e-04 - 5s/epoch - 8ms/step
# Epoch 19/50
# 653/653 - 5s - loss: 2.2940e-04 - val_loss: 1.9569e-04 - 5s/epoch - 8ms/step
# Epoch 20/50
# 653/653 - 5s - loss: 2.1801e-04 - val_loss: 1.7716e-04 - 5s/epoch - 8ms/step
# Epoch 21/50
# 653/653 - 5s - loss: 2.0846e-04 - val_loss: 1.5894e-04 - 5s/epoch - 8ms/step
# Epoch 22/50
# 653/653 - 5s - loss: 1.9908e-04 - val_loss: 1.4391e-04 - 5s/epoch - 8ms/step
# Epoch 23/50
# 653/653 - 5s - loss: 1.9077e-04 - val_loss: 1.3182e-04 - 5s/epoch - 8ms/step
# Epoch 24/50
# 653/653 - 5s - loss: 1.8372e-04 - val_loss: 1.2307e-04 - 5s/epoch - 8ms/step
# Epoch 25/50
# 653/653 - 5s - loss: 1.7769e-04 - val_loss: 1.1701e-04 - 5s/epoch - 8ms/step
# Epoch 26/50
# 653/653 - 5s - loss: 1.7250e-04 - val_loss: 1.1105e-04 - 5s/epoch - 8ms/step
# Epoch 27/50
# 653/653 - 5s - loss: 1.6768e-04 - val_loss: 1.0797e-04 - 5s/epoch - 8ms/step
# Epoch 28/50
# 653/653 - 6s - loss: 1.6336e-04 - val_loss: 1.0231e-04 - 6s/epoch - 9ms/step
# Epoch 29/50
# 653/653 - 5s - loss: 1.5810e-04 - val_loss: 9.7227e-05 - 5s/epoch - 8ms/step
# Epoch 30/50
# 653/653 - 5s - loss: 1.5314e-04 - val_loss: 9.2790e-05 - 5s/epoch - 8ms/step
# Epoch 31/50
# 653/653 - 5s - loss: 1.4912e-04 - val_loss: 9.0465e-05 - 5s/epoch - 8ms/step
# Epoch 32/50
# 653/653 - 6s - loss: 1.4582e-04 - val_loss: 8.7499e-05 - 6s/epoch - 8ms/step
# Epoch 33/50
# 653/653 - 5s - loss: 1.4218e-04 - val_loss: 8.4351e-05 - 5s/epoch - 8ms/step
# Epoch 34/50
# 653/653 - 5s - loss: 1.3848e-04 - val_loss: 8.1554e-05 - 5s/epoch - 8ms/step
# Epoch 35/50
# 653/653 - 6s - loss: 1.3511e-04 - val_loss: 7.8985e-05 - 6s/epoch - 9ms/step
# Epoch 36/50
# 653/653 - 6s - loss: 1.3196e-04 - val_loss: 7.7575e-05 - 6s/epoch - 9ms/step
# Epoch 37/50
# 653/653 - 5s - loss: 1.2929e-04 - val_loss: 7.5957e-05 - 5s/epoch - 8ms/step
# Epoch 38/50
# 653/653 - 5s - loss: 1.2641e-04 - val_loss: 7.4485e-05 - 5s/epoch - 8ms/step
# Epoch 39/50
# 653/653 - 5s - loss: 1.2376e-04 - val_loss: 7.2947e-05 - 5s/epoch - 8ms/step
# Epoch 40/50
# 653/653 - 6s - loss: 1.2117e-04 - val_loss: 7.1662e-05 - 6s/epoch - 8ms/step
# Epoch 41/50
# 653/653 - 5s - loss: 1.1894e-04 - val_loss: 7.0322e-05 - 5s/epoch - 8ms/step
# Epoch 42/50
# 653/653 - 5s - loss: 1.1678e-04 - val_loss: 6.9339e-05 - 5s/epoch - 8ms/step
# Epoch 43/50
# 653/653 - 5s - loss: 1.1479e-04 - val_loss: 6.8097e-05 - 5s/epoch - 8ms/step
# Epoch 44/50
# 653/653 - 5s - loss: 1.1268e-04 - val_loss: 6.6922e-05 - 5s/epoch - 8ms/step
# Epoch 45/50
# 653/653 - 5s - loss: 1.1074e-04 - val_loss: 6.5649e-05 - 5s/epoch - 8ms/step
# Epoch 46/50
# 653/653 - 5s - loss: 1.0869e-04 - val_loss: 6.4478e-05 - 5s/epoch - 8ms/step
# Epoch 47/50
# 653/653 - 5s - loss: 1.0688e-04 - val_loss: 6.3359e-05 - 5s/epoch - 8ms/step
# Epoch 48/50
# 653/653 - 5s - loss: 1.0502e-04 - val_loss: 6.2359e-05 - 5s/epoch - 8ms/step
# Epoch 49/50
# 653/653 - 5s - loss: 1.0334e-04 - val_loss: 6.1456e-05 - 5s/epoch - 8ms/step
# Epoch 50/50
# 653/653 - 5s - loss: 1.0163e-04 - val_loss: 6.0617e-05 - 5s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-02 18:27:18.669673: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:27:18.748840: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:27:18.821578: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:27:23.532922: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:27:23.563251: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 653/653 - 6s - loss: 2.7033e-04 - val_loss: 0.0023 - 6s/epoch - 9ms/step
# Epoch 2/50
# 653/653 - 5s - loss: 3.6090e-04 - val_loss: 0.0022 - 5s/epoch - 8ms/step
# Epoch 3/50
# 653/653 - 5s - loss: 5.1231e-04 - val_loss: 0.0018 - 5s/epoch - 8ms/step
# Epoch 4/50
# 653/653 - 5s - loss: 8.0337e-04 - val_loss: 0.0035 - 5s/epoch - 8ms/step
# Epoch 5/50
# 653/653 - 5s - loss: 0.0013 - val_loss: 0.0050 - 5s/epoch - 8ms/step
# Epoch 6/50
# 653/653 - 5s - loss: 0.0014 - val_loss: 0.0043 - 5s/epoch - 8ms/step
# Epoch 7/50
# 653/653 - 5s - loss: 0.0011 - val_loss: 0.0034 - 5s/epoch - 8ms/step
# Epoch 8/50
# 653/653 - 5s - loss: 8.7032e-04 - val_loss: 0.0025 - 5s/epoch - 8ms/step
# Epoch 9/50
# 653/653 - 5s - loss: 6.7830e-04 - val_loss: 0.0018 - 5s/epoch - 8ms/step
# Epoch 10/50
# 653/653 - 5s - loss: 5.1688e-04 - val_loss: 0.0012 - 5s/epoch - 8ms/step
# Epoch 11/50
# 653/653 - 5s - loss: 3.9825e-04 - val_loss: 7.1589e-04 - 5s/epoch - 8ms/step
# Epoch 12/50
# 653/653 - 5s - loss: 3.1786e-04 - val_loss: 4.3484e-04 - 5s/epoch - 8ms/step
# Epoch 13/50
# 653/653 - 5s - loss: 2.6940e-04 - val_loss: 2.9179e-04 - 5s/epoch - 8ms/step
# Epoch 14/50
# 653/653 - 5s - loss: 2.4566e-04 - val_loss: 2.4143e-04 - 5s/epoch - 8ms/step
# Epoch 15/50
# 653/653 - 5s - loss: 2.3883e-04 - val_loss: 2.3357e-04 - 5s/epoch - 8ms/step
# Epoch 16/50
# 653/653 - 5s - loss: 2.3986e-04 - val_loss: 2.4636e-04 - 5s/epoch - 8ms/step
# Epoch 17/50
# 653/653 - 6s - loss: 2.4356e-04 - val_loss: 2.5733e-04 - 6s/epoch - 9ms/step
# Epoch 18/50
# 653/653 - 5s - loss: 2.4149e-04 - val_loss: 2.4477e-04 - 5s/epoch - 8ms/step
# Epoch 19/50
# 653/653 - 6s - loss: 2.2871e-04 - val_loss: 2.1442e-04 - 6s/epoch - 9ms/step
# Epoch 20/50
# 653/653 - 6s - loss: 2.1356e-04 - val_loss: 1.8279e-04 - 6s/epoch - 9ms/step
# Epoch 21/50
# 653/653 - 5s - loss: 1.9980e-04 - val_loss: 1.5685e-04 - 5s/epoch - 8ms/step
# Epoch 22/50
# 653/653 - 5s - loss: 1.8956e-04 - val_loss: 1.4185e-04 - 5s/epoch - 8ms/step
# Epoch 23/50
# 653/653 - 6s - loss: 1.8256e-04 - val_loss: 1.3230e-04 - 6s/epoch - 9ms/step
# Epoch 24/50
# 653/653 - 6s - loss: 1.7727e-04 - val_loss: 1.2627e-04 - 6s/epoch - 9ms/step
# Epoch 25/50
# 653/653 - 5s - loss: 1.7287e-04 - val_loss: 1.2178e-04 - 5s/epoch - 8ms/step
# Epoch 26/50
# 653/653 - 5s - loss: 1.6786e-04 - val_loss: 1.1463e-04 - 5s/epoch - 8ms/step
# Epoch 27/50
# 653/653 - 5s - loss: 1.6250e-04 - val_loss: 1.0839e-04 - 5s/epoch - 8ms/step
# Epoch 28/50
# 653/653 - 5s - loss: 1.5772e-04 - val_loss: 1.0449e-04 - 5s/epoch - 8ms/step
# Epoch 29/50
# 653/653 - 5s - loss: 1.5348e-04 - val_loss: 9.9126e-05 - 5s/epoch - 8ms/step
# Epoch 30/50
# 653/653 - 5s - loss: 1.4870e-04 - val_loss: 9.4338e-05 - 5s/epoch - 8ms/step
# Epoch 31/50
# 653/653 - 5s - loss: 1.4451e-04 - val_loss: 9.1747e-05 - 5s/epoch - 8ms/step
# Epoch 32/50
# 653/653 - 5s - loss: 1.4111e-04 - val_loss: 8.8335e-05 - 5s/epoch - 8ms/step
# Epoch 33/50
# 653/653 - 5s - loss: 1.3735e-04 - val_loss: 8.5124e-05 - 5s/epoch - 8ms/step
# Epoch 34/50
# 653/653 - 5s - loss: 1.3413e-04 - val_loss: 8.2710e-05 - 5s/epoch - 8ms/step
# Epoch 35/50
# 653/653 - 5s - loss: 1.3127e-04 - val_loss: 8.0541e-05 - 5s/epoch - 8ms/step
# Epoch 36/50
# 653/653 - 5s - loss: 1.2880e-04 - val_loss: 7.9144e-05 - 5s/epoch - 8ms/step
# Epoch 37/50
# 653/653 - 5s - loss: 1.2643e-04 - val_loss: 7.7234e-05 - 5s/epoch - 8ms/step
# Epoch 38/50
# 653/653 - 5s - loss: 1.2415e-04 - val_loss: 7.5988e-05 - 5s/epoch - 8ms/step
# Epoch 39/50
# 653/653 - 5s - loss: 1.2190e-04 - val_loss: 7.4106e-05 - 5s/epoch - 8ms/step
# Epoch 40/50
# 653/653 - 5s - loss: 1.1957e-04 - val_loss: 7.2257e-05 - 5s/epoch - 8ms/step
# Epoch 41/50
# 653/653 - 5s - loss: 1.1731e-04 - val_loss: 7.0678e-05 - 5s/epoch - 8ms/step
# Epoch 42/50
# 653/653 - 5s - loss: 1.1526e-04 - val_loss: 6.9191e-05 - 5s/epoch - 8ms/step
# Epoch 43/50
# 653/653 - 5s - loss: 1.1336e-04 - val_loss: 6.8119e-05 - 5s/epoch - 8ms/step
# Epoch 44/50
# 653/653 - 5s - loss: 1.1164e-04 - val_loss: 6.6843e-05 - 5s/epoch - 8ms/step
# Epoch 45/50
# 653/653 - 5s - loss: 1.0983e-04 - val_loss: 6.5604e-05 - 5s/epoch - 8ms/step
# Epoch 46/50
# 653/653 - 5s - loss: 1.0813e-04 - val_loss: 6.4478e-05 - 5s/epoch - 8ms/step
# Epoch 47/50
# 653/653 - 5s - loss: 1.0649e-04 - val_loss: 6.3413e-05 - 5s/epoch - 8ms/step
# Epoch 48/50
# 653/653 - 5s - loss: 1.0494e-04 - val_loss: 6.2316e-05 - 5s/epoch - 8ms/step
# Epoch 49/50
# 653/653 - 5s - loss: 1.0339e-04 - val_loss: 6.1266e-05 - 5s/epoch - 8ms/step
# Epoch 50/50
# 653/653 - 5s - loss: 1.0196e-04 - val_loss: 6.0342e-05 - 5s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-02 18:31:41.442406: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:31:41.589879: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:31:41.672557: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:31:46.634324: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:31:46.665385: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 653/653 - 6s - loss: 3.4514e-04 - val_loss: 0.0033 - 6s/epoch - 10ms/step
# Epoch 2/50
# 653/653 - 5s - loss: 4.7610e-04 - val_loss: 0.0029 - 5s/epoch - 8ms/step
# Epoch 3/50
# 653/653 - 6s - loss: 6.1133e-04 - val_loss: 0.0023 - 6s/epoch - 8ms/step
# Epoch 4/50
# 653/653 - 5s - loss: 8.9207e-04 - val_loss: 0.0041 - 5s/epoch - 8ms/step
# Epoch 5/50
# 653/653 - 5s - loss: 0.0016 - val_loss: 0.0065 - 5s/epoch - 8ms/step
# Epoch 6/50
# 653/653 - 5s - loss: 0.0018 - val_loss: 0.0060 - 5s/epoch - 8ms/step
# Epoch 7/50
# 653/653 - 5s - loss: 0.0016 - val_loss: 0.0051 - 5s/epoch - 7ms/step
# Epoch 8/50
# 653/653 - 5s - loss: 0.0013 - val_loss: 0.0039 - 5s/epoch - 8ms/step
# Epoch 9/50
# 653/653 - 6s - loss: 0.0010 - val_loss: 0.0027 - 6s/epoch - 9ms/step
# Epoch 10/50
# 653/653 - 6s - loss: 7.7300e-04 - val_loss: 0.0018 - 6s/epoch - 9ms/step
# Epoch 11/50
# 653/653 - 6s - loss: 5.7461e-04 - val_loss: 0.0011 - 6s/epoch - 9ms/step
# Epoch 12/50
# 653/653 - 5s - loss: 4.3294e-04 - val_loss: 6.3479e-04 - 5s/epoch - 8ms/step
# Epoch 13/50
# 653/653 - 5s - loss: 3.3797e-04 - val_loss: 3.3953e-04 - 5s/epoch - 8ms/step
# Epoch 14/50
# 653/653 - 5s - loss: 2.8192e-04 - val_loss: 1.8876e-04 - 5s/epoch - 8ms/step
# Epoch 15/50
# 653/653 - 5s - loss: 2.4977e-04 - val_loss: 1.2811e-04 - 5s/epoch - 7ms/step
# Epoch 16/50
# 653/653 - 5s - loss: 2.3311e-04 - val_loss: 1.0655e-04 - 5s/epoch - 8ms/step
# Epoch 17/50
# 653/653 - 5s - loss: 2.2512e-04 - val_loss: 1.0512e-04 - 5s/epoch - 8ms/step
# Epoch 18/50
# 653/653 - 5s - loss: 2.2241e-04 - val_loss: 1.1193e-04 - 5s/epoch - 8ms/step
# Epoch 19/50
# 653/653 - 5s - loss: 2.1920e-04 - val_loss: 1.1586e-04 - 5s/epoch - 7ms/step
# Epoch 20/50
# 653/653 - 5s - loss: 2.1215e-04 - val_loss: 1.1172e-04 - 5s/epoch - 7ms/step
# Epoch 21/50
# 653/653 - 5s - loss: 2.0498e-04 - val_loss: 1.0694e-04 - 5s/epoch - 7ms/step
# Epoch 22/50
# 653/653 - 5s - loss: 1.9555e-04 - val_loss: 9.7955e-05 - 5s/epoch - 8ms/step
# Epoch 23/50
# 653/653 - 5s - loss: 1.8562e-04 - val_loss: 9.0295e-05 - 5s/epoch - 8ms/step
# Epoch 24/50
# 653/653 - 5s - loss: 1.7656e-04 - val_loss: 8.4597e-05 - 5s/epoch - 8ms/step
# Epoch 25/50
# 653/653 - 5s - loss: 1.6923e-04 - val_loss: 8.0704e-05 - 5s/epoch - 8ms/step
# Epoch 26/50
# 653/653 - 5s - loss: 1.6289e-04 - val_loss: 7.9884e-05 - 5s/epoch - 8ms/step
# Epoch 27/50
# 653/653 - 5s - loss: 1.5873e-04 - val_loss: 7.9861e-05 - 5s/epoch - 7ms/step
# Epoch 28/50
# 653/653 - 5s - loss: 1.5401e-04 - val_loss: 7.8426e-05 - 5s/epoch - 7ms/step
# Epoch 29/50
# 653/653 - 5s - loss: 1.4862e-04 - val_loss: 7.7140e-05 - 5s/epoch - 7ms/step
# Epoch 30/50
# 653/653 - 5s - loss: 1.4394e-04 - val_loss: 7.6949e-05 - 5s/epoch - 7ms/step
# Epoch 31/50
# 653/653 - 5s - loss: 1.4025e-04 - val_loss: 7.6778e-05 - 5s/epoch - 7ms/step
# Epoch 32/50
# 653/653 - 5s - loss: 1.3651e-04 - val_loss: 7.6765e-05 - 5s/epoch - 7ms/step
# Epoch 33/50
# 653/653 - 5s - loss: 1.3299e-04 - val_loss: 7.6987e-05 - 5s/epoch - 7ms/step
# Epoch 34/50
# 653/653 - 5s - loss: 1.2988e-04 - val_loss: 7.7487e-05 - 5s/epoch - 7ms/step
# Epoch 35/50
# 653/653 - 5s - loss: 1.2696e-04 - val_loss: 7.7756e-05 - 5s/epoch - 7ms/step
# Epoch 36/50
# 653/653 - 5s - loss: 1.2412e-04 - val_loss: 7.7977e-05 - 5s/epoch - 8ms/step
# Epoch 37/50
# 653/653 - 5s - loss: 1.2151e-04 - val_loss: 7.8108e-05 - 5s/epoch - 8ms/step
# Epoch 38/50
# 653/653 - 5s - loss: 1.1904e-04 - val_loss: 7.8263e-05 - 5s/epoch - 8ms/step
# Epoch 39/50
# 653/653 - 5s - loss: 1.1682e-04 - val_loss: 7.8373e-05 - 5s/epoch - 8ms/step
# Epoch 40/50
# 653/653 - 5s - loss: 1.1477e-04 - val_loss: 7.8402e-05 - 5s/epoch - 8ms/step
# Epoch 41/50
# 653/653 - 5s - loss: 1.1286e-04 - val_loss: 7.8307e-05 - 5s/epoch - 8ms/step
# Epoch 42/50
# 653/653 - 5s - loss: 1.1088e-04 - val_loss: 7.7522e-05 - 5s/epoch - 8ms/step
# Epoch 43/50
# 653/653 - 5s - loss: 1.0896e-04 - val_loss: 7.6875e-05 - 5s/epoch - 7ms/step
# Epoch 44/50
# 653/653 - 5s - loss: 1.0718e-04 - val_loss: 7.5803e-05 - 5s/epoch - 7ms/step
# Epoch 45/50
# 653/653 - 5s - loss: 1.0542e-04 - val_loss: 7.4540e-05 - 5s/epoch - 7ms/step
# Epoch 46/50
# 653/653 - 5s - loss: 1.0379e-04 - val_loss: 7.3384e-05 - 5s/epoch - 7ms/step
# Epoch 47/50
# 653/653 - 5s - loss: 1.0234e-04 - val_loss: 7.2485e-05 - 5s/epoch - 7ms/step
# Epoch 48/50
# 653/653 - 5s - loss: 1.0115e-04 - val_loss: 7.2059e-05 - 5s/epoch - 7ms/step
# Epoch 49/50
# 653/653 - 5s - loss: 1.0007e-04 - val_loss: 7.1978e-05 - 5s/epoch - 7ms/step
# Epoch 50/50
# 653/653 - 5s - loss: 9.8894e-05 - val_loss: 7.1842e-05 - 5s/epoch - 7ms/step
# Epoch 1/100
# 2023-04-02 18:35:53.965899: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:35:54.043771: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:35:54.123106: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:35:58.785461: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:35:58.815534: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 653/653 - 6s - loss: 3.0752e-04 - val_loss: 0.0026 - 6s/epoch - 9ms/step
# Epoch 2/100
# 653/653 - 5s - loss: 4.5606e-04 - val_loss: 0.0018 - 5s/epoch - 8ms/step
# Epoch 3/100
# 653/653 - 5s - loss: 6.0844e-04 - val_loss: 0.0023 - 5s/epoch - 8ms/step
# Epoch 4/100
# 653/653 - 5s - loss: 0.0012 - val_loss: 0.0044 - 5s/epoch - 8ms/step
# Epoch 5/100
# 653/653 - 5s - loss: 0.0012 - val_loss: 0.0040 - 5s/epoch - 8ms/step
# Epoch 6/100
# 653/653 - 5s - loss: 0.0010 - val_loss: 0.0033 - 5s/epoch - 8ms/step
# Epoch 7/100
# 653/653 - 5s - loss: 8.5538e-04 - val_loss: 0.0025 - 5s/epoch - 8ms/step
# Epoch 8/100
# 653/653 - 5s - loss: 6.8084e-04 - val_loss: 0.0018 - 5s/epoch - 8ms/step
# Epoch 9/100
# 653/653 - 5s - loss: 5.3592e-04 - val_loss: 0.0012 - 5s/epoch - 8ms/step
# Epoch 10/100
# 653/653 - 5s - loss: 4.2414e-04 - val_loss: 7.8890e-04 - 5s/epoch - 8ms/step
# Epoch 11/100
# 653/653 - 5s - loss: 3.4666e-04 - val_loss: 5.2015e-04 - 5s/epoch - 8ms/step
# Epoch 12/100
# 653/653 - 5s - loss: 3.0063e-04 - val_loss: 3.7999e-04 - 5s/epoch - 8ms/step
# Epoch 13/100
# 653/653 - 5s - loss: 2.7747e-04 - val_loss: 3.2177e-04 - 5s/epoch - 8ms/step
# Epoch 14/100
# 653/653 - 5s - loss: 2.7215e-04 - val_loss: 3.1631e-04 - 5s/epoch - 8ms/step
# Epoch 15/100
# 653/653 - 5s - loss: 2.7327e-04 - val_loss: 3.1383e-04 - 5s/epoch - 8ms/step
# Epoch 16/100
# 653/653 - 5s - loss: 2.7152e-04 - val_loss: 3.0724e-04 - 5s/epoch - 8ms/step
# Epoch 17/100
# 653/653 - 5s - loss: 2.6300e-04 - val_loss: 2.7984e-04 - 5s/epoch - 8ms/step
# Epoch 18/100
# 653/653 - 5s - loss: 2.4760e-04 - val_loss: 2.3904e-04 - 5s/epoch - 8ms/step
# Epoch 19/100
# 653/653 - 5s - loss: 2.3211e-04 - val_loss: 2.0813e-04 - 5s/epoch - 8ms/step
# Epoch 20/100
# 653/653 - 5s - loss: 2.1954e-04 - val_loss: 1.8050e-04 - 5s/epoch - 8ms/step
# Epoch 21/100
# 653/653 - 5s - loss: 2.0912e-04 - val_loss: 1.6381e-04 - 5s/epoch - 8ms/step
# Epoch 22/100
# 653/653 - 5s - loss: 2.0224e-04 - val_loss: 1.5380e-04 - 5s/epoch - 8ms/step
# Epoch 23/100
# 653/653 - 5s - loss: 1.9586e-04 - val_loss: 1.4296e-04 - 5s/epoch - 8ms/step
# Epoch 24/100
# 653/653 - 5s - loss: 1.9013e-04 - val_loss: 1.3901e-04 - 5s/epoch - 8ms/step
# Epoch 25/100
# 653/653 - 5s - loss: 1.8529e-04 - val_loss: 1.3045e-04 - 5s/epoch - 8ms/step
# Epoch 26/100
# 653/653 - 5s - loss: 1.7873e-04 - val_loss: 1.2276e-04 - 5s/epoch - 8ms/step
# Epoch 27/100
# 653/653 - 5s - loss: 1.7275e-04 - val_loss: 1.1501e-04 - 5s/epoch - 8ms/step
# Epoch 28/100
# 653/653 - 5s - loss: 1.6677e-04 - val_loss: 1.0881e-04 - 5s/epoch - 8ms/step
# Epoch 29/100
# 653/653 - 5s - loss: 1.6156e-04 - val_loss: 1.0399e-04 - 5s/epoch - 8ms/step
# Epoch 30/100
# 653/653 - 5s - loss: 1.5710e-04 - val_loss: 1.0036e-04 - 5s/epoch - 8ms/step
# Epoch 31/100
# 653/653 - 5s - loss: 1.5307e-04 - val_loss: 9.8507e-05 - 5s/epoch - 8ms/step
# Epoch 32/100
# 653/653 - 5s - loss: 1.4986e-04 - val_loss: 9.7146e-05 - 5s/epoch - 8ms/step
# Epoch 33/100
# 653/653 - 5s - loss: 1.4607e-04 - val_loss: 9.3799e-05 - 5s/epoch - 8ms/step
# Epoch 34/100
# 653/653 - 5s - loss: 1.4186e-04 - val_loss: 9.0556e-05 - 5s/epoch - 8ms/step
# Epoch 35/100
# 653/653 - 5s - loss: 1.3814e-04 - val_loss: 8.9453e-05 - 5s/epoch - 8ms/step
# Epoch 36/100
# 653/653 - 5s - loss: 1.3501e-04 - val_loss: 8.7109e-05 - 5s/epoch - 8ms/step
# Epoch 37/100
# 653/653 - 5s - loss: 1.3164e-04 - val_loss: 8.5848e-05 - 5s/epoch - 8ms/step
# Epoch 38/100
# 653/653 - 5s - loss: 1.2880e-04 - val_loss: 8.4810e-05 - 5s/epoch - 8ms/step
# Epoch 39/100
# 653/653 - 5s - loss: 1.2593e-04 - val_loss: 8.3744e-05 - 5s/epoch - 8ms/step
# Epoch 40/100
# 653/653 - 5s - loss: 1.2312e-04 - val_loss: 8.2784e-05 - 5s/epoch - 8ms/step
# Epoch 41/100
# 653/653 - 5s - loss: 1.2044e-04 - val_loss: 8.2110e-05 - 5s/epoch - 8ms/step
# Epoch 42/100
# 653/653 - 5s - loss: 1.1810e-04 - val_loss: 8.1855e-05 - 5s/epoch - 8ms/step
# Epoch 43/100
# 653/653 - 5s - loss: 1.1589e-04 - val_loss: 8.1157e-05 - 5s/epoch - 8ms/step
# Epoch 44/100
# 653/653 - 5s - loss: 1.1375e-04 - val_loss: 8.0727e-05 - 5s/epoch - 8ms/step
# Epoch 45/100
# 653/653 - 5s - loss: 1.1173e-04 - val_loss: 7.9959e-05 - 5s/epoch - 8ms/step
# Epoch 46/100
# 653/653 - 5s - loss: 1.0984e-04 - val_loss: 7.9423e-05 - 5s/epoch - 8ms/step
# Epoch 47/100
# 653/653 - 5s - loss: 1.0805e-04 - val_loss: 7.8611e-05 - 5s/epoch - 8ms/step
# Epoch 48/100
# 653/653 - 5s - loss: 1.0625e-04 - val_loss: 7.7728e-05 - 5s/epoch - 8ms/step
# Epoch 49/100
# 653/653 - 5s - loss: 1.0451e-04 - val_loss: 7.6638e-05 - 5s/epoch - 8ms/step
# Epoch 50/100
# 653/653 - 5s - loss: 1.0279e-04 - val_loss: 7.5594e-05 - 5s/epoch - 8ms/step
# Epoch 51/100
# 653/653 - 5s - loss: 1.0117e-04 - val_loss: 7.4491e-05 - 5s/epoch - 8ms/step
# Epoch 52/100
# 653/653 - 5s - loss: 9.9619e-05 - val_loss: 7.3457e-05 - 5s/epoch - 8ms/step
# Epoch 53/100
# 653/653 - 5s - loss: 9.8153e-05 - val_loss: 7.2364e-05 - 5s/epoch - 8ms/step
# Epoch 54/100
# 653/653 - 5s - loss: 9.6728e-05 - val_loss: 7.1308e-05 - 5s/epoch - 8ms/step
# Epoch 55/100
# 653/653 - 5s - loss: 9.5365e-05 - val_loss: 7.0176e-05 - 5s/epoch - 8ms/step
# Epoch 56/100
# 653/653 - 5s - loss: 9.4042e-05 - val_loss: 6.9102e-05 - 5s/epoch - 8ms/step
# Epoch 57/100
# 653/653 - 5s - loss: 9.2779e-05 - val_loss: 6.7967e-05 - 5s/epoch - 8ms/step
# Epoch 58/100
# 653/653 - 5s - loss: 9.1558e-05 - val_loss: 6.6915e-05 - 5s/epoch - 8ms/step
# Epoch 59/100
# 653/653 - 5s - loss: 9.0402e-05 - val_loss: 6.5821e-05 - 5s/epoch - 8ms/step
# Epoch 60/100
# 653/653 - 5s - loss: 8.9275e-05 - val_loss: 6.4807e-05 - 5s/epoch - 8ms/step
# Epoch 61/100
# 653/653 - 5s - loss: 8.8204e-05 - val_loss: 6.3744e-05 - 5s/epoch - 8ms/step
# Epoch 62/100
# 653/653 - 5s - loss: 8.7156e-05 - val_loss: 6.2793e-05 - 5s/epoch - 8ms/step
# Epoch 63/100
# 653/653 - 5s - loss: 8.6150e-05 - val_loss: 6.1749e-05 - 5s/epoch - 8ms/step
# Epoch 64/100
# 653/653 - 5s - loss: 8.5173e-05 - val_loss: 6.0853e-05 - 5s/epoch - 8ms/step
# Epoch 65/100
# 653/653 - 5s - loss: 8.4252e-05 - val_loss: 5.9924e-05 - 5s/epoch - 8ms/step
# Epoch 66/100
# 653/653 - 5s - loss: 8.3370e-05 - val_loss: 5.9126e-05 - 5s/epoch - 8ms/step
# Epoch 67/100
# 653/653 - 5s - loss: 8.2507e-05 - val_loss: 5.8238e-05 - 5s/epoch - 8ms/step
# Epoch 68/100
# 653/653 - 5s - loss: 8.1653e-05 - val_loss: 5.7430e-05 - 5s/epoch - 8ms/step
# Epoch 69/100
# 653/653 - 5s - loss: 8.0831e-05 - val_loss: 5.6587e-05 - 5s/epoch - 8ms/step
# Epoch 70/100
# 653/653 - 5s - loss: 8.0042e-05 - val_loss: 5.5875e-05 - 5s/epoch - 8ms/step
# Epoch 71/100
# 653/653 - 5s - loss: 7.9298e-05 - val_loss: 5.5172e-05 - 5s/epoch - 8ms/step
# Epoch 72/100
# 653/653 - 5s - loss: 7.8574e-05 - val_loss: 5.4485e-05 - 5s/epoch - 8ms/step
# Epoch 73/100
# 653/653 - 5s - loss: 7.7864e-05 - val_loss: 5.3795e-05 - 5s/epoch - 8ms/step
# Epoch 74/100
# 653/653 - 5s - loss: 7.7166e-05 - val_loss: 5.3122e-05 - 5s/epoch - 8ms/step
# Epoch 75/100
# 653/653 - 5s - loss: 7.6491e-05 - val_loss: 5.2480e-05 - 5s/epoch - 8ms/step
# Epoch 76/100
# 653/653 - 5s - loss: 7.5844e-05 - val_loss: 5.1858e-05 - 5s/epoch - 8ms/step
# Epoch 77/100
# 653/653 - 5s - loss: 7.5216e-05 - val_loss: 5.1252e-05 - 5s/epoch - 8ms/step
# Epoch 78/100
# 653/653 - 5s - loss: 7.4601e-05 - val_loss: 5.0607e-05 - 5s/epoch - 8ms/step
# Epoch 79/100
# 653/653 - 5s - loss: 7.4007e-05 - val_loss: 5.0015e-05 - 5s/epoch - 8ms/step
# Epoch 80/100
# 653/653 - 5s - loss: 7.3441e-05 - val_loss: 4.9407e-05 - 5s/epoch - 8ms/step
# Epoch 81/100
# 653/653 - 5s - loss: 7.2870e-05 - val_loss: 4.8750e-05 - 5s/epoch - 8ms/step
# Epoch 82/100
# 653/653 - 5s - loss: 7.2304e-05 - val_loss: 4.8075e-05 - 5s/epoch - 8ms/step
# Epoch 83/100
# 653/653 - 5s - loss: 7.1751e-05 - val_loss: 4.7376e-05 - 5s/epoch - 8ms/step
# Epoch 84/100
# 653/653 - 5s - loss: 7.1214e-05 - val_loss: 4.6688e-05 - 5s/epoch - 8ms/step
# Epoch 85/100
# 653/653 - 5s - loss: 7.0702e-05 - val_loss: 4.6010e-05 - 5s/epoch - 8ms/step
# Epoch 86/100
# 653/653 - 5s - loss: 7.0199e-05 - val_loss: 4.5292e-05 - 5s/epoch - 8ms/step
# Epoch 87/100
# 653/653 - 5s - loss: 6.9689e-05 - val_loss: 4.4541e-05 - 5s/epoch - 8ms/step
# Epoch 88/100
# 653/653 - 5s - loss: 6.9187e-05 - val_loss: 4.3791e-05 - 5s/epoch - 8ms/step
# Epoch 89/100
# 653/653 - 5s - loss: 6.8703e-05 - val_loss: 4.3045e-05 - 5s/epoch - 8ms/step
# Epoch 90/100
# 653/653 - 5s - loss: 6.8231e-05 - val_loss: 4.2292e-05 - 5s/epoch - 8ms/step
# Epoch 91/100
# 653/653 - 5s - loss: 6.7761e-05 - val_loss: 4.1522e-05 - 5s/epoch - 8ms/step
# Epoch 92/100
# 653/653 - 5s - loss: 6.7294e-05 - val_loss: 4.0742e-05 - 5s/epoch - 8ms/step
# Epoch 93/100
# 653/653 - 5s - loss: 6.6836e-05 - val_loss: 3.9964e-05 - 5s/epoch - 8ms/step
# Epoch 94/100
# 653/653 - 5s - loss: 6.6391e-05 - val_loss: 3.9191e-05 - 5s/epoch - 8ms/step
# Epoch 95/100
# 653/653 - 5s - loss: 6.5954e-05 - val_loss: 3.8415e-05 - 5s/epoch - 8ms/step
# Epoch 96/100
# 653/653 - 5s - loss: 6.5522e-05 - val_loss: 3.7636e-05 - 5s/epoch - 8ms/step
# Epoch 97/100
# 653/653 - 5s - loss: 6.5093e-05 - val_loss: 3.6855e-05 - 5s/epoch - 8ms/step
# Epoch 98/100
# 653/653 - 5s - loss: 6.4669e-05 - val_loss: 3.6077e-05 - 5s/epoch - 8ms/step
# Epoch 99/100
# 653/653 - 5s - loss: 6.4253e-05 - val_loss: 3.5306e-05 - 5s/epoch - 8ms/step
# Epoch 100/100
# 653/653 - 5s - loss: 6.3845e-05 - val_loss: 3.4542e-05 - 5s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-02 18:44:14.635339: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:44:14.718766: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:44:14.801589: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:44:19.577109: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:44:19.607477: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 653/653 - 6s - loss: 2.6625e-04 - val_loss: 0.0022 - 6s/epoch - 9ms/step
# Epoch 2/100
# 653/653 - 5s - loss: 3.5759e-04 - val_loss: 0.0022 - 5s/epoch - 8ms/step
# Epoch 3/100
# 653/653 - 5s - loss: 4.8703e-04 - val_loss: 0.0017 - 5s/epoch - 8ms/step
# Epoch 4/100
# 653/653 - 5s - loss: 6.7274e-04 - val_loss: 0.0027 - 5s/epoch - 8ms/step
# Epoch 5/100
# 653/653 - 5s - loss: 0.0013 - val_loss: 0.0045 - 5s/epoch - 8ms/step
# Epoch 6/100
# 653/653 - 5s - loss: 0.0012 - val_loss: 0.0040 - 5s/epoch - 8ms/step
# Epoch 7/100
# 653/653 - 5s - loss: 0.0011 - val_loss: 0.0032 - 5s/epoch - 8ms/step
# Epoch 8/100
# 653/653 - 5s - loss: 8.7422e-04 - val_loss: 0.0024 - 5s/epoch - 8ms/step
# Epoch 9/100
# 653/653 - 5s - loss: 6.7233e-04 - val_loss: 0.0017 - 5s/epoch - 8ms/step
# Epoch 10/100
# 653/653 - 5s - loss: 5.2702e-04 - val_loss: 0.0011 - 5s/epoch - 8ms/step
# Epoch 11/100
# 653/653 - 5s - loss: 4.0939e-04 - val_loss: 7.0578e-04 - 5s/epoch - 8ms/step
# Epoch 12/100
# 653/653 - 5s - loss: 3.3229e-04 - val_loss: 4.3692e-04 - 5s/epoch - 8ms/step
# Epoch 13/100
# 653/653 - 5s - loss: 2.8214e-04 - val_loss: 2.9093e-04 - 5s/epoch - 8ms/step
# Epoch 14/100
# 653/653 - 5s - loss: 2.5757e-04 - val_loss: 2.3433e-04 - 5s/epoch - 8ms/step
# Epoch 15/100
# 653/653 - 5s - loss: 2.4717e-04 - val_loss: 2.1687e-04 - 5s/epoch - 8ms/step
# Epoch 16/100
# 653/653 - 5s - loss: 2.4503e-04 - val_loss: 2.2395e-04 - 5s/epoch - 8ms/step
# Epoch 17/100
# 653/653 - 5s - loss: 2.4847e-04 - val_loss: 2.2944e-04 - 5s/epoch - 8ms/step
# Epoch 18/100
# 653/653 - 5s - loss: 2.4391e-04 - val_loss: 2.2009e-04 - 5s/epoch - 8ms/step
# Epoch 19/100
# 653/653 - 5s - loss: 2.3409e-04 - val_loss: 1.9447e-04 - 5s/epoch - 8ms/step
# Epoch 20/100
# 653/653 - 5s - loss: 2.1944e-04 - val_loss: 1.6396e-04 - 5s/epoch - 8ms/step
# Epoch 21/100
# 653/653 - 5s - loss: 2.0634e-04 - val_loss: 1.4397e-04 - 5s/epoch - 8ms/step
# Epoch 22/100
# 653/653 - 5s - loss: 1.9667e-04 - val_loss: 1.2703e-04 - 5s/epoch - 8ms/step
# Epoch 23/100
# 653/653 - 5s - loss: 1.8779e-04 - val_loss: 1.1558e-04 - 5s/epoch - 8ms/step
# Epoch 24/100
# 653/653 - 5s - loss: 1.8072e-04 - val_loss: 1.0729e-04 - 5s/epoch - 8ms/step
# Epoch 25/100
# 653/653 - 5s - loss: 1.7587e-04 - val_loss: 1.0649e-04 - 5s/epoch - 8ms/step
# Epoch 26/100
# 653/653 - 5s - loss: 1.7294e-04 - val_loss: 1.0433e-04 - 5s/epoch - 8ms/step
# Epoch 27/100
# 653/653 - 6s - loss: 1.6848e-04 - val_loss: 9.9841e-05 - 6s/epoch - 8ms/step
# Epoch 28/100
# 653/653 - 5s - loss: 1.6319e-04 - val_loss: 9.4048e-05 - 5s/epoch - 8ms/step
# Epoch 29/100
# 653/653 - 6s - loss: 1.5751e-04 - val_loss: 8.9271e-05 - 6s/epoch - 9ms/step
# Epoch 30/100
# 653/653 - 5s - loss: 1.5220e-04 - val_loss: 8.3929e-05 - 5s/epoch - 8ms/step
# Epoch 31/100
# 653/653 - 6s - loss: 1.4742e-04 - val_loss: 8.1520e-05 - 6s/epoch - 8ms/step
# Epoch 32/100
# 653/653 - 6s - loss: 1.4423e-04 - val_loss: 8.1147e-05 - 6s/epoch - 9ms/step
# Epoch 33/100
# 653/653 - 6s - loss: 1.4142e-04 - val_loss: 8.0375e-05 - 6s/epoch - 8ms/step
# Epoch 34/100
# 653/653 - 6s - loss: 1.3827e-04 - val_loss: 7.8938e-05 - 6s/epoch - 9ms/step
# Epoch 35/100
# 653/653 - 6s - loss: 1.3486e-04 - val_loss: 7.7448e-05 - 6s/epoch - 8ms/step
# Epoch 36/100
# 653/653 - 6s - loss: 1.3170e-04 - val_loss: 7.6390e-05 - 6s/epoch - 8ms/step
# Epoch 37/100
# 653/653 - 5s - loss: 1.2864e-04 - val_loss: 7.5327e-05 - 5s/epoch - 8ms/step
# Epoch 38/100
# 653/653 - 6s - loss: 1.2577e-04 - val_loss: 7.4298e-05 - 6s/epoch - 9ms/step
# Epoch 39/100
# 653/653 - 6s - loss: 1.2327e-04 - val_loss: 7.3905e-05 - 6s/epoch - 9ms/step
# Epoch 40/100
# 653/653 - 5s - loss: 1.2108e-04 - val_loss: 7.3264e-05 - 5s/epoch - 8ms/step
# Epoch 41/100
# 653/653 - 5s - loss: 1.1902e-04 - val_loss: 7.2863e-05 - 5s/epoch - 8ms/step
# Epoch 42/100
# 653/653 - 5s - loss: 1.1706e-04 - val_loss: 7.2116e-05 - 5s/epoch - 8ms/step
# Epoch 43/100
# 653/653 - 6s - loss: 1.1503e-04 - val_loss: 7.1165e-05 - 6s/epoch - 8ms/step
# Epoch 44/100
# 653/653 - 5s - loss: 1.1303e-04 - val_loss: 7.0044e-05 - 5s/epoch - 8ms/step
# Epoch 45/100
# 653/653 - 5s - loss: 1.1112e-04 - val_loss: 6.9024e-05 - 5s/epoch - 8ms/step
# Epoch 46/100
# 653/653 - 5s - loss: 1.0932e-04 - val_loss: 6.7964e-05 - 5s/epoch - 8ms/step
# Epoch 47/100
# 653/653 - 5s - loss: 1.0763e-04 - val_loss: 6.6985e-05 - 5s/epoch - 8ms/step
# Epoch 48/100
# 653/653 - 5s - loss: 1.0599e-04 - val_loss: 6.5817e-05 - 5s/epoch - 8ms/step
# Epoch 49/100
# 653/653 - 5s - loss: 1.0441e-04 - val_loss: 6.4754e-05 - 5s/epoch - 8ms/step
# Epoch 50/100
# 653/653 - 5s - loss: 1.0287e-04 - val_loss: 6.3539e-05 - 5s/epoch - 8ms/step
# Epoch 51/100
# 653/653 - 5s - loss: 1.0139e-04 - val_loss: 6.2470e-05 - 5s/epoch - 8ms/step
# Epoch 52/100
# 653/653 - 5s - loss: 9.9951e-05 - val_loss: 6.1295e-05 - 5s/epoch - 8ms/step
# Epoch 53/100
# 653/653 - 5s - loss: 9.8569e-05 - val_loss: 6.0295e-05 - 5s/epoch - 8ms/step
# Epoch 54/100
# 653/653 - 5s - loss: 9.7250e-05 - val_loss: 5.9257e-05 - 5s/epoch - 8ms/step
# Epoch 55/100
# 653/653 - 5s - loss: 9.5951e-05 - val_loss: 5.8324e-05 - 5s/epoch - 8ms/step
# Epoch 56/100
# 653/653 - 5s - loss: 9.4699e-05 - val_loss: 5.7395e-05 - 5s/epoch - 8ms/step
# Epoch 57/100
# 653/653 - 5s - loss: 9.3491e-05 - val_loss: 5.6616e-05 - 5s/epoch - 8ms/step
# Epoch 58/100
# 653/653 - 5s - loss: 9.2325e-05 - val_loss: 5.5859e-05 - 5s/epoch - 8ms/step
# Epoch 59/100
# 653/653 - 5s - loss: 9.1185e-05 - val_loss: 5.5239e-05 - 5s/epoch - 8ms/step
# Epoch 60/100
# 653/653 - 5s - loss: 9.0111e-05 - val_loss: 5.4716e-05 - 5s/epoch - 8ms/step
# Epoch 61/100
# 653/653 - 5s - loss: 8.9072e-05 - val_loss: 5.4274e-05 - 5s/epoch - 8ms/step
# Epoch 62/100
# 653/653 - 5s - loss: 8.8073e-05 - val_loss: 5.3927e-05 - 5s/epoch - 8ms/step
# Epoch 63/100
# 653/653 - 5s - loss: 8.7099e-05 - val_loss: 5.3632e-05 - 5s/epoch - 8ms/step
# Epoch 64/100
# 653/653 - 5s - loss: 8.6160e-05 - val_loss: 5.3409e-05 - 5s/epoch - 8ms/step
# Epoch 65/100
# 653/653 - 5s - loss: 8.5236e-05 - val_loss: 5.3226e-05 - 5s/epoch - 8ms/step
# Epoch 66/100
# 653/653 - 5s - loss: 8.4354e-05 - val_loss: 5.3079e-05 - 5s/epoch - 8ms/step
# Epoch 67/100
# 653/653 - 5s - loss: 8.3509e-05 - val_loss: 5.2964e-05 - 5s/epoch - 8ms/step
# Epoch 68/100
# 653/653 - 5s - loss: 8.2704e-05 - val_loss: 5.2880e-05 - 5s/epoch - 8ms/step
# Epoch 69/100
# 653/653 - 5s - loss: 8.1937e-05 - val_loss: 5.2844e-05 - 5s/epoch - 8ms/step
# Epoch 70/100
# 653/653 - 5s - loss: 8.1191e-05 - val_loss: 5.2772e-05 - 5s/epoch - 8ms/step
# Epoch 71/100
# 653/653 - 5s - loss: 8.0448e-05 - val_loss: 5.2678e-05 - 5s/epoch - 8ms/step
# Epoch 72/100
# 653/653 - 5s - loss: 7.9702e-05 - val_loss: 5.2515e-05 - 5s/epoch - 8ms/step
# Epoch 73/100
# 653/653 - 5s - loss: 7.8992e-05 - val_loss: 5.2385e-05 - 5s/epoch - 8ms/step
# Epoch 74/100
# 653/653 - 5s - loss: 7.8326e-05 - val_loss: 5.2257e-05 - 5s/epoch - 8ms/step
# Epoch 75/100
# 653/653 - 5s - loss: 7.7691e-05 - val_loss: 5.2120e-05 - 5s/epoch - 8ms/step
# Epoch 76/100
# 653/653 - 5s - loss: 7.7065e-05 - val_loss: 5.1902e-05 - 5s/epoch - 8ms/step
# Epoch 77/100
# 653/653 - 5s - loss: 7.6459e-05 - val_loss: 5.1701e-05 - 5s/epoch - 8ms/step
# Epoch 78/100
# 653/653 - 5s - loss: 7.5866e-05 - val_loss: 5.1428e-05 - 5s/epoch - 8ms/step
# Epoch 79/100
# 653/653 - 5s - loss: 7.5283e-05 - val_loss: 5.1132e-05 - 5s/epoch - 8ms/step
# Epoch 80/100
# 653/653 - 5s - loss: 7.4714e-05 - val_loss: 5.0766e-05 - 5s/epoch - 8ms/step
# Epoch 81/100
# 653/653 - 5s - loss: 7.4166e-05 - val_loss: 5.0387e-05 - 5s/epoch - 8ms/step
# Epoch 82/100
# 653/653 - 5s - loss: 7.3647e-05 - val_loss: 4.9971e-05 - 5s/epoch - 8ms/step
# Epoch 83/100
# 653/653 - 6s - loss: 7.3126e-05 - val_loss: 4.9498e-05 - 6s/epoch - 9ms/step
# Epoch 84/100
# 653/653 - 5s - loss: 7.2631e-05 - val_loss: 4.9013e-05 - 5s/epoch - 8ms/step
# Epoch 85/100
# 653/653 - 6s - loss: 7.2116e-05 - val_loss: 4.8422e-05 - 6s/epoch - 9ms/step
# Epoch 86/100
# 653/653 - 6s - loss: 7.1631e-05 - val_loss: 4.7846e-05 - 6s/epoch - 9ms/step
# Epoch 87/100
# 653/653 - 5s - loss: 7.1144e-05 - val_loss: 4.7207e-05 - 5s/epoch - 8ms/step
# Epoch 88/100
# 653/653 - 6s - loss: 7.0691e-05 - val_loss: 4.6580e-05 - 6s/epoch - 9ms/step
# Epoch 89/100
# 653/653 - 6s - loss: 7.0222e-05 - val_loss: 4.5877e-05 - 6s/epoch - 9ms/step
# Epoch 90/100
# 653/653 - 5s - loss: 6.9778e-05 - val_loss: 4.5183e-05 - 5s/epoch - 8ms/step
# Epoch 91/100
# 653/653 - 6s - loss: 6.9322e-05 - val_loss: 4.4428e-05 - 6s/epoch - 8ms/step
# Epoch 92/100
# 653/653 - 6s - loss: 6.8889e-05 - val_loss: 4.3677e-05 - 6s/epoch - 8ms/step
# Epoch 93/100
# 653/653 - 6s - loss: 6.8451e-05 - val_loss: 4.2893e-05 - 6s/epoch - 9ms/step
# Epoch 94/100
# 653/653 - 6s - loss: 6.8040e-05 - val_loss: 4.2119e-05 - 6s/epoch - 9ms/step
# Epoch 95/100
# 653/653 - 6s - loss: 6.7616e-05 - val_loss: 4.1294e-05 - 6s/epoch - 9ms/step
# Epoch 96/100
# 653/653 - 6s - loss: 6.7206e-05 - val_loss: 4.0478e-05 - 6s/epoch - 9ms/step
# Epoch 97/100
# 653/653 - 6s - loss: 6.6791e-05 - val_loss: 3.9643e-05 - 6s/epoch - 9ms/step
# Epoch 98/100
# 653/653 - 6s - loss: 6.6393e-05 - val_loss: 3.8818e-05 - 6s/epoch - 9ms/step
# Epoch 99/100
# 653/653 - 6s - loss: 6.5997e-05 - val_loss: 3.7988e-05 - 6s/epoch - 9ms/step
# Epoch 100/100
# 653/653 - 6s - loss: 6.5608e-05 - val_loss: 3.7164e-05 - 6s/epoch - 9ms/step
# Epoch 1/100
# 2023-04-02 18:53:09.139397: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:53:09.230449: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:53:09.342912: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:53:14.624927: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 18:53:14.658811: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 653/653 - 7s - loss: 3.4482e-04 - val_loss: 0.0032 - 7s/epoch - 10ms/step
# Epoch 2/100
# 653/653 - 5s - loss: 4.6480e-04 - val_loss: 0.0028 - 5s/epoch - 8ms/step
# Epoch 3/100
# 653/653 - 5s - loss: 5.8454e-04 - val_loss: 0.0022 - 5s/epoch - 8ms/step
# Epoch 4/100
# 653/653 - 5s - loss: 7.9235e-04 - val_loss: 0.0034 - 5s/epoch - 8ms/step
# Epoch 5/100
# 653/653 - 6s - loss: 0.0012 - val_loss: 0.0061 - 6s/epoch - 9ms/step
# Epoch 6/100
# 653/653 - 6s - loss: 0.0019 - val_loss: 0.0065 - 6s/epoch - 9ms/step
# Epoch 7/100
# 653/653 - 6s - loss: 0.0017 - val_loss: 0.0057 - 6s/epoch - 9ms/step
# Epoch 8/100
# 653/653 - 6s - loss: 0.0015 - val_loss: 0.0045 - 6s/epoch - 9ms/step
# Epoch 9/100
# 653/653 - 6s - loss: 0.0011 - val_loss: 0.0032 - 6s/epoch - 9ms/step
# Epoch 10/100
# 653/653 - 6s - loss: 8.7231e-04 - val_loss: 0.0021 - 6s/epoch - 9ms/step
# Epoch 11/100
# 653/653 - 6s - loss: 6.2650e-04 - val_loss: 0.0013 - 6s/epoch - 9ms/step
# Epoch 12/100
# 653/653 - 6s - loss: 4.6432e-04 - val_loss: 7.3758e-04 - 6s/epoch - 9ms/step
# Epoch 13/100
# 653/653 - 6s - loss: 3.5014e-04 - val_loss: 3.8432e-04 - 6s/epoch - 9ms/step
# Epoch 14/100
# 653/653 - 6s - loss: 2.8522e-04 - val_loss: 2.0139e-04 - 6s/epoch - 9ms/step
# Epoch 15/100
# 653/653 - 6s - loss: 2.4995e-04 - val_loss: 1.2838e-04 - 6s/epoch - 9ms/step
# Epoch 16/100
# 653/653 - 6s - loss: 2.3394e-04 - val_loss: 1.1054e-04 - 6s/epoch - 9ms/step
# Epoch 17/100
# 653/653 - 6s - loss: 2.2676e-04 - val_loss: 1.1030e-04 - 6s/epoch - 9ms/step
# Epoch 18/100
# 653/653 - 6s - loss: 2.2421e-04 - val_loss: 1.1853e-04 - 6s/epoch - 9ms/step
# Epoch 19/100
# 653/653 - 6s - loss: 2.2224e-04 - val_loss: 1.2663e-04 - 6s/epoch - 9ms/step
# Epoch 20/100
# 653/653 - 6s - loss: 2.1739e-04 - val_loss: 1.2771e-04 - 6s/epoch - 9ms/step
# Epoch 21/100
# 653/653 - 6s - loss: 2.0915e-04 - val_loss: 1.2008e-04 - 6s/epoch - 9ms/step
# Epoch 22/100
# 653/653 - 6s - loss: 1.9893e-04 - val_loss: 1.1246e-04 - 6s/epoch - 9ms/step
# Epoch 23/100
# 653/653 - 5s - loss: 1.9002e-04 - val_loss: 1.0446e-04 - 5s/epoch - 8ms/step
# Epoch 24/100
# 653/653 - 6s - loss: 1.8122e-04 - val_loss: 9.7961e-05 - 6s/epoch - 9ms/step
# Epoch 25/100
# 653/653 - 6s - loss: 1.7409e-04 - val_loss: 9.3503e-05 - 6s/epoch - 8ms/step
# Epoch 26/100
# 653/653 - 6s - loss: 1.6785e-04 - val_loss: 8.9677e-05 - 6s/epoch - 8ms/step
# Epoch 27/100
# 653/653 - 6s - loss: 1.6126e-04 - val_loss: 8.5910e-05 - 6s/epoch - 8ms/step
# Epoch 28/100
# 653/653 - 6s - loss: 1.5516e-04 - val_loss: 8.2707e-05 - 6s/epoch - 9ms/step
# Epoch 29/100
# 653/653 - 5s - loss: 1.4991e-04 - val_loss: 8.1493e-05 - 5s/epoch - 8ms/step
# Epoch 30/100
# 653/653 - 6s - loss: 1.4576e-04 - val_loss: 8.0754e-05 - 6s/epoch - 9ms/step
# Epoch 31/100
# 653/653 - 5s - loss: 1.4188e-04 - val_loss: 8.0794e-05 - 5s/epoch - 8ms/step
# Epoch 32/100
# 653/653 - 6s - loss: 1.3807e-04 - val_loss: 7.9265e-05 - 6s/epoch - 9ms/step
# Epoch 33/100
# 653/653 - 5s - loss: 1.3397e-04 - val_loss: 7.8639e-05 - 5s/epoch - 8ms/step
# Epoch 34/100
# 653/653 - 6s - loss: 1.3053e-04 - val_loss: 7.7881e-05 - 6s/epoch - 9ms/step
# Epoch 35/100
# 653/653 - 6s - loss: 1.2731e-04 - val_loss: 7.8124e-05 - 6s/epoch - 9ms/step
# Epoch 36/100
# 653/653 - 6s - loss: 1.2479e-04 - val_loss: 7.8684e-05 - 6s/epoch - 9ms/step
# Epoch 37/100
# 653/653 - 6s - loss: 1.2229e-04 - val_loss: 7.8377e-05 - 6s/epoch - 10ms/step
# Epoch 38/100
# 653/653 - 6s - loss: 1.1961e-04 - val_loss: 7.8340e-05 - 6s/epoch - 9ms/step
# Epoch 39/100
# 653/653 - 6s - loss: 1.1717e-04 - val_loss: 7.8162e-05 - 6s/epoch - 9ms/step
# Epoch 40/100
# 653/653 - 6s - loss: 1.1482e-04 - val_loss: 7.8506e-05 - 6s/epoch - 9ms/step
# Epoch 41/100
# 653/653 - 6s - loss: 1.1266e-04 - val_loss: 7.7632e-05 - 6s/epoch - 9ms/step
# Epoch 42/100
# 653/653 - 6s - loss: 1.1036e-04 - val_loss: 7.7693e-05 - 6s/epoch - 9ms/step
# Epoch 43/100
# 653/653 - 6s - loss: 1.0847e-04 - val_loss: 7.7207e-05 - 6s/epoch - 9ms/step
# Epoch 44/100
# 653/653 - 6s - loss: 1.0647e-04 - val_loss: 7.7396e-05 - 6s/epoch - 9ms/step
# Epoch 45/100
# 653/653 - 6s - loss: 1.0482e-04 - val_loss: 7.7178e-05 - 6s/epoch - 10ms/step
# Epoch 46/100
# 653/653 - 6s - loss: 1.0301e-04 - val_loss: 7.7094e-05 - 6s/epoch - 9ms/step
# Epoch 47/100
# 653/653 - 6s - loss: 1.0134e-04 - val_loss: 7.6899e-05 - 6s/epoch - 9ms/step
# Epoch 48/100
# 653/653 - 6s - loss: 9.9726e-05 - val_loss: 7.6951e-05 - 6s/epoch - 9ms/step
# Epoch 49/100
# 653/653 - 6s - loss: 9.8254e-05 - val_loss: 7.6773e-05 - 6s/epoch - 9ms/step
# Epoch 50/100
# 653/653 - 6s - loss: 9.6811e-05 - val_loss: 7.6769e-05 - 6s/epoch - 10ms/step
# Epoch 51/100
# 653/653 - 6s - loss: 9.5439e-05 - val_loss: 7.6378e-05 - 6s/epoch - 10ms/step
# Epoch 52/100
# 653/653 - 6s - loss: 9.4070e-05 - val_loss: 7.6129e-05 - 6s/epoch - 9ms/step
# Epoch 53/100
# 653/653 - 6s - loss: 9.2808e-05 - val_loss: 7.5653e-05 - 6s/epoch - 10ms/step
# Epoch 54/100
# 653/653 - 6s - loss: 9.1652e-05 - val_loss: 7.5406e-05 - 6s/epoch - 9ms/step
# Epoch 55/100
# 653/653 - 6s - loss: 9.0598e-05 - val_loss: 7.4920e-05 - 6s/epoch - 10ms/step
# Epoch 56/100
# 653/653 - 6s - loss: 8.9530e-05 - val_loss: 7.4236e-05 - 6s/epoch - 10ms/step
# Epoch 57/100
# 653/653 - 6s - loss: 8.8444e-05 - val_loss: 7.3319e-05 - 6s/epoch - 10ms/step
# Epoch 58/100
# 653/653 - 7s - loss: 8.7362e-05 - val_loss: 7.2285e-05 - 7s/epoch - 10ms/step
# Epoch 59/100
# 653/653 - 6s - loss: 8.6402e-05 - val_loss: 7.1403e-05 - 6s/epoch - 10ms/step
# Epoch 60/100
# 653/653 - 6s - loss: 8.5584e-05 - val_loss: 7.0653e-05 - 6s/epoch - 9ms/step
# Epoch 61/100
# 653/653 - 6s - loss: 8.4865e-05 - val_loss: 7.0017e-05 - 6s/epoch - 10ms/step
# Epoch 62/100
# 653/653 - 6s - loss: 8.4136e-05 - val_loss: 6.9275e-05 - 6s/epoch - 9ms/step
# Epoch 63/100
# 653/653 - 6s - loss: 8.3342e-05 - val_loss: 6.8504e-05 - 6s/epoch - 9ms/step
# Epoch 64/100
# 653/653 - 7s - loss: 8.2530e-05 - val_loss: 6.7814e-05 - 7s/epoch - 10ms/step
# Epoch 65/100
# 653/653 - 6s - loss: 8.1744e-05 - val_loss: 6.7245e-05 - 6s/epoch - 9ms/step
# Epoch 66/100
# 653/653 - 6s - loss: 8.1007e-05 - val_loss: 6.6820e-05 - 6s/epoch - 10ms/step
# Epoch 67/100
# 653/653 - 6s - loss: 8.0298e-05 - val_loss: 6.6439e-05 - 6s/epoch - 9ms/step
# Epoch 68/100
# 653/653 - 7s - loss: 7.9595e-05 - val_loss: 6.6054e-05 - 7s/epoch - 10ms/step
# Epoch 69/100
# 653/653 - 6s - loss: 7.8894e-05 - val_loss: 6.5640e-05 - 6s/epoch - 10ms/step
# Epoch 70/100
# 653/653 - 6s - loss: 7.8204e-05 - val_loss: 6.5202e-05 - 6s/epoch - 9ms/step
# Epoch 71/100
# 653/653 - 6s - loss: 7.7536e-05 - val_loss: 6.4743e-05 - 6s/epoch - 10ms/step
# Epoch 72/100
# 653/653 - 7s - loss: 7.6889e-05 - val_loss: 6.4251e-05 - 7s/epoch - 10ms/step
# Epoch 73/100
# 653/653 - 6s - loss: 7.6260e-05 - val_loss: 6.3720e-05 - 6s/epoch - 10ms/step
# Epoch 74/100
# 653/653 - 7s - loss: 7.5643e-05 - val_loss: 6.3140e-05 - 7s/epoch - 11ms/step
# Epoch 75/100
# 653/653 - 7s - loss: 7.5037e-05 - val_loss: 6.2513e-05 - 7s/epoch - 10ms/step
# Epoch 76/100
# 653/653 - 6s - loss: 7.4443e-05 - val_loss: 6.1846e-05 - 6s/epoch - 9ms/step
# Epoch 77/100
# 653/653 - 6s - loss: 7.3862e-05 - val_loss: 6.1141e-05 - 6s/epoch - 9ms/step
# Epoch 78/100
# 653/653 - 6s - loss: 7.3294e-05 - val_loss: 6.0401e-05 - 6s/epoch - 9ms/step
# Epoch 79/100
# 653/653 - 6s - loss: 7.2737e-05 - val_loss: 5.9623e-05 - 6s/epoch - 10ms/step
# Epoch 80/100
# 653/653 - 7s - loss: 7.2190e-05 - val_loss: 5.8811e-05 - 7s/epoch - 10ms/step
# Epoch 81/100
# 653/653 - 7s - loss: 7.1653e-05 - val_loss: 5.7970e-05 - 7s/epoch - 10ms/step
# Epoch 82/100
# 653/653 - 7s - loss: 7.1127e-05 - val_loss: 5.7104e-05 - 7s/epoch - 11ms/step
# Epoch 83/100
# 653/653 - 7s - loss: 7.0611e-05 - val_loss: 5.6215e-05 - 7s/epoch - 11ms/step
# Epoch 84/100
# 653/653 - 7s - loss: 7.0103e-05 - val_loss: 5.5305e-05 - 7s/epoch - 11ms/step
# Epoch 85/100
# 653/653 - 7s - loss: 6.9605e-05 - val_loss: 5.4381e-05 - 7s/epoch - 10ms/step
# Epoch 86/100
# 653/653 - 7s - loss: 6.9113e-05 - val_loss: 5.3443e-05 - 7s/epoch - 11ms/step
# Epoch 87/100
# 653/653 - 7s - loss: 6.8630e-05 - val_loss: 5.2498e-05 - 7s/epoch - 10ms/step
# Epoch 88/100
# 653/653 - 8s - loss: 6.8156e-05 - val_loss: 5.1549e-05 - 8s/epoch - 12ms/step
# Epoch 89/100
# 653/653 - 7s - loss: 6.7689e-05 - val_loss: 5.0600e-05 - 7s/epoch - 10ms/step
# Epoch 90/100
# 653/653 - 7s - loss: 6.7231e-05 - val_loss: 4.9652e-05 - 7s/epoch - 10ms/step
# Epoch 91/100
# 653/653 - 7s - loss: 6.6780e-05 - val_loss: 4.8710e-05 - 7s/epoch - 11ms/step
# Epoch 92/100
# 653/653 - 7s - loss: 6.6338e-05 - val_loss: 4.7778e-05 - 7s/epoch - 11ms/step
# Epoch 93/100
# 653/653 - 7s - loss: 6.5904e-05 - val_loss: 4.6857e-05 - 7s/epoch - 11ms/step
# Epoch 94/100
# 653/653 - 7s - loss: 6.5476e-05 - val_loss: 4.5948e-05 - 7s/epoch - 10ms/step
# Epoch 95/100
# 653/653 - 6s - loss: 6.5056e-05 - val_loss: 4.5053e-05 - 6s/epoch - 10ms/step
# Epoch 96/100
# 653/653 - 6s - loss: 6.4645e-05 - val_loss: 4.4176e-05 - 6s/epoch - 9ms/step
# Epoch 97/100
# 653/653 - 6s - loss: 6.4240e-05 - val_loss: 4.3318e-05 - 6s/epoch - 9ms/step
# Epoch 98/100
# 653/653 - 6s - loss: 6.3843e-05 - val_loss: 4.2477e-05 - 6s/epoch - 9ms/step
# Epoch 99/100
# 653/653 - 6s - loss: 6.3452e-05 - val_loss: 4.1654e-05 - 6s/epoch - 9ms/step
# Epoch 100/100
# 653/653 - 6s - loss: 6.3068e-05 - val_loss: 4.0852e-05 - 6s/epoch - 9ms/step

# %%
i=0
wb1 = Workbook()
ws1 = wb1.active
for m in models1:
    # make a prediction
    test_x2 = test_X
    yhat = LSTMUnit.predict(test_x2, m)
    inv_yhat = Preprocessing.inverse_scaler(yhat, scaler)
    inv_y = Preprocessing.inverse_scaler(test_y.reshape(-1,1), scaler)
    print(hyperparam1[i])
    print("Epoch: "+ str(lstms1[i].params['epochs']))
    print("Neurons: "+str(m.layers[0].units))
    i = i+1
    ws1['A'+str(i)] = 'LSTM'
    ws1['B'+str(i)] = hyperparam1[i-1][0]
    ws1['C'+str(i)] = hyperparam1[i-1][1]
    ws1['D'+str(i)] = hyperparam1[i-1][2]
    print('RMSE')
    print(Evaluation.rmse(inv_y,inv_yhat)[0])
    ws1['E'+str(i)] = Evaluation.rmse(inv_y,inv_yhat)[0]
    print('MAE')
    print(Evaluation.mae(inv_y,inv_yhat)[0])
    ws1['F'+str(i)] = Evaluation.mae(inv_y,inv_yhat)[0]
    print('MAPE')
    print(Evaluation.mape(inv_y,inv_yhat)[0])
    ws1['G'+str(i)] = Evaluation.mape(inv_y,inv_yhat)[0]
    LSTMUnit.save_model(m, 0, 'BTC',hyperparam1[i-1])
wb1.save('LSTM_BTC_result1.xlsx')
# Out:
#  14/164 [=>............................] - ETA: 0s
# 2023-04-02 19:03:23.930237: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:23.967958: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (32, 25, 50)
# Epoch: 25
# Neurons: 50
# RMSE
# 755.846830821159
# MAE
# 706.5074387519177
# MAPE
# 3.6718606712951725
#  30/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:03:24.970064: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:25.000947: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (32, 25, 60)
# Epoch: 25
# Neurons: 60
# RMSE
# 712.0457072635317
# MAE
# 663.9296583435164
# MAPE
# 3.4500943447619905
#  30/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:03:25.831868: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:25.864188: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (32, 25, 100)
# Epoch: 25
# Neurons: 100
# RMSE
# 596.222754371715
# MAE
# 552.6189575396544
# MAPE
# 2.867622509347573
#  29/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:03:26.673925: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:26.707623: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (32, 50, 50)
# Epoch: 50
# Neurons: 50
# RMSE
# 502.20103269351506
# MAE
# 461.02829787234106
# MAPE
# 2.3918493906330554
#  14/164 [=>............................] - ETA: 0s
# 2023-04-02 19:03:27.553007: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:27.587345: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (32, 50, 60)
# Epoch: 50
# Neurons: 60
# RMSE
# 501.0605240031887
# MAE
# 459.1495558390844
# MAPE
# 2.3817932927176564
#  30/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:03:28.407528: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:28.439297: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (32, 50, 100)
# Epoch: 50
# Neurons: 100
# RMSE
# 546.7249651018084
# MAE
# 506.11149273109584
# MAPE
# 2.6230158485237447
#  14/164 [=>............................] - ETA: 0s
# 2023-04-02 19:03:29.248808: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:29.279807: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (32, 100, 50)
# Epoch: 100
# Neurons: 50
# RMSE
# 379.1002466283899
# MAE
# 343.58373712143015
# MAPE
# 1.7695125113499546
#  29/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:03:30.101910: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:30.134145: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (32, 100, 60)
# Epoch: 100
# Neurons: 60
# RMSE
# 393.22573418183896
# MAE
# 357.4296686912978
# MAPE
# 1.8416391347841108
#   7/164 [>.............................] - ETA: 1s
# 2023-04-02 19:03:31.103278: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:31.149314: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 4ms/step
# (32, 100, 100)
# Epoch: 100
# Neurons: 100
# RMSE
# 412.27543416562594
# MAE
# 375.62647459627186
# MAPE
# 1.9359767484632098

# %%
lstms2 = []
models2 = []
for batch, epoch, neuron in hyperparam2:
    model, lstm = LSTMUnit.train_lstm(train_X, train_y, test_X, test_y, neuron, epoch, batch)
    lstms2.append(lstm)
    models2.append(model)
# Out:
# Epoch 1/25
# 2023-04-02 19:03:32.607838: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:32.724577: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:32.862865: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:36.106528: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:03:36.144597: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 327/327 - 4s - loss: 9.6678e-04 - val_loss: 0.0020 - 4s/epoch - 14ms/step
# Epoch 2/25
# 327/327 - 3s - loss: 6.9868e-04 - val_loss: 0.0018 - 3s/epoch - 10ms/step
# Epoch 3/25
# 327/327 - 3s - loss: 6.6451e-04 - val_loss: 0.0018 - 3s/epoch - 10ms/step
# Epoch 4/25
# 327/327 - 3s - loss: 6.5089e-04 - val_loss: 0.0018 - 3s/epoch - 9ms/step
# Epoch 5/25
# 327/327 - 3s - loss: 6.4840e-04 - val_loss: 0.0018 - 3s/epoch - 10ms/step
# Epoch 6/25
# 327/327 - 3s - loss: 6.5765e-04 - val_loss: 0.0019 - 3s/epoch - 10ms/step
# Epoch 7/25
# 327/327 - 3s - loss: 6.7657e-04 - val_loss: 0.0020 - 3s/epoch - 10ms/step
# Epoch 8/25
# 327/327 - 3s - loss: 6.9206e-04 - val_loss: 0.0022 - 3s/epoch - 9ms/step
# Epoch 9/25
# 327/327 - 4s - loss: 7.5898e-04 - val_loss: 0.0024 - 4s/epoch - 11ms/step
# Epoch 10/25
# 327/327 - 3s - loss: 7.9340e-04 - val_loss: 0.0026 - 3s/epoch - 10ms/step
# Epoch 11/25
# 327/327 - 3s - loss: 8.6079e-04 - val_loss: 0.0028 - 3s/epoch - 9ms/step
# Epoch 12/25
# 327/327 - 3s - loss: 9.2480e-04 - val_loss: 0.0031 - 3s/epoch - 10ms/step
# Epoch 13/25
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0034 - 3s/epoch - 10ms/step
# Epoch 14/25
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0038 - 3s/epoch - 11ms/step
# Epoch 15/25
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0041 - 3s/epoch - 10ms/step
# Epoch 16/25
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0042 - 3s/epoch - 10ms/step
# Epoch 17/25
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0043 - 3s/epoch - 10ms/step
# Epoch 18/25
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0039 - 3s/epoch - 10ms/step
# Epoch 19/25
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0036 - 3s/epoch - 9ms/step
# Epoch 20/25
# 327/327 - 3s - loss: 9.2312e-04 - val_loss: 0.0031 - 3s/epoch - 10ms/step
# Epoch 21/25
# 327/327 - 3s - loss: 8.4954e-04 - val_loss: 0.0028 - 3s/epoch - 11ms/step
# Epoch 22/25
# 327/327 - 3s - loss: 7.8793e-04 - val_loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 23/25
# 327/327 - 3s - loss: 7.3491e-04 - val_loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 24/25
# 327/327 - 3s - loss: 6.9142e-04 - val_loss: 0.0020 - 3s/epoch - 10ms/step
# Epoch 25/25
# 327/327 - 3s - loss: 6.5346e-04 - val_loss: 0.0018 - 3s/epoch - 10ms/step
# Epoch 1/25
# 2023-04-02 19:04:54.675778: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:04:54.791685: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:04:54.924852: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:04:58.312416: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:04:58.351638: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 327/327 - 5s - loss: 7.0926e-04 - val_loss: 0.0016 - 5s/epoch - 15ms/step
# Epoch 2/25
# 327/327 - 3s - loss: 7.5584e-04 - val_loss: 0.0015 - 3s/epoch - 11ms/step
# Epoch 3/25
# 327/327 - 3s - loss: 6.3869e-04 - val_loss: 0.0014 - 3s/epoch - 10ms/step
# Epoch 4/25
# 327/327 - 4s - loss: 5.8781e-04 - val_loss: 0.0013 - 4s/epoch - 11ms/step
# Epoch 5/25
# 327/327 - 3s - loss: 5.4741e-04 - val_loss: 0.0012 - 3s/epoch - 10ms/step
# Epoch 6/25
# 327/327 - 3s - loss: 5.1235e-04 - val_loss: 0.0011 - 3s/epoch - 10ms/step
# Epoch 7/25
# 327/327 - 3s - loss: 4.8199e-04 - val_loss: 0.0010 - 3s/epoch - 10ms/step
# Epoch 8/25
# 327/327 - 3s - loss: 4.3961e-04 - val_loss: 9.0349e-04 - 3s/epoch - 10ms/step
# Epoch 9/25
# 327/327 - 3s - loss: 4.0255e-04 - val_loss: 7.8542e-04 - 3s/epoch - 10ms/step
# Epoch 10/25
# 327/327 - 4s - loss: 3.6241e-04 - val_loss: 6.5415e-04 - 4s/epoch - 11ms/step
# Epoch 11/25
# 327/327 - 3s - loss: 3.1600e-04 - val_loss: 5.1556e-04 - 3s/epoch - 10ms/step
# Epoch 12/25
# 327/327 - 4s - loss: 2.6856e-04 - val_loss: 3.7989e-04 - 4s/epoch - 11ms/step
# Epoch 13/25
# 327/327 - 3s - loss: 2.1826e-04 - val_loss: 2.6862e-04 - 3s/epoch - 10ms/step
# Epoch 14/25
# 327/327 - 3s - loss: 1.6780e-04 - val_loss: 1.9644e-04 - 3s/epoch - 10ms/step
# Epoch 15/25
# 327/327 - 3s - loss: 1.2348e-04 - val_loss: 1.4572e-04 - 3s/epoch - 10ms/step
# Epoch 16/25
# 327/327 - 3s - loss: 9.3432e-05 - val_loss: 9.5509e-05 - 3s/epoch - 10ms/step
# Epoch 17/25
# 327/327 - 3s - loss: 7.9753e-05 - val_loss: 5.9645e-05 - 3s/epoch - 10ms/step
# Epoch 18/25
# 327/327 - 3s - loss: 7.7542e-05 - val_loss: 4.3288e-05 - 3s/epoch - 10ms/step
# Epoch 19/25
# 327/327 - 3s - loss: 8.0939e-05 - val_loss: 4.0426e-05 - 3s/epoch - 10ms/step
# Epoch 20/25
# 327/327 - 3s - loss: 8.9518e-05 - val_loss: 5.0973e-05 - 3s/epoch - 10ms/step
# Epoch 21/25
# 327/327 - 3s - loss: 1.0651e-04 - val_loss: 8.4188e-05 - 3s/epoch - 10ms/step
# Epoch 22/25
# 327/327 - 3s - loss: 1.1498e-04 - val_loss: 1.0596e-04 - 3s/epoch - 10ms/step
# Epoch 23/25
# 327/327 - 3s - loss: 1.1202e-04 - val_loss: 1.1138e-04 - 3s/epoch - 10ms/step
# Epoch 24/25
# 327/327 - 3s - loss: 1.0676e-04 - val_loss: 1.0951e-04 - 3s/epoch - 10ms/step
# Epoch 25/25
# 327/327 - 3s - loss: 1.0189e-04 - val_loss: 1.0590e-04 - 3s/epoch - 10ms/step
# Epoch 1/25
# 2023-04-02 19:06:18.892303: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:06:19.045908: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:06:19.253078: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:06:22.503324: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:06:22.540812: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 327/327 - 5s - loss: 7.7993e-04 - val_loss: 0.0024 - 5s/epoch - 15ms/step
# Epoch 2/25
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0021 - 3s/epoch - 9ms/step
# Epoch 3/25
# 327/327 - 4s - loss: 9.6936e-04 - val_loss: 0.0022 - 4s/epoch - 11ms/step
# Epoch 4/25
# 327/327 - 3s - loss: 9.6953e-04 - val_loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 5/25
# 327/327 - 3s - loss: 9.5382e-04 - val_loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 6/25
# 327/327 - 3s - loss: 9.5476e-04 - val_loss: 0.0028 - 3s/epoch - 9ms/step
# Epoch 7/25
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0032 - 3s/epoch - 9ms/step
# Epoch 8/25
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0034 - 3s/epoch - 9ms/step
# Epoch 9/25
# 327/327 - 3s - loss: 0.0013 - val_loss: 0.0036 - 3s/epoch - 9ms/step
# Epoch 10/25
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0037 - 3s/epoch - 9ms/step
# Epoch 11/25
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0037 - 3s/epoch - 9ms/step
# Epoch 12/25
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0038 - 3s/epoch - 9ms/step
# Epoch 13/25
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0038 - 3s/epoch - 9ms/step
# Epoch 14/25
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0038 - 3s/epoch - 9ms/step
# Epoch 15/25
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0038 - 3s/epoch - 9ms/step
# Epoch 16/25
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0034 - 3s/epoch - 9ms/step
# Epoch 17/25
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0031 - 3s/epoch - 9ms/step
# Epoch 18/25
# 327/327 - 3s - loss: 9.5233e-04 - val_loss: 0.0029 - 3s/epoch - 9ms/step
# Epoch 19/25
# 327/327 - 3s - loss: 9.0238e-04 - val_loss: 0.0027 - 3s/epoch - 9ms/step
# Epoch 20/25
# 327/327 - 3s - loss: 8.5299e-04 - val_loss: 0.0025 - 3s/epoch - 9ms/step
# Epoch 21/25
# 327/327 - 3s - loss: 7.9355e-04 - val_loss: 0.0022 - 3s/epoch - 9ms/step
# Epoch 22/25
# 327/327 - 3s - loss: 7.4956e-04 - val_loss: 0.0020 - 3s/epoch - 9ms/step
# Epoch 23/25
# 327/327 - 3s - loss: 7.1822e-04 - val_loss: 0.0018 - 3s/epoch - 9ms/step
# Epoch 24/25
# 327/327 - 3s - loss: 7.0158e-04 - val_loss: 0.0017 - 3s/epoch - 9ms/step
# Epoch 25/25
# 327/327 - 3s - loss: 6.8837e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 1/50
# 2023-04-02 19:07:35.482017: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:07:35.568948: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:07:35.678342: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:07:38.459494: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:07:38.493394: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 327/327 - 4s - loss: 9.8146e-04 - val_loss: 0.0020 - 4s/epoch - 12ms/step
# Epoch 2/50
# 327/327 - 3s - loss: 7.3849e-04 - val_loss: 0.0019 - 3s/epoch - 8ms/step
# Epoch 3/50
# 327/327 - 3s - loss: 6.7182e-04 - val_loss: 0.0018 - 3s/epoch - 8ms/step
# Epoch 4/50
# 327/327 - 3s - loss: 6.5895e-04 - val_loss: 0.0019 - 3s/epoch - 8ms/step
# Epoch 5/50
# 327/327 - 3s - loss: 6.5609e-04 - val_loss: 0.0019 - 3s/epoch - 8ms/step
# Epoch 6/50
# 327/327 - 3s - loss: 6.7291e-04 - val_loss: 0.0020 - 3s/epoch - 8ms/step
# Epoch 7/50
# 327/327 - 3s - loss: 6.9403e-04 - val_loss: 0.0021 - 3s/epoch - 8ms/step
# Epoch 8/50
# 327/327 - 3s - loss: 7.4144e-04 - val_loss: 0.0022 - 3s/epoch - 8ms/step
# Epoch 9/50
# 327/327 - 3s - loss: 7.3058e-04 - val_loss: 0.0024 - 3s/epoch - 8ms/step
# Epoch 10/50
# 327/327 - 3s - loss: 7.6566e-04 - val_loss: 0.0025 - 3s/epoch - 8ms/step
# Epoch 11/50
# 327/327 - 3s - loss: 7.9598e-04 - val_loss: 0.0027 - 3s/epoch - 8ms/step
# Epoch 12/50
# 327/327 - 3s - loss: 8.5413e-04 - val_loss: 0.0029 - 3s/epoch - 8ms/step
# Epoch 13/50
# 327/327 - 3s - loss: 9.1764e-04 - val_loss: 0.0031 - 3s/epoch - 8ms/step
# Epoch 14/50
# 327/327 - 3s - loss: 9.6335e-04 - val_loss: 0.0033 - 3s/epoch - 8ms/step
# Epoch 15/50
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0035 - 3s/epoch - 8ms/step
# Epoch 16/50
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0037 - 3s/epoch - 8ms/step
# Epoch 17/50
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0037 - 3s/epoch - 8ms/step
# Epoch 18/50
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0037 - 3s/epoch - 8ms/step
# Epoch 19/50
# 327/327 - 3s - loss: 9.8095e-04 - val_loss: 0.0035 - 3s/epoch - 8ms/step
# Epoch 20/50
# 327/327 - 3s - loss: 9.3726e-04 - val_loss: 0.0032 - 3s/epoch - 8ms/step
# Epoch 21/50
# 327/327 - 3s - loss: 8.7242e-04 - val_loss: 0.0030 - 3s/epoch - 8ms/step
# Epoch 22/50
# 327/327 - 3s - loss: 8.0271e-04 - val_loss: 0.0026 - 3s/epoch - 8ms/step
# Epoch 23/50
# 327/327 - 3s - loss: 7.3091e-04 - val_loss: 0.0022 - 3s/epoch - 8ms/step
# Epoch 24/50
# 327/327 - 3s - loss: 6.8089e-04 - val_loss: 0.0020 - 3s/epoch - 8ms/step
# Epoch 25/50
# 327/327 - 3s - loss: 6.4318e-04 - val_loss: 0.0018 - 3s/epoch - 8ms/step
# Epoch 26/50
# 327/327 - 3s - loss: 6.0778e-04 - val_loss: 0.0016 - 3s/epoch - 8ms/step
# Epoch 27/50
# 327/327 - 3s - loss: 5.7957e-04 - val_loss: 0.0015 - 3s/epoch - 8ms/step
# Epoch 28/50
# 327/327 - 3s - loss: 5.6554e-04 - val_loss: 0.0014 - 3s/epoch - 9ms/step
# Epoch 29/50
# 327/327 - 3s - loss: 5.5009e-04 - val_loss: 0.0013 - 3s/epoch - 8ms/step
# Epoch 30/50
# 327/327 - 3s - loss: 5.4417e-04 - val_loss: 0.0013 - 3s/epoch - 8ms/step
# Epoch 31/50
# 327/327 - 3s - loss: 5.4053e-04 - val_loss: 0.0012 - 3s/epoch - 8ms/step
# Epoch 32/50
# 327/327 - 3s - loss: 5.3762e-04 - val_loss: 0.0012 - 3s/epoch - 8ms/step
# Epoch 33/50
# 327/327 - 3s - loss: 5.3402e-04 - val_loss: 0.0012 - 3s/epoch - 8ms/step
# Epoch 34/50
# 327/327 - 3s - loss: 5.2855e-04 - val_loss: 0.0011 - 3s/epoch - 8ms/step
# Epoch 35/50
# 327/327 - 3s - loss: 5.2801e-04 - val_loss: 0.0011 - 3s/epoch - 8ms/step
# Epoch 36/50
# 327/327 - 3s - loss: 5.2730e-04 - val_loss: 0.0011 - 3s/epoch - 8ms/step
# Epoch 37/50
# 327/327 - 3s - loss: 5.2664e-04 - val_loss: 0.0011 - 3s/epoch - 8ms/step
# Epoch 38/50
# 327/327 - 3s - loss: 5.2676e-04 - val_loss: 0.0011 - 3s/epoch - 8ms/step
# Epoch 39/50
# 327/327 - 3s - loss: 5.2576e-04 - val_loss: 0.0010 - 3s/epoch - 8ms/step
# Epoch 40/50
# 327/327 - 3s - loss: 5.1715e-04 - val_loss: 9.9706e-04 - 3s/epoch - 8ms/step
# Epoch 41/50
# 327/327 - 3s - loss: 5.1343e-04 - val_loss: 9.7302e-04 - 3s/epoch - 8ms/step
# Epoch 42/50
# 327/327 - 3s - loss: 5.0930e-04 - val_loss: 9.5357e-04 - 3s/epoch - 8ms/step
# Epoch 43/50
# 327/327 - 3s - loss: 5.0786e-04 - val_loss: 9.4451e-04 - 3s/epoch - 8ms/step
# Epoch 44/50
# 327/327 - 3s - loss: 5.0325e-04 - val_loss: 9.0963e-04 - 3s/epoch - 8ms/step
# Epoch 45/50
# 327/327 - 3s - loss: 4.9685e-04 - val_loss: 8.8505e-04 - 3s/epoch - 8ms/step
# Epoch 46/50
# 327/327 - 3s - loss: 4.8086e-04 - val_loss: 8.3048e-04 - 3s/epoch - 8ms/step
# Epoch 47/50
# 327/327 - 3s - loss: 4.7597e-04 - val_loss: 8.1767e-04 - 3s/epoch - 8ms/step
# Epoch 48/50
# 327/327 - 3s - loss: 4.7123e-04 - val_loss: 7.9953e-04 - 3s/epoch - 8ms/step
# Epoch 49/50
# 327/327 - 3s - loss: 4.6532e-04 - val_loss: 7.7893e-04 - 3s/epoch - 8ms/step
# Epoch 50/50
# 327/327 - 3s - loss: 4.5760e-04 - val_loss: 7.6189e-04 - 3s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-02 19:09:51.723795: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:09:51.812091: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:09:51.913935: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:09:54.671319: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:09:54.704231: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 327/327 - 4s - loss: 7.2025e-04 - val_loss: 0.0016 - 4s/epoch - 12ms/step
# Epoch 2/50
# 327/327 - 3s - loss: 7.6350e-04 - val_loss: 0.0015 - 3s/epoch - 8ms/step
# Epoch 3/50
# 327/327 - 3s - loss: 6.8070e-04 - val_loss: 0.0014 - 3s/epoch - 8ms/step
# Epoch 4/50
# 327/327 - 3s - loss: 5.9920e-04 - val_loss: 0.0014 - 3s/epoch - 8ms/step
# Epoch 5/50
# 327/327 - 3s - loss: 5.6278e-04 - val_loss: 0.0013 - 3s/epoch - 8ms/step
# Epoch 6/50
# 327/327 - 3s - loss: 5.3427e-04 - val_loss: 0.0012 - 3s/epoch - 8ms/step
# Epoch 7/50
# 327/327 - 3s - loss: 5.0250e-04 - val_loss: 0.0012 - 3s/epoch - 8ms/step
# Epoch 8/50
# 327/327 - 3s - loss: 4.7718e-04 - val_loss: 0.0011 - 3s/epoch - 9ms/step
# Epoch 9/50
# 327/327 - 3s - loss: 4.4720e-04 - val_loss: 0.0010 - 3s/epoch - 9ms/step
# Epoch 10/50
# 327/327 - 3s - loss: 4.1826e-04 - val_loss: 8.9568e-04 - 3s/epoch - 9ms/step
# Epoch 11/50
# 327/327 - 3s - loss: 3.7543e-04 - val_loss: 7.7714e-04 - 3s/epoch - 9ms/step
# Epoch 12/50
# 327/327 - 3s - loss: 3.3506e-04 - val_loss: 6.4344e-04 - 3s/epoch - 9ms/step
# Epoch 13/50
# 327/327 - 3s - loss: 2.9121e-04 - val_loss: 5.0104e-04 - 3s/epoch - 9ms/step
# Epoch 14/50
# 327/327 - 3s - loss: 2.4420e-04 - val_loss: 3.6230e-04 - 3s/epoch - 8ms/step
# Epoch 15/50
# 327/327 - 3s - loss: 1.9493e-04 - val_loss: 2.5176e-04 - 3s/epoch - 8ms/step
# Epoch 16/50
# 327/327 - 3s - loss: 1.4762e-04 - val_loss: 1.8185e-04 - 3s/epoch - 8ms/step
# Epoch 17/50
# 327/327 - 3s - loss: 1.0718e-04 - val_loss: 1.3057e-04 - 3s/epoch - 8ms/step
# Epoch 18/50
# 327/327 - 3s - loss: 8.0920e-05 - val_loss: 8.1173e-05 - 3s/epoch - 9ms/step
# Epoch 19/50
# 327/327 - 3s - loss: 6.9915e-05 - val_loss: 4.9864e-05 - 3s/epoch - 8ms/step
# Epoch 20/50
# 327/327 - 3s - loss: 6.8967e-05 - val_loss: 3.7722e-05 - 3s/epoch - 8ms/step
# Epoch 21/50
# 327/327 - 3s - loss: 7.3710e-05 - val_loss: 3.9864e-05 - 3s/epoch - 9ms/step
# Epoch 22/50
# 327/327 - 3s - loss: 8.5438e-05 - val_loss: 5.7305e-05 - 3s/epoch - 9ms/step
# Epoch 23/50
# 327/327 - 3s - loss: 9.8511e-05 - val_loss: 8.2148e-05 - 3s/epoch - 8ms/step
# Epoch 24/50
# 327/327 - 3s - loss: 1.0452e-04 - val_loss: 1.0169e-04 - 3s/epoch - 8ms/step
# Epoch 25/50
# 327/327 - 3s - loss: 1.0073e-04 - val_loss: 1.0476e-04 - 3s/epoch - 9ms/step
# Epoch 26/50
# 327/327 - 3s - loss: 9.7118e-05 - val_loss: 1.0447e-04 - 3s/epoch - 9ms/step
# Epoch 27/50
# 327/327 - 3s - loss: 9.3411e-05 - val_loss: 1.0260e-04 - 3s/epoch - 9ms/step
# Epoch 28/50
# 327/327 - 3s - loss: 9.1466e-05 - val_loss: 1.0254e-04 - 3s/epoch - 9ms/step
# Epoch 29/50
# 327/327 - 3s - loss: 9.1241e-05 - val_loss: 1.0612e-04 - 3s/epoch - 9ms/step
# Epoch 30/50
# 327/327 - 3s - loss: 9.0671e-05 - val_loss: 1.0972e-04 - 3s/epoch - 10ms/step
# Epoch 31/50
# 327/327 - 3s - loss: 9.1949e-05 - val_loss: 1.1704e-04 - 3s/epoch - 9ms/step
# Epoch 32/50
# 327/327 - 3s - loss: 9.1883e-05 - val_loss: 1.2243e-04 - 3s/epoch - 9ms/step
# Epoch 33/50
# 327/327 - 3s - loss: 9.1285e-05 - val_loss: 1.2581e-04 - 3s/epoch - 10ms/step
# Epoch 34/50
# 327/327 - 3s - loss: 8.8871e-05 - val_loss: 1.2315e-04 - 3s/epoch - 9ms/step
# Epoch 35/50
# 327/327 - 3s - loss: 8.7637e-05 - val_loss: 1.2199e-04 - 3s/epoch - 9ms/step
# Epoch 36/50
# 327/327 - 3s - loss: 8.5592e-05 - val_loss: 1.2089e-04 - 3s/epoch - 9ms/step
# Epoch 37/50
# 327/327 - 3s - loss: 8.5044e-05 - val_loss: 1.2048e-04 - 3s/epoch - 9ms/step
# Epoch 38/50
# 327/327 - 3s - loss: 8.5469e-05 - val_loss: 1.2414e-04 - 3s/epoch - 10ms/step
# Epoch 39/50
# 327/327 - 3s - loss: 8.5541e-05 - val_loss: 1.2746e-04 - 3s/epoch - 9ms/step
# Epoch 40/50
# 327/327 - 3s - loss: 8.3795e-05 - val_loss: 1.2536e-04 - 3s/epoch - 10ms/step
# Epoch 41/50
# 327/327 - 3s - loss: 8.2101e-05 - val_loss: 1.2229e-04 - 3s/epoch - 10ms/step
# Epoch 42/50
# 327/327 - 3s - loss: 8.0811e-05 - val_loss: 1.2074e-04 - 3s/epoch - 10ms/step
# Epoch 43/50
# 327/327 - 3s - loss: 8.1629e-05 - val_loss: 1.2422e-04 - 3s/epoch - 9ms/step
# Epoch 44/50
# 327/327 - 3s - loss: 8.0391e-05 - val_loss: 1.2368e-04 - 3s/epoch - 9ms/step
# Epoch 45/50
# 327/327 - 3s - loss: 8.0286e-05 - val_loss: 1.2298e-04 - 3s/epoch - 9ms/step
# Epoch 46/50
# 327/327 - 3s - loss: 7.8448e-05 - val_loss: 1.2060e-04 - 3s/epoch - 9ms/step
# Epoch 47/50
# 327/327 - 3s - loss: 7.7300e-05 - val_loss: 1.1732e-04 - 3s/epoch - 9ms/step
# Epoch 48/50
# 327/327 - 3s - loss: 7.5784e-05 - val_loss: 1.1551e-04 - 3s/epoch - 10ms/step
# Epoch 49/50
# 327/327 - 3s - loss: 7.4851e-05 - val_loss: 1.1352e-04 - 3s/epoch - 9ms/step
# Epoch 50/50
# 327/327 - 3s - loss: 7.3906e-05 - val_loss: 1.1288e-04 - 3s/epoch - 9ms/step
# Epoch 1/50
# 2023-04-02 19:12:18.515676: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:12:18.609667: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:12:18.719939: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:12:22.237680: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:12:22.273791: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 327/327 - 5s - loss: 8.0313e-04 - val_loss: 0.0024 - 5s/epoch - 14ms/step
# Epoch 2/50
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 3/50
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0024 - 3s/epoch - 9ms/step
# Epoch 4/50
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0025 - 3s/epoch - 9ms/step
# Epoch 5/50
# 327/327 - 3s - loss: 9.8644e-04 - val_loss: 0.0027 - 3s/epoch - 10ms/step
# Epoch 6/50
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0030 - 3s/epoch - 10ms/step
# Epoch 7/50
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0034 - 3s/epoch - 9ms/step
# Epoch 8/50
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0036 - 3s/epoch - 9ms/step
# Epoch 9/50
# 327/327 - 4s - loss: 0.0012 - val_loss: 0.0038 - 4s/epoch - 11ms/step
# Epoch 10/50
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0037 - 3s/epoch - 9ms/step
# Epoch 11/50
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0038 - 3s/epoch - 10ms/step
# Epoch 12/50
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0038 - 3s/epoch - 10ms/step
# Epoch 13/50
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0039 - 3s/epoch - 9ms/step
# Epoch 14/50
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0037 - 3s/epoch - 9ms/step
# Epoch 15/50
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0036 - 3s/epoch - 9ms/step
# Epoch 16/50
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0033 - 3s/epoch - 10ms/step
# Epoch 17/50
# 327/327 - 3s - loss: 9.8851e-04 - val_loss: 0.0030 - 3s/epoch - 9ms/step
# Epoch 18/50
# 327/327 - 3s - loss: 9.2647e-04 - val_loss: 0.0027 - 3s/epoch - 10ms/step
# Epoch 19/50
# 327/327 - 3s - loss: 8.6126e-04 - val_loss: 0.0025 - 3s/epoch - 9ms/step
# Epoch 20/50
# 327/327 - 3s - loss: 8.1225e-04 - val_loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 21/50
# 327/327 - 3s - loss: 7.7232e-04 - val_loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 22/50
# 327/327 - 3s - loss: 7.4885e-04 - val_loss: 0.0019 - 3s/epoch - 9ms/step
# Epoch 23/50
# 327/327 - 3s - loss: 7.3057e-04 - val_loss: 0.0018 - 3s/epoch - 9ms/step
# Epoch 24/50
# 327/327 - 3s - loss: 7.1964e-04 - val_loss: 0.0018 - 3s/epoch - 10ms/step
# Epoch 25/50
# 327/327 - 3s - loss: 7.1350e-04 - val_loss: 0.0017 - 3s/epoch - 9ms/step
# Epoch 26/50
# 327/327 - 3s - loss: 7.0889e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 27/50
# 327/327 - 3s - loss: 7.0354e-04 - val_loss: 0.0015 - 3s/epoch - 9ms/step
# Epoch 28/50
# 327/327 - 3s - loss: 6.9624e-04 - val_loss: 0.0015 - 3s/epoch - 9ms/step
# Epoch 29/50
# 327/327 - 3s - loss: 6.9581e-04 - val_loss: 0.0014 - 3s/epoch - 10ms/step
# Epoch 30/50
# 327/327 - 3s - loss: 6.9321e-04 - val_loss: 0.0014 - 3s/epoch - 9ms/step
# Epoch 31/50
# 327/327 - 3s - loss: 6.9398e-04 - val_loss: 0.0014 - 3s/epoch - 10ms/step
# Epoch 32/50
# 327/327 - 3s - loss: 7.0571e-04 - val_loss: 0.0014 - 3s/epoch - 9ms/step
# Epoch 33/50
# 327/327 - 3s - loss: 7.0518e-04 - val_loss: 0.0013 - 3s/epoch - 9ms/step
# Epoch 34/50
# 327/327 - 3s - loss: 7.0654e-04 - val_loss: 0.0013 - 3s/epoch - 10ms/step
# Epoch 35/50
# 327/327 - 3s - loss: 7.0351e-04 - val_loss: 0.0013 - 3s/epoch - 10ms/step
# Epoch 36/50
# 327/327 - 3s - loss: 7.0860e-04 - val_loss: 0.0013 - 3s/epoch - 10ms/step
# Epoch 37/50
# 327/327 - 3s - loss: 7.1480e-04 - val_loss: 0.0013 - 3s/epoch - 10ms/step
# Epoch 38/50
# 327/327 - 3s - loss: 7.0662e-04 - val_loss: 0.0012 - 3s/epoch - 9ms/step
# Epoch 39/50
# 327/327 - 4s - loss: 7.0093e-04 - val_loss: 0.0012 - 4s/epoch - 11ms/step
# Epoch 40/50
# 327/327 - 3s - loss: 6.8748e-04 - val_loss: 0.0011 - 3s/epoch - 9ms/step
# Epoch 41/50
# 327/327 - 4s - loss: 6.8322e-04 - val_loss: 0.0011 - 4s/epoch - 12ms/step
# Epoch 42/50
# 327/327 - 3s - loss: 6.6942e-04 - val_loss: 0.0010 - 3s/epoch - 10ms/step
# Epoch 43/50
# 327/327 - 3s - loss: 6.5931e-04 - val_loss: 9.9818e-04 - 3s/epoch - 10ms/step
# Epoch 44/50
# 327/327 - 4s - loss: 6.4538e-04 - val_loss: 9.4974e-04 - 4s/epoch - 11ms/step
# Epoch 45/50
# 327/327 - 3s - loss: 6.2847e-04 - val_loss: 9.1381e-04 - 3s/epoch - 11ms/step
# Epoch 46/50
# 327/327 - 3s - loss: 6.0729e-04 - val_loss: 8.7221e-04 - 3s/epoch - 9ms/step
# Epoch 47/50
# 327/327 - 3s - loss: 5.9167e-04 - val_loss: 8.3427e-04 - 3s/epoch - 9ms/step
# Epoch 48/50
# 327/327 - 3s - loss: 5.7437e-04 - val_loss: 8.0293e-04 - 3s/epoch - 9ms/step
# Epoch 49/50
# 327/327 - 3s - loss: 5.5830e-04 - val_loss: 7.8844e-04 - 3s/epoch - 9ms/step
# Epoch 50/50
# 327/327 - 3s - loss: 5.4145e-04 - val_loss: 7.4907e-04 - 3s/epoch - 9ms/step
# Epoch 1/100
# 2023-04-02 19:14:59.200130: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:14:59.289001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:14:59.418673: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:15:02.594445: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:15:02.626994: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 327/327 - 4s - loss: 9.9055e-04 - val_loss: 0.0019 - 4s/epoch - 13ms/step
# Epoch 2/100
# 327/327 - 3s - loss: 7.0294e-04 - val_loss: 0.0017 - 3s/epoch - 8ms/step
# Epoch 3/100
# 327/327 - 3s - loss: 6.3967e-04 - val_loss: 0.0017 - 3s/epoch - 9ms/step
# Epoch 4/100
# 327/327 - 3s - loss: 6.1638e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 5/100
# 327/327 - 3s - loss: 5.9570e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 6/100
# 327/327 - 3s - loss: 5.8921e-04 - val_loss: 0.0017 - 3s/epoch - 9ms/step
# Epoch 7/100
# 327/327 - 3s - loss: 5.8579e-04 - val_loss: 0.0017 - 3s/epoch - 9ms/step
# Epoch 8/100
# 327/327 - 3s - loss: 5.9918e-04 - val_loss: 0.0018 - 3s/epoch - 9ms/step
# Epoch 9/100
# 327/327 - 3s - loss: 6.1401e-04 - val_loss: 0.0019 - 3s/epoch - 9ms/step
# Epoch 10/100
# 327/327 - 3s - loss: 6.4133e-04 - val_loss: 0.0020 - 3s/epoch - 9ms/step
# Epoch 11/100
# 327/327 - 3s - loss: 6.7019e-04 - val_loss: 0.0021 - 3s/epoch - 9ms/step
# Epoch 12/100
# 327/327 - 3s - loss: 6.9316e-04 - val_loss: 0.0021 - 3s/epoch - 9ms/step
# Epoch 13/100
# 327/327 - 3s - loss: 6.8813e-04 - val_loss: 0.0022 - 3s/epoch - 8ms/step
# Epoch 14/100
# 327/327 - 3s - loss: 6.9805e-04 - val_loss: 0.0023 - 3s/epoch - 9ms/step
# Epoch 15/100
# 327/327 - 3s - loss: 7.4107e-04 - val_loss: 0.0023 - 3s/epoch - 8ms/step
# Epoch 16/100
# 327/327 - 3s - loss: 7.4661e-04 - val_loss: 0.0023 - 3s/epoch - 8ms/step
# Epoch 17/100
# 327/327 - 3s - loss: 7.3905e-04 - val_loss: 0.0023 - 3s/epoch - 9ms/step
# Epoch 18/100
# 327/327 - 3s - loss: 7.5897e-04 - val_loss: 0.0024 - 3s/epoch - 8ms/step
# Epoch 19/100
# 327/327 - 3s - loss: 7.9298e-04 - val_loss: 0.0026 - 3s/epoch - 9ms/step
# Epoch 20/100
# 327/327 - 3s - loss: 8.2125e-04 - val_loss: 0.0027 - 3s/epoch - 8ms/step
# Epoch 21/100
# 327/327 - 3s - loss: 8.3629e-04 - val_loss: 0.0027 - 3s/epoch - 9ms/step
# Epoch 22/100
# 327/327 - 3s - loss: 7.9675e-04 - val_loss: 0.0026 - 3s/epoch - 9ms/step
# Epoch 23/100
# 327/327 - 3s - loss: 7.6763e-04 - val_loss: 0.0025 - 3s/epoch - 8ms/step
# Epoch 24/100
# 327/327 - 3s - loss: 7.4537e-04 - val_loss: 0.0024 - 3s/epoch - 8ms/step
# Epoch 25/100
# 327/327 - 3s - loss: 7.2219e-04 - val_loss: 0.0022 - 3s/epoch - 8ms/step
# Epoch 26/100
# 327/327 - 3s - loss: 6.7896e-04 - val_loss: 0.0021 - 3s/epoch - 8ms/step
# Epoch 27/100
# 327/327 - 3s - loss: 6.4225e-04 - val_loss: 0.0019 - 3s/epoch - 8ms/step
# Epoch 28/100
# 327/327 - 3s - loss: 6.0809e-04 - val_loss: 0.0017 - 3s/epoch - 8ms/step
# Epoch 29/100
# 327/327 - 3s - loss: 5.8133e-04 - val_loss: 0.0016 - 3s/epoch - 8ms/step
# Epoch 30/100
# 327/327 - 3s - loss: 5.5103e-04 - val_loss: 0.0014 - 3s/epoch - 8ms/step
# Epoch 31/100
# 327/327 - 3s - loss: 5.2771e-04 - val_loss: 0.0013 - 3s/epoch - 8ms/step
# Epoch 32/100
# 327/327 - 3s - loss: 5.1846e-04 - val_loss: 0.0012 - 3s/epoch - 8ms/step
# Epoch 33/100
# 327/327 - 3s - loss: 5.1176e-04 - val_loss: 0.0012 - 3s/epoch - 9ms/step
# Epoch 34/100
# 327/327 - 3s - loss: 5.0866e-04 - val_loss: 0.0012 - 3s/epoch - 8ms/step
# Epoch 35/100
# 327/327 - 3s - loss: 5.0578e-04 - val_loss: 0.0011 - 3s/epoch - 8ms/step
# Epoch 36/100
# 327/327 - 3s - loss: 5.0327e-04 - val_loss: 0.0011 - 3s/epoch - 8ms/step
# Epoch 37/100
# 327/327 - 3s - loss: 4.9580e-04 - val_loss: 0.0011 - 3s/epoch - 8ms/step
# Epoch 38/100
# 327/327 - 3s - loss: 4.9342e-04 - val_loss: 0.0010 - 3s/epoch - 8ms/step
# Epoch 39/100
# 327/327 - 3s - loss: 4.8818e-04 - val_loss: 9.9361e-04 - 3s/epoch - 8ms/step
# Epoch 40/100
# 327/327 - 3s - loss: 4.8227e-04 - val_loss: 9.6537e-04 - 3s/epoch - 8ms/step
# Epoch 41/100
# 327/327 - 3s - loss: 4.7752e-04 - val_loss: 9.4198e-04 - 3s/epoch - 8ms/step
# Epoch 42/100
# 327/327 - 3s - loss: 4.7600e-04 - val_loss: 9.3671e-04 - 3s/epoch - 8ms/step
# Epoch 43/100
# 327/327 - 3s - loss: 4.7969e-04 - val_loss: 9.4282e-04 - 3s/epoch - 9ms/step
# Epoch 44/100
# 327/327 - 3s - loss: 4.7815e-04 - val_loss: 9.2787e-04 - 3s/epoch - 8ms/step
# Epoch 45/100
# 327/327 - 3s - loss: 4.7699e-04 - val_loss: 9.0630e-04 - 3s/epoch - 8ms/step
# Epoch 46/100
# 327/327 - 3s - loss: 4.7089e-04 - val_loss: 8.7727e-04 - 3s/epoch - 8ms/step
# Epoch 47/100
# 327/327 - 3s - loss: 4.6729e-04 - val_loss: 8.5544e-04 - 3s/epoch - 8ms/step
# Epoch 48/100
# 327/327 - 3s - loss: 4.5975e-04 - val_loss: 8.3081e-04 - 3s/epoch - 8ms/step
# Epoch 49/100
# 327/327 - 3s - loss: 4.5528e-04 - val_loss: 8.1682e-04 - 3s/epoch - 9ms/step
# Epoch 50/100
# 327/327 - 3s - loss: 4.5103e-04 - val_loss: 8.0300e-04 - 3s/epoch - 8ms/step
# Epoch 51/100
# 327/327 - 3s - loss: 4.4664e-04 - val_loss: 7.8543e-04 - 3s/epoch - 8ms/step
# Epoch 52/100
# 327/327 - 3s - loss: 4.4031e-04 - val_loss: 7.6118e-04 - 3s/epoch - 8ms/step
# Epoch 53/100
# 327/327 - 3s - loss: 4.3404e-04 - val_loss: 7.3845e-04 - 3s/epoch - 9ms/step
# Epoch 54/100
# 327/327 - 3s - loss: 4.2749e-04 - val_loss: 7.1987e-04 - 3s/epoch - 8ms/step
# Epoch 55/100
# 327/327 - 3s - loss: 4.2034e-04 - val_loss: 7.0706e-04 - 3s/epoch - 9ms/step
# Epoch 56/100
# 327/327 - 3s - loss: 4.1346e-04 - val_loss: 6.9334e-04 - 3s/epoch - 8ms/step
# Epoch 57/100
# 327/327 - 3s - loss: 4.0772e-04 - val_loss: 6.7553e-04 - 3s/epoch - 8ms/step
# Epoch 58/100
# 327/327 - 3s - loss: 3.9882e-04 - val_loss: 6.5698e-04 - 3s/epoch - 9ms/step
# Epoch 59/100
# 327/327 - 3s - loss: 3.9200e-04 - val_loss: 6.4453e-04 - 3s/epoch - 9ms/step
# Epoch 60/100
# 327/327 - 3s - loss: 3.8493e-04 - val_loss: 6.3028e-04 - 3s/epoch - 9ms/step
# Epoch 61/100
# 327/327 - 3s - loss: 3.7817e-04 - val_loss: 6.1721e-04 - 3s/epoch - 9ms/step
# Epoch 62/100
# 327/327 - 3s - loss: 3.7092e-04 - val_loss: 6.0674e-04 - 3s/epoch - 9ms/step
# Epoch 63/100
# 327/327 - 3s - loss: 3.6325e-04 - val_loss: 5.9274e-04 - 3s/epoch - 9ms/step
# Epoch 64/100
# 327/327 - 3s - loss: 3.5591e-04 - val_loss: 5.7745e-04 - 3s/epoch - 9ms/step
# Epoch 65/100
# 327/327 - 3s - loss: 3.4756e-04 - val_loss: 5.6123e-04 - 3s/epoch - 9ms/step
# Epoch 66/100
# 327/327 - 3s - loss: 3.3938e-04 - val_loss: 5.4699e-04 - 3s/epoch - 9ms/step
# Epoch 67/100
# 327/327 - 3s - loss: 3.3110e-04 - val_loss: 5.2816e-04 - 3s/epoch - 8ms/step
# Epoch 68/100
# 327/327 - 3s - loss: 3.2296e-04 - val_loss: 5.1506e-04 - 3s/epoch - 8ms/step
# Epoch 69/100
# 327/327 - 3s - loss: 3.1623e-04 - val_loss: 5.0468e-04 - 3s/epoch - 9ms/step
# Epoch 70/100
# 327/327 - 3s - loss: 3.0939e-04 - val_loss: 4.9383e-04 - 3s/epoch - 8ms/step
# Epoch 71/100
# 327/327 - 3s - loss: 3.0274e-04 - val_loss: 4.8980e-04 - 3s/epoch - 9ms/step
# Epoch 72/100
# 327/327 - 3s - loss: 2.9614e-04 - val_loss: 4.8041e-04 - 3s/epoch - 9ms/step
# Epoch 73/100
# 327/327 - 3s - loss: 2.8923e-04 - val_loss: 4.6781e-04 - 3s/epoch - 8ms/step
# Epoch 74/100
# 327/327 - 3s - loss: 2.8177e-04 - val_loss: 4.5501e-04 - 3s/epoch - 8ms/step
# Epoch 75/100
# 327/327 - 3s - loss: 2.7554e-04 - val_loss: 4.4446e-04 - 3s/epoch - 8ms/step
# Epoch 76/100
# 327/327 - 3s - loss: 2.6916e-04 - val_loss: 4.3866e-04 - 3s/epoch - 8ms/step
# Epoch 77/100
# 327/327 - 3s - loss: 2.6350e-04 - val_loss: 4.3021e-04 - 3s/epoch - 8ms/step
# Epoch 78/100
# 327/327 - 3s - loss: 2.5726e-04 - val_loss: 4.2134e-04 - 3s/epoch - 9ms/step
# Epoch 79/100
# 327/327 - 3s - loss: 2.5233e-04 - val_loss: 4.1249e-04 - 3s/epoch - 9ms/step
# Epoch 80/100
# 327/327 - 5s - loss: 2.4588e-04 - val_loss: 4.0603e-04 - 5s/epoch - 16ms/step
# Epoch 81/100
# 327/327 - 3s - loss: 2.4117e-04 - val_loss: 4.0172e-04 - 3s/epoch - 10ms/step
# Epoch 82/100
# 327/327 - 3s - loss: 2.3524e-04 - val_loss: 3.9363e-04 - 3s/epoch - 10ms/step
# Epoch 83/100
# 327/327 - 3s - loss: 2.3051e-04 - val_loss: 3.8814e-04 - 3s/epoch - 9ms/step
# Epoch 84/100
# 327/327 - 4s - loss: 2.2510e-04 - val_loss: 3.7973e-04 - 4s/epoch - 12ms/step
# Epoch 85/100
# 327/327 - 3s - loss: 2.2016e-04 - val_loss: 3.7242e-04 - 3s/epoch - 10ms/step
# Epoch 86/100
# 327/327 - 3s - loss: 2.1478e-04 - val_loss: 3.6348e-04 - 3s/epoch - 10ms/step
# Epoch 87/100
# 327/327 - 3s - loss: 2.1040e-04 - val_loss: 3.5896e-04 - 3s/epoch - 10ms/step
# Epoch 88/100
# 327/327 - 3s - loss: 2.0541e-04 - val_loss: 3.5202e-04 - 3s/epoch - 10ms/step
# Epoch 89/100
# 327/327 - 3s - loss: 2.0159e-04 - val_loss: 3.5048e-04 - 3s/epoch - 10ms/step
# Epoch 90/100
# 327/327 - 3s - loss: 1.9752e-04 - val_loss: 3.4715e-04 - 3s/epoch - 10ms/step
# Epoch 91/100
# 327/327 - 4s - loss: 1.9432e-04 - val_loss: 3.4987e-04 - 4s/epoch - 12ms/step
# Epoch 92/100
# 327/327 - 4s - loss: 1.9075e-04 - val_loss: 3.4770e-04 - 4s/epoch - 11ms/step
# Epoch 93/100
# 327/327 - 3s - loss: 1.8727e-04 - val_loss: 3.4485e-04 - 3s/epoch - 10ms/step
# Epoch 94/100
# 327/327 - 3s - loss: 1.8303e-04 - val_loss: 3.3568e-04 - 3s/epoch - 9ms/step
# Epoch 95/100
# 327/327 - 3s - loss: 1.7889e-04 - val_loss: 3.3087e-04 - 3s/epoch - 10ms/step
# Epoch 96/100
# 327/327 - 3s - loss: 1.7521e-04 - val_loss: 3.2487e-04 - 3s/epoch - 9ms/step
# Epoch 97/100
# 327/327 - 3s - loss: 1.7173e-04 - val_loss: 3.2352e-04 - 3s/epoch - 9ms/step
# Epoch 98/100
# 327/327 - 3s - loss: 1.6901e-04 - val_loss: 3.2181e-04 - 3s/epoch - 9ms/step
# Epoch 99/100
# 327/327 - 3s - loss: 1.6623e-04 - val_loss: 3.2223e-04 - 3s/epoch - 9ms/step
# Epoch 100/100
# 327/327 - 3s - loss: 1.6384e-04 - val_loss: 3.2181e-04 - 3s/epoch - 9ms/step
# Epoch 1/100
# 2023-04-02 19:19:50.937685: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:19:51.026056: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:19:51.182576: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:19:54.215183: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:19:54.250230: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 327/327 - 4s - loss: 7.2027e-04 - val_loss: 0.0017 - 4s/epoch - 13ms/step
# Epoch 2/100
# 327/327 - 3s - loss: 8.1438e-04 - val_loss: 0.0017 - 3s/epoch - 9ms/step
# Epoch 3/100
# 327/327 - 3s - loss: 6.9535e-04 - val_loss: 0.0016 - 3s/epoch - 10ms/step
# Epoch 4/100
# 327/327 - 3s - loss: 6.5891e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 5/100
# 327/327 - 3s - loss: 6.2640e-04 - val_loss: 0.0015 - 3s/epoch - 10ms/step
# Epoch 6/100
# 327/327 - 3s - loss: 6.0850e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 7/100
# 327/327 - 3s - loss: 6.0951e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 8/100
# 327/327 - 3s - loss: 6.4548e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 9/100
# 327/327 - 3s - loss: 6.0577e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 10/100
# 327/327 - 3s - loss: 6.2542e-04 - val_loss: 0.0017 - 3s/epoch - 9ms/step
# Epoch 11/100
# 327/327 - 3s - loss: 6.3071e-04 - val_loss: 0.0017 - 3s/epoch - 9ms/step
# Epoch 12/100
# 327/327 - 3s - loss: 6.1854e-04 - val_loss: 0.0018 - 3s/epoch - 9ms/step
# Epoch 13/100
# 327/327 - 3s - loss: 6.2169e-04 - val_loss: 0.0018 - 3s/epoch - 9ms/step
# Epoch 14/100
# 327/327 - 3s - loss: 6.2458e-04 - val_loss: 0.0019 - 3s/epoch - 9ms/step
# Epoch 15/100
# 327/327 - 3s - loss: 6.4643e-04 - val_loss: 0.0020 - 3s/epoch - 10ms/step
# Epoch 16/100
# 327/327 - 3s - loss: 6.7227e-04 - val_loss: 0.0021 - 3s/epoch - 9ms/step
# Epoch 17/100
# 327/327 - 3s - loss: 7.0700e-04 - val_loss: 0.0022 - 3s/epoch - 9ms/step
# Epoch 18/100
# 327/327 - 3s - loss: 7.4812e-04 - val_loss: 0.0023 - 3s/epoch - 9ms/step
# Epoch 19/100
# 327/327 - 3s - loss: 7.8930e-04 - val_loss: 0.0025 - 3s/epoch - 9ms/step
# Epoch 20/100
# 327/327 - 3s - loss: 8.0929e-04 - val_loss: 0.0026 - 3s/epoch - 9ms/step
# Epoch 21/100
# 327/327 - 3s - loss: 8.1805e-04 - val_loss: 0.0026 - 3s/epoch - 9ms/step
# Epoch 22/100
# 327/327 - 3s - loss: 8.1660e-04 - val_loss: 0.0027 - 3s/epoch - 9ms/step
# Epoch 23/100
# 327/327 - 3s - loss: 8.0548e-04 - val_loss: 0.0026 - 3s/epoch - 9ms/step
# Epoch 24/100
# 327/327 - 3s - loss: 7.6512e-04 - val_loss: 0.0023 - 3s/epoch - 9ms/step
# Epoch 25/100
# 327/327 - 3s - loss: 7.1740e-04 - val_loss: 0.0021 - 3s/epoch - 9ms/step
# Epoch 26/100
# 327/327 - 3s - loss: 6.8079e-04 - val_loss: 0.0020 - 3s/epoch - 9ms/step
# Epoch 27/100
# 327/327 - 3s - loss: 6.4343e-04 - val_loss: 0.0018 - 3s/epoch - 9ms/step
# Epoch 28/100
# 327/327 - 3s - loss: 6.1592e-04 - val_loss: 0.0017 - 3s/epoch - 10ms/step
# Epoch 29/100
# 327/327 - 3s - loss: 5.8962e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 30/100
# 327/327 - 3s - loss: 5.7040e-04 - val_loss: 0.0015 - 3s/epoch - 9ms/step
# Epoch 31/100
# 327/327 - 3s - loss: 5.5958e-04 - val_loss: 0.0014 - 3s/epoch - 9ms/step
# Epoch 32/100
# 327/327 - 3s - loss: 5.4802e-04 - val_loss: 0.0013 - 3s/epoch - 9ms/step
# Epoch 33/100
# 327/327 - 3s - loss: 5.3933e-04 - val_loss: 0.0013 - 3s/epoch - 9ms/step
# Epoch 34/100
# 327/327 - 3s - loss: 5.3288e-04 - val_loss: 0.0013 - 3s/epoch - 9ms/step
# Epoch 35/100
# 327/327 - 3s - loss: 5.2861e-04 - val_loss: 0.0012 - 3s/epoch - 9ms/step
# Epoch 36/100
# 327/327 - 3s - loss: 5.2249e-04 - val_loss: 0.0011 - 3s/epoch - 9ms/step
# Epoch 37/100
# 327/327 - 3s - loss: 5.0996e-04 - val_loss: 0.0011 - 3s/epoch - 9ms/step
# Epoch 38/100
# 327/327 - 3s - loss: 5.0298e-04 - val_loss: 0.0010 - 3s/epoch - 9ms/step
# Epoch 39/100
# 327/327 - 3s - loss: 4.9536e-04 - val_loss: 9.9836e-04 - 3s/epoch - 9ms/step
# Epoch 40/100
# 327/327 - 3s - loss: 4.9000e-04 - val_loss: 9.8109e-04 - 3s/epoch - 9ms/step
# Epoch 41/100
# 327/327 - 3s - loss: 4.9024e-04 - val_loss: 9.5311e-04 - 3s/epoch - 9ms/step
# Epoch 42/100
# 327/327 - 3s - loss: 4.8621e-04 - val_loss: 9.3307e-04 - 3s/epoch - 9ms/step
# Epoch 43/100
# 327/327 - 3s - loss: 4.8600e-04 - val_loss: 9.1641e-04 - 3s/epoch - 9ms/step
# Epoch 44/100
# 327/327 - 3s - loss: 4.8152e-04 - val_loss: 8.9724e-04 - 3s/epoch - 9ms/step
# Epoch 45/100
# 327/327 - 3s - loss: 4.7835e-04 - val_loss: 8.8711e-04 - 3s/epoch - 9ms/step
# Epoch 46/100
# 327/327 - 3s - loss: 4.7698e-04 - val_loss: 8.8281e-04 - 3s/epoch - 9ms/step
# Epoch 47/100
# 327/327 - 3s - loss: 4.7596e-04 - val_loss: 8.6984e-04 - 3s/epoch - 9ms/step
# Epoch 48/100
# 327/327 - 3s - loss: 4.7270e-04 - val_loss: 8.5345e-04 - 3s/epoch - 9ms/step
# Epoch 49/100
# 327/327 - 3s - loss: 4.6821e-04 - val_loss: 8.2259e-04 - 3s/epoch - 9ms/step
# Epoch 50/100
# 327/327 - 3s - loss: 4.6234e-04 - val_loss: 8.0115e-04 - 3s/epoch - 9ms/step
# Epoch 51/100
# 327/327 - 3s - loss: 4.5690e-04 - val_loss: 7.8160e-04 - 3s/epoch - 9ms/step
# Epoch 52/100
# 327/327 - 3s - loss: 4.5194e-04 - val_loss: 7.6654e-04 - 3s/epoch - 9ms/step
# Epoch 53/100
# 327/327 - 3s - loss: 4.4554e-04 - val_loss: 7.5137e-04 - 3s/epoch - 9ms/step
# Epoch 54/100
# 327/327 - 3s - loss: 4.3972e-04 - val_loss: 7.3104e-04 - 3s/epoch - 9ms/step
# Epoch 55/100
# 327/327 - 3s - loss: 4.3320e-04 - val_loss: 7.1201e-04 - 3s/epoch - 10ms/step
# Epoch 56/100
# 327/327 - 3s - loss: 4.2652e-04 - val_loss: 6.9508e-04 - 3s/epoch - 9ms/step
# Epoch 57/100
# 327/327 - 3s - loss: 4.1944e-04 - val_loss: 6.7380e-04 - 3s/epoch - 10ms/step
# Epoch 58/100
# 327/327 - 3s - loss: 4.1171e-04 - val_loss: 6.5861e-04 - 3s/epoch - 9ms/step
# Epoch 59/100
# 327/327 - 3s - loss: 4.0396e-04 - val_loss: 6.3871e-04 - 3s/epoch - 9ms/step
# Epoch 60/100
# 327/327 - 3s - loss: 3.9657e-04 - val_loss: 6.2285e-04 - 3s/epoch - 9ms/step
# Epoch 61/100
# 327/327 - 3s - loss: 3.8853e-04 - val_loss: 6.0660e-04 - 3s/epoch - 9ms/step
# Epoch 62/100
# 327/327 - 3s - loss: 3.8027e-04 - val_loss: 5.9043e-04 - 3s/epoch - 9ms/step
# Epoch 63/100
# 327/327 - 3s - loss: 3.7321e-04 - val_loss: 5.7761e-04 - 3s/epoch - 9ms/step
# Epoch 64/100
# 327/327 - 3s - loss: 3.6525e-04 - val_loss: 5.6213e-04 - 3s/epoch - 9ms/step
# Epoch 65/100
# 327/327 - 3s - loss: 3.5663e-04 - val_loss: 5.4995e-04 - 3s/epoch - 9ms/step
# Epoch 66/100
# 327/327 - 3s - loss: 3.4988e-04 - val_loss: 5.3604e-04 - 3s/epoch - 9ms/step
# Epoch 67/100
# 327/327 - 3s - loss: 3.4140e-04 - val_loss: 5.2575e-04 - 3s/epoch - 10ms/step
# Epoch 68/100
# 327/327 - 4s - loss: 3.3426e-04 - val_loss: 5.1113e-04 - 4s/epoch - 12ms/step
# Epoch 69/100
# 327/327 - 4s - loss: 3.2614e-04 - val_loss: 4.9718e-04 - 4s/epoch - 11ms/step
# Epoch 70/100
# 327/327 - 3s - loss: 3.1851e-04 - val_loss: 4.8692e-04 - 3s/epoch - 11ms/step
# Epoch 71/100
# 327/327 - 4s - loss: 3.1082e-04 - val_loss: 4.7374e-04 - 4s/epoch - 11ms/step
# Epoch 72/100
# 327/327 - 4s - loss: 3.0368e-04 - val_loss: 4.6202e-04 - 4s/epoch - 11ms/step
# Epoch 73/100
# 327/327 - 3s - loss: 2.9607e-04 - val_loss: 4.5213e-04 - 3s/epoch - 10ms/step
# Epoch 74/100
# 327/327 - 3s - loss: 2.8992e-04 - val_loss: 4.4154e-04 - 3s/epoch - 9ms/step
# Epoch 75/100
# 327/327 - 3s - loss: 2.8220e-04 - val_loss: 4.3058e-04 - 3s/epoch - 9ms/step
# Epoch 76/100
# 327/327 - 3s - loss: 2.7619e-04 - val_loss: 4.1976e-04 - 3s/epoch - 9ms/step
# Epoch 77/100
# 327/327 - 3s - loss: 2.6897e-04 - val_loss: 4.1017e-04 - 3s/epoch - 9ms/step
# Epoch 78/100
# 327/327 - 3s - loss: 2.6354e-04 - val_loss: 4.0060e-04 - 3s/epoch - 9ms/step
# Epoch 79/100
# 327/327 - 3s - loss: 2.5697e-04 - val_loss: 3.9266e-04 - 3s/epoch - 9ms/step
# Epoch 80/100
# 327/327 - 3s - loss: 2.5122e-04 - val_loss: 3.8166e-04 - 3s/epoch - 9ms/step
# Epoch 81/100
# 327/327 - 3s - loss: 2.4501e-04 - val_loss: 3.7528e-04 - 3s/epoch - 9ms/step
# Epoch 82/100
# 327/327 - 3s - loss: 2.4068e-04 - val_loss: 3.6885e-04 - 3s/epoch - 9ms/step
# Epoch 83/100
# 327/327 - 3s - loss: 2.3507e-04 - val_loss: 3.6323e-04 - 3s/epoch - 11ms/step
# Epoch 84/100
# 327/327 - 6s - loss: 2.3099e-04 - val_loss: 3.5816e-04 - 6s/epoch - 18ms/step
# Epoch 85/100
# 327/327 - 6s - loss: 2.2573e-04 - val_loss: 3.5213e-04 - 6s/epoch - 19ms/step
# Epoch 86/100
# 327/327 - 3s - loss: 2.2165e-04 - val_loss: 3.4646e-04 - 3s/epoch - 10ms/step
# Epoch 87/100
# 327/327 - 3s - loss: 2.1663e-04 - val_loss: 3.3899e-04 - 3s/epoch - 9ms/step
# Epoch 88/100
# 327/327 - 3s - loss: 2.1266e-04 - val_loss: 3.3389e-04 - 3s/epoch - 11ms/step
# Epoch 89/100
# 327/327 - 3s - loss: 2.0822e-04 - val_loss: 3.2909e-04 - 3s/epoch - 10ms/step
# Epoch 90/100
# 327/327 - 3s - loss: 2.0472e-04 - val_loss: 3.2557e-04 - 3s/epoch - 10ms/step
# Epoch 91/100
# 327/327 - 3s - loss: 2.0061e-04 - val_loss: 3.2105e-04 - 3s/epoch - 10ms/step
# Epoch 92/100
# 327/327 - 3s - loss: 1.9730e-04 - val_loss: 3.1738e-04 - 3s/epoch - 10ms/step
# Epoch 93/100
# 327/327 - 3s - loss: 1.9329e-04 - val_loss: 3.1296e-04 - 3s/epoch - 10ms/step
# Epoch 94/100
# 327/327 - 3s - loss: 1.9010e-04 - val_loss: 3.0972e-04 - 3s/epoch - 9ms/step
# Epoch 95/100
# 327/327 - 3s - loss: 1.8635e-04 - val_loss: 3.0521e-04 - 3s/epoch - 10ms/step
# Epoch 96/100
# 327/327 - 3s - loss: 1.8327e-04 - val_loss: 3.0213e-04 - 3s/epoch - 10ms/step
# Epoch 97/100
# 327/327 - 3s - loss: 1.7978e-04 - val_loss: 2.9810e-04 - 3s/epoch - 9ms/step
# Epoch 98/100
# 327/327 - 3s - loss: 1.7696e-04 - val_loss: 2.9615e-04 - 3s/epoch - 9ms/step
# Epoch 99/100
# 327/327 - 3s - loss: 1.7380e-04 - val_loss: 2.9331e-04 - 3s/epoch - 9ms/step
# Epoch 100/100
# 327/327 - 3s - loss: 1.7129e-04 - val_loss: 2.9250e-04 - 3s/epoch - 9ms/step
# Epoch 1/100
# 2023-04-02 19:25:04.080911: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:25:04.205931: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:25:04.371122: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:25:07.607527: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:25:07.644161: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 327/327 - 5s - loss: 8.0972e-04 - val_loss: 0.0024 - 5s/epoch - 14ms/step
# Epoch 2/100
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 3/100
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0024 - 3s/epoch - 9ms/step
# Epoch 4/100
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 5/100
# 327/327 - 3s - loss: 9.9943e-04 - val_loss: 0.0027 - 3s/epoch - 9ms/step
# Epoch 6/100
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0031 - 3s/epoch - 9ms/step
# Epoch 7/100
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0034 - 3s/epoch - 10ms/step
# Epoch 8/100
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0038 - 3s/epoch - 9ms/step
# Epoch 9/100
# 327/327 - 3s - loss: 0.0013 - val_loss: 0.0040 - 3s/epoch - 9ms/step
# Epoch 10/100
# 327/327 - 3s - loss: 0.0013 - val_loss: 0.0042 - 3s/epoch - 9ms/step
# Epoch 11/100
# 327/327 - 3s - loss: 0.0014 - val_loss: 0.0043 - 3s/epoch - 10ms/step
# Epoch 12/100
# 327/327 - 3s - loss: 0.0014 - val_loss: 0.0045 - 3s/epoch - 10ms/step
# Epoch 13/100
# 327/327 - 3s - loss: 0.0014 - val_loss: 0.0043 - 3s/epoch - 9ms/step
# Epoch 14/100
# 327/327 - 3s - loss: 0.0013 - val_loss: 0.0041 - 3s/epoch - 9ms/step
# Epoch 15/100
# 327/327 - 3s - loss: 0.0012 - val_loss: 0.0039 - 3s/epoch - 10ms/step
# Epoch 16/100
# 327/327 - 3s - loss: 0.0011 - val_loss: 0.0035 - 3s/epoch - 9ms/step
# Epoch 17/100
# 327/327 - 3s - loss: 0.0010 - val_loss: 0.0032 - 3s/epoch - 9ms/step
# Epoch 18/100
# 327/327 - 3s - loss: 9.5120e-04 - val_loss: 0.0029 - 3s/epoch - 10ms/step
# Epoch 19/100
# 327/327 - 3s - loss: 8.8109e-04 - val_loss: 0.0025 - 3s/epoch - 9ms/step
# Epoch 20/100
# 327/327 - 3s - loss: 8.1807e-04 - val_loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 21/100
# 327/327 - 3s - loss: 7.8134e-04 - val_loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 22/100
# 327/327 - 3s - loss: 7.4985e-04 - val_loss: 0.0019 - 3s/epoch - 9ms/step
# Epoch 23/100
# 327/327 - 3s - loss: 7.2578e-04 - val_loss: 0.0017 - 3s/epoch - 10ms/step
# Epoch 24/100
# 327/327 - 3s - loss: 7.0572e-04 - val_loss: 0.0016 - 3s/epoch - 9ms/step
# Epoch 25/100
# 327/327 - 3s - loss: 6.9240e-04 - val_loss: 0.0015 - 3s/epoch - 10ms/step
# Epoch 26/100
# 327/327 - 3s - loss: 6.9098e-04 - val_loss: 0.0015 - 3s/epoch - 10ms/step
# Epoch 27/100
# 327/327 - 3s - loss: 6.9626e-04 - val_loss: 0.0015 - 3s/epoch - 9ms/step
# Epoch 28/100
# 327/327 - 3s - loss: 7.0345e-04 - val_loss: 0.0014 - 3s/epoch - 9ms/step
# Epoch 29/100
# 327/327 - 3s - loss: 7.0374e-04 - val_loss: 0.0014 - 3s/epoch - 10ms/step
# Epoch 30/100
# 327/327 - 3s - loss: 7.0711e-04 - val_loss: 0.0014 - 3s/epoch - 9ms/step
# Epoch 31/100
# 327/327 - 3s - loss: 7.1121e-04 - val_loss: 0.0014 - 3s/epoch - 9ms/step
# Epoch 32/100
# 327/327 - 3s - loss: 7.1654e-04 - val_loss: 0.0014 - 3s/epoch - 10ms/step
# Epoch 33/100
# 327/327 - 3s - loss: 7.0848e-04 - val_loss: 0.0013 - 3s/epoch - 10ms/step
# Epoch 34/100
# 327/327 - 3s - loss: 7.0921e-04 - val_loss: 0.0013 - 3s/epoch - 9ms/step
# Epoch 35/100
# 327/327 - 3s - loss: 7.0237e-04 - val_loss: 0.0012 - 3s/epoch - 9ms/step
# Epoch 36/100
# 327/327 - 3s - loss: 6.9709e-04 - val_loss: 0.0012 - 3s/epoch - 10ms/step
# Epoch 37/100
# 327/327 - 3s - loss: 6.9728e-04 - val_loss: 0.0012 - 3s/epoch - 9ms/step
# Epoch 38/100
# 327/327 - 3s - loss: 6.9786e-04 - val_loss: 0.0012 - 3s/epoch - 10ms/step
# Epoch 39/100
# 327/327 - 3s - loss: 6.8789e-04 - val_loss: 0.0011 - 3s/epoch - 9ms/step
# Epoch 40/100
# 327/327 - 3s - loss: 6.8348e-04 - val_loss: 0.0011 - 3s/epoch - 10ms/step
# Epoch 41/100
# 327/327 - 3s - loss: 6.7549e-04 - val_loss: 0.0011 - 3s/epoch - 9ms/step
# Epoch 42/100
# 327/327 - 3s - loss: 6.6370e-04 - val_loss: 0.0010 - 3s/epoch - 9ms/step
# Epoch 43/100
# 327/327 - 3s - loss: 6.5339e-04 - val_loss: 9.8910e-04 - 3s/epoch - 10ms/step
# Epoch 44/100
# 327/327 - 3s - loss: 6.3898e-04 - val_loss: 9.5115e-04 - 3s/epoch - 9ms/step
# Epoch 45/100
# 327/327 - 3s - loss: 6.2000e-04 - val_loss: 8.8941e-04 - 3s/epoch - 9ms/step
# Epoch 46/100
# 327/327 - 3s - loss: 5.9967e-04 - val_loss: 8.6267e-04 - 3s/epoch - 9ms/step
# Epoch 47/100
# 327/327 - 3s - loss: 5.8451e-04 - val_loss: 8.3205e-04 - 3s/epoch - 9ms/step
# Epoch 48/100
# 327/327 - 3s - loss: 5.6525e-04 - val_loss: 8.1564e-04 - 3s/epoch - 10ms/step
# Epoch 49/100
# 327/327 - 3s - loss: 5.5071e-04 - val_loss: 7.7748e-04 - 3s/epoch - 10ms/step
# Epoch 50/100
# 327/327 - 3s - loss: 5.2981e-04 - val_loss: 7.6161e-04 - 3s/epoch - 9ms/step
# Epoch 51/100
# 327/327 - 3s - loss: 5.1429e-04 - val_loss: 7.3219e-04 - 3s/epoch - 9ms/step
# Epoch 52/100
# 327/327 - 3s - loss: 4.9541e-04 - val_loss: 7.1253e-04 - 3s/epoch - 10ms/step
# Epoch 53/100
# 327/327 - 3s - loss: 4.8087e-04 - val_loss: 7.1139e-04 - 3s/epoch - 9ms/step
# Epoch 54/100
# 327/327 - 3s - loss: 4.6777e-04 - val_loss: 7.0202e-04 - 3s/epoch - 9ms/step
# Epoch 55/100
# 327/327 - 3s - loss: 4.4956e-04 - val_loss: 6.8753e-04 - 3s/epoch - 9ms/step
# Epoch 56/100
# 327/327 - 3s - loss: 4.3501e-04 - val_loss: 6.8497e-04 - 3s/epoch - 10ms/step
# Epoch 57/100
# 327/327 - 3s - loss: 4.2032e-04 - val_loss: 6.7103e-04 - 3s/epoch - 9ms/step
# Epoch 58/100
# 327/327 - 3s - loss: 4.0577e-04 - val_loss: 6.6528e-04 - 3s/epoch - 9ms/step
# Epoch 59/100
# 327/327 - 3s - loss: 3.9207e-04 - val_loss: 6.4767e-04 - 3s/epoch - 9ms/step
# Epoch 60/100
# 327/327 - 3s - loss: 3.7958e-04 - val_loss: 6.4774e-04 - 3s/epoch - 10ms/step
# Epoch 61/100
# 327/327 - 3s - loss: 3.6608e-04 - val_loss: 6.3597e-04 - 3s/epoch - 9ms/step
# Epoch 62/100
# 327/327 - 3s - loss: 3.5413e-04 - val_loss: 6.3014e-04 - 3s/epoch - 10ms/step
# Epoch 63/100
# 327/327 - 3s - loss: 3.4281e-04 - val_loss: 6.1695e-04 - 3s/epoch - 11ms/step
# Epoch 64/100
# 327/327 - 3s - loss: 3.3132e-04 - val_loss: 6.0745e-04 - 3s/epoch - 10ms/step
# Epoch 65/100
# 327/327 - 3s - loss: 3.2147e-04 - val_loss: 5.9969e-04 - 3s/epoch - 11ms/step
# Epoch 66/100
# 327/327 - 4s - loss: 3.0943e-04 - val_loss: 5.8743e-04 - 4s/epoch - 11ms/step
# Epoch 67/100
# 327/327 - 3s - loss: 2.9936e-04 - val_loss: 5.8098e-04 - 3s/epoch - 10ms/step
# Epoch 68/100
# 327/327 - 3s - loss: 2.8974e-04 - val_loss: 5.6967e-04 - 3s/epoch - 9ms/step
# Epoch 69/100
# 327/327 - 3s - loss: 2.8051e-04 - val_loss: 5.6101e-04 - 3s/epoch - 9ms/step
# Epoch 70/100
# 327/327 - 3s - loss: 2.7234e-04 - val_loss: 5.5494e-04 - 3s/epoch - 10ms/step
# Epoch 71/100
# 327/327 - 3s - loss: 2.6374e-04 - val_loss: 5.4173e-04 - 3s/epoch - 9ms/step
# Epoch 72/100
# 327/327 - 3s - loss: 2.5634e-04 - val_loss: 5.3707e-04 - 3s/epoch - 9ms/step
# Epoch 73/100
# 327/327 - 3s - loss: 2.4853e-04 - val_loss: 5.2569e-04 - 3s/epoch - 10ms/step
# Epoch 74/100
# 327/327 - 3s - loss: 2.4098e-04 - val_loss: 5.1735e-04 - 3s/epoch - 9ms/step
# Epoch 75/100
# 327/327 - 3s - loss: 2.3356e-04 - val_loss: 5.0571e-04 - 3s/epoch - 9ms/step
# Epoch 76/100
# 327/327 - 3s - loss: 2.2628e-04 - val_loss: 4.9587e-04 - 3s/epoch - 9ms/step
# Epoch 77/100
# 327/327 - 3s - loss: 2.2019e-04 - val_loss: 4.8603e-04 - 3s/epoch - 9ms/step
# Epoch 78/100
# 327/327 - 3s - loss: 2.1357e-04 - val_loss: 4.7904e-04 - 3s/epoch - 10ms/step
# Epoch 79/100
# 327/327 - 3s - loss: 2.0818e-04 - val_loss: 4.7482e-04 - 3s/epoch - 10ms/step
# Epoch 80/100
# 327/327 - 3s - loss: 2.0280e-04 - val_loss: 4.6713e-04 - 3s/epoch - 10ms/step
# Epoch 81/100
# 327/327 - 3s - loss: 1.9753e-04 - val_loss: 4.6427e-04 - 3s/epoch - 9ms/step
# Epoch 82/100
# 327/327 - 3s - loss: 1.9303e-04 - val_loss: 4.5556e-04 - 3s/epoch - 9ms/step
# Epoch 83/100
# 327/327 - 3s - loss: 1.8817e-04 - val_loss: 4.5276e-04 - 3s/epoch - 10ms/step
# Epoch 84/100
# 327/327 - 3s - loss: 1.8427e-04 - val_loss: 4.4468e-04 - 3s/epoch - 9ms/step
# Epoch 85/100
# 327/327 - 3s - loss: 1.7972e-04 - val_loss: 4.4151e-04 - 3s/epoch - 9ms/step
# Epoch 86/100
# 327/327 - 3s - loss: 1.7604e-04 - val_loss: 4.3613e-04 - 3s/epoch - 9ms/step
# Epoch 87/100
# 327/327 - 3s - loss: 1.7245e-04 - val_loss: 4.3560e-04 - 3s/epoch - 10ms/step
# Epoch 88/100
# 327/327 - 3s - loss: 1.6869e-04 - val_loss: 4.3044e-04 - 3s/epoch - 9ms/step
# Epoch 89/100
# 327/327 - 3s - loss: 1.6497e-04 - val_loss: 4.2521e-04 - 3s/epoch - 9ms/step
# Epoch 90/100
# 327/327 - 3s - loss: 1.6153e-04 - val_loss: 4.2094e-04 - 3s/epoch - 10ms/step
# Epoch 91/100
# 327/327 - 3s - loss: 1.5812e-04 - val_loss: 4.1403e-04 - 3s/epoch - 9ms/step
# Epoch 92/100
# 327/327 - 3s - loss: 1.5480e-04 - val_loss: 4.0714e-04 - 3s/epoch - 9ms/step
# Epoch 93/100
# 327/327 - 3s - loss: 1.5170e-04 - val_loss: 4.0225e-04 - 3s/epoch - 10ms/step
# Epoch 94/100
# 327/327 - 3s - loss: 1.4897e-04 - val_loss: 3.9749e-04 - 3s/epoch - 9ms/step
# Epoch 95/100
# 327/327 - 3s - loss: 1.4694e-04 - val_loss: 3.9739e-04 - 3s/epoch - 10ms/step
# Epoch 96/100
# 327/327 - 3s - loss: 1.4566e-04 - val_loss: 4.0473e-04 - 3s/epoch - 10ms/step
# Epoch 97/100
# 327/327 - 3s - loss: 1.4436e-04 - val_loss: 4.0703e-04 - 3s/epoch - 10ms/step
# Epoch 98/100
# 327/327 - 3s - loss: 1.4311e-04 - val_loss: 4.0943e-04 - 3s/epoch - 9ms/step
# Epoch 99/100
# 327/327 - 4s - loss: 1.4145e-04 - val_loss: 4.1030e-04 - 4s/epoch - 11ms/step
# Epoch 100/100
# 327/327 - 3s - loss: 1.3968e-04 - val_loss: 4.0948e-04 - 3s/epoch - 10ms/step

# %%
i=0
wb2 = Workbook()
ws2 = wb2.active
for m in models2:
    # make a prediction
    test_x2 = test_X
    yhat = LSTMUnit.predict(test_x2, m)
    inv_yhat = Preprocessing.inverse_scaler(yhat, scaler)
    inv_y = Preprocessing.inverse_scaler(test_y.reshape(-1,1), scaler)
    print(hyperparam2[i])
    print("Epoch: "+ str(lstms2[i].params['epochs']))
    print("Neurons: "+str(m.layers[0].units))
    i = i+1
    ws2['A'+str(i)] = 'LSTM'
    ws2['B'+str(i)] = hyperparam2[i-1][0]
    ws2['C'+str(i)] = hyperparam2[i-1][1]
    ws2['D'+str(i)] = hyperparam2[i-1][2]
    print('RMSE')
    print(Evaluation.rmse(inv_y,inv_yhat)[0])
    ws2['E'+str(i)] = Evaluation.rmse(inv_y,inv_yhat)[0]
    print('MAE')
    print(Evaluation.mae(inv_y,inv_yhat)[0])
    ws2['F'+str(i)] = Evaluation.mae(inv_y,inv_yhat)[0]
    print('MAPE')
    print(Evaluation.mape(inv_y,inv_yhat)[0])
    ws2['G'+str(i)] = Evaluation.mape(inv_y,inv_yhat)[0]
    LSTMUnit.save_model(m, 0, 'BTC',hyperparam2[i-1])
wb2.save('LSTM_BTC_result2.xlsx')
# Out:
#   1/164 [..............................] - ETA: 45s
# 2023-04-02 19:30:18.672241: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:18.708467: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 4ms/step
# (64, 25, 50)
# Epoch: 25
# Neurons: 50
# RMSE
# 2731.690500656773
# MAE
# 2644.62421103783
# MAPE
# 13.658124940310115
#   9/164 [>.............................] - ETA: 0s
# 2023-04-02 19:30:19.724543: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:19.756562: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 4ms/step
# (64, 25, 60)
# Epoch: 25
# Neurons: 60
# RMSE
# 663.7927007820763
# MAE
# 612.0577255996023
# MAPE
# 3.1986919804225895
#   9/164 [>.............................] - ETA: 1s
# 2023-04-02 19:30:20.644674: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:20.678093: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (64, 25, 100)
# Epoch: 25
# Neurons: 100
# RMSE
# 2588.439233517593
# MAE
# 2501.2380767502873
# MAPE
# 12.929126439670682
#   9/164 [>.............................] - ETA: 1s
# 2023-04-02 19:30:21.540697: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:21.574954: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 4ms/step
# (64, 50, 50)
# Epoch: 50
# Neurons: 50
# RMSE
# 1780.439598209091
# MAE
# 1736.5668907088561
# MAPE
# 8.909370792381068
#  12/164 [=>............................] - ETA: 0s
# 2023-04-02 19:30:22.462741: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:22.495607: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (64, 50, 60)
# Epoch: 50
# Neurons: 60
# RMSE
# 685.3244412445846
# MAE
# 631.319673722925
# MAPE
# 3.310953618639935
#   7/164 [>.............................] - ETA: 1s
# 2023-04-02 19:30:23.362730: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:23.394614: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (64, 50, 100)
# Epoch: 50
# Neurons: 100
# RMSE
# 1765.3976617363182
# MAE
# 1732.0706944843737
# MAPE
# 8.846324305545854
#  10/164 [>.............................] - ETA: 0s
# 2023-04-02 19:30:24.203843: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:24.235499: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (64, 100, 50)
# Epoch: 100
# Neurons: 50
# RMSE
# 1157.1288020356196
# MAE
# 1107.5331457255104
# MAPE
# 5.740374861421507
#   9/164 [>.............................] - ETA: 1s
# 2023-04-02 19:30:25.053231: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:25.085185: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (64, 100, 60)
# Epoch: 100
# Neurons: 60
# RMSE
# 1103.1735474915843
# MAE
# 1055.2720142233313
# MAPE
# 5.470138948395145
#  11/164 [=>............................] - ETA: 0s
# 2023-04-02 19:30:25.898044: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:25.929303: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (64, 100, 100)
# Epoch: 100
# Neurons: 100
# RMSE
# 1305.257296817899
# MAE
# 1236.6623577966257
# MAPE
# 6.453166023063241

# %%
lstms3 = []
models3 = []
for batch, epoch, neuron in hyperparam3:
    model, lstm = LSTMUnit.train_lstm(train_X, train_y, test_X, test_y, neuron, epoch, batch)
    lstms3.append(lstm)
    models3.append(model)
# Out:
# Epoch 1/25
# 2023-04-02 19:30:27.232246: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:27.335634: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:27.521211: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:29.532901: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:30:29.569949: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 - 3s - loss: 0.0013 - val_loss: 0.0031 - 3s/epoch - 19ms/step
# Epoch 2/25
# 164/164 - 2s - loss: 0.0015 - val_loss: 0.0047 - 2s/epoch - 10ms/step
# Epoch 3/25
# 164/164 - 2s - loss: 0.0019 - val_loss: 0.0079 - 2s/epoch - 10ms/step
# Epoch 4/25
# 164/164 - 2s - loss: 0.0025 - val_loss: 0.0114 - 2s/epoch - 10ms/step
# Epoch 5/25
# 164/164 - 2s - loss: 0.0035 - val_loss: 0.0144 - 2s/epoch - 10ms/step
# Epoch 6/25
# 164/164 - 2s - loss: 0.0042 - val_loss: 0.0146 - 2s/epoch - 10ms/step
# Epoch 7/25
# 164/164 - 2s - loss: 0.0048 - val_loss: 0.0116 - 2s/epoch - 10ms/step
# Epoch 8/25
# 164/164 - 2s - loss: 0.0048 - val_loss: 0.0071 - 2s/epoch - 10ms/step
# Epoch 9/25
# 164/164 - 2s - loss: 0.0033 - val_loss: 0.0037 - 2s/epoch - 10ms/step
# Epoch 10/25
# 164/164 - 2s - loss: 0.0018 - val_loss: 0.0017 - 2s/epoch - 9ms/step
# Epoch 11/25
# 164/164 - 2s - loss: 9.3434e-04 - val_loss: 6.5002e-04 - 2s/epoch - 10ms/step
# Epoch 12/25
# 164/164 - 2s - loss: 5.3775e-04 - val_loss: 2.0407e-04 - 2s/epoch - 10ms/step
# Epoch 13/25
# 164/164 - 2s - loss: 4.0086e-04 - val_loss: 7.8766e-05 - 2s/epoch - 10ms/step
# Epoch 14/25
# 164/164 - 2s - loss: 3.5496e-04 - val_loss: 5.9013e-05 - 2s/epoch - 10ms/step
# Epoch 15/25
# 164/164 - 2s - loss: 3.3467e-04 - val_loss: 7.5425e-05 - 2s/epoch - 10ms/step
# Epoch 16/25
# 164/164 - 2s - loss: 3.2923e-04 - val_loss: 1.3409e-04 - 2s/epoch - 10ms/step
# Epoch 17/25
# 164/164 - 2s - loss: 3.4246e-04 - val_loss: 2.6145e-04 - 2s/epoch - 10ms/step
# Epoch 18/25
# 164/164 - 2s - loss: 3.8084e-04 - val_loss: 4.9468e-04 - 2s/epoch - 10ms/step
# Epoch 19/25
# 164/164 - 2s - loss: 4.5275e-04 - val_loss: 8.8172e-04 - 2s/epoch - 10ms/step
# Epoch 20/25
# 164/164 - 2s - loss: 5.6879e-04 - val_loss: 0.0015 - 2s/epoch - 9ms/step
# Epoch 21/25
# 164/164 - 2s - loss: 7.3975e-04 - val_loss: 0.0023 - 2s/epoch - 10ms/step
# Epoch 22/25
# 164/164 - 2s - loss: 9.6846e-04 - val_loss: 0.0031 - 2s/epoch - 9ms/step
# Epoch 23/25
# 164/164 - 2s - loss: 0.0012 - val_loss: 0.0036 - 2s/epoch - 9ms/step
# Epoch 24/25
# 164/164 - 2s - loss: 0.0013 - val_loss: 0.0037 - 2s/epoch - 9ms/step
# Epoch 25/25
# 164/164 - 2s - loss: 0.0016 - val_loss: 0.0032 - 2s/epoch - 9ms/step
# Epoch 1/25
# 2023-04-02 19:31:08.483367: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:31:08.590240: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:31:08.760186: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:31:10.613425: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:31:10.649945: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 - 3s - loss: 0.0011 - val_loss: 0.0030 - 3s/epoch - 18ms/step
# Epoch 2/25
# 164/164 - 1s - loss: 0.0015 - val_loss: 0.0048 - 1s/epoch - 9ms/step
# Epoch 3/25
# 164/164 - 1s - loss: 0.0021 - val_loss: 0.0091 - 1s/epoch - 9ms/step
# Epoch 4/25
# 164/164 - 1s - loss: 0.0029 - val_loss: 0.0132 - 1s/epoch - 9ms/step
# Epoch 5/25
# 164/164 - 1s - loss: 0.0038 - val_loss: 0.0161 - 1s/epoch - 9ms/step
# Epoch 6/25
# 164/164 - 2s - loss: 0.0048 - val_loss: 0.0160 - 2s/epoch - 9ms/step
# Epoch 7/25
# 164/164 - 1s - loss: 0.0057 - val_loss: 0.0118 - 1s/epoch - 9ms/step
# Epoch 8/25
# 164/164 - 2s - loss: 0.0054 - val_loss: 0.0066 - 2s/epoch - 9ms/step
# Epoch 9/25
# 164/164 - 1s - loss: 0.0036 - val_loss: 0.0032 - 1s/epoch - 9ms/step
# Epoch 10/25
# 164/164 - 1s - loss: 0.0019 - val_loss: 0.0014 - 1s/epoch - 9ms/step
# Epoch 11/25
# 164/164 - 1s - loss: 9.3546e-04 - val_loss: 4.9398e-04 - 1s/epoch - 9ms/step
# Epoch 12/25
# 164/164 - 1s - loss: 5.3488e-04 - val_loss: 1.3221e-04 - 1s/epoch - 9ms/step
# Epoch 13/25
# 164/164 - 1s - loss: 4.0370e-04 - val_loss: 5.0651e-05 - 1s/epoch - 9ms/step
# Epoch 14/25
# 164/164 - 1s - loss: 3.5869e-04 - val_loss: 4.1694e-05 - 1s/epoch - 9ms/step
# Epoch 15/25
# 164/164 - 1s - loss: 3.3411e-04 - val_loss: 5.1996e-05 - 1s/epoch - 9ms/step
# Epoch 16/25
# 164/164 - 1s - loss: 3.2230e-04 - val_loss: 9.6013e-05 - 1s/epoch - 9ms/step
# Epoch 17/25
# 164/164 - 1s - loss: 3.2809e-04 - val_loss: 1.9994e-04 - 1s/epoch - 9ms/step
# Epoch 18/25
# 164/164 - 1s - loss: 3.5748e-04 - val_loss: 3.9759e-04 - 1s/epoch - 9ms/step
# Epoch 19/25
# 164/164 - 1s - loss: 4.1805e-04 - val_loss: 7.3486e-04 - 1s/epoch - 9ms/step
# Epoch 20/25
# 164/164 - 1s - loss: 5.2014e-04 - val_loss: 0.0013 - 1s/epoch - 9ms/step
# Epoch 21/25
# 164/164 - 1s - loss: 6.7618e-04 - val_loss: 0.0020 - 1s/epoch - 9ms/step
# Epoch 22/25
# 164/164 - 1s - loss: 8.9562e-04 - val_loss: 0.0029 - 1s/epoch - 9ms/step
# Epoch 23/25
# 164/164 - 1s - loss: 0.0012 - val_loss: 0.0036 - 1s/epoch - 9ms/step
# Epoch 24/25
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0037 - 1s/epoch - 9ms/step
# Epoch 25/25
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0033 - 1s/epoch - 8ms/step
# Epoch 1/25
# 2023-04-02 19:31:46.553438: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:31:46.647677: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:31:46.790964: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:31:48.488723: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:31:48.522323: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 - 3s - loss: 0.0013 - val_loss: 0.0037 - 3s/epoch - 18ms/step
# Epoch 2/25
# 164/164 - 1s - loss: 0.0019 - val_loss: 0.0065 - 1s/epoch - 9ms/step
# Epoch 3/25
# 164/164 - 1s - loss: 0.0033 - val_loss: 0.0123 - 1s/epoch - 9ms/step
# Epoch 4/25
# 164/164 - 1s - loss: 0.0046 - val_loss: 0.0188 - 1s/epoch - 9ms/step
# Epoch 5/25
# 164/164 - 2s - loss: 0.0063 - val_loss: 0.0225 - 2s/epoch - 9ms/step
# Epoch 6/25
# 164/164 - 1s - loss: 0.0079 - val_loss: 0.0180 - 1s/epoch - 9ms/step
# Epoch 7/25
# 164/164 - 1s - loss: 0.0088 - val_loss: 0.0104 - 1s/epoch - 9ms/step
# Epoch 8/25
# 164/164 - 1s - loss: 0.0063 - val_loss: 0.0052 - 1s/epoch - 9ms/step
# Epoch 9/25
# 164/164 - 1s - loss: 0.0035 - val_loss: 0.0022 - 1s/epoch - 9ms/step
# Epoch 10/25
# 164/164 - 1s - loss: 0.0016 - val_loss: 7.5479e-04 - 1s/epoch - 9ms/step
# Epoch 11/25
# 164/164 - 1s - loss: 8.1820e-04 - val_loss: 1.5992e-04 - 1s/epoch - 9ms/step
# Epoch 12/25
# 164/164 - 1s - loss: 5.4845e-04 - val_loss: 5.1350e-05 - 1s/epoch - 8ms/step
# Epoch 13/25
# 164/164 - 1s - loss: 4.7018e-04 - val_loss: 5.2910e-05 - 1s/epoch - 9ms/step
# Epoch 14/25
# 164/164 - 1s - loss: 4.2629e-04 - val_loss: 4.4325e-05 - 1s/epoch - 9ms/step
# Epoch 15/25
# 164/164 - 1s - loss: 3.9297e-04 - val_loss: 6.2503e-05 - 1s/epoch - 8ms/step
# Epoch 16/25
# 164/164 - 1s - loss: 3.8040e-04 - val_loss: 1.4145e-04 - 1s/epoch - 8ms/step
# Epoch 17/25
# 164/164 - 1s - loss: 3.9520e-04 - val_loss: 3.1269e-04 - 1s/epoch - 8ms/step
# Epoch 18/25
# 164/164 - 1s - loss: 4.4356e-04 - val_loss: 6.1817e-04 - 1s/epoch - 8ms/step
# Epoch 19/25
# 164/164 - 1s - loss: 5.3419e-04 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 20/25
# 164/164 - 1s - loss: 6.7811e-04 - val_loss: 0.0018 - 1s/epoch - 8ms/step
# Epoch 21/25
# 164/164 - 1s - loss: 8.8441e-04 - val_loss: 0.0027 - 1s/epoch - 8ms/step
# Epoch 22/25
# 164/164 - 1s - loss: 0.0011 - val_loss: 0.0035 - 1s/epoch - 8ms/step
# Epoch 23/25
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0039 - 1s/epoch - 8ms/step
# Epoch 24/25
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0034 - 1s/epoch - 8ms/step
# Epoch 25/25
# 164/164 - 1s - loss: 0.0016 - val_loss: 0.0036 - 1s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-02 19:32:23.129368: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:32:23.216904: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:32:23.379437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:32:25.101438: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:32:25.132976: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 - 3s - loss: 0.0012 - val_loss: 0.0030 - 3s/epoch - 16ms/step
# Epoch 2/50
# 164/164 - 1s - loss: 0.0015 - val_loss: 0.0046 - 1s/epoch - 8ms/step
# Epoch 3/50
# 164/164 - 1s - loss: 0.0020 - val_loss: 0.0086 - 1s/epoch - 8ms/step
# Epoch 4/50
# 164/164 - 1s - loss: 0.0027 - val_loss: 0.0128 - 1s/epoch - 9ms/step
# Epoch 5/50
# 164/164 - 1s - loss: 0.0039 - val_loss: 0.0158 - 1s/epoch - 8ms/step
# Epoch 6/50
# 164/164 - 1s - loss: 0.0052 - val_loss: 0.0146 - 1s/epoch - 8ms/step
# Epoch 7/50
# 164/164 - 1s - loss: 0.0057 - val_loss: 0.0098 - 1s/epoch - 9ms/step
# Epoch 8/50
# 164/164 - 1s - loss: 0.0046 - val_loss: 0.0053 - 1s/epoch - 8ms/step
# Epoch 9/50
# 164/164 - 1s - loss: 0.0027 - val_loss: 0.0025 - 1s/epoch - 8ms/step
# Epoch 10/50
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0010 - 1s/epoch - 8ms/step
# Epoch 11/50
# 164/164 - 1s - loss: 6.9342e-04 - val_loss: 3.4021e-04 - 1s/epoch - 8ms/step
# Epoch 12/50
# 164/164 - 1s - loss: 4.3641e-04 - val_loss: 9.9560e-05 - 1s/epoch - 8ms/step
# Epoch 13/50
# 164/164 - 1s - loss: 3.5605e-04 - val_loss: 5.0652e-05 - 1s/epoch - 8ms/step
# Epoch 14/50
# 164/164 - 1s - loss: 3.2605e-04 - val_loss: 4.9607e-05 - 1s/epoch - 8ms/step
# Epoch 15/50
# 164/164 - 1s - loss: 3.1163e-04 - val_loss: 7.6562e-05 - 1s/epoch - 8ms/step
# Epoch 16/50
# 164/164 - 1s - loss: 3.1207e-04 - val_loss: 1.5226e-04 - 1s/epoch - 8ms/step
# Epoch 17/50
# 164/164 - 1s - loss: 3.3303e-04 - val_loss: 3.0823e-04 - 1s/epoch - 8ms/step
# Epoch 18/50
# 164/164 - 1s - loss: 3.8172e-04 - val_loss: 5.8746e-04 - 1s/epoch - 8ms/step
# Epoch 19/50
# 164/164 - 1s - loss: 4.6772e-04 - val_loss: 0.0010 - 1s/epoch - 8ms/step
# Epoch 20/50
# 164/164 - 1s - loss: 6.0341e-04 - val_loss: 0.0017 - 1s/epoch - 8ms/step
# Epoch 21/50
# 164/164 - 1s - loss: 8.0232e-04 - val_loss: 0.0026 - 1s/epoch - 8ms/step
# Epoch 22/50
# 164/164 - 1s - loss: 0.0011 - val_loss: 0.0036 - 1s/epoch - 8ms/step
# Epoch 23/50
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0040 - 1s/epoch - 8ms/step
# Epoch 24/50
# 164/164 - 1s - loss: 0.0015 - val_loss: 0.0040 - 1s/epoch - 8ms/step
# Epoch 25/50
# 164/164 - 1s - loss: 0.0017 - val_loss: 0.0034 - 1s/epoch - 8ms/step
# Epoch 26/50
# 164/164 - 1s - loss: 0.0016 - val_loss: 0.0019 - 1s/epoch - 8ms/step
# Epoch 27/50
# 164/164 - 1s - loss: 0.0012 - val_loss: 7.3015e-04 - 1s/epoch - 8ms/step
# Epoch 28/50
# 164/164 - 1s - loss: 9.1539e-04 - val_loss: 1.3654e-04 - 1s/epoch - 8ms/step
# Epoch 29/50
# 164/164 - 1s - loss: 6.8836e-04 - val_loss: 8.6026e-05 - 1s/epoch - 8ms/step
# Epoch 30/50
# 164/164 - 1s - loss: 5.9595e-04 - val_loss: 1.2845e-04 - 1s/epoch - 8ms/step
# Epoch 31/50
# 164/164 - 1s - loss: 5.1973e-04 - val_loss: 1.1712e-04 - 1s/epoch - 8ms/step
# Epoch 32/50
# 164/164 - 1s - loss: 4.4908e-04 - val_loss: 8.2987e-05 - 1s/epoch - 8ms/step
# Epoch 33/50
# 164/164 - 1s - loss: 3.9249e-04 - val_loss: 5.0350e-05 - 1s/epoch - 8ms/step
# Epoch 34/50
# 164/164 - 1s - loss: 3.5228e-04 - val_loss: 3.4965e-05 - 1s/epoch - 8ms/step
# Epoch 35/50
# 164/164 - 1s - loss: 3.2935e-04 - val_loss: 4.8753e-05 - 1s/epoch - 8ms/step
# Epoch 36/50
# 164/164 - 1s - loss: 3.2435e-04 - val_loss: 1.0456e-04 - 1s/epoch - 9ms/step
# Epoch 37/50
# 164/164 - 1s - loss: 3.3870e-04 - val_loss: 2.1908e-04 - 1s/epoch - 8ms/step
# Epoch 38/50
# 164/164 - 1s - loss: 3.7488e-04 - val_loss: 4.1221e-04 - 1s/epoch - 8ms/step
# Epoch 39/50
# 164/164 - 1s - loss: 4.3597e-04 - val_loss: 6.9724e-04 - 1s/epoch - 8ms/step
# Epoch 40/50
# 164/164 - 1s - loss: 5.2293e-04 - val_loss: 0.0010 - 1s/epoch - 8ms/step
# Epoch 41/50
# 164/164 - 1s - loss: 6.2061e-04 - val_loss: 0.0013 - 1s/epoch - 8ms/step
# Epoch 42/50
# 164/164 - 1s - loss: 7.2049e-04 - val_loss: 0.0017 - 1s/epoch - 8ms/step
# Epoch 43/50
# 164/164 - 1s - loss: 8.9953e-04 - val_loss: 0.0021 - 1s/epoch - 8ms/step
# Epoch 44/50
# 164/164 - 1s - loss: 9.8909e-04 - val_loss: 0.0019 - 1s/epoch - 8ms/step
# Epoch 45/50
# 164/164 - 1s - loss: 9.7306e-04 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 46/50
# 164/164 - 1s - loss: 7.6854e-04 - val_loss: 3.7564e-04 - 1s/epoch - 9ms/step
# Epoch 47/50
# 164/164 - 1s - loss: 5.6850e-04 - val_loss: 7.3780e-05 - 1s/epoch - 8ms/step
# Epoch 48/50
# 164/164 - 1s - loss: 4.5159e-04 - val_loss: 5.5433e-05 - 1s/epoch - 8ms/step
# Epoch 49/50
# 164/164 - 1s - loss: 3.9253e-04 - val_loss: 7.7949e-05 - 1s/epoch - 8ms/step
# Epoch 50/50
# 164/164 - 1s - loss: 3.4600e-04 - val_loss: 7.2806e-05 - 1s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-02 19:33:33.128216: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:33:33.209469: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:33:33.332403: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:33:34.998010: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:33:35.029451: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 - 3s - loss: 0.0012 - val_loss: 0.0029 - 3s/epoch - 16ms/step
# Epoch 2/50
# 164/164 - 1s - loss: 0.0015 - val_loss: 0.0049 - 1s/epoch - 8ms/step
# Epoch 3/50
# 164/164 - 1s - loss: 0.0021 - val_loss: 0.0092 - 1s/epoch - 8ms/step
# Epoch 4/50
# 164/164 - 1s - loss: 0.0029 - val_loss: 0.0133 - 1s/epoch - 8ms/step
# Epoch 5/50
# 164/164 - 1s - loss: 0.0041 - val_loss: 0.0170 - 1s/epoch - 8ms/step
# Epoch 6/50
# 164/164 - 1s - loss: 0.0055 - val_loss: 0.0154 - 1s/epoch - 8ms/step
# Epoch 7/50
# 164/164 - 1s - loss: 0.0062 - val_loss: 0.0102 - 1s/epoch - 8ms/step
# Epoch 8/50
# 164/164 - 1s - loss: 0.0051 - val_loss: 0.0054 - 1s/epoch - 8ms/step
# Epoch 9/50
# 164/164 - 1s - loss: 0.0031 - val_loss: 0.0026 - 1s/epoch - 8ms/step
# Epoch 10/50
# 164/164 - 1s - loss: 0.0016 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 11/50
# 164/164 - 1s - loss: 7.7786e-04 - val_loss: 3.6573e-04 - 1s/epoch - 8ms/step
# Epoch 12/50
# 164/164 - 1s - loss: 4.6803e-04 - val_loss: 9.8500e-05 - 1s/epoch - 8ms/step
# Epoch 13/50
# 164/164 - 1s - loss: 3.7020e-04 - val_loss: 4.5294e-05 - 1s/epoch - 8ms/step
# Epoch 14/50
# 164/164 - 1s - loss: 3.3418e-04 - val_loss: 4.1263e-05 - 1s/epoch - 8ms/step
# Epoch 15/50
# 164/164 - 1s - loss: 3.1391e-04 - val_loss: 5.7587e-05 - 1s/epoch - 8ms/step
# Epoch 16/50
# 164/164 - 1s - loss: 3.0685e-04 - val_loss: 1.1310e-04 - 1s/epoch - 8ms/step
# Epoch 17/50
# 164/164 - 1s - loss: 3.1825e-04 - val_loss: 2.3568e-04 - 1s/epoch - 8ms/step
# Epoch 18/50
# 164/164 - 1s - loss: 3.5444e-04 - val_loss: 4.6279e-04 - 1s/epoch - 8ms/step
# Epoch 19/50
# 164/164 - 1s - loss: 4.2380e-04 - val_loss: 8.4590e-04 - 1s/epoch - 8ms/step
# Epoch 20/50
# 164/164 - 1s - loss: 5.3777e-04 - val_loss: 0.0014 - 1s/epoch - 8ms/step
# Epoch 21/50
# 164/164 - 1s - loss: 7.0977e-04 - val_loss: 0.0023 - 1s/epoch - 8ms/step
# Epoch 22/50
# 164/164 - 1s - loss: 9.5137e-04 - val_loss: 0.0033 - 1s/epoch - 8ms/step
# Epoch 23/50
# 164/164 - 1s - loss: 0.0012 - val_loss: 0.0039 - 1s/epoch - 8ms/step
# Epoch 24/50
# 164/164 - 1s - loss: 0.0013 - val_loss: 0.0040 - 1s/epoch - 8ms/step
# Epoch 25/50
# 164/164 - 1s - loss: 0.0017 - val_loss: 0.0041 - 1s/epoch - 8ms/step
# Epoch 26/50
# 164/164 - 1s - loss: 0.0018 - val_loss: 0.0032 - 1s/epoch - 8ms/step
# Epoch 27/50
# 164/164 - 1s - loss: 0.0016 - val_loss: 0.0016 - 1s/epoch - 8ms/step
# Epoch 28/50
# 164/164 - 1s - loss: 0.0012 - val_loss: 5.1734e-04 - 1s/epoch - 8ms/step
# Epoch 29/50
# 164/164 - 1s - loss: 8.5357e-04 - val_loss: 8.3840e-05 - 1s/epoch - 8ms/step
# Epoch 30/50
# 164/164 - 1s - loss: 6.5895e-04 - val_loss: 1.0003e-04 - 1s/epoch - 8ms/step
# Epoch 31/50
# 164/164 - 1s - loss: 5.7371e-04 - val_loss: 1.2422e-04 - 1s/epoch - 8ms/step
# Epoch 32/50
# 164/164 - 1s - loss: 4.9019e-04 - val_loss: 1.0475e-04 - 1s/epoch - 8ms/step
# Epoch 33/50
# 164/164 - 1s - loss: 4.1830e-04 - val_loss: 7.0725e-05 - 1s/epoch - 8ms/step
# Epoch 34/50
# 164/164 - 1s - loss: 3.6265e-04 - val_loss: 4.1988e-05 - 1s/epoch - 8ms/step
# Epoch 35/50
# 164/164 - 1s - loss: 3.2436e-04 - val_loss: 3.1231e-05 - 1s/epoch - 8ms/step
# Epoch 36/50
# 164/164 - 1s - loss: 3.0337e-04 - val_loss: 4.8964e-05 - 1s/epoch - 8ms/step
# Epoch 37/50
# 164/164 - 1s - loss: 2.9998e-04 - val_loss: 1.0747e-04 - 1s/epoch - 8ms/step
# Epoch 38/50
# 164/164 - 1s - loss: 3.1539e-04 - val_loss: 2.2366e-04 - 1s/epoch - 8ms/step
# Epoch 39/50
# 164/164 - 1s - loss: 3.5206e-04 - val_loss: 4.1889e-04 - 1s/epoch - 8ms/step
# Epoch 40/50
# 164/164 - 1s - loss: 4.1330e-04 - val_loss: 7.0917e-04 - 1s/epoch - 8ms/step
# Epoch 41/50
# 164/164 - 1s - loss: 4.9878e-04 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 42/50
# 164/164 - 1s - loss: 5.9233e-04 - val_loss: 0.0013 - 1s/epoch - 8ms/step
# Epoch 43/50
# 164/164 - 1s - loss: 6.9554e-04 - val_loss: 0.0020 - 1s/epoch - 8ms/step
# Epoch 44/50
# 164/164 - 1s - loss: 8.6625e-04 - val_loss: 0.0024 - 1s/epoch - 8ms/step
# Epoch 45/50
# 164/164 - 1s - loss: 0.0011 - val_loss: 0.0021 - 1s/epoch - 8ms/step
# Epoch 46/50
# 164/164 - 1s - loss: 0.0010 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 47/50
# 164/164 - 1s - loss: 7.8759e-04 - val_loss: 3.5404e-04 - 1s/epoch - 8ms/step
# Epoch 48/50
# 164/164 - 1s - loss: 5.7109e-04 - val_loss: 6.4267e-05 - 1s/epoch - 8ms/step
# Epoch 49/50
# 164/164 - 1s - loss: 4.5021e-04 - val_loss: 5.6257e-05 - 1s/epoch - 8ms/step
# Epoch 50/50
# 164/164 - 1s - loss: 3.8517e-04 - val_loss: 7.8451e-05 - 1s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-02 19:34:41.048704: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:34:41.128556: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:34:41.255001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:34:42.894168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:34:42.924962: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 - 3s - loss: 0.0012 - val_loss: 0.0029 - 3s/epoch - 16ms/step
# Epoch 2/50
# 164/164 - 1s - loss: 0.0018 - val_loss: 0.0064 - 1s/epoch - 8ms/step
# Epoch 3/50
# 164/164 - 1s - loss: 0.0030 - val_loss: 0.0117 - 1s/epoch - 8ms/step
# Epoch 4/50
# 164/164 - 1s - loss: 0.0047 - val_loss: 0.0185 - 1s/epoch - 8ms/step
# Epoch 5/50
# 164/164 - 1s - loss: 0.0065 - val_loss: 0.0251 - 1s/epoch - 8ms/step
# Epoch 6/50
# 164/164 - 1s - loss: 0.0091 - val_loss: 0.0189 - 1s/epoch - 8ms/step
# Epoch 7/50
# 164/164 - 1s - loss: 0.0103 - val_loss: 0.0103 - 1s/epoch - 8ms/step
# Epoch 8/50
# 164/164 - 1s - loss: 0.0068 - val_loss: 0.0045 - 1s/epoch - 8ms/step
# Epoch 9/50
# 164/164 - 1s - loss: 0.0034 - val_loss: 0.0017 - 1s/epoch - 8ms/step
# Epoch 10/50
# 164/164 - 1s - loss: 0.0015 - val_loss: 4.9570e-04 - 1s/epoch - 8ms/step
# Epoch 11/50
# 164/164 - 1s - loss: 7.4237e-04 - val_loss: 7.9209e-05 - 1s/epoch - 9ms/step
# Epoch 12/50
# 164/164 - 1s - loss: 5.0140e-04 - val_loss: 5.7355e-05 - 1s/epoch - 8ms/step
# Epoch 13/50
# 164/164 - 1s - loss: 4.3192e-04 - val_loss: 7.0131e-05 - 1s/epoch - 8ms/step
# Epoch 14/50
# 164/164 - 1s - loss: 3.8604e-04 - val_loss: 4.5443e-05 - 1s/epoch - 8ms/step
# Epoch 15/50
# 164/164 - 1s - loss: 3.4888e-04 - val_loss: 3.8567e-05 - 1s/epoch - 8ms/step
# Epoch 16/50
# 164/164 - 1s - loss: 3.3149e-04 - val_loss: 8.6047e-05 - 1s/epoch - 8ms/step
# Epoch 17/50
# 164/164 - 1s - loss: 3.3997e-04 - val_loss: 2.1922e-04 - 1s/epoch - 8ms/step
# Epoch 18/50
# 164/164 - 1s - loss: 3.8032e-04 - val_loss: 4.8254e-04 - 1s/epoch - 8ms/step
# Epoch 19/50
# 164/164 - 1s - loss: 4.6195e-04 - val_loss: 9.3812e-04 - 1s/epoch - 8ms/step
# Epoch 20/50
# 164/164 - 1s - loss: 5.9826e-04 - val_loss: 0.0016 - 1s/epoch - 8ms/step
# Epoch 21/50
# 164/164 - 1s - loss: 8.0313e-04 - val_loss: 0.0026 - 1s/epoch - 8ms/step
# Epoch 22/50
# 164/164 - 1s - loss: 0.0011 - val_loss: 0.0036 - 1s/epoch - 8ms/step
# Epoch 23/50
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0041 - 1s/epoch - 8ms/step
# Epoch 24/50
# 164/164 - 1s - loss: 0.0015 - val_loss: 0.0037 - 1s/epoch - 8ms/step
# Epoch 25/50
# 164/164 - 1s - loss: 0.0016 - val_loss: 0.0039 - 1s/epoch - 8ms/step
# Epoch 26/50
# 164/164 - 1s - loss: 0.0019 - val_loss: 0.0034 - 1s/epoch - 8ms/step
# Epoch 27/50
# 164/164 - 1s - loss: 0.0018 - val_loss: 0.0022 - 1s/epoch - 8ms/step
# Epoch 28/50
# 164/164 - 1s - loss: 0.0015 - val_loss: 8.5358e-04 - 1s/epoch - 8ms/step
# Epoch 29/50
# 164/164 - 1s - loss: 0.0011 - val_loss: 1.1601e-04 - 1s/epoch - 8ms/step
# Epoch 30/50
# 164/164 - 1s - loss: 8.0281e-04 - val_loss: 1.9424e-04 - 1s/epoch - 8ms/step
# Epoch 31/50
# 164/164 - 1s - loss: 6.9472e-04 - val_loss: 2.6641e-04 - 1s/epoch - 8ms/step
# Epoch 32/50
# 164/164 - 1s - loss: 5.6884e-04 - val_loss: 2.4026e-04 - 1s/epoch - 8ms/step
# Epoch 33/50
# 164/164 - 1s - loss: 4.6576e-04 - val_loss: 1.7291e-04 - 1s/epoch - 8ms/step
# Epoch 34/50
# 164/164 - 1s - loss: 3.8592e-04 - val_loss: 1.0207e-04 - 1s/epoch - 8ms/step
# Epoch 35/50
# 164/164 - 1s - loss: 3.2848e-04 - val_loss: 4.9714e-05 - 1s/epoch - 8ms/step
# Epoch 36/50
# 164/164 - 1s - loss: 2.9267e-04 - val_loss: 2.6547e-05 - 1s/epoch - 8ms/step
# Epoch 37/50
# 164/164 - 1s - loss: 2.7752e-04 - val_loss: 4.3519e-05 - 1s/epoch - 8ms/step
# Epoch 38/50
# 164/164 - 1s - loss: 2.8326e-04 - val_loss: 1.1781e-04 - 1s/epoch - 8ms/step
# Epoch 39/50
# 164/164 - 1s - loss: 3.1214e-04 - val_loss: 2.7585e-04 - 1s/epoch - 8ms/step
# Epoch 40/50
# 164/164 - 1s - loss: 3.6844e-04 - val_loss: 5.4860e-04 - 1s/epoch - 8ms/step
# Epoch 41/50
# 164/164 - 1s - loss: 4.5613e-04 - val_loss: 9.3406e-04 - 1s/epoch - 8ms/step
# Epoch 42/50
# 164/164 - 1s - loss: 5.5483e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 43/50
# 164/164 - 1s - loss: 6.4010e-04 - val_loss: 0.0018 - 1s/epoch - 8ms/step
# Epoch 44/50
# 164/164 - 1s - loss: 7.7468e-04 - val_loss: 0.0023 - 1s/epoch - 8ms/step
# Epoch 45/50
# 164/164 - 1s - loss: 0.0011 - val_loss: 0.0029 - 1s/epoch - 8ms/step
# Epoch 46/50
# 164/164 - 2s - loss: 0.0012 - val_loss: 0.0026 - 2s/epoch - 10ms/step
# Epoch 47/50
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 48/50
# 164/164 - 1s - loss: 9.8637e-04 - val_loss: 2.1553e-04 - 1s/epoch - 8ms/step
# Epoch 49/50
# 164/164 - 1s - loss: 6.1602e-04 - val_loss: 9.6235e-05 - 1s/epoch - 8ms/step
# Epoch 50/50
# 164/164 - 1s - loss: 4.5770e-04 - val_loss: 3.1195e-04 - 1s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-02 19:35:50.634351: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:35:50.722835: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:35:50.853812: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:35:52.530943: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:35:52.562014: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 - 3s - loss: 0.0011 - val_loss: 0.0027 - 3s/epoch - 16ms/step
# Epoch 2/100
# 164/164 - 1s - loss: 0.0013 - val_loss: 0.0040 - 1s/epoch - 8ms/step
# Epoch 3/100
# 164/164 - 1s - loss: 0.0018 - val_loss: 0.0073 - 1s/epoch - 8ms/step
# Epoch 4/100
# 164/164 - 1s - loss: 0.0024 - val_loss: 0.0103 - 1s/epoch - 9ms/step
# Epoch 5/100
# 164/164 - 1s - loss: 0.0031 - val_loss: 0.0136 - 1s/epoch - 8ms/step
# Epoch 6/100
# 164/164 - 1s - loss: 0.0040 - val_loss: 0.0148 - 1s/epoch - 8ms/step
# Epoch 7/100
# 164/164 - 1s - loss: 0.0048 - val_loss: 0.0128 - 1s/epoch - 8ms/step
# Epoch 8/100
# 164/164 - 1s - loss: 0.0050 - val_loss: 0.0083 - 1s/epoch - 8ms/step
# Epoch 9/100
# 164/164 - 1s - loss: 0.0038 - val_loss: 0.0044 - 1s/epoch - 8ms/step
# Epoch 10/100
# 164/164 - 1s - loss: 0.0022 - val_loss: 0.0021 - 1s/epoch - 8ms/step
# Epoch 11/100
# 164/164 - 1s - loss: 0.0011 - val_loss: 8.3225e-04 - 1s/epoch - 8ms/step
# Epoch 12/100
# 164/164 - 1s - loss: 6.2521e-04 - val_loss: 2.6238e-04 - 1s/epoch - 8ms/step
# Epoch 13/100
# 164/164 - 1s - loss: 4.3783e-04 - val_loss: 8.7384e-05 - 1s/epoch - 8ms/step
# Epoch 14/100
# 164/164 - 1s - loss: 3.7661e-04 - val_loss: 5.5001e-05 - 1s/epoch - 8ms/step
# Epoch 15/100
# 164/164 - 1s - loss: 3.5048e-04 - val_loss: 6.1258e-05 - 1s/epoch - 8ms/step
# Epoch 16/100
# 164/164 - 1s - loss: 3.3920e-04 - val_loss: 1.0146e-04 - 1s/epoch - 8ms/step
# Epoch 17/100
# 164/164 - 1s - loss: 3.4489e-04 - val_loss: 1.9860e-04 - 1s/epoch - 8ms/step
# Epoch 18/100
# 164/164 - 1s - loss: 3.7346e-04 - val_loss: 3.8527e-04 - 1s/epoch - 8ms/step
# Epoch 19/100
# 164/164 - 1s - loss: 4.3239e-04 - val_loss: 7.0424e-04 - 1s/epoch - 8ms/step
# Epoch 20/100
# 164/164 - 1s - loss: 5.3131e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 21/100
# 164/164 - 1s - loss: 6.8127e-04 - val_loss: 0.0019 - 1s/epoch - 8ms/step
# Epoch 22/100
# 164/164 - 1s - loss: 8.8957e-04 - val_loss: 0.0027 - 1s/epoch - 8ms/step
# Epoch 23/100
# 164/164 - 1s - loss: 0.0011 - val_loss: 0.0034 - 1s/epoch - 8ms/step
# Epoch 24/100
# 164/164 - 1s - loss: 0.0013 - val_loss: 0.0034 - 1s/epoch - 8ms/step
# Epoch 25/100
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0031 - 1s/epoch - 8ms/step
# Epoch 26/100
# 164/164 - 1s - loss: 0.0016 - val_loss: 0.0024 - 1s/epoch - 8ms/step
# Epoch 27/100
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 28/100
# 164/164 - 1s - loss: 0.0011 - val_loss: 3.4416e-04 - 1s/epoch - 8ms/step
# Epoch 29/100
# 164/164 - 1s - loss: 7.7797e-04 - val_loss: 7.3060e-05 - 1s/epoch - 8ms/step
# Epoch 30/100
# 164/164 - 1s - loss: 6.4172e-04 - val_loss: 9.8702e-05 - 1s/epoch - 8ms/step
# Epoch 31/100
# 164/164 - 1s - loss: 5.6634e-04 - val_loss: 1.1292e-04 - 1s/epoch - 8ms/step
# Epoch 32/100
# 164/164 - 1s - loss: 4.9494e-04 - val_loss: 9.2903e-05 - 1s/epoch - 8ms/step
# Epoch 33/100
# 164/164 - 1s - loss: 4.3392e-04 - val_loss: 6.2345e-05 - 1s/epoch - 8ms/step
# Epoch 34/100
# 164/164 - 1s - loss: 3.8720e-04 - val_loss: 3.9874e-05 - 1s/epoch - 8ms/step
# Epoch 35/100
# 164/164 - 1s - loss: 3.5649e-04 - val_loss: 3.8658e-05 - 1s/epoch - 8ms/step
# Epoch 36/100
# 164/164 - 1s - loss: 3.4266e-04 - val_loss: 7.0364e-05 - 1s/epoch - 8ms/step
# Epoch 37/100
# 164/164 - 1s - loss: 3.4672e-04 - val_loss: 1.4825e-04 - 1s/epoch - 8ms/step
# Epoch 38/100
# 164/164 - 1s - loss: 3.7038e-04 - val_loss: 2.8787e-04 - 1s/epoch - 8ms/step
# Epoch 39/100
# 164/164 - 1s - loss: 4.1590e-04 - val_loss: 5.0237e-04 - 1s/epoch - 8ms/step
# Epoch 40/100
# 164/164 - 1s - loss: 4.8458e-04 - val_loss: 7.8388e-04 - 1s/epoch - 8ms/step
# Epoch 41/100
# 164/164 - 1s - loss: 5.7089e-04 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 42/100
# 164/164 - 1s - loss: 6.6170e-04 - val_loss: 0.0013 - 1s/epoch - 8ms/step
# Epoch 43/100
# 164/164 - 1s - loss: 7.0761e-04 - val_loss: 0.0015 - 1s/epoch - 8ms/step
# Epoch 44/100
# 164/164 - 1s - loss: 8.9332e-04 - val_loss: 0.0017 - 1s/epoch - 8ms/step
# Epoch 45/100
# 164/164 - 1s - loss: 9.3621e-04 - val_loss: 0.0013 - 1s/epoch - 8ms/step
# Epoch 46/100
# 164/164 - 1s - loss: 8.2366e-04 - val_loss: 6.1384e-04 - 1s/epoch - 8ms/step
# Epoch 47/100
# 164/164 - 1s - loss: 6.4277e-04 - val_loss: 1.8087e-04 - 1s/epoch - 8ms/step
# Epoch 48/100
# 164/164 - 1s - loss: 4.9694e-04 - val_loss: 4.6628e-05 - 1s/epoch - 8ms/step
# Epoch 49/100
# 164/164 - 1s - loss: 4.1402e-04 - val_loss: 5.8329e-05 - 1s/epoch - 8ms/step
# Epoch 50/100
# 164/164 - 1s - loss: 3.6450e-04 - val_loss: 6.9967e-05 - 1s/epoch - 8ms/step
# Epoch 51/100
# 164/164 - 1s - loss: 3.2411e-04 - val_loss: 5.8690e-05 - 1s/epoch - 8ms/step
# Epoch 52/100
# 164/164 - 1s - loss: 2.9147e-04 - val_loss: 3.8288e-05 - 1s/epoch - 8ms/step
# Epoch 53/100
# 164/164 - 1s - loss: 2.6843e-04 - val_loss: 2.4577e-05 - 1s/epoch - 8ms/step
# Epoch 54/100
# 164/164 - 1s - loss: 2.5687e-04 - val_loss: 3.2168e-05 - 1s/epoch - 8ms/step
# Epoch 55/100
# 164/164 - 1s - loss: 2.5881e-04 - val_loss: 7.6423e-05 - 1s/epoch - 8ms/step
# Epoch 56/100
# 164/164 - 1s - loss: 2.7658e-04 - val_loss: 1.7519e-04 - 1s/epoch - 8ms/step
# Epoch 57/100
# 164/164 - 1s - loss: 3.1306e-04 - val_loss: 3.4588e-04 - 1s/epoch - 8ms/step
# Epoch 58/100
# 164/164 - 1s - loss: 3.6993e-04 - val_loss: 5.7817e-04 - 1s/epoch - 8ms/step
# Epoch 59/100
# 164/164 - 1s - loss: 4.3487e-04 - val_loss: 7.9205e-04 - 1s/epoch - 8ms/step
# Epoch 60/100
# 164/164 - 1s - loss: 5.2447e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 61/100
# 164/164 - 1s - loss: 6.4778e-04 - val_loss: 0.0013 - 1s/epoch - 8ms/step
# Epoch 62/100
# 164/164 - 1s - loss: 6.8916e-04 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 63/100
# 164/164 - 1s - loss: 6.3725e-04 - val_loss: 6.0919e-04 - 1s/epoch - 8ms/step
# Epoch 64/100
# 164/164 - 1s - loss: 5.1864e-04 - val_loss: 2.2745e-04 - 1s/epoch - 8ms/step
# Epoch 65/100
# 164/164 - 1s - loss: 4.0135e-04 - val_loss: 5.3684e-05 - 1s/epoch - 8ms/step
# Epoch 66/100
# 164/164 - 1s - loss: 3.2323e-04 - val_loss: 3.0269e-05 - 1s/epoch - 8ms/step
# Epoch 67/100
# 164/164 - 1s - loss: 2.7743e-04 - val_loss: 4.1447e-05 - 1s/epoch - 8ms/step
# Epoch 68/100
# 164/164 - 1s - loss: 2.4597e-04 - val_loss: 3.9807e-05 - 1s/epoch - 8ms/step
# Epoch 69/100
# 164/164 - 1s - loss: 2.2261e-04 - val_loss: 2.6931e-05 - 1s/epoch - 8ms/step
# Epoch 70/100
# 164/164 - 1s - loss: 2.0730e-04 - val_loss: 1.7061e-05 - 1s/epoch - 8ms/step
# Epoch 71/100
# 164/164 - 1s - loss: 2.0173e-04 - val_loss: 2.6702e-05 - 1s/epoch - 8ms/step
# Epoch 72/100
# 164/164 - 1s - loss: 2.0826e-04 - val_loss: 7.4691e-05 - 1s/epoch - 8ms/step
# Epoch 73/100
# 164/164 - 1s - loss: 2.2990e-04 - val_loss: 1.8286e-04 - 1s/epoch - 8ms/step
# Epoch 74/100
# 164/164 - 1s - loss: 2.7010e-04 - val_loss: 3.6403e-04 - 1s/epoch - 8ms/step
# Epoch 75/100
# 164/164 - 1s - loss: 3.2567e-04 - val_loss: 5.6947e-04 - 1s/epoch - 8ms/step
# Epoch 76/100
# 164/164 - 1s - loss: 3.9989e-04 - val_loss: 9.3343e-04 - 1s/epoch - 8ms/step
# Epoch 77/100
# 164/164 - 1s - loss: 4.8608e-04 - val_loss: 0.0010 - 1s/epoch - 8ms/step
# Epoch 78/100
# 164/164 - 1s - loss: 5.4588e-04 - val_loss: 9.5510e-04 - 1s/epoch - 8ms/step
# Epoch 79/100
# 164/164 - 1s - loss: 5.2897e-04 - val_loss: 6.0704e-04 - 1s/epoch - 8ms/step
# Epoch 80/100
# 164/164 - 1s - loss: 4.4506e-04 - val_loss: 2.6932e-04 - 1s/epoch - 8ms/step
# Epoch 81/100
# 164/164 - 1s - loss: 3.4826e-04 - val_loss: 7.6967e-05 - 1s/epoch - 8ms/step
# Epoch 82/100
# 164/164 - 1s - loss: 2.7592e-04 - val_loss: 2.2876e-05 - 1s/epoch - 8ms/step
# Epoch 83/100
# 164/164 - 1s - loss: 2.3161e-04 - val_loss: 2.3503e-05 - 1s/epoch - 8ms/step
# Epoch 84/100
# 164/164 - 1s - loss: 2.0363e-04 - val_loss: 2.5115e-05 - 1s/epoch - 8ms/step
# Epoch 85/100
# 164/164 - 1s - loss: 1.8467e-04 - val_loss: 1.8307e-05 - 1s/epoch - 8ms/step
# Epoch 86/100
# 164/164 - 1s - loss: 1.7332e-04 - val_loss: 1.3291e-05 - 1s/epoch - 8ms/step
# Epoch 87/100
# 164/164 - 1s - loss: 1.7076e-04 - val_loss: 2.6445e-05 - 1s/epoch - 8ms/step
# Epoch 88/100
# 164/164 - 1s - loss: 1.7928e-04 - val_loss: 7.7751e-05 - 1s/epoch - 8ms/step
# Epoch 89/100
# 164/164 - 1s - loss: 2.0190e-04 - val_loss: 1.8916e-04 - 1s/epoch - 8ms/step
# Epoch 90/100
# 164/164 - 1s - loss: 2.4123e-04 - val_loss: 3.6969e-04 - 1s/epoch - 8ms/step
# Epoch 91/100
# 164/164 - 1s - loss: 2.9154e-04 - val_loss: 5.8186e-04 - 1s/epoch - 8ms/step
# Epoch 92/100
# 164/164 - 1s - loss: 3.6093e-04 - val_loss: 8.3539e-04 - 1s/epoch - 8ms/step
# Epoch 93/100
# 164/164 - 1s - loss: 4.1806e-04 - val_loss: 8.9519e-04 - 1s/epoch - 8ms/step
# Epoch 94/100
# 164/164 - 1s - loss: 4.4270e-04 - val_loss: 7.1458e-04 - 1s/epoch - 8ms/step
# Epoch 95/100
# 164/164 - 1s - loss: 4.1572e-04 - val_loss: 4.3215e-04 - 1s/epoch - 8ms/step
# Epoch 96/100
# 164/164 - 1s - loss: 3.4633e-04 - val_loss: 1.9091e-04 - 1s/epoch - 8ms/step
# Epoch 97/100
# 164/164 - 1s - loss: 2.7560e-04 - val_loss: 6.1824e-05 - 1s/epoch - 8ms/step
# Epoch 98/100
# 164/164 - 1s - loss: 2.2395e-04 - val_loss: 2.0518e-05 - 1s/epoch - 8ms/step
# Epoch 99/100
# 164/164 - 1s - loss: 1.9120e-04 - val_loss: 1.4512e-05 - 1s/epoch - 8ms/step
# Epoch 100/100
# 164/164 - 1s - loss: 1.7078e-04 - val_loss: 1.3123e-05 - 1s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-02 19:38:08.441465: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:38:08.521693: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:38:08.647437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:38:10.292780: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:38:10.323823: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 - 3s - loss: 0.0011 - val_loss: 0.0029 - 3s/epoch - 16ms/step
# Epoch 2/100
# 164/164 - 1s - loss: 0.0015 - val_loss: 0.0047 - 1s/epoch - 8ms/step
# Epoch 3/100
# 164/164 - 1s - loss: 0.0021 - val_loss: 0.0094 - 1s/epoch - 8ms/step
# Epoch 4/100
# 164/164 - 1s - loss: 0.0029 - val_loss: 0.0136 - 1s/epoch - 8ms/step
# Epoch 5/100
# 164/164 - 1s - loss: 0.0040 - val_loss: 0.0167 - 1s/epoch - 8ms/step
# Epoch 6/100
# 164/164 - 1s - loss: 0.0049 - val_loss: 0.0159 - 1s/epoch - 8ms/step
# Epoch 7/100
# 164/164 - 1s - loss: 0.0056 - val_loss: 0.0116 - 1s/epoch - 8ms/step
# Epoch 8/100
# 164/164 - 1s - loss: 0.0054 - val_loss: 0.0065 - 1s/epoch - 8ms/step
# Epoch 9/100
# 164/164 - 1s - loss: 0.0035 - val_loss: 0.0032 - 1s/epoch - 8ms/step
# Epoch 10/100
# 164/164 - 1s - loss: 0.0019 - val_loss: 0.0014 - 1s/epoch - 8ms/step
# Epoch 11/100
# 164/164 - 1s - loss: 9.2430e-04 - val_loss: 5.0090e-04 - 1s/epoch - 8ms/step
# Epoch 12/100
# 164/164 - 1s - loss: 5.2551e-04 - val_loss: 1.3847e-04 - 1s/epoch - 8ms/step
# Epoch 13/100
# 164/164 - 1s - loss: 3.9371e-04 - val_loss: 5.2321e-05 - 1s/epoch - 8ms/step
# Epoch 14/100
# 164/164 - 1s - loss: 3.4930e-04 - val_loss: 4.2008e-05 - 1s/epoch - 8ms/step
# Epoch 15/100
# 164/164 - 1s - loss: 3.2579e-04 - val_loss: 5.1987e-05 - 1s/epoch - 8ms/step
# Epoch 16/100
# 164/164 - 1s - loss: 3.1440e-04 - val_loss: 9.4096e-05 - 1s/epoch - 8ms/step
# Epoch 17/100
# 164/164 - 1s - loss: 3.1954e-04 - val_loss: 1.9277e-04 - 1s/epoch - 8ms/step
# Epoch 18/100
# 164/164 - 1s - loss: 3.4690e-04 - val_loss: 3.7967e-04 - 1s/epoch - 8ms/step
# Epoch 19/100
# 164/164 - 1s - loss: 4.0363e-04 - val_loss: 6.9816e-04 - 1s/epoch - 8ms/step
# Epoch 20/100
# 164/164 - 1s - loss: 4.9945e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 21/100
# 164/164 - 1s - loss: 6.4632e-04 - val_loss: 0.0019 - 1s/epoch - 8ms/step
# Epoch 22/100
# 164/164 - 1s - loss: 8.5359e-04 - val_loss: 0.0028 - 1s/epoch - 8ms/step
# Epoch 23/100
# 164/164 - 1s - loss: 0.0011 - val_loss: 0.0036 - 1s/epoch - 8ms/step
# Epoch 24/100
# 164/164 - 1s - loss: 0.0013 - val_loss: 0.0041 - 1s/epoch - 8ms/step
# Epoch 25/100
# 164/164 - 1s - loss: 0.0016 - val_loss: 0.0041 - 1s/epoch - 8ms/step
# Epoch 26/100
# 164/164 - 1s - loss: 0.0018 - val_loss: 0.0033 - 1s/epoch - 8ms/step
# Epoch 27/100
# 164/164 - 1s - loss: 0.0016 - val_loss: 0.0018 - 1s/epoch - 8ms/step
# Epoch 28/100
# 164/164 - 1s - loss: 0.0013 - val_loss: 6.5622e-04 - 1s/epoch - 8ms/step
# Epoch 29/100
# 164/164 - 1s - loss: 9.1779e-04 - val_loss: 1.1336e-04 - 1s/epoch - 8ms/step
# Epoch 30/100
# 164/164 - 1s - loss: 6.8576e-04 - val_loss: 9.3855e-05 - 1s/epoch - 8ms/step
# Epoch 31/100
# 164/164 - 1s - loss: 5.9416e-04 - val_loss: 1.3851e-04 - 1s/epoch - 8ms/step
# Epoch 32/100
# 164/164 - 1s - loss: 5.1415e-04 - val_loss: 1.2513e-04 - 1s/epoch - 8ms/step
# Epoch 33/100
# 164/164 - 1s - loss: 4.3914e-04 - val_loss: 8.9333e-05 - 1s/epoch - 8ms/step
# Epoch 34/100
# 164/164 - 1s - loss: 3.7844e-04 - val_loss: 5.3927e-05 - 1s/epoch - 8ms/step
# Epoch 35/100
# 164/164 - 1s - loss: 3.3404e-04 - val_loss: 3.2997e-05 - 1s/epoch - 8ms/step
# Epoch 36/100
# 164/164 - 1s - loss: 3.0645e-04 - val_loss: 3.6434e-05 - 1s/epoch - 8ms/step
# Epoch 37/100
# 164/164 - 1s - loss: 2.9579e-04 - val_loss: 7.4554e-05 - 1s/epoch - 8ms/step
# Epoch 38/100
# 164/164 - 1s - loss: 3.0283e-04 - val_loss: 1.6133e-04 - 1s/epoch - 8ms/step
# Epoch 39/100
# 164/164 - 1s - loss: 3.2947e-04 - val_loss: 3.1567e-04 - 1s/epoch - 8ms/step
# Epoch 40/100
# 164/164 - 1s - loss: 3.7868e-04 - val_loss: 5.5719e-04 - 1s/epoch - 8ms/step
# Epoch 41/100
# 164/164 - 1s - loss: 4.5280e-04 - val_loss: 8.8302e-04 - 1s/epoch - 8ms/step
# Epoch 42/100
# 164/164 - 1s - loss: 5.4581e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 43/100
# 164/164 - 1s - loss: 6.1790e-04 - val_loss: 0.0015 - 1s/epoch - 8ms/step
# Epoch 44/100
# 164/164 - 1s - loss: 7.0204e-04 - val_loss: 0.0018 - 1s/epoch - 8ms/step
# Epoch 45/100
# 164/164 - 1s - loss: 9.0230e-04 - val_loss: 0.0021 - 1s/epoch - 8ms/step
# Epoch 46/100
# 164/164 - 1s - loss: 9.8332e-04 - val_loss: 0.0017 - 1s/epoch - 8ms/step
# Epoch 47/100
# 164/164 - 1s - loss: 9.2237e-04 - val_loss: 8.7440e-04 - 1s/epoch - 8ms/step
# Epoch 48/100
# 164/164 - 1s - loss: 7.1172e-04 - val_loss: 2.7658e-04 - 1s/epoch - 8ms/step
# Epoch 49/100
# 164/164 - 1s - loss: 5.2711e-04 - val_loss: 5.4938e-05 - 1s/epoch - 8ms/step
# Epoch 50/100
# 164/164 - 1s - loss: 4.1897e-04 - val_loss: 5.5739e-05 - 1s/epoch - 8ms/step
# Epoch 51/100
# 164/164 - 1s - loss: 3.6167e-04 - val_loss: 7.7836e-05 - 1s/epoch - 8ms/step
# Epoch 52/100
# 164/164 - 1s - loss: 3.1623e-04 - val_loss: 7.1730e-05 - 1s/epoch - 8ms/step
# Epoch 53/100
# 164/164 - 1s - loss: 2.7790e-04 - val_loss: 4.9336e-05 - 1s/epoch - 8ms/step
# Epoch 54/100
# 164/164 - 1s - loss: 2.4801e-04 - val_loss: 2.7966e-05 - 1s/epoch - 8ms/step
# Epoch 55/100
# 164/164 - 1s - loss: 2.2877e-04 - val_loss: 2.1226e-05 - 1s/epoch - 8ms/step
# Epoch 56/100
# 164/164 - 1s - loss: 2.2184e-04 - val_loss: 4.1441e-05 - 1s/epoch - 8ms/step
# Epoch 57/100
# 164/164 - 1s - loss: 2.2874e-04 - val_loss: 1.0342e-04 - 1s/epoch - 8ms/step
# Epoch 58/100
# 164/164 - 1s - loss: 2.5183e-04 - val_loss: 2.2619e-04 - 1s/epoch - 8ms/step
# Epoch 59/100
# 164/164 - 1s - loss: 2.9409e-04 - val_loss: 4.2666e-04 - 1s/epoch - 8ms/step
# Epoch 60/100
# 164/164 - 1s - loss: 3.5358e-04 - val_loss: 6.3342e-04 - 1s/epoch - 8ms/step
# Epoch 61/100
# 164/164 - 1s - loss: 4.2323e-04 - val_loss: 9.6417e-04 - 1s/epoch - 8ms/step
# Epoch 62/100
# 164/164 - 1s - loss: 5.0338e-04 - val_loss: 0.0014 - 1s/epoch - 8ms/step
# Epoch 63/100
# 164/164 - 1s - loss: 6.5355e-04 - val_loss: 0.0015 - 1s/epoch - 8ms/step
# Epoch 64/100
# 164/164 - 1s - loss: 6.8316e-04 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 65/100
# 164/164 - 1s - loss: 6.2679e-04 - val_loss: 5.9544e-04 - 1s/epoch - 8ms/step
# Epoch 66/100
# 164/164 - 1s - loss: 4.9339e-04 - val_loss: 1.9905e-04 - 1s/epoch - 8ms/step
# Epoch 67/100
# 164/164 - 1s - loss: 3.7687e-04 - val_loss: 4.5078e-05 - 1s/epoch - 8ms/step
# Epoch 68/100
# 164/164 - 1s - loss: 3.0530e-04 - val_loss: 3.0796e-05 - 1s/epoch - 8ms/step
# Epoch 69/100
# 164/164 - 1s - loss: 2.6253e-04 - val_loss: 4.1848e-05 - 1s/epoch - 8ms/step
# Epoch 70/100
# 164/164 - 1s - loss: 2.3174e-04 - val_loss: 3.9060e-05 - 1s/epoch - 8ms/step
# Epoch 71/100
# 164/164 - 1s - loss: 2.0770e-04 - val_loss: 2.6171e-05 - 1s/epoch - 8ms/step
# Epoch 72/100
# 164/164 - 1s - loss: 1.9091e-04 - val_loss: 1.6222e-05 - 1s/epoch - 8ms/step
# Epoch 73/100
# 164/164 - 1s - loss: 1.8331e-04 - val_loss: 2.3080e-05 - 1s/epoch - 8ms/step
# Epoch 74/100
# 164/164 - 1s - loss: 1.8664e-04 - val_loss: 6.1689e-05 - 1s/epoch - 8ms/step
# Epoch 75/100
# 164/164 - 1s - loss: 2.0300e-04 - val_loss: 1.5031e-04 - 1s/epoch - 8ms/step
# Epoch 76/100
# 164/164 - 1s - loss: 2.3527e-04 - val_loss: 3.0557e-04 - 1s/epoch - 8ms/step
# Epoch 77/100
# 164/164 - 1s - loss: 2.8187e-04 - val_loss: 4.8829e-04 - 1s/epoch - 8ms/step
# Epoch 78/100
# 164/164 - 1s - loss: 3.4109e-04 - val_loss: 8.0919e-04 - 1s/epoch - 8ms/step
# Epoch 79/100
# 164/164 - 1s - loss: 4.1642e-04 - val_loss: 9.8908e-04 - 1s/epoch - 8ms/step
# Epoch 80/100
# 164/164 - 1s - loss: 4.8470e-04 - val_loss: 9.9606e-04 - 1s/epoch - 8ms/step
# Epoch 81/100
# 164/164 - 1s - loss: 4.9813e-04 - val_loss: 7.5118e-04 - 1s/epoch - 8ms/step
# Epoch 82/100
# 164/164 - 1s - loss: 4.5284e-04 - val_loss: 4.4041e-04 - 1s/epoch - 8ms/step
# Epoch 83/100
# 164/164 - 1s - loss: 3.6947e-04 - val_loss: 1.7523e-04 - 1s/epoch - 8ms/step
# Epoch 84/100
# 164/164 - 1s - loss: 2.9164e-04 - val_loss: 5.0014e-05 - 1s/epoch - 8ms/step
# Epoch 85/100
# 164/164 - 1s - loss: 2.3842e-04 - val_loss: 1.9932e-05 - 1s/epoch - 8ms/step
# Epoch 86/100
# 164/164 - 1s - loss: 2.0587e-04 - val_loss: 1.9841e-05 - 1s/epoch - 8ms/step
# Epoch 87/100
# 164/164 - 1s - loss: 1.8468e-04 - val_loss: 1.8170e-05 - 1s/epoch - 8ms/step
# Epoch 88/100
# 164/164 - 1s - loss: 1.7053e-04 - val_loss: 1.3787e-05 - 1s/epoch - 8ms/step
# Epoch 89/100
# 164/164 - 1s - loss: 1.6329e-04 - val_loss: 1.7515e-05 - 1s/epoch - 8ms/step
# Epoch 90/100
# 164/164 - 1s - loss: 1.6446e-04 - val_loss: 4.4264e-05 - 1s/epoch - 8ms/step
# Epoch 91/100
# 164/164 - 1s - loss: 1.7628e-04 - val_loss: 1.1147e-04 - 1s/epoch - 8ms/step
# Epoch 92/100
# 164/164 - 1s - loss: 2.0139e-04 - val_loss: 2.3328e-04 - 1s/epoch - 8ms/step
# Epoch 93/100
# 164/164 - 1s - loss: 2.3989e-04 - val_loss: 3.8699e-04 - 1s/epoch - 8ms/step
# Epoch 94/100
# 164/164 - 1s - loss: 3.0189e-04 - val_loss: 7.2216e-04 - 1s/epoch - 8ms/step
# Epoch 95/100
# 164/164 - 1s - loss: 3.5463e-04 - val_loss: 7.8053e-04 - 1s/epoch - 8ms/step
# Epoch 96/100
# 164/164 - 1s - loss: 3.8368e-04 - val_loss: 7.3328e-04 - 1s/epoch - 8ms/step
# Epoch 97/100
# 164/164 - 1s - loss: 3.9198e-04 - val_loss: 5.7177e-04 - 1s/epoch - 8ms/step
# Epoch 98/100
# 164/164 - 1s - loss: 3.5633e-04 - val_loss: 3.4133e-04 - 1s/epoch - 8ms/step
# Epoch 99/100
# 164/164 - 1s - loss: 2.9687e-04 - val_loss: 1.5320e-04 - 1s/epoch - 8ms/step
# Epoch 100/100
# 164/164 - 1s - loss: 2.4077e-04 - val_loss: 5.5066e-05 - 1s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-02 19:40:23.980040: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:40:24.061227: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:40:24.187763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:40:25.812582: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:40:25.842883: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 - 3s - loss: 0.0013 - val_loss: 0.0036 - 3s/epoch - 16ms/step
# Epoch 2/100
# 164/164 - 1s - loss: 0.0019 - val_loss: 0.0067 - 1s/epoch - 8ms/step
# Epoch 3/100
# 164/164 - 1s - loss: 0.0034 - val_loss: 0.0131 - 1s/epoch - 8ms/step
# Epoch 4/100
# 164/164 - 1s - loss: 0.0048 - val_loss: 0.0209 - 1s/epoch - 8ms/step
# Epoch 5/100
# 164/164 - 1s - loss: 0.0065 - val_loss: 0.0226 - 1s/epoch - 8ms/step
# Epoch 6/100
# 164/164 - 1s - loss: 0.0082 - val_loss: 0.0174 - 1s/epoch - 8ms/step
# Epoch 7/100
# 164/164 - 1s - loss: 0.0086 - val_loss: 0.0099 - 1s/epoch - 8ms/step
# Epoch 8/100
# 164/164 - 1s - loss: 0.0061 - val_loss: 0.0045 - 1s/epoch - 8ms/step
# Epoch 9/100
# 164/164 - 1s - loss: 0.0032 - val_loss: 0.0018 - 1s/epoch - 8ms/step
# Epoch 10/100
# 164/164 - 1s - loss: 0.0015 - val_loss: 5.2155e-04 - 1s/epoch - 8ms/step
# Epoch 11/100
# 164/164 - 1s - loss: 7.9208e-04 - val_loss: 9.0392e-05 - 1s/epoch - 8ms/step
# Epoch 12/100
# 164/164 - 1s - loss: 5.5685e-04 - val_loss: 6.2051e-05 - 1s/epoch - 8ms/step
# Epoch 13/100
# 164/164 - 1s - loss: 4.8584e-04 - val_loss: 6.7915e-05 - 1s/epoch - 8ms/step
# Epoch 14/100
# 164/164 - 1s - loss: 4.3616e-04 - val_loss: 4.5988e-05 - 1s/epoch - 8ms/step
# Epoch 15/100
# 164/164 - 1s - loss: 3.9722e-04 - val_loss: 5.1308e-05 - 1s/epoch - 8ms/step
# Epoch 16/100
# 164/164 - 1s - loss: 3.8069e-04 - val_loss: 1.1713e-04 - 1s/epoch - 8ms/step
# Epoch 17/100
# 164/164 - 1s - loss: 3.9217e-04 - val_loss: 2.7372e-04 - 1s/epoch - 9ms/step
# Epoch 18/100
# 164/164 - 1s - loss: 4.3734e-04 - val_loss: 5.6254e-04 - 1s/epoch - 8ms/step
# Epoch 19/100
# 164/164 - 1s - loss: 5.2464e-04 - val_loss: 0.0010 - 1s/epoch - 8ms/step
# Epoch 20/100
# 164/164 - 1s - loss: 6.6480e-04 - val_loss: 0.0017 - 1s/epoch - 8ms/step
# Epoch 21/100
# 164/164 - 1s - loss: 8.6615e-04 - val_loss: 0.0026 - 1s/epoch - 8ms/step
# Epoch 22/100
# 164/164 - 1s - loss: 0.0011 - val_loss: 0.0034 - 1s/epoch - 8ms/step
# Epoch 23/100
# 164/164 - 1s - loss: 0.0014 - val_loss: 0.0037 - 1s/epoch - 8ms/step
# Epoch 24/100
# 164/164 - 1s - loss: 0.0015 - val_loss: 0.0037 - 1s/epoch - 8ms/step
# Epoch 25/100
# 164/164 - 1s - loss: 0.0016 - val_loss: 0.0034 - 1s/epoch - 8ms/step
# Epoch 26/100
# 164/164 - 1s - loss: 0.0017 - val_loss: 0.0027 - 1s/epoch - 8ms/step
# Epoch 27/100
# 164/164 - 1s - loss: 0.0016 - val_loss: 0.0016 - 1s/epoch - 8ms/step
# Epoch 28/100
# 164/164 - 1s - loss: 0.0013 - val_loss: 6.5155e-04 - 1s/epoch - 8ms/step
# Epoch 29/100
# 164/164 - 1s - loss: 0.0010 - val_loss: 9.8882e-05 - 1s/epoch - 8ms/step
# Epoch 30/100
# 164/164 - 1s - loss: 8.0201e-04 - val_loss: 1.3901e-04 - 1s/epoch - 8ms/step
# Epoch 31/100
# 164/164 - 1s - loss: 6.9187e-04 - val_loss: 1.5980e-04 - 1s/epoch - 8ms/step
# Epoch 32/100
# 164/164 - 1s - loss: 5.6927e-04 - val_loss: 1.4434e-04 - 1s/epoch - 8ms/step
# Epoch 33/100
# 164/164 - 1s - loss: 4.7819e-04 - val_loss: 1.0223e-04 - 1s/epoch - 8ms/step
# Epoch 34/100
# 164/164 - 1s - loss: 4.0902e-04 - val_loss: 6.0200e-05 - 1s/epoch - 8ms/step
# Epoch 35/100
# 164/164 - 1s - loss: 3.6075e-04 - val_loss: 3.5622e-05 - 1s/epoch - 8ms/step
# Epoch 36/100
# 164/164 - 1s - loss: 3.3265e-04 - val_loss: 4.0721e-05 - 1s/epoch - 8ms/step
# Epoch 37/100
# 164/164 - 1s - loss: 3.2453e-04 - val_loss: 8.8165e-05 - 1s/epoch - 8ms/step
# Epoch 38/100
# 164/164 - 1s - loss: 3.3715e-04 - val_loss: 1.9494e-04 - 1s/epoch - 8ms/step
# Epoch 39/100
# 164/164 - 1s - loss: 3.7260e-04 - val_loss: 3.8177e-04 - 1s/epoch - 8ms/step
# Epoch 40/100
# 164/164 - 1s - loss: 4.3380e-04 - val_loss: 6.6180e-04 - 1s/epoch - 8ms/step
# Epoch 41/100
# 164/164 - 1s - loss: 5.1980e-04 - val_loss: 9.8424e-04 - 1s/epoch - 8ms/step
# Epoch 42/100
# 164/164 - 1s - loss: 6.1079e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 43/100
# 164/164 - 1s - loss: 6.7131e-04 - val_loss: 0.0015 - 1s/epoch - 8ms/step
# Epoch 44/100
# 164/164 - 1s - loss: 8.4306e-04 - val_loss: 0.0021 - 1s/epoch - 8ms/step
# Epoch 45/100
# 164/164 - 1s - loss: 0.0010 - val_loss: 0.0024 - 1s/epoch - 8ms/step
# Epoch 46/100
# 164/164 - 1s - loss: 0.0012 - val_loss: 0.0020 - 1s/epoch - 8ms/step
# Epoch 47/100
# 164/164 - 1s - loss: 0.0012 - val_loss: 8.2436e-04 - 1s/epoch - 8ms/step
# Epoch 48/100
# 164/164 - 1s - loss: 8.0211e-04 - val_loss: 1.3014e-04 - 1s/epoch - 8ms/step
# Epoch 49/100
# 164/164 - 1s - loss: 5.4236e-04 - val_loss: 8.9455e-05 - 1s/epoch - 8ms/step
# Epoch 50/100
# 164/164 - 1s - loss: 4.3928e-04 - val_loss: 1.9386e-04 - 1s/epoch - 8ms/step
# Epoch 51/100
# 164/164 - 1s - loss: 3.7213e-04 - val_loss: 2.0024e-04 - 1s/epoch - 8ms/step
# Epoch 52/100
# 164/164 - 1s - loss: 3.0988e-04 - val_loss: 1.4433e-04 - 1s/epoch - 8ms/step
# Epoch 53/100
# 164/164 - 1s - loss: 2.6011e-04 - val_loss: 7.5306e-05 - 1s/epoch - 8ms/step
# Epoch 54/100
# 164/164 - 1s - loss: 2.2776e-04 - val_loss: 2.9742e-05 - 1s/epoch - 8ms/step
# Epoch 55/100
# 164/164 - 1s - loss: 2.0821e-04 - val_loss: 1.7825e-05 - 1s/epoch - 8ms/step
# Epoch 56/100
# 164/164 - 1s - loss: 2.0422e-04 - val_loss: 3.8881e-05 - 1s/epoch - 8ms/step
# Epoch 57/100
# 164/164 - 1s - loss: 2.1657e-04 - val_loss: 1.1622e-04 - 1s/epoch - 8ms/step
# Epoch 58/100
# 164/164 - 1s - loss: 2.4902e-04 - val_loss: 2.8037e-04 - 1s/epoch - 8ms/step
# Epoch 59/100
# 164/164 - 1s - loss: 3.0625e-04 - val_loss: 5.5627e-04 - 1s/epoch - 8ms/step
# Epoch 60/100
# 164/164 - 1s - loss: 3.8657e-04 - val_loss: 8.5040e-04 - 1s/epoch - 8ms/step
# Epoch 61/100
# 164/164 - 1s - loss: 4.5512e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 62/100
# 164/164 - 1s - loss: 5.6964e-04 - val_loss: 0.0017 - 1s/epoch - 8ms/step
# Epoch 63/100
# 164/164 - 1s - loss: 7.1534e-04 - val_loss: 0.0018 - 1s/epoch - 8ms/step
# Epoch 64/100
# 164/164 - 1s - loss: 8.2669e-04 - val_loss: 0.0014 - 1s/epoch - 8ms/step
# Epoch 65/100
# 164/164 - 1s - loss: 7.7987e-04 - val_loss: 6.3073e-04 - 1s/epoch - 8ms/step
# Epoch 66/100
# 164/164 - 1s - loss: 5.7739e-04 - val_loss: 1.1666e-04 - 1s/epoch - 8ms/step
# Epoch 67/100
# 164/164 - 1s - loss: 4.0307e-04 - val_loss: 4.7238e-05 - 1s/epoch - 8ms/step
# Epoch 68/100
# 164/164 - 1s - loss: 3.1784e-04 - val_loss: 1.2874e-04 - 1s/epoch - 8ms/step
# Epoch 69/100
# 164/164 - 1s - loss: 2.7083e-04 - val_loss: 1.4667e-04 - 1s/epoch - 8ms/step
# Epoch 70/100
# 164/164 - 1s - loss: 2.2964e-04 - val_loss: 1.0584e-04 - 1s/epoch - 8ms/step
# Epoch 71/100
# 164/164 - 1s - loss: 1.9742e-04 - val_loss: 4.8253e-05 - 1s/epoch - 8ms/step
# Epoch 72/100
# 164/164 - 1s - loss: 1.7456e-04 - val_loss: 1.8055e-05 - 1s/epoch - 8ms/step
# Epoch 73/100
# 164/164 - 1s - loss: 1.6477e-04 - val_loss: 1.5105e-05 - 1s/epoch - 8ms/step
# Epoch 74/100
# 164/164 - 1s - loss: 1.6897e-04 - val_loss: 5.1532e-05 - 1s/epoch - 8ms/step
# Epoch 75/100
# 164/164 - 1s - loss: 1.8905e-04 - val_loss: 1.5556e-04 - 1s/epoch - 8ms/step
# Epoch 76/100
# 164/164 - 1s - loss: 2.2943e-04 - val_loss: 3.5522e-04 - 1s/epoch - 8ms/step
# Epoch 77/100
# 164/164 - 1s - loss: 2.9094e-04 - val_loss: 6.1325e-04 - 1s/epoch - 8ms/step
# Epoch 78/100
# 164/164 - 1s - loss: 3.6162e-04 - val_loss: 9.2162e-04 - 1s/epoch - 8ms/step
# Epoch 79/100
# 164/164 - 1s - loss: 4.4374e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 80/100
# 164/164 - 1s - loss: 5.1403e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 81/100
# 164/164 - 1s - loss: 5.5042e-04 - val_loss: 8.4101e-04 - 1s/epoch - 8ms/step
# Epoch 82/100
# 164/164 - 1s - loss: 5.0807e-04 - val_loss: 4.1595e-04 - 1s/epoch - 8ms/step
# Epoch 83/100
# 164/164 - 1s - loss: 4.0289e-04 - val_loss: 1.1362e-04 - 1s/epoch - 8ms/step
# Epoch 84/100
# 164/164 - 1s - loss: 3.0440e-04 - val_loss: 2.3644e-05 - 1s/epoch - 8ms/step
# Epoch 85/100
# 164/164 - 1s - loss: 2.4495e-04 - val_loss: 3.8653e-05 - 1s/epoch - 8ms/step
# Epoch 86/100
# 164/164 - 1s - loss: 2.1020e-04 - val_loss: 5.0536e-05 - 1s/epoch - 8ms/step
# Epoch 87/100
# 164/164 - 1s - loss: 1.8496e-04 - val_loss: 3.9035e-05 - 1s/epoch - 8ms/step
# Epoch 88/100
# 164/164 - 1s - loss: 1.6675e-04 - val_loss: 1.9545e-05 - 1s/epoch - 8ms/step
# Epoch 89/100
# 164/164 - 1s - loss: 1.5708e-04 - val_loss: 1.1949e-05 - 1s/epoch - 8ms/step
# Epoch 90/100
# 164/164 - 1s - loss: 1.5810e-04 - val_loss: 3.7074e-05 - 1s/epoch - 8ms/step
# Epoch 91/100
# 164/164 - 1s - loss: 1.7257e-04 - val_loss: 1.1814e-04 - 1s/epoch - 8ms/step
# Epoch 92/100
# 164/164 - 1s - loss: 2.0385e-04 - val_loss: 2.7156e-04 - 1s/epoch - 8ms/step
# Epoch 93/100
# 164/164 - 1s - loss: 2.5439e-04 - val_loss: 4.7215e-04 - 1s/epoch - 8ms/step
# Epoch 94/100
# 164/164 - 1s - loss: 3.2067e-04 - val_loss: 7.8447e-04 - 1s/epoch - 8ms/step
# Epoch 95/100
# 164/164 - 1s - loss: 3.8364e-04 - val_loss: 8.3887e-04 - 1s/epoch - 8ms/step
# Epoch 96/100
# 164/164 - 1s - loss: 4.1807e-04 - val_loss: 8.0381e-04 - 1s/epoch - 8ms/step
# Epoch 97/100
# 164/164 - 1s - loss: 4.2037e-04 - val_loss: 5.0391e-04 - 1s/epoch - 8ms/step
# Epoch 98/100
# 164/164 - 1s - loss: 3.6089e-04 - val_loss: 2.2508e-04 - 1s/epoch - 8ms/step
# Epoch 99/100
# 164/164 - 1s - loss: 2.8860e-04 - val_loss: 6.1915e-05 - 1s/epoch - 8ms/step
# Epoch 100/100
# 164/164 - 1s - loss: 2.2948e-04 - val_loss: 1.7662e-05 - 1s/epoch - 8ms/step

# %%
i=0
wb3 = Workbook()
ws3 = wb3.active
for m in models3:
    # make a prediction
    test_x2 = test_X
    yhat = LSTMUnit.predict(test_x2, m)
    inv_yhat = Preprocessing.inverse_scaler(yhat, scaler)
    inv_y = Preprocessing.inverse_scaler(test_y.reshape(-1,1), scaler)
    print(hyperparam3[i])
    print("Epoch: "+ str(lstms3[i].params['epochs']))
    print("Neurons: "+str(m.layers[0].units))
    i = i+1
    ws3['A'+str(i)] = 'LSTM'
    ws3['B'+str(i)] = hyperparam3[i-1][0]
    ws3['C'+str(i)] = hyperparam3[i-1][1]
    ws3['D'+str(i)] = hyperparam3[i-1][2]
    print('RMSE')
    print(Evaluation.rmse(inv_y,inv_yhat)[0])
    ws3['E'+str(i)] = Evaluation.rmse(inv_y,inv_yhat)[0]
    print('MAE')
    print(Evaluation.mae(inv_y,inv_yhat)[0])
    ws3['F'+str(i)] = Evaluation.mae(inv_y,inv_yhat)[0]
    print('MAPE')
    print(Evaluation.mape(inv_y,inv_yhat)[0])
    ws3['G'+str(i)] = Evaluation.mape(inv_y,inv_yhat)[0]
    LSTMUnit.save_model(m, 0, 'BTC',hyperparam3[i-1])
wb3.save('LSTM_BTC_result3.xlsx')
# Out:
#  10/164 [>.............................] - ETA: 0s
# 2023-04-02 19:42:41.125243: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:42:41.156125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (128, 25, 50)
# Epoch: 25
# Neurons: 50
# RMSE
# 3666.432415012078
# MAE
# 3651.0230177634494
# MAPE
# 18.382461324140493
#  34/164 [=====>........................] - ETA: 0s
# 2023-04-02 19:42:41.884771: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:42:41.911610: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (128, 25, 60)
# Epoch: 25
# Neurons: 60
# RMSE
# 3685.433039232616
# MAE
# 3669.6955022492652
# MAPE
# 18.482579056282415
#  30/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:42:42.612988: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:42:42.640034: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (128, 25, 100)
# Epoch: 25
# Neurons: 100
# RMSE
# 3844.983748641163
# MAE
# 3830.3162100165355
# MAPE
# 19.26839469357834
#  30/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:42:43.323357: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:42:43.350798: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (128, 50, 50)
# Epoch: 50
# Neurons: 50
# RMSE
# 550.3818288046432
# MAE
# 468.1478423977496
# MAPE
# 2.4423060576593594
#  32/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:42:44.051239: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:42:44.077101: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (128, 50, 60)
# Epoch: 50
# Neurons: 60
# RMSE
# 571.3215793845844
# MAE
# 486.9030995348739
# MAPE
# 2.542741802894557
#  32/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:42:44.782711: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:42:44.808855: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (128, 50, 100)
# Epoch: 50
# Neurons: 100
# RMSE
# 1139.2627582058042
# MAE
# 1042.300573553107
# MAPE
# 5.490522779971975
#  13/164 [=>............................] - ETA: 0s
# 2023-04-02 19:42:45.811188: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:42:45.845055: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (128, 100, 50)
# Epoch: 100
# Neurons: 50
# RMSE
# 233.66510246692454
# MAE
# 168.10859295632073
# MAPE
# 0.8065115736720382
#  31/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:42:46.569902: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:42:46.598024: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (128, 100, 60)
# Epoch: 100
# Neurons: 60
# RMSE
# 478.6536799517072
# MAE
# 435.786535050675
# MAPE
# 2.0853231760730053
#  30/164 [====>.........................] - ETA: 0s
# 2023-04-02 19:42:47.298356: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-02 19:42:47.325334: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 1s 3ms/step
# (128, 100, 100)
# Epoch: 100
# Neurons: 100
# RMSE
# 271.0787176818398
# MAE
# 189.37833870938775
# MAPE
# 0.8667970697544651

# %%
test_X
# Out:
# array([[[0.38958251],
#         [0.39058727],
#         [0.38225758],
#         [0.38323475],
#         [0.38142925]],
#
#        [[0.39058727],
#         [0.38225758],
#         [0.38323475],
#         [0.38142925],
#         [0.37606749]],
#
#        [[0.38225758],
#         [0.38323475],
#         [0.38142925],
#         [0.37606749],
#         [0.37728495]],
#
#        ...,
#
#        [[0.19332032],
#         [0.19303645],
#         [0.19296994],
#         [0.19285135],
#         [0.19282747]],
#
#        [[0.19303645],
#         [0.19296994],
#         [0.19285135],
#         [0.19282747],
#         [0.19251245]],
#
#        [[0.19296994],
#         [0.19285135],
#         [0.19282747],
#         [0.19251245],
#         [0.19208658]]])
