# %%
from Skripsi import Preprocessing
from Skripsi import Evaluation
from Skripsi import LSTMUnit
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import pandas as pd
from openpyxl.workbook import Workbook

# %%
eth_dfd = pd.read_csv('../Dataset/Binance_ETHUSDT_1h.csv')
eth_dfd
# Out:
#                 Unix                 Date   Symbol     Open     High      Low  \
# 0      1672527600000  2022-12-31 23:00:00  ETHUSDT  1196.18  1197.43  1193.60
# 1      1672524000000  2022-12-31 22:00:00  ETHUSDT  1200.09  1201.11  1193.08
# 2      1672520400000  2022-12-31 21:00:00  ETHUSDT  1202.33  1203.00  1199.83
# 3      1672516800000  2022-12-31 20:00:00  ETHUSDT  1202.66  1203.71  1202.30
# 4      1672513200000  2022-12-31 19:00:00  ETHUSDT  1199.59  1205.61  1199.42
# ...              ...                  ...      ...      ...      ...      ...
# 26269  1577851200000  2020-01-01 04:00:00  ETHUSDT   130.21   130.74   130.15
# 26270  1577847600000  2020-01-01 03:00:00  ETHUSDT   130.85   130.89   129.94
# 26271  1577844000000  2020-01-01 02:00:00  ETHUSDT   130.63   130.98   130.35
# 26272  1577840400000  2020-01-01 01:00:00  ETHUSDT   128.87   130.65   128.78
# 26273  1577836800000  2020-01-01 00:00:00  ETHUSDT   129.16   129.19   128.68
#
#          Close   Volume ETH   Volume USDT  tradecount
# 0      1196.13   5927.43200  7.086714e+06       11029
# 1      1196.19   9549.47930  1.143952e+07       13241
# 2      1200.10   3865.48620  4.643401e+06        7913
# 3      1202.34   3557.34730  4.278879e+06        7917
# 4      1202.65   6435.02040  7.738029e+06        9906
# ...        ...          ...           ...         ...
# 26269   130.20   3397.90747  4.430067e+05        2264
# 26270   130.20   4968.55433  6.473610e+05        2818
# 26271   130.85   7603.35623  9.940256e+05        3046
# 26272   130.64  11344.65516  1.474278e+06        4885
# 26273   128.87   7769.17336  1.000930e+06        2504
#
# [26274 rows x 10 columns]

# %%
df = Preprocessing.feature_selection(eth_dfd)
df
# Out:
#          Close
# 0       128.87
# 1       130.64
# 2       130.85
# 3       130.20
# 4       130.20
# ...        ...
# 26269  1202.65
# 26270  1202.34
# 26271  1200.10
# 26272  1196.19
# 26273  1196.13
#
# [26274 rows x 1 columns]

# %%
df_no_dup = Preprocessing.handle_duplicate(df)
df_no_dup
# Out:
# duplicate ok
#          Close
# 0       128.87
# 1       130.64
# 2       130.85
# 3       130.20
# 5       130.30
# ...        ...
# 26268  1199.60
# 26269  1202.65
# 26270  1202.34
# 26272  1196.19
# 26273  1196.13
#
# [24417 rows x 1 columns]

# %%
miss = Preprocessing.handle_missing_value(df_no_dup)
miss
# Out:
# No missing value
# False

# %%
x, scaler = Preprocessing.minmax_scale(df_no_dup)
x
# Out:
# array([[0.00678935],
#        [0.00716197],
#        [0.00720618],
#        ...,
#        [0.23277875],
#        [0.23148404],
#        [0.2314714 ]])

# %%
train, test = Preprocessing.splitting_data(x)
train
# Out:
# array([[0.00678935],
#        [0.00716197],
#        [0.00720618],
#        ...,
#        [0.35186281],
#        [0.34708184],
#        [0.34520188]])

# %%
test
# Out:
# array([[0.35243332],
#        [0.35114703],
#        [0.35150913],
#        ...,
#        [0.23277875],
#        [0.23148404],
#        [0.2314714 ]])

# %%
train_X, train_y = Preprocessing.create_dataset(train,5)
test_X, test_y = Preprocessing.create_dataset(test,5)

# %%
train_X
# Out:
# array([[[0.00678935],
#         [0.00716197],
#         [0.00720618],
#         [0.00706934],
#         [0.00709039]],
#
#        [[0.00716197],
#         [0.00720618],
#         [0.00706934],
#         [0.00709039],
#         [0.00711987]],
#
#        [[0.00720618],
#         [0.00706934],
#         [0.00709039],
#         [0.00711987],
#         [0.00707776]],
#
#        ...,
#
#        [[0.36570254],
#         [0.36294049],
#         [0.35696376],
#         [0.34664396],
#         [0.34877655]],
#
#        [[0.36294049],
#         [0.35696376],
#         [0.34664396],
#         [0.34877655],
#         [0.35186281]],
#
#        [[0.35696376],
#         [0.34664396],
#         [0.34877655],
#         [0.35186281],
#         [0.34708184]]])

# %%
train_y
# Out:
# array([0.00711987, 0.00707776, 0.00710302, ..., 0.35186281, 0.34708184,
#        0.34520188])

# %%
test_X
# Out:
# array([[[0.35243332],
#         [0.35114703],
#         [0.35150913],
#         [0.35544379],
#         [0.3500881 ]],
#
#        [[0.35114703],
#         [0.35150913],
#         [0.35544379],
#         [0.3500881 ],
#         [0.352547  ]],
#
#        [[0.35150913],
#         [0.35544379],
#         [0.3500881 ],
#         [0.352547  ],
#         [0.36117421]],
#
#        ...,
#
#        [[0.23301032],
#         [0.23287348],
#         [0.23245033],
#         [0.23220192],
#         [0.23284401]],
#
#        [[0.23287348],
#         [0.23245033],
#         [0.23220192],
#         [0.23284401],
#         [0.23277875]],
#
#        [[0.23245033],
#         [0.23220192],
#         [0.23284401],
#         [0.23277875],
#         [0.23148404]]])

# %%
test_y
# Out:
# array([0.352547  , 0.36117421, 0.36182472, ..., 0.23277875, 0.23148404,
#        0.2314714 ])

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (19528, 5, 1) (19528,) (4879, 5, 1) (4879,)

# %% [markdown]
# ## Model Training

# %%
hyperparams = []
batch = [32, 64, 128]
epoch = [25, 50, 100]
neuron = [50, 60, 100]
for j in batch:
    for k in epoch:
        for l in neuron:
            hyperparams.append((j,k,l))
hyperparams
# Out:
# [(32, 25, 50),
#  (32, 25, 60),
#  (32, 25, 100),
#  (32, 50, 50),
#  (32, 50, 60),
#  (32, 50, 100),
#  (32, 100, 50),
#  (32, 100, 60),
#  (32, 100, 100),
#  (64, 25, 50),
#  (64, 25, 60),
#  (64, 25, 100),
#  (64, 50, 50),
#  (64, 50, 60),
#  (64, 50, 100),
#  (64, 100, 50),
#  (64, 100, 60),
#  (64, 100, 100),
#  (128, 25, 50),
#  (128, 25, 60),
#  (128, 25, 100),
#  (128, 50, 50),
#  (128, 50, 60),
#  (128, 50, 100),
#  (128, 100, 50),
#  (128, 100, 60),
#  (128, 100, 100)]

# %%
hyperparam1 = hyperparams[:9]
hyperparam2 = hyperparams[9:18]
hyperparam3 = hyperparams[18:27]
hyperparam1
# Out:
# [(32, 25, 50),
#  (32, 25, 60),
#  (32, 25, 100),
#  (32, 50, 50),
#  (32, 50, 60),
#  (32, 50, 100),
#  (32, 100, 50),
#  (32, 100, 60),
#  (32, 100, 100)]

# %%
hyperparam2
# Out:
# [(64, 25, 50),
#  (64, 25, 60),
#  (64, 25, 100),
#  (64, 50, 50),
#  (64, 50, 60),
#  (64, 50, 100),
#  (64, 100, 50),
#  (64, 100, 60),
#  (64, 100, 100)]

# %%
hyperparam3
# Out:
# [(128, 25, 50),
#  (128, 25, 60),
#  (128, 25, 100),
#  (128, 50, 50),
#  (128, 50, 60),
#  (128, 50, 100),
#  (128, 100, 50),
#  (128, 100, 60),
#  (128, 100, 100)]

# %%
lstms1 = []
models1 = []
for batch, epoch, neuron in hyperparam1:
    model, lstm = LSTMUnit.train_lstm(train_X, train_y, test_X, test_y, neuron, epoch, batch)
    lstms1.append(lstm)
    models1.append(model)
# Out:
# Metal device set to: Apple M1
# 2023-04-03 09:01:09.886876: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-04-03 09:01:09.887964: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/25
# 2023-04-03 09:01:10.563828: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-04-03 09:01:11.000876: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:01:11.131265: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:01:12.608378: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:01:18.436516: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:01:18.468272: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 611/611 - 9s - loss: 3.8399e-04 - val_loss: 0.0011 - 9s/epoch - 14ms/step
# Epoch 2/25
# 611/611 - 5s - loss: 6.1692e-04 - val_loss: 0.0010 - 5s/epoch - 8ms/step
# Epoch 3/25
# 611/611 - 5s - loss: 7.3938e-04 - val_loss: 0.0015 - 5s/epoch - 8ms/step
# Epoch 4/25
# 611/611 - 5s - loss: 8.9002e-04 - val_loss: 0.0024 - 5s/epoch - 8ms/step
# Epoch 5/25
# 611/611 - 5s - loss: 9.7487e-04 - val_loss: 0.0025 - 5s/epoch - 8ms/step
# Epoch 6/25
# 611/611 - 6s - loss: 9.0592e-04 - val_loss: 0.0020 - 6s/epoch - 9ms/step
# Epoch 7/25
# 611/611 - 5s - loss: 7.2790e-04 - val_loss: 0.0014 - 5s/epoch - 8ms/step
# Epoch 8/25
# 611/611 - 5s - loss: 5.5937e-04 - val_loss: 9.2245e-04 - 5s/epoch - 8ms/step
# Epoch 9/25
# 611/611 - 5s - loss: 4.3284e-04 - val_loss: 5.7369e-04 - 5s/epoch - 8ms/step
# Epoch 10/25
# 611/611 - 5s - loss: 3.4798e-04 - val_loss: 3.6184e-04 - 5s/epoch - 8ms/step
# Epoch 11/25
# 611/611 - 5s - loss: 2.9799e-04 - val_loss: 2.4976e-04 - 5s/epoch - 8ms/step
# Epoch 12/25
# 611/611 - 5s - loss: 2.7095e-04 - val_loss: 1.9443e-04 - 5s/epoch - 8ms/step
# Epoch 13/25
# 611/611 - 5s - loss: 2.5856e-04 - val_loss: 1.6764e-04 - 5s/epoch - 8ms/step
# Epoch 14/25
# 611/611 - 5s - loss: 2.5627e-04 - val_loss: 1.5900e-04 - 5s/epoch - 8ms/step
# Epoch 15/25
# 611/611 - 5s - loss: 2.5568e-04 - val_loss: 1.5441e-04 - 5s/epoch - 8ms/step
# Epoch 16/25
# 611/611 - 5s - loss: 2.5461e-04 - val_loss: 1.5036e-04 - 5s/epoch - 8ms/step
# Epoch 17/25
# 611/611 - 5s - loss: 2.4721e-04 - val_loss: 1.3690e-04 - 5s/epoch - 8ms/step
# Epoch 18/25
# 611/611 - 5s - loss: 2.3631e-04 - val_loss: 1.2053e-04 - 5s/epoch - 8ms/step
# Epoch 19/25
# 611/611 - 5s - loss: 2.2341e-04 - val_loss: 1.0357e-04 - 5s/epoch - 8ms/step
# Epoch 20/25
# 611/611 - 5s - loss: 2.1202e-04 - val_loss: 8.8405e-05 - 5s/epoch - 8ms/step
# Epoch 21/25
# 611/611 - 5s - loss: 2.0098e-04 - val_loss: 7.6623e-05 - 5s/epoch - 8ms/step
# Epoch 22/25
# 611/611 - 5s - loss: 1.9210e-04 - val_loss: 6.6747e-05 - 5s/epoch - 8ms/step
# Epoch 23/25
# 611/611 - 5s - loss: 1.8452e-04 - val_loss: 5.8452e-05 - 5s/epoch - 8ms/step
# Epoch 24/25
# 611/611 - 5s - loss: 1.7726e-04 - val_loss: 5.2789e-05 - 5s/epoch - 8ms/step
# Epoch 25/25
# 611/611 - 5s - loss: 1.7170e-04 - val_loss: 4.7986e-05 - 5s/epoch - 8ms/step
# Epoch 1/25
# 2023-04-03 09:03:15.462008: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:03:15.546712: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:03:15.620176: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:03:20.393853: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:03:20.423886: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 611/611 - 6s - loss: 4.0175e-04 - val_loss: 0.0010 - 6s/epoch - 10ms/step
# Epoch 2/25
# 611/611 - 5s - loss: 6.2312e-04 - val_loss: 0.0011 - 5s/epoch - 8ms/step
# Epoch 3/25
# 611/611 - 5s - loss: 8.0314e-04 - val_loss: 0.0018 - 5s/epoch - 8ms/step
# Epoch 4/25
# 611/611 - 5s - loss: 0.0010 - val_loss: 0.0029 - 5s/epoch - 8ms/step
# Epoch 5/25
# 611/611 - 5s - loss: 0.0011 - val_loss: 0.0029 - 5s/epoch - 8ms/step
# Epoch 6/25
# 611/611 - 5s - loss: 0.0010 - val_loss: 0.0023 - 5s/epoch - 8ms/step
# Epoch 7/25
# 611/611 - 5s - loss: 8.4706e-04 - val_loss: 0.0017 - 5s/epoch - 8ms/step
# Epoch 8/25
# 611/611 - 5s - loss: 6.4220e-04 - val_loss: 0.0011 - 5s/epoch - 8ms/step
# Epoch 9/25
# 611/611 - 5s - loss: 4.8159e-04 - val_loss: 6.4307e-04 - 5s/epoch - 8ms/step
# Epoch 10/25
# 611/611 - 5s - loss: 3.7320e-04 - val_loss: 3.7421e-04 - 5s/epoch - 8ms/step
# Epoch 11/25
# 611/611 - 5s - loss: 3.0802e-04 - val_loss: 2.3263e-04 - 5s/epoch - 8ms/step
# Epoch 12/25
# 611/611 - 5s - loss: 2.7223e-04 - val_loss: 1.6638e-04 - 5s/epoch - 8ms/step
# Epoch 13/25
# 611/611 - 5s - loss: 2.5549e-04 - val_loss: 1.3862e-04 - 5s/epoch - 8ms/step
# Epoch 14/25
# 611/611 - 5s - loss: 2.5017e-04 - val_loss: 1.3135e-04 - 5s/epoch - 8ms/step
# Epoch 15/25
# 611/611 - 5s - loss: 2.4916e-04 - val_loss: 1.3127e-04 - 5s/epoch - 8ms/step
# Epoch 16/25
# 611/611 - 5s - loss: 2.4703e-04 - val_loss: 1.2944e-04 - 5s/epoch - 8ms/step
# Epoch 17/25
# 611/611 - 5s - loss: 2.3987e-04 - val_loss: 1.2115e-04 - 5s/epoch - 8ms/step
# Epoch 18/25
# 611/611 - 5s - loss: 2.2980e-04 - val_loss: 1.0820e-04 - 5s/epoch - 8ms/step
# Epoch 19/25
# 611/611 - 5s - loss: 2.1690e-04 - val_loss: 9.3954e-05 - 5s/epoch - 8ms/step
# Epoch 20/25
# 611/611 - 5s - loss: 2.0401e-04 - val_loss: 7.8644e-05 - 5s/epoch - 9ms/step
# Epoch 21/25
# 611/611 - 5s - loss: 1.9143e-04 - val_loss: 6.7380e-05 - 5s/epoch - 8ms/step
# Epoch 22/25
# 611/611 - 5s - loss: 1.8134e-04 - val_loss: 5.8457e-05 - 5s/epoch - 8ms/step
# Epoch 23/25
# 611/611 - 5s - loss: 1.7293e-04 - val_loss: 5.1522e-05 - 5s/epoch - 8ms/step
# Epoch 24/25
# 611/611 - 5s - loss: 1.6620e-04 - val_loss: 4.6167e-05 - 5s/epoch - 9ms/step
# Epoch 25/25
# 611/611 - 5s - loss: 1.5965e-04 - val_loss: 4.2038e-05 - 5s/epoch - 8ms/step
# Epoch 1/25
# 2023-04-03 09:05:21.090027: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:05:21.184137: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:05:21.359604: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:05:26.126309: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:05:26.161334: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 611/611 - 6s - loss: 5.6526e-04 - val_loss: 0.0014 - 6s/epoch - 10ms/step
# Epoch 2/25
# 611/611 - 6s - loss: 9.4219e-04 - val_loss: 0.0019 - 6s/epoch - 9ms/step
# Epoch 3/25
# 611/611 - 5s - loss: 0.0012 - val_loss: 0.0033 - 5s/epoch - 8ms/step
# Epoch 4/25
# 611/611 - 5s - loss: 0.0013 - val_loss: 0.0042 - 5s/epoch - 8ms/step
# Epoch 5/25
# 611/611 - 5s - loss: 0.0015 - val_loss: 0.0039 - 5s/epoch - 8ms/step
# Epoch 6/25
# 611/611 - 5s - loss: 0.0014 - val_loss: 0.0030 - 5s/epoch - 8ms/step
# Epoch 7/25
# 611/611 - 5s - loss: 0.0011 - val_loss: 0.0021 - 5s/epoch - 8ms/step
# Epoch 8/25
# 611/611 - 5s - loss: 8.4066e-04 - val_loss: 0.0013 - 5s/epoch - 8ms/step
# Epoch 9/25
# 611/611 - 5s - loss: 6.0191e-04 - val_loss: 7.4319e-04 - 5s/epoch - 8ms/step
# Epoch 10/25
# 611/611 - 5s - loss: 4.4888e-04 - val_loss: 3.9842e-04 - 5s/epoch - 8ms/step
# Epoch 11/25
# 611/611 - 5s - loss: 3.6130e-04 - val_loss: 2.1907e-04 - 5s/epoch - 8ms/step
# Epoch 12/25
# 611/611 - 5s - loss: 3.1350e-04 - val_loss: 1.4011e-04 - 5s/epoch - 8ms/step
# Epoch 13/25
# 611/611 - 5s - loss: 2.8742e-04 - val_loss: 1.0863e-04 - 5s/epoch - 8ms/step
# Epoch 14/25
# 611/611 - 5s - loss: 2.7297e-04 - val_loss: 9.6972e-05 - 5s/epoch - 8ms/step
# Epoch 15/25
# 611/611 - 5s - loss: 2.7733e-04 - val_loss: 1.1105e-04 - 5s/epoch - 8ms/step
# Epoch 16/25
# 611/611 - 5s - loss: 2.7157e-04 - val_loss: 1.1438e-04 - 5s/epoch - 8ms/step
# Epoch 17/25
# 611/611 - 5s - loss: 2.6505e-04 - val_loss: 1.0878e-04 - 5s/epoch - 8ms/step
# Epoch 18/25
# 611/611 - 5s - loss: 2.5247e-04 - val_loss: 9.6872e-05 - 5s/epoch - 8ms/step
# Epoch 19/25
# 611/611 - 5s - loss: 2.3566e-04 - val_loss: 8.0861e-05 - 5s/epoch - 7ms/step
# Epoch 20/25
# 611/611 - 5s - loss: 2.2040e-04 - val_loss: 6.6277e-05 - 5s/epoch - 8ms/step
# Epoch 21/25
# 611/611 - 5s - loss: 2.0434e-04 - val_loss: 5.6191e-05 - 5s/epoch - 8ms/step
# Epoch 22/25
# 611/611 - 5s - loss: 1.9544e-04 - val_loss: 5.0279e-05 - 5s/epoch - 8ms/step
# Epoch 23/25
# 611/611 - 5s - loss: 1.8399e-04 - val_loss: 4.4099e-05 - 5s/epoch - 8ms/step
# Epoch 24/25
# 611/611 - 5s - loss: 1.7801e-04 - val_loss: 4.2116e-05 - 5s/epoch - 8ms/step
# Epoch 25/25
# 611/611 - 5s - loss: 1.7092e-04 - val_loss: 3.9023e-05 - 5s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-03 09:07:23.557759: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:07:23.635003: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:07:23.716817: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:07:28.598729: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:07:28.629164: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 611/611 - 6s - loss: 3.9944e-04 - val_loss: 0.0011 - 6s/epoch - 10ms/step
# Epoch 2/50
# 611/611 - 5s - loss: 6.5984e-04 - val_loss: 0.0011 - 5s/epoch - 8ms/step
# Epoch 3/50
# 611/611 - 5s - loss: 7.9384e-04 - val_loss: 0.0018 - 5s/epoch - 8ms/step
# Epoch 4/50
# 611/611 - 5s - loss: 9.6059e-04 - val_loss: 0.0026 - 5s/epoch - 8ms/step
# Epoch 5/50
# 611/611 - 5s - loss: 0.0010 - val_loss: 0.0026 - 5s/epoch - 8ms/step
# Epoch 6/50
# 611/611 - 5s - loss: 9.2350e-04 - val_loss: 0.0020 - 5s/epoch - 8ms/step
# Epoch 7/50
# 611/611 - 5s - loss: 7.4549e-04 - val_loss: 0.0014 - 5s/epoch - 8ms/step
# Epoch 8/50
# 611/611 - 5s - loss: 5.6077e-04 - val_loss: 9.0146e-04 - 5s/epoch - 8ms/step
# Epoch 9/50
# 611/611 - 5s - loss: 4.2938e-04 - val_loss: 5.4471e-04 - 5s/epoch - 8ms/step
# Epoch 10/50
# 611/611 - 5s - loss: 3.4524e-04 - val_loss: 3.4069e-04 - 5s/epoch - 8ms/step
# Epoch 11/50
# 611/611 - 5s - loss: 2.9724e-04 - val_loss: 2.3552e-04 - 5s/epoch - 8ms/step
# Epoch 12/50
# 611/611 - 5s - loss: 2.7213e-04 - val_loss: 1.8441e-04 - 5s/epoch - 8ms/step
# Epoch 13/50
# 611/611 - 5s - loss: 2.6115e-04 - val_loss: 1.6269e-04 - 5s/epoch - 8ms/step
# Epoch 14/50
# 611/611 - 5s - loss: 2.5972e-04 - val_loss: 1.5553e-04 - 5s/epoch - 8ms/step
# Epoch 15/50
# 611/611 - 6s - loss: 2.5980e-04 - val_loss: 1.5403e-04 - 6s/epoch - 9ms/step
# Epoch 16/50
# 611/611 - 5s - loss: 2.5795e-04 - val_loss: 1.4910e-04 - 5s/epoch - 9ms/step
# Epoch 17/50
# 611/611 - 5s - loss: 2.5050e-04 - val_loss: 1.3647e-04 - 5s/epoch - 8ms/step
# Epoch 18/50
# 611/611 - 5s - loss: 2.3846e-04 - val_loss: 1.1792e-04 - 5s/epoch - 8ms/step
# Epoch 19/50
# 611/611 - 5s - loss: 2.2548e-04 - val_loss: 1.0069e-04 - 5s/epoch - 8ms/step
# Epoch 20/50
# 611/611 - 5s - loss: 2.1381e-04 - val_loss: 8.5540e-05 - 5s/epoch - 8ms/step
# Epoch 21/50
# 611/611 - 5s - loss: 2.0146e-04 - val_loss: 7.3526e-05 - 5s/epoch - 9ms/step
# Epoch 22/50
# 611/611 - 6s - loss: 1.9217e-04 - val_loss: 6.3511e-05 - 6s/epoch - 9ms/step
# Epoch 23/50
# 611/611 - 5s - loss: 1.8326e-04 - val_loss: 5.6341e-05 - 5s/epoch - 8ms/step
# Epoch 24/50
# 611/611 - 5s - loss: 1.7634e-04 - val_loss: 5.0115e-05 - 5s/epoch - 8ms/step
# Epoch 25/50
# 611/611 - 5s - loss: 1.6995e-04 - val_loss: 4.5744e-05 - 5s/epoch - 8ms/step
# Epoch 26/50
# 611/611 - 5s - loss: 1.6454e-04 - val_loss: 4.2134e-05 - 5s/epoch - 8ms/step
# Epoch 27/50
# 611/611 - 5s - loss: 1.5907e-04 - val_loss: 3.9326e-05 - 5s/epoch - 8ms/step
# Epoch 28/50
# 611/611 - 5s - loss: 1.5461e-04 - val_loss: 3.6783e-05 - 5s/epoch - 8ms/step
# Epoch 29/50
# 611/611 - 5s - loss: 1.5003e-04 - val_loss: 3.4229e-05 - 5s/epoch - 8ms/step
# Epoch 30/50
# 611/611 - 5s - loss: 1.4532e-04 - val_loss: 3.1796e-05 - 5s/epoch - 8ms/step
# Epoch 31/50
# 611/611 - 5s - loss: 1.4075e-04 - val_loss: 2.9883e-05 - 5s/epoch - 8ms/step
# Epoch 32/50
# 611/611 - 5s - loss: 1.3649e-04 - val_loss: 2.8232e-05 - 5s/epoch - 8ms/step
# Epoch 33/50
# 611/611 - 5s - loss: 1.3262e-04 - val_loss: 2.6819e-05 - 5s/epoch - 8ms/step
# Epoch 34/50
# 611/611 - 5s - loss: 1.2852e-04 - val_loss: 2.5230e-05 - 5s/epoch - 8ms/step
# Epoch 35/50
# 611/611 - 5s - loss: 1.2458e-04 - val_loss: 2.4126e-05 - 5s/epoch - 8ms/step
# Epoch 36/50
# 611/611 - 5s - loss: 1.2084e-04 - val_loss: 2.2943e-05 - 5s/epoch - 8ms/step
# Epoch 37/50
# 611/611 - 5s - loss: 1.1749e-04 - val_loss: 2.2000e-05 - 5s/epoch - 8ms/step
# Epoch 38/50
# 611/611 - 5s - loss: 1.1380e-04 - val_loss: 2.0885e-05 - 5s/epoch - 8ms/step
# Epoch 39/50
# 611/611 - 5s - loss: 1.1058e-04 - val_loss: 2.0065e-05 - 5s/epoch - 8ms/step
# Epoch 40/50
# 611/611 - 5s - loss: 1.0754e-04 - val_loss: 1.9205e-05 - 5s/epoch - 8ms/step
# Epoch 41/50
# 611/611 - 5s - loss: 1.0492e-04 - val_loss: 1.8561e-05 - 5s/epoch - 8ms/step
# Epoch 42/50
# 611/611 - 6s - loss: 1.0260e-04 - val_loss: 1.7909e-05 - 6s/epoch - 9ms/step
# Epoch 43/50
# 611/611 - 5s - loss: 1.0041e-04 - val_loss: 1.7347e-05 - 5s/epoch - 9ms/step
# Epoch 44/50
# 611/611 - 5s - loss: 9.8263e-05 - val_loss: 1.6781e-05 - 5s/epoch - 8ms/step
# Epoch 45/50
# 611/611 - 5s - loss: 9.6198e-05 - val_loss: 1.6263e-05 - 5s/epoch - 8ms/step
# Epoch 46/50
# 611/611 - 5s - loss: 9.4176e-05 - val_loss: 1.5774e-05 - 5s/epoch - 8ms/step
# Epoch 47/50
# 611/611 - 5s - loss: 9.2243e-05 - val_loss: 1.5329e-05 - 5s/epoch - 8ms/step
# Epoch 48/50
# 611/611 - 5s - loss: 9.0360e-05 - val_loss: 1.4890e-05 - 5s/epoch - 8ms/step
# Epoch 49/50
# 611/611 - 5s - loss: 8.8560e-05 - val_loss: 1.4499e-05 - 5s/epoch - 8ms/step
# Epoch 50/50
# 611/611 - 5s - loss: 8.6818e-05 - val_loss: 1.4135e-05 - 5s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-03 09:11:32.847719: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:11:32.960900: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:11:33.056877: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:11:37.737314: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:11:37.769506: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 611/611 - 6s - loss: 3.8626e-04 - val_loss: 0.0011 - 6s/epoch - 10ms/step
# Epoch 2/50
# 611/611 - 5s - loss: 5.9452e-04 - val_loss: 0.0010 - 5s/epoch - 8ms/step
# Epoch 3/50
# 611/611 - 5s - loss: 7.2915e-04 - val_loss: 0.0015 - 5s/epoch - 8ms/step
# Epoch 4/50
# 611/611 - 5s - loss: 9.1102e-04 - val_loss: 0.0025 - 5s/epoch - 8ms/step
# Epoch 5/50
# 611/611 - 5s - loss: 0.0010 - val_loss: 0.0028 - 5s/epoch - 8ms/step
# Epoch 6/50
# 611/611 - 5s - loss: 0.0010 - val_loss: 0.0024 - 5s/epoch - 8ms/step
# Epoch 7/50
# 611/611 - 5s - loss: 8.3974e-04 - val_loss: 0.0017 - 5s/epoch - 9ms/step
# Epoch 8/50
# 611/611 - 5s - loss: 6.3722e-04 - val_loss: 0.0011 - 5s/epoch - 8ms/step
# Epoch 9/50
# 611/611 - 5s - loss: 4.7396e-04 - val_loss: 6.6681e-04 - 5s/epoch - 8ms/step
# Epoch 10/50
# 611/611 - 5s - loss: 3.6600e-04 - val_loss: 3.9170e-04 - 5s/epoch - 8ms/step
# Epoch 11/50
# 611/611 - 5s - loss: 3.0111e-04 - val_loss: 2.4702e-04 - 5s/epoch - 8ms/step
# Epoch 12/50
# 611/611 - 5s - loss: 2.6579e-04 - val_loss: 1.7848e-04 - 5s/epoch - 8ms/step
# Epoch 13/50
# 611/611 - 5s - loss: 2.4820e-04 - val_loss: 1.4705e-04 - 5s/epoch - 8ms/step
# Epoch 14/50
# 611/611 - 5s - loss: 2.4470e-04 - val_loss: 1.4069e-04 - 5s/epoch - 8ms/step
# Epoch 15/50
# 611/611 - 5s - loss: 2.4682e-04 - val_loss: 1.4435e-04 - 5s/epoch - 8ms/step
# Epoch 16/50
# 611/611 - 5s - loss: 2.4615e-04 - val_loss: 1.4438e-04 - 5s/epoch - 8ms/step
# Epoch 17/50
# 611/611 - 5s - loss: 2.4066e-04 - val_loss: 1.3552e-04 - 5s/epoch - 8ms/step
# Epoch 18/50
# 611/611 - 5s - loss: 2.3053e-04 - val_loss: 1.1991e-04 - 5s/epoch - 8ms/step
# Epoch 19/50
# 611/611 - 5s - loss: 2.1698e-04 - val_loss: 1.0280e-04 - 5s/epoch - 8ms/step
# Epoch 20/50
# 611/611 - 5s - loss: 2.0462e-04 - val_loss: 8.7605e-05 - 5s/epoch - 8ms/step
# Epoch 21/50
# 611/611 - 5s - loss: 1.9327e-04 - val_loss: 7.5526e-05 - 5s/epoch - 8ms/step
# Epoch 22/50
# 611/611 - 5s - loss: 1.8304e-04 - val_loss: 6.5922e-05 - 5s/epoch - 8ms/step
# Epoch 23/50
# 611/611 - 5s - loss: 1.7477e-04 - val_loss: 5.7990e-05 - 5s/epoch - 8ms/step
# Epoch 24/50
# 611/611 - 5s - loss: 1.6774e-04 - val_loss: 5.1304e-05 - 5s/epoch - 8ms/step
# Epoch 25/50
# 611/611 - 5s - loss: 1.6141e-04 - val_loss: 4.6645e-05 - 5s/epoch - 8ms/step
# Epoch 26/50
# 611/611 - 5s - loss: 1.5605e-04 - val_loss: 4.3195e-05 - 5s/epoch - 8ms/step
# Epoch 27/50
# 611/611 - 5s - loss: 1.5158e-04 - val_loss: 4.0034e-05 - 5s/epoch - 8ms/step
# Epoch 28/50
# 611/611 - 5s - loss: 1.4725e-04 - val_loss: 3.7528e-05 - 5s/epoch - 8ms/step
# Epoch 29/50
# 611/611 - 5s - loss: 1.4311e-04 - val_loss: 3.5064e-05 - 5s/epoch - 8ms/step
# Epoch 30/50
# 611/611 - 5s - loss: 1.3911e-04 - val_loss: 3.3042e-05 - 5s/epoch - 8ms/step
# Epoch 31/50
# 611/611 - 5s - loss: 1.3524e-04 - val_loss: 3.1293e-05 - 5s/epoch - 8ms/step
# Epoch 32/50
# 611/611 - 5s - loss: 1.3166e-04 - val_loss: 2.9559e-05 - 5s/epoch - 8ms/step
# Epoch 33/50
# 611/611 - 5s - loss: 1.2804e-04 - val_loss: 2.7991e-05 - 5s/epoch - 8ms/step
# Epoch 34/50
# 611/611 - 5s - loss: 1.2477e-04 - val_loss: 2.6574e-05 - 5s/epoch - 8ms/step
# Epoch 35/50
# 611/611 - 5s - loss: 1.2142e-04 - val_loss: 2.5053e-05 - 5s/epoch - 8ms/step
# Epoch 36/50
# 611/611 - 5s - loss: 1.1844e-04 - val_loss: 2.4014e-05 - 5s/epoch - 8ms/step
# Epoch 37/50
# 611/611 - 5s - loss: 1.1596e-04 - val_loss: 2.3064e-05 - 5s/epoch - 8ms/step
# Epoch 38/50
# 611/611 - 5s - loss: 1.1370e-04 - val_loss: 2.2195e-05 - 5s/epoch - 8ms/step
# Epoch 39/50
# 611/611 - 5s - loss: 1.1150e-04 - val_loss: 2.1237e-05 - 5s/epoch - 8ms/step
# Epoch 40/50
# 611/611 - 5s - loss: 1.0930e-04 - val_loss: 2.0390e-05 - 5s/epoch - 8ms/step
# Epoch 41/50
# 611/611 - 5s - loss: 1.0703e-04 - val_loss: 1.9591e-05 - 5s/epoch - 8ms/step
# Epoch 42/50
# 611/611 - 5s - loss: 1.0498e-04 - val_loss: 1.8884e-05 - 5s/epoch - 8ms/step
# Epoch 43/50
# 611/611 - 5s - loss: 1.0315e-04 - val_loss: 1.8182e-05 - 5s/epoch - 8ms/step
# Epoch 44/50
# 611/611 - 5s - loss: 1.0126e-04 - val_loss: 1.7559e-05 - 5s/epoch - 8ms/step
# Epoch 45/50
# 611/611 - 5s - loss: 9.9556e-05 - val_loss: 1.6937e-05 - 5s/epoch - 8ms/step
# Epoch 46/50
# 611/611 - 5s - loss: 9.7750e-05 - val_loss: 1.6375e-05 - 5s/epoch - 8ms/step
# Epoch 47/50
# 611/611 - 5s - loss: 9.5956e-05 - val_loss: 1.5850e-05 - 5s/epoch - 8ms/step
# Epoch 48/50
# 611/611 - 5s - loss: 9.4168e-05 - val_loss: 1.5398e-05 - 5s/epoch - 8ms/step
# Epoch 49/50
# 611/611 - 5s - loss: 9.3024e-05 - val_loss: 1.4996e-05 - 5s/epoch - 8ms/step
# Epoch 50/50
# 611/611 - 5s - loss: 9.1171e-05 - val_loss: 1.4616e-05 - 5s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-03 09:15:36.298104: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:15:36.376057: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:15:36.460563: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:15:40.701324: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:15:40.731057: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 611/611 - 5s - loss: 5.6045e-04 - val_loss: 0.0015 - 5s/epoch - 9ms/step
# Epoch 2/50
# 611/611 - 5s - loss: 9.8363e-04 - val_loss: 0.0020 - 5s/epoch - 8ms/step
# Epoch 3/50
# 611/611 - 5s - loss: 0.0012 - val_loss: 0.0032 - 5s/epoch - 8ms/step
# Epoch 4/50
# 611/611 - 6s - loss: 0.0014 - val_loss: 0.0041 - 6s/epoch - 9ms/step
# Epoch 5/50
# 611/611 - 5s - loss: 0.0014 - val_loss: 0.0039 - 5s/epoch - 8ms/step
# Epoch 6/50
# 611/611 - 6s - loss: 0.0014 - val_loss: 0.0031 - 6s/epoch - 9ms/step
# Epoch 7/50
# 611/611 - 6s - loss: 0.0012 - val_loss: 0.0022 - 6s/epoch - 10ms/step
# Epoch 8/50
# 611/611 - 5s - loss: 8.6783e-04 - val_loss: 0.0014 - 5s/epoch - 8ms/step
# Epoch 9/50
# 611/611 - 5s - loss: 6.3280e-04 - val_loss: 7.9439e-04 - 5s/epoch - 8ms/step
# Epoch 10/50
# 611/611 - 5s - loss: 4.7670e-04 - val_loss: 4.3908e-04 - 5s/epoch - 8ms/step
# Epoch 11/50
# 611/611 - 5s - loss: 3.8216e-04 - val_loss: 2.4082e-04 - 5s/epoch - 8ms/step
# Epoch 12/50
# 611/611 - 5s - loss: 3.2752e-04 - val_loss: 1.4748e-04 - 5s/epoch - 8ms/step
# Epoch 13/50
# 611/611 - 5s - loss: 2.9621e-04 - val_loss: 1.0875e-04 - 5s/epoch - 8ms/step
# Epoch 14/50
# 611/611 - 5s - loss: 2.7669e-04 - val_loss: 9.2588e-05 - 5s/epoch - 8ms/step
# Epoch 15/50
# 611/611 - 5s - loss: 2.7018e-04 - val_loss: 9.1032e-05 - 5s/epoch - 8ms/step
# Epoch 16/50
# 611/611 - 5s - loss: 2.6800e-04 - val_loss: 1.0156e-04 - 5s/epoch - 8ms/step
# Epoch 17/50
# 611/611 - 5s - loss: 2.6923e-04 - val_loss: 1.1162e-04 - 5s/epoch - 8ms/step
# Epoch 18/50
# 611/611 - 5s - loss: 2.6298e-04 - val_loss: 1.1674e-04 - 5s/epoch - 7ms/step
# Epoch 19/50
# 611/611 - 5s - loss: 2.4614e-04 - val_loss: 9.2876e-05 - 5s/epoch - 7ms/step
# Epoch 20/50
# 611/611 - 5s - loss: 2.2084e-04 - val_loss: 6.8811e-05 - 5s/epoch - 7ms/step
# Epoch 21/50
# 611/611 - 5s - loss: 2.0168e-04 - val_loss: 5.2650e-05 - 5s/epoch - 7ms/step
# Epoch 22/50
# 611/611 - 5s - loss: 1.8798e-04 - val_loss: 4.5535e-05 - 5s/epoch - 7ms/step
# Epoch 23/50
# 611/611 - 5s - loss: 1.7879e-04 - val_loss: 4.1623e-05 - 5s/epoch - 7ms/step
# Epoch 24/50
# 611/611 - 5s - loss: 1.7290e-04 - val_loss: 4.0353e-05 - 5s/epoch - 7ms/step
# Epoch 25/50
# 611/611 - 5s - loss: 1.6874e-04 - val_loss: 4.0569e-05 - 5s/epoch - 8ms/step
# Epoch 26/50
# 611/611 - 5s - loss: 1.6315e-04 - val_loss: 3.8195e-05 - 5s/epoch - 8ms/step
# Epoch 27/50
# 611/611 - 5s - loss: 1.5864e-04 - val_loss: 3.5649e-05 - 5s/epoch - 8ms/step
# Epoch 28/50
# 611/611 - 5s - loss: 1.5307e-04 - val_loss: 3.3829e-05 - 5s/epoch - 8ms/step
# Epoch 29/50
# 611/611 - 5s - loss: 1.4664e-04 - val_loss: 3.1272e-05 - 5s/epoch - 8ms/step
# Epoch 30/50
# 611/611 - 5s - loss: 1.4080e-04 - val_loss: 2.8802e-05 - 5s/epoch - 8ms/step
# Epoch 31/50
# 611/611 - 5s - loss: 1.3567e-04 - val_loss: 2.6767e-05 - 5s/epoch - 8ms/step
# Epoch 32/50
# 611/611 - 5s - loss: 1.3172e-04 - val_loss: 2.5336e-05 - 5s/epoch - 8ms/step
# Epoch 33/50
# 611/611 - 5s - loss: 1.2810e-04 - val_loss: 2.4093e-05 - 5s/epoch - 8ms/step
# Epoch 34/50
# 611/611 - 5s - loss: 1.2425e-04 - val_loss: 2.2868e-05 - 5s/epoch - 7ms/step
# Epoch 35/50
# 611/611 - 5s - loss: 1.2119e-04 - val_loss: 2.1888e-05 - 5s/epoch - 8ms/step
# Epoch 36/50
# 611/611 - 5s - loss: 1.1809e-04 - val_loss: 2.0803e-05 - 5s/epoch - 8ms/step
# Epoch 37/50
# 611/611 - 5s - loss: 1.1512e-04 - val_loss: 1.9934e-05 - 5s/epoch - 7ms/step
# Epoch 38/50
# 611/611 - 5s - loss: 1.1218e-04 - val_loss: 1.9124e-05 - 5s/epoch - 8ms/step
# Epoch 39/50
# 611/611 - 5s - loss: 1.0965e-04 - val_loss: 1.8338e-05 - 5s/epoch - 8ms/step
# Epoch 40/50
# 611/611 - 5s - loss: 1.0701e-04 - val_loss: 1.7648e-05 - 5s/epoch - 8ms/step
# Epoch 41/50
# 611/611 - 5s - loss: 1.0507e-04 - val_loss: 1.7014e-05 - 5s/epoch - 8ms/step
# Epoch 42/50
# 611/611 - 5s - loss: 1.0249e-04 - val_loss: 1.6374e-05 - 5s/epoch - 8ms/step
# Epoch 43/50
# 611/611 - 5s - loss: 1.0048e-04 - val_loss: 1.5844e-05 - 5s/epoch - 8ms/step
# Epoch 44/50
# 611/611 - 5s - loss: 9.8342e-05 - val_loss: 1.5360e-05 - 5s/epoch - 7ms/step
# Epoch 45/50
# 611/611 - 5s - loss: 9.6503e-05 - val_loss: 1.4917e-05 - 5s/epoch - 8ms/step
# Epoch 46/50
# 611/611 - 5s - loss: 9.4598e-05 - val_loss: 1.4530e-05 - 5s/epoch - 8ms/step
# Epoch 47/50
# 611/611 - 5s - loss: 9.2923e-05 - val_loss: 1.4175e-05 - 5s/epoch - 7ms/step
# Epoch 48/50
# 611/611 - 5s - loss: 9.0997e-05 - val_loss: 1.3864e-05 - 5s/epoch - 8ms/step
# Epoch 49/50
# 611/611 - 5s - loss: 8.9514e-05 - val_loss: 1.3613e-05 - 5s/epoch - 8ms/step
# Epoch 50/50
# 611/611 - 5s - loss: 8.8010e-05 - val_loss: 1.3401e-05 - 5s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-03 09:19:33.107638: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:19:33.219694: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:19:33.312816: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:19:37.799072: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:19:37.828921: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 611/611 - 6s - loss: 3.8686e-04 - val_loss: 0.0011 - 6s/epoch - 9ms/step
# Epoch 2/100
# 611/611 - 5s - loss: 6.2599e-04 - val_loss: 0.0010 - 5s/epoch - 8ms/step
# Epoch 3/100
# 611/611 - 5s - loss: 7.4652e-04 - val_loss: 0.0015 - 5s/epoch - 8ms/step
# Epoch 4/100
# 611/611 - 5s - loss: 9.1337e-04 - val_loss: 0.0025 - 5s/epoch - 8ms/step
# Epoch 5/100
# 611/611 - 5s - loss: 0.0010 - val_loss: 0.0027 - 5s/epoch - 8ms/step
# Epoch 6/100
# 611/611 - 5s - loss: 9.4285e-04 - val_loss: 0.0022 - 5s/epoch - 8ms/step
# Epoch 7/100
# 611/611 - 5s - loss: 7.5844e-04 - val_loss: 0.0015 - 5s/epoch - 8ms/step
# Epoch 8/100
# 611/611 - 5s - loss: 5.7814e-04 - val_loss: 9.9968e-04 - 5s/epoch - 8ms/step
# Epoch 9/100
# 611/611 - 5s - loss: 4.3931e-04 - val_loss: 6.1803e-04 - 5s/epoch - 8ms/step
# Epoch 10/100
# 611/611 - 5s - loss: 3.5029e-04 - val_loss: 3.9100e-04 - 5s/epoch - 8ms/step
# Epoch 11/100
# 611/611 - 5s - loss: 2.9773e-04 - val_loss: 2.7159e-04 - 5s/epoch - 8ms/step
# Epoch 12/100
# 611/611 - 5s - loss: 2.6974e-04 - val_loss: 2.1271e-04 - 5s/epoch - 8ms/step
# Epoch 13/100
# 611/611 - 5s - loss: 2.5702e-04 - val_loss: 1.8575e-04 - 5s/epoch - 8ms/step
# Epoch 14/100
# 611/611 - 5s - loss: 2.5585e-04 - val_loss: 1.8068e-04 - 5s/epoch - 8ms/step
# Epoch 15/100
# 611/611 - 5s - loss: 2.5664e-04 - val_loss: 1.7801e-04 - 5s/epoch - 8ms/step
# Epoch 16/100
# 611/611 - 5s - loss: 2.5403e-04 - val_loss: 1.7128e-04 - 5s/epoch - 8ms/step
# Epoch 17/100
# 611/611 - 5s - loss: 2.4727e-04 - val_loss: 1.5973e-04 - 5s/epoch - 9ms/step
# Epoch 18/100
# 611/611 - 5s - loss: 2.3845e-04 - val_loss: 1.4324e-04 - 5s/epoch - 8ms/step
# Epoch 19/100
# 611/611 - 5s - loss: 2.2596e-04 - val_loss: 1.2422e-04 - 5s/epoch - 8ms/step
# Epoch 20/100
# 611/611 - 5s - loss: 2.1359e-04 - val_loss: 1.0619e-04 - 5s/epoch - 8ms/step
# Epoch 21/100
# 611/611 - 5s - loss: 2.0194e-04 - val_loss: 9.1138e-05 - 5s/epoch - 8ms/step
# Epoch 22/100
# 611/611 - 5s - loss: 1.9168e-04 - val_loss: 7.8674e-05 - 5s/epoch - 8ms/step
# Epoch 23/100
# 611/611 - 5s - loss: 1.8306e-04 - val_loss: 6.8428e-05 - 5s/epoch - 8ms/step
# Epoch 24/100
# 611/611 - 5s - loss: 1.7585e-04 - val_loss: 6.1833e-05 - 5s/epoch - 8ms/step
# Epoch 25/100
# 611/611 - 5s - loss: 1.6991e-04 - val_loss: 5.6165e-05 - 5s/epoch - 8ms/step
# Epoch 26/100
# 611/611 - 5s - loss: 1.6529e-04 - val_loss: 5.1757e-05 - 5s/epoch - 8ms/step
# Epoch 27/100
# 611/611 - 5s - loss: 1.6017e-04 - val_loss: 4.7638e-05 - 5s/epoch - 8ms/step
# Epoch 28/100
# 611/611 - 5s - loss: 1.5562e-04 - val_loss: 4.4716e-05 - 5s/epoch - 8ms/step
# Epoch 29/100
# 611/611 - 5s - loss: 1.5145e-04 - val_loss: 4.1861e-05 - 5s/epoch - 8ms/step
# Epoch 30/100
# 611/611 - 5s - loss: 1.4751e-04 - val_loss: 3.9008e-05 - 5s/epoch - 8ms/step
# Epoch 31/100
# 611/611 - 5s - loss: 1.4311e-04 - val_loss: 3.6524e-05 - 5s/epoch - 8ms/step
# Epoch 32/100
# 611/611 - 5s - loss: 1.3934e-04 - val_loss: 3.4643e-05 - 5s/epoch - 8ms/step
# Epoch 33/100
# 611/611 - 5s - loss: 1.3537e-04 - val_loss: 3.2631e-05 - 5s/epoch - 8ms/step
# Epoch 34/100
# 611/611 - 5s - loss: 1.3162e-04 - val_loss: 3.0821e-05 - 5s/epoch - 8ms/step
# Epoch 35/100
# 611/611 - 5s - loss: 1.2804e-04 - val_loss: 2.9355e-05 - 5s/epoch - 8ms/step
# Epoch 36/100
# 611/611 - 5s - loss: 1.2476e-04 - val_loss: 2.7920e-05 - 5s/epoch - 8ms/step
# Epoch 37/100
# 611/611 - 5s - loss: 1.2125e-04 - val_loss: 2.6664e-05 - 5s/epoch - 8ms/step
# Epoch 38/100
# 611/611 - 5s - loss: 1.1781e-04 - val_loss: 2.5476e-05 - 5s/epoch - 8ms/step
# Epoch 39/100
# 611/611 - 5s - loss: 1.1465e-04 - val_loss: 2.4490e-05 - 5s/epoch - 8ms/step
# Epoch 40/100
# 611/611 - 5s - loss: 1.1141e-04 - val_loss: 2.3284e-05 - 5s/epoch - 8ms/step
# Epoch 41/100
# 611/611 - 5s - loss: 1.0845e-04 - val_loss: 2.2334e-05 - 5s/epoch - 8ms/step
# Epoch 42/100
# 611/611 - 5s - loss: 1.0585e-04 - val_loss: 2.1365e-05 - 5s/epoch - 8ms/step
# Epoch 43/100
# 611/611 - 5s - loss: 1.0337e-04 - val_loss: 2.0620e-05 - 5s/epoch - 8ms/step
# Epoch 44/100
# 611/611 - 5s - loss: 1.0123e-04 - val_loss: 1.9845e-05 - 5s/epoch - 8ms/step
# Epoch 45/100
# 611/611 - 5s - loss: 9.9116e-05 - val_loss: 1.9164e-05 - 5s/epoch - 8ms/step
# Epoch 46/100
# 611/611 - 5s - loss: 9.7224e-05 - val_loss: 1.8510e-05 - 5s/epoch - 8ms/step
# Epoch 47/100
# 611/611 - 5s - loss: 9.5184e-05 - val_loss: 1.7832e-05 - 5s/epoch - 8ms/step
# Epoch 48/100
# 611/611 - 5s - loss: 9.3312e-05 - val_loss: 1.7275e-05 - 5s/epoch - 8ms/step
# Epoch 49/100
# 611/611 - 5s - loss: 9.1526e-05 - val_loss: 1.6748e-05 - 5s/epoch - 8ms/step
# Epoch 50/100
# 611/611 - 5s - loss: 8.9814e-05 - val_loss: 1.6250e-05 - 5s/epoch - 8ms/step
# Epoch 51/100
# 611/611 - 5s - loss: 8.8264e-05 - val_loss: 1.5771e-05 - 5s/epoch - 8ms/step
# Epoch 52/100
# 611/611 - 5s - loss: 8.6453e-05 - val_loss: 1.5295e-05 - 5s/epoch - 8ms/step
# Epoch 53/100
# 611/611 - 5s - loss: 8.4923e-05 - val_loss: 1.4877e-05 - 5s/epoch - 9ms/step
# Epoch 54/100
# 611/611 - 5s - loss: 8.3468e-05 - val_loss: 1.4461e-05 - 5s/epoch - 8ms/step
# Epoch 55/100
# 611/611 - 5s - loss: 8.1821e-05 - val_loss: 1.4105e-05 - 5s/epoch - 9ms/step
# Epoch 56/100
# 611/611 - 6s - loss: 8.0408e-05 - val_loss: 1.3781e-05 - 6s/epoch - 9ms/step
# Epoch 57/100
# 611/611 - 5s - loss: 7.9033e-05 - val_loss: 1.3505e-05 - 5s/epoch - 8ms/step
# Epoch 58/100
# 611/611 - 5s - loss: 7.7875e-05 - val_loss: 1.3268e-05 - 5s/epoch - 8ms/step
# Epoch 59/100
# 611/611 - 5s - loss: 7.6660e-05 - val_loss: 1.3049e-05 - 5s/epoch - 8ms/step
# Epoch 60/100
# 611/611 - 5s - loss: 7.5761e-05 - val_loss: 1.2878e-05 - 5s/epoch - 8ms/step
# Epoch 61/100
# 611/611 - 5s - loss: 7.4631e-05 - val_loss: 1.2696e-05 - 5s/epoch - 8ms/step
# Epoch 62/100
# 611/611 - 5s - loss: 7.3723e-05 - val_loss: 1.2554e-05 - 5s/epoch - 8ms/step
# Epoch 63/100
# 611/611 - 5s - loss: 7.2795e-05 - val_loss: 1.2430e-05 - 5s/epoch - 8ms/step
# Epoch 64/100
# 611/611 - 5s - loss: 7.1936e-05 - val_loss: 1.2325e-05 - 5s/epoch - 8ms/step
# Epoch 65/100
# 611/611 - 5s - loss: 7.1191e-05 - val_loss: 1.2237e-05 - 5s/epoch - 8ms/step
# Epoch 66/100
# 611/611 - 5s - loss: 7.0451e-05 - val_loss: 1.2160e-05 - 5s/epoch - 8ms/step
# Epoch 67/100
# 611/611 - 5s - loss: 6.9747e-05 - val_loss: 1.2091e-05 - 5s/epoch - 8ms/step
# Epoch 68/100
# 611/611 - 5s - loss: 6.9078e-05 - val_loss: 1.2037e-05 - 5s/epoch - 8ms/step
# Epoch 69/100
# 611/611 - 5s - loss: 6.8437e-05 - val_loss: 1.1993e-05 - 5s/epoch - 8ms/step
# Epoch 70/100
# 611/611 - 5s - loss: 6.7905e-05 - val_loss: 1.1965e-05 - 5s/epoch - 8ms/step
# Epoch 71/100
# 611/611 - 5s - loss: 6.7310e-05 - val_loss: 1.1939e-05 - 5s/epoch - 8ms/step
# Epoch 72/100
# 611/611 - 5s - loss: 6.6750e-05 - val_loss: 1.1927e-05 - 5s/epoch - 8ms/step
# Epoch 73/100
# 611/611 - 5s - loss: 6.6249e-05 - val_loss: 1.1927e-05 - 5s/epoch - 8ms/step
# Epoch 74/100
# 611/611 - 5s - loss: 6.5786e-05 - val_loss: 1.1941e-05 - 5s/epoch - 8ms/step
# Epoch 75/100
# 611/611 - 5s - loss: 6.5291e-05 - val_loss: 1.1959e-05 - 5s/epoch - 8ms/step
# Epoch 76/100
# 611/611 - 5s - loss: 6.4844e-05 - val_loss: 1.1992e-05 - 5s/epoch - 8ms/step
# Epoch 77/100
# 611/611 - 5s - loss: 6.4378e-05 - val_loss: 1.2034e-05 - 5s/epoch - 8ms/step
# Epoch 78/100
# 611/611 - 5s - loss: 6.3961e-05 - val_loss: 1.2085e-05 - 5s/epoch - 8ms/step
# Epoch 79/100
# 611/611 - 5s - loss: 6.3561e-05 - val_loss: 1.2141e-05 - 5s/epoch - 8ms/step
# Epoch 80/100
# 611/611 - 5s - loss: 6.3125e-05 - val_loss: 1.2208e-05 - 5s/epoch - 8ms/step
# Epoch 81/100
# 611/611 - 5s - loss: 6.2729e-05 - val_loss: 1.2278e-05 - 5s/epoch - 8ms/step
# Epoch 82/100
# 611/611 - 5s - loss: 6.2362e-05 - val_loss: 1.2351e-05 - 5s/epoch - 8ms/step
# Epoch 83/100
# 611/611 - 5s - loss: 6.2009e-05 - val_loss: 1.2428e-05 - 5s/epoch - 8ms/step
# Epoch 84/100
# 611/611 - 5s - loss: 6.1629e-05 - val_loss: 1.2508e-05 - 5s/epoch - 8ms/step
# Epoch 85/100
# 611/611 - 5s - loss: 6.1288e-05 - val_loss: 1.2587e-05 - 5s/epoch - 8ms/step
# Epoch 86/100
# 611/611 - 5s - loss: 6.0942e-05 - val_loss: 1.2667e-05 - 5s/epoch - 8ms/step
# Epoch 87/100
# 611/611 - 5s - loss: 6.0615e-05 - val_loss: 1.2745e-05 - 5s/epoch - 8ms/step
# Epoch 88/100
# 611/611 - 5s - loss: 6.0284e-05 - val_loss: 1.2823e-05 - 5s/epoch - 8ms/step
# Epoch 89/100
# 611/611 - 5s - loss: 5.9969e-05 - val_loss: 1.2898e-05 - 5s/epoch - 8ms/step
# Epoch 90/100
# 611/611 - 5s - loss: 5.9646e-05 - val_loss: 1.2972e-05 - 5s/epoch - 8ms/step
# Epoch 91/100
# 611/611 - 5s - loss: 5.9319e-05 - val_loss: 1.3042e-05 - 5s/epoch - 8ms/step
# Epoch 92/100
# 611/611 - 5s - loss: 5.8987e-05 - val_loss: 1.3109e-05 - 5s/epoch - 8ms/step
# Epoch 93/100
# 611/611 - 5s - loss: 5.8675e-05 - val_loss: 1.3168e-05 - 5s/epoch - 8ms/step
# Epoch 94/100
# 611/611 - 5s - loss: 5.8356e-05 - val_loss: 1.3225e-05 - 5s/epoch - 9ms/step
# Epoch 95/100
# 611/611 - 5s - loss: 5.8039e-05 - val_loss: 1.3277e-05 - 5s/epoch - 8ms/step
# Epoch 96/100
# 611/611 - 5s - loss: 5.7718e-05 - val_loss: 1.3323e-05 - 5s/epoch - 8ms/step
# Epoch 97/100
# 611/611 - 5s - loss: 5.7409e-05 - val_loss: 1.3361e-05 - 5s/epoch - 8ms/step
# Epoch 98/100
# 611/611 - 5s - loss: 5.7091e-05 - val_loss: 1.3397e-05 - 5s/epoch - 8ms/step
# Epoch 99/100
# 611/611 - 5s - loss: 5.6773e-05 - val_loss: 1.3427e-05 - 5s/epoch - 8ms/step
# Epoch 100/100
# 611/611 - 5s - loss: 5.6458e-05 - val_loss: 1.3451e-05 - 5s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-03 09:27:39.490159: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:27:39.611951: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:27:39.714796: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:27:44.307107: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:27:44.337143: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 611/611 - 6s - loss: 3.9723e-04 - val_loss: 0.0010 - 6s/epoch - 10ms/step
# Epoch 2/100
# 611/611 - 5s - loss: 6.3437e-04 - val_loss: 0.0011 - 5s/epoch - 8ms/step
# Epoch 3/100
# 611/611 - 5s - loss: 8.0347e-04 - val_loss: 0.0019 - 5s/epoch - 8ms/step
# Epoch 4/100
# 611/611 - 5s - loss: 0.0010 - val_loss: 0.0028 - 5s/epoch - 8ms/step
# Epoch 5/100
# 611/611 - 5s - loss: 0.0011 - val_loss: 0.0028 - 5s/epoch - 8ms/step
# Epoch 6/100
# 611/611 - 5s - loss: 0.0010 - val_loss: 0.0022 - 5s/epoch - 8ms/step
# Epoch 7/100
# 611/611 - 5s - loss: 8.1903e-04 - val_loss: 0.0016 - 5s/epoch - 8ms/step
# Epoch 8/100
# 611/611 - 5s - loss: 6.2113e-04 - val_loss: 0.0010 - 5s/epoch - 8ms/step
# Epoch 9/100
# 611/611 - 5s - loss: 4.7038e-04 - val_loss: 6.1998e-04 - 5s/epoch - 8ms/step
# Epoch 10/100
# 611/611 - 5s - loss: 3.6740e-04 - val_loss: 3.6334e-04 - 5s/epoch - 8ms/step
# Epoch 11/100
# 611/611 - 5s - loss: 3.0632e-04 - val_loss: 2.2876e-04 - 5s/epoch - 8ms/step
# Epoch 12/100
# 611/611 - 5s - loss: 2.7274e-04 - val_loss: 1.6514e-04 - 5s/epoch - 8ms/step
# Epoch 13/100
# 611/611 - 5s - loss: 2.5535e-04 - val_loss: 1.3640e-04 - 5s/epoch - 8ms/step
# Epoch 14/100
# 611/611 - 5s - loss: 2.5300e-04 - val_loss: 1.3230e-04 - 5s/epoch - 8ms/step
# Epoch 15/100
# 611/611 - 5s - loss: 2.5168e-04 - val_loss: 1.3128e-04 - 5s/epoch - 8ms/step
# Epoch 16/100
# 611/611 - 5s - loss: 2.4827e-04 - val_loss: 1.2871e-04 - 5s/epoch - 8ms/step
# Epoch 17/100
# 611/611 - 5s - loss: 2.3906e-04 - val_loss: 1.1811e-04 - 5s/epoch - 8ms/step
# Epoch 18/100
# 611/611 - 5s - loss: 2.2949e-04 - val_loss: 1.0616e-04 - 5s/epoch - 8ms/step
# Epoch 19/100
# 611/611 - 5s - loss: 2.1910e-04 - val_loss: 9.4482e-05 - 5s/epoch - 8ms/step
# Epoch 20/100
# 611/611 - 5s - loss: 2.0583e-04 - val_loss: 8.0065e-05 - 5s/epoch - 8ms/step
# Epoch 21/100
# 611/611 - 5s - loss: 1.9416e-04 - val_loss: 6.8198e-05 - 5s/epoch - 8ms/step
# Epoch 22/100
# 611/611 - 5s - loss: 1.8373e-04 - val_loss: 5.9734e-05 - 5s/epoch - 8ms/step
# Epoch 23/100
# 611/611 - 5s - loss: 1.7561e-04 - val_loss: 5.2758e-05 - 5s/epoch - 8ms/step
# Epoch 24/100
# 611/611 - 5s - loss: 1.6896e-04 - val_loss: 4.7564e-05 - 5s/epoch - 8ms/step
# Epoch 25/100
# 611/611 - 5s - loss: 1.6230e-04 - val_loss: 4.3784e-05 - 5s/epoch - 8ms/step
# Epoch 26/100
# 611/611 - 5s - loss: 1.5680e-04 - val_loss: 4.0432e-05 - 5s/epoch - 8ms/step
# Epoch 27/100
# 611/611 - 5s - loss: 1.5211e-04 - val_loss: 3.7345e-05 - 5s/epoch - 8ms/step
# Epoch 28/100
# 611/611 - 5s - loss: 1.4688e-04 - val_loss: 3.4654e-05 - 5s/epoch - 8ms/step
# Epoch 29/100
# 611/611 - 5s - loss: 1.4229e-04 - val_loss: 3.2515e-05 - 5s/epoch - 8ms/step
# Epoch 30/100
# 611/611 - 5s - loss: 1.3790e-04 - val_loss: 3.0728e-05 - 5s/epoch - 8ms/step
# Epoch 31/100
# 611/611 - 5s - loss: 1.3431e-04 - val_loss: 2.8890e-05 - 5s/epoch - 8ms/step
# Epoch 32/100
# 611/611 - 5s - loss: 1.3035e-04 - val_loss: 2.7190e-05 - 5s/epoch - 8ms/step
# Epoch 33/100
# 611/611 - 5s - loss: 1.2643e-04 - val_loss: 2.5847e-05 - 5s/epoch - 8ms/step
# Epoch 34/100
# 611/611 - 5s - loss: 1.2304e-04 - val_loss: 2.4673e-05 - 5s/epoch - 8ms/step
# Epoch 35/100
# 611/611 - 5s - loss: 1.1987e-04 - val_loss: 2.3595e-05 - 5s/epoch - 8ms/step
# Epoch 36/100
# 611/611 - 5s - loss: 1.1655e-04 - val_loss: 2.2390e-05 - 5s/epoch - 8ms/step
# Epoch 37/100
# 611/611 - 5s - loss: 1.1350e-04 - val_loss: 2.1334e-05 - 5s/epoch - 8ms/step
# Epoch 38/100
# 611/611 - 5s - loss: 1.1067e-04 - val_loss: 2.0353e-05 - 5s/epoch - 8ms/step
# Epoch 39/100
# 611/611 - 5s - loss: 1.0824e-04 - val_loss: 1.9577e-05 - 5s/epoch - 8ms/step
# Epoch 40/100
# 611/611 - 5s - loss: 1.0624e-04 - val_loss: 1.8843e-05 - 5s/epoch - 8ms/step
# Epoch 41/100
# 611/611 - 5s - loss: 1.0453e-04 - val_loss: 1.8200e-05 - 5s/epoch - 8ms/step
# Epoch 42/100
# 611/611 - 5s - loss: 1.0284e-04 - val_loss: 1.7565e-05 - 5s/epoch - 8ms/step
# Epoch 43/100
# 611/611 - 5s - loss: 1.0106e-04 - val_loss: 1.6995e-05 - 5s/epoch - 8ms/step
# Epoch 44/100
# 611/611 - 5s - loss: 9.9587e-05 - val_loss: 1.6476e-05 - 5s/epoch - 8ms/step
# Epoch 45/100
# 611/611 - 5s - loss: 9.8049e-05 - val_loss: 1.5990e-05 - 5s/epoch - 8ms/step
# Epoch 46/100
# 611/611 - 5s - loss: 9.6327e-05 - val_loss: 1.5553e-05 - 5s/epoch - 8ms/step
# Epoch 47/100
# 611/611 - 5s - loss: 9.4833e-05 - val_loss: 1.5178e-05 - 5s/epoch - 8ms/step
# Epoch 48/100
# 611/611 - 5s - loss: 9.3537e-05 - val_loss: 1.4820e-05 - 5s/epoch - 8ms/step
# Epoch 49/100
# 611/611 - 5s - loss: 9.1915e-05 - val_loss: 1.4478e-05 - 5s/epoch - 8ms/step
# Epoch 50/100
# 611/611 - 5s - loss: 9.0350e-05 - val_loss: 1.4186e-05 - 5s/epoch - 7ms/step
# Epoch 51/100
# 611/611 - 5s - loss: 8.8844e-05 - val_loss: 1.3945e-05 - 5s/epoch - 7ms/step
# Epoch 52/100
# 611/611 - 5s - loss: 8.7572e-05 - val_loss: 1.3731e-05 - 5s/epoch - 7ms/step
# Epoch 53/100
# 611/611 - 5s - loss: 8.6101e-05 - val_loss: 1.3551e-05 - 5s/epoch - 7ms/step
# Epoch 54/100
# 611/611 - 5s - loss: 8.4846e-05 - val_loss: 1.3406e-05 - 5s/epoch - 8ms/step
# Epoch 55/100
# 611/611 - 5s - loss: 8.3386e-05 - val_loss: 1.3253e-05 - 5s/epoch - 8ms/step
# Epoch 56/100
# 611/611 - 5s - loss: 8.2255e-05 - val_loss: 1.3148e-05 - 5s/epoch - 7ms/step
# Epoch 57/100
# 611/611 - 5s - loss: 8.1038e-05 - val_loss: 1.3055e-05 - 5s/epoch - 8ms/step
# Epoch 58/100
# 611/611 - 5s - loss: 7.9986e-05 - val_loss: 1.2973e-05 - 5s/epoch - 7ms/step
# Epoch 59/100
# 611/611 - 5s - loss: 7.9034e-05 - val_loss: 1.2909e-05 - 5s/epoch - 8ms/step
# Epoch 60/100
# 611/611 - 5s - loss: 7.8089e-05 - val_loss: 1.2842e-05 - 5s/epoch - 7ms/step
# Epoch 61/100
# 611/611 - 5s - loss: 7.7246e-05 - val_loss: 1.2792e-05 - 5s/epoch - 7ms/step
# Epoch 62/100
# 611/611 - 5s - loss: 7.6463e-05 - val_loss: 1.2741e-05 - 5s/epoch - 7ms/step
# Epoch 63/100
# 611/611 - 5s - loss: 7.5608e-05 - val_loss: 1.2686e-05 - 5s/epoch - 8ms/step
# Epoch 64/100
# 611/611 - 5s - loss: 7.4780e-05 - val_loss: 1.2639e-05 - 5s/epoch - 8ms/step
# Epoch 65/100
# 611/611 - 5s - loss: 7.4110e-05 - val_loss: 1.2604e-05 - 5s/epoch - 7ms/step
# Epoch 66/100
# 611/611 - 5s - loss: 7.3321e-05 - val_loss: 1.2565e-05 - 5s/epoch - 8ms/step
# Epoch 67/100
# 611/611 - 5s - loss: 7.2561e-05 - val_loss: 1.2536e-05 - 5s/epoch - 8ms/step
# Epoch 68/100
# 611/611 - 5s - loss: 7.1937e-05 - val_loss: 1.2512e-05 - 5s/epoch - 7ms/step
# Epoch 69/100
# 611/611 - 5s - loss: 7.1294e-05 - val_loss: 1.2492e-05 - 5s/epoch - 8ms/step
# Epoch 70/100
# 611/611 - 5s - loss: 7.0725e-05 - val_loss: 1.2478e-05 - 5s/epoch - 7ms/step
# Epoch 71/100
# 611/611 - 5s - loss: 7.0078e-05 - val_loss: 1.2463e-05 - 5s/epoch - 8ms/step
# Epoch 72/100
# 611/611 - 5s - loss: 6.9471e-05 - val_loss: 1.2458e-05 - 5s/epoch - 7ms/step
# Epoch 73/100
# 611/611 - 5s - loss: 6.8986e-05 - val_loss: 1.2457e-05 - 5s/epoch - 7ms/step
# Epoch 74/100
# 611/611 - 5s - loss: 6.8376e-05 - val_loss: 1.2459e-05 - 5s/epoch - 7ms/step
# Epoch 75/100
# 611/611 - 5s - loss: 6.7860e-05 - val_loss: 1.2468e-05 - 5s/epoch - 7ms/step
# Epoch 76/100
# 611/611 - 5s - loss: 6.7376e-05 - val_loss: 1.2481e-05 - 5s/epoch - 7ms/step
# Epoch 77/100
# 611/611 - 5s - loss: 6.6890e-05 - val_loss: 1.2498e-05 - 5s/epoch - 7ms/step
# Epoch 78/100
# 611/611 - 5s - loss: 6.6397e-05 - val_loss: 1.2519e-05 - 5s/epoch - 7ms/step
# Epoch 79/100
# 611/611 - 5s - loss: 6.5941e-05 - val_loss: 1.2545e-05 - 5s/epoch - 8ms/step
# Epoch 80/100
# 611/611 - 5s - loss: 6.5506e-05 - val_loss: 1.2576e-05 - 5s/epoch - 7ms/step
# Epoch 81/100
# 611/611 - 5s - loss: 6.5065e-05 - val_loss: 1.2608e-05 - 5s/epoch - 8ms/step
# Epoch 82/100
# 611/611 - 5s - loss: 6.4621e-05 - val_loss: 1.2647e-05 - 5s/epoch - 7ms/step
# Epoch 83/100
# 611/611 - 5s - loss: 6.4224e-05 - val_loss: 1.2688e-05 - 5s/epoch - 7ms/step
# Epoch 84/100
# 611/611 - 5s - loss: 6.3817e-05 - val_loss: 1.2734e-05 - 5s/epoch - 8ms/step
# Epoch 85/100
# 611/611 - 5s - loss: 6.3425e-05 - val_loss: 1.2783e-05 - 5s/epoch - 7ms/step
# Epoch 86/100
# 611/611 - 5s - loss: 6.3018e-05 - val_loss: 1.2834e-05 - 5s/epoch - 8ms/step
# Epoch 87/100
# 611/611 - 5s - loss: 6.2652e-05 - val_loss: 1.2885e-05 - 5s/epoch - 7ms/step
# Epoch 88/100
# 611/611 - 5s - loss: 6.2254e-05 - val_loss: 1.2941e-05 - 5s/epoch - 8ms/step
# Epoch 89/100
# 611/611 - 5s - loss: 6.1880e-05 - val_loss: 1.3000e-05 - 5s/epoch - 7ms/step
# Epoch 90/100
# 611/611 - 5s - loss: 6.1523e-05 - val_loss: 1.3060e-05 - 5s/epoch - 7ms/step
# Epoch 91/100
# 611/611 - 5s - loss: 6.1157e-05 - val_loss: 1.3122e-05 - 5s/epoch - 8ms/step
# Epoch 92/100
# 611/611 - 5s - loss: 6.0803e-05 - val_loss: 1.3186e-05 - 5s/epoch - 7ms/step
# Epoch 93/100
# 611/611 - 5s - loss: 6.0453e-05 - val_loss: 1.3252e-05 - 5s/epoch - 8ms/step
# Epoch 94/100
# 611/611 - 5s - loss: 6.0098e-05 - val_loss: 1.3319e-05 - 5s/epoch - 8ms/step
# Epoch 95/100
# 611/611 - 5s - loss: 5.9743e-05 - val_loss: 1.3386e-05 - 5s/epoch - 8ms/step
# Epoch 96/100
# 611/611 - 5s - loss: 5.9410e-05 - val_loss: 1.3450e-05 - 5s/epoch - 9ms/step
# Epoch 97/100
# 611/611 - 5s - loss: 5.9070e-05 - val_loss: 1.3515e-05 - 5s/epoch - 8ms/step
# Epoch 98/100
# 611/611 - 5s - loss: 5.8749e-05 - val_loss: 1.3578e-05 - 5s/epoch - 8ms/step
# Epoch 99/100
# 611/611 - 5s - loss: 5.8412e-05 - val_loss: 1.3641e-05 - 5s/epoch - 8ms/step
# Epoch 100/100
# 611/611 - 5s - loss: 5.8092e-05 - val_loss: 1.3699e-05 - 5s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-03 09:35:30.090128: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:35:30.195739: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:35:30.305623: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:35:34.739320: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:35:34.770180: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 611/611 - 6s - loss: 5.6195e-04 - val_loss: 0.0015 - 6s/epoch - 9ms/step
# Epoch 2/100
# 611/611 - 5s - loss: 9.6094e-04 - val_loss: 0.0019 - 5s/epoch - 7ms/step
# Epoch 3/100
# 611/611 - 5s - loss: 0.0011 - val_loss: 0.0032 - 5s/epoch - 7ms/step
# Epoch 4/100
# 611/611 - 5s - loss: 0.0013 - val_loss: 0.0041 - 5s/epoch - 8ms/step
# Epoch 5/100
# 611/611 - 5s - loss: 0.0014 - val_loss: 0.0040 - 5s/epoch - 7ms/step
# Epoch 6/100
# 611/611 - 5s - loss: 0.0014 - val_loss: 0.0032 - 5s/epoch - 7ms/step
# Epoch 7/100
# 611/611 - 5s - loss: 0.0012 - val_loss: 0.0023 - 5s/epoch - 7ms/step
# Epoch 8/100
# 611/611 - 5s - loss: 8.8487e-04 - val_loss: 0.0015 - 5s/epoch - 7ms/step
# Epoch 9/100
# 611/611 - 5s - loss: 6.4092e-04 - val_loss: 8.6959e-04 - 5s/epoch - 7ms/step
# Epoch 10/100
# 611/611 - 5s - loss: 4.7673e-04 - val_loss: 4.8240e-04 - 5s/epoch - 7ms/step
# Epoch 11/100
# 611/611 - 5s - loss: 3.7555e-04 - val_loss: 2.6438e-04 - 5s/epoch - 8ms/step
# Epoch 12/100
# 611/611 - 5s - loss: 3.1892e-04 - val_loss: 1.6185e-04 - 5s/epoch - 7ms/step
# Epoch 13/100
# 611/611 - 5s - loss: 2.8712e-04 - val_loss: 1.1949e-04 - 5s/epoch - 7ms/step
# Epoch 14/100
# 611/611 - 5s - loss: 2.6878e-04 - val_loss: 1.0289e-04 - 5s/epoch - 7ms/step
# Epoch 15/100
# 611/611 - 5s - loss: 2.6236e-04 - val_loss: 1.0196e-04 - 5s/epoch - 8ms/step
# Epoch 16/100
# 611/611 - 5s - loss: 2.6145e-04 - val_loss: 1.1169e-04 - 5s/epoch - 7ms/step
# Epoch 17/100
# 611/611 - 5s - loss: 2.5939e-04 - val_loss: 1.1825e-04 - 5s/epoch - 7ms/step
# Epoch 18/100
# 611/611 - 5s - loss: 2.4997e-04 - val_loss: 1.0820e-04 - 5s/epoch - 8ms/step
# Epoch 19/100
# 611/611 - 5s - loss: 2.3077e-04 - val_loss: 8.8780e-05 - 5s/epoch - 7ms/step
# Epoch 20/100
# 611/611 - 5s - loss: 2.1407e-04 - val_loss: 7.3640e-05 - 5s/epoch - 7ms/step
# Epoch 21/100
# 611/611 - 5s - loss: 1.9721e-04 - val_loss: 6.0292e-05 - 5s/epoch - 7ms/step
# Epoch 22/100
# 611/611 - 4s - loss: 1.8600e-04 - val_loss: 5.1867e-05 - 4s/epoch - 7ms/step
# Epoch 23/100
# 611/611 - 5s - loss: 1.7689e-04 - val_loss: 4.6189e-05 - 5s/epoch - 8ms/step
# Epoch 24/100
# 611/611 - 5s - loss: 1.6929e-04 - val_loss: 4.2244e-05 - 5s/epoch - 8ms/step
# Epoch 25/100
# 611/611 - 5s - loss: 1.6278e-04 - val_loss: 3.9436e-05 - 5s/epoch - 8ms/step
# Epoch 26/100
# 611/611 - 5s - loss: 1.5842e-04 - val_loss: 3.7654e-05 - 5s/epoch - 7ms/step
# Epoch 27/100
# 611/611 - 5s - loss: 1.5341e-04 - val_loss: 3.5573e-05 - 5s/epoch - 8ms/step
# Epoch 28/100
# 611/611 - 5s - loss: 1.4833e-04 - val_loss: 3.3471e-05 - 5s/epoch - 8ms/step
# Epoch 29/100
# 611/611 - 5s - loss: 1.4370e-04 - val_loss: 3.0953e-05 - 5s/epoch - 8ms/step
# Epoch 30/100
# 611/611 - 5s - loss: 1.3909e-04 - val_loss: 2.8890e-05 - 5s/epoch - 8ms/step
# Epoch 31/100
# 611/611 - 5s - loss: 1.3424e-04 - val_loss: 2.6853e-05 - 5s/epoch - 7ms/step
# Epoch 32/100
# 611/611 - 5s - loss: 1.3004e-04 - val_loss: 2.5299e-05 - 5s/epoch - 7ms/step
# Epoch 33/100
# 611/611 - 5s - loss: 1.2598e-04 - val_loss: 2.3503e-05 - 5s/epoch - 7ms/step
# Epoch 34/100
# 611/611 - 5s - loss: 1.2254e-04 - val_loss: 2.2356e-05 - 5s/epoch - 7ms/step
# Epoch 35/100
# 611/611 - 5s - loss: 1.1920e-04 - val_loss: 2.1156e-05 - 5s/epoch - 8ms/step
# Epoch 36/100
# 611/611 - 5s - loss: 1.1639e-04 - val_loss: 2.0141e-05 - 5s/epoch - 8ms/step
# Epoch 37/100
# 611/611 - 5s - loss: 1.1341e-04 - val_loss: 1.9415e-05 - 5s/epoch - 7ms/step
# Epoch 38/100
# 611/611 - 5s - loss: 1.1069e-04 - val_loss: 1.8578e-05 - 5s/epoch - 7ms/step
# Epoch 39/100
# 611/611 - 5s - loss: 1.0842e-04 - val_loss: 1.7904e-05 - 5s/epoch - 8ms/step
# Epoch 40/100
# 611/611 - 5s - loss: 1.0600e-04 - val_loss: 1.7240e-05 - 5s/epoch - 7ms/step
# Epoch 41/100
# 611/611 - 5s - loss: 1.0369e-04 - val_loss: 1.6694e-05 - 5s/epoch - 7ms/step
# Epoch 42/100
# 611/611 - 5s - loss: 1.0130e-04 - val_loss: 1.6014e-05 - 5s/epoch - 7ms/step
# Epoch 43/100
# 611/611 - 5s - loss: 9.9163e-05 - val_loss: 1.5518e-05 - 5s/epoch - 7ms/step
# Epoch 44/100
# 611/611 - 5s - loss: 9.6806e-05 - val_loss: 1.5044e-05 - 5s/epoch - 7ms/step
# Epoch 45/100
# 611/611 - 5s - loss: 9.5010e-05 - val_loss: 1.4673e-05 - 5s/epoch - 7ms/step
# Epoch 46/100
# 611/611 - 5s - loss: 9.3144e-05 - val_loss: 1.4305e-05 - 5s/epoch - 7ms/step
# Epoch 47/100
# 611/611 - 5s - loss: 9.1435e-05 - val_loss: 1.4006e-05 - 5s/epoch - 7ms/step
# Epoch 48/100
# 611/611 - 5s - loss: 8.9687e-05 - val_loss: 1.3733e-05 - 5s/epoch - 8ms/step
# Epoch 49/100
# 611/611 - 5s - loss: 8.8324e-05 - val_loss: 1.3512e-05 - 5s/epoch - 7ms/step
# Epoch 50/100
# 611/611 - 5s - loss: 8.6524e-05 - val_loss: 1.3286e-05 - 5s/epoch - 7ms/step
# Epoch 51/100
# 611/611 - 5s - loss: 8.5201e-05 - val_loss: 1.3139e-05 - 5s/epoch - 7ms/step
# Epoch 52/100
# 611/611 - 5s - loss: 8.3985e-05 - val_loss: 1.3026e-05 - 5s/epoch - 7ms/step
# Epoch 53/100
# 611/611 - 5s - loss: 8.2792e-05 - val_loss: 1.2900e-05 - 5s/epoch - 7ms/step
# Epoch 54/100
# 611/611 - 5s - loss: 8.1239e-05 - val_loss: 1.2809e-05 - 5s/epoch - 7ms/step
# Epoch 55/100
# 611/611 - 5s - loss: 8.0087e-05 - val_loss: 1.2757e-05 - 5s/epoch - 7ms/step
# Epoch 56/100
# 611/611 - 5s - loss: 7.8965e-05 - val_loss: 1.2737e-05 - 5s/epoch - 7ms/step
# Epoch 57/100
# 611/611 - 5s - loss: 7.8052e-05 - val_loss: 1.2725e-05 - 5s/epoch - 7ms/step
# Epoch 58/100
# 611/611 - 5s - loss: 7.7064e-05 - val_loss: 1.2749e-05 - 5s/epoch - 7ms/step
# Epoch 59/100
# 611/611 - 5s - loss: 7.6128e-05 - val_loss: 1.2763e-05 - 5s/epoch - 7ms/step
# Epoch 60/100
# 611/611 - 5s - loss: 7.5207e-05 - val_loss: 1.2802e-05 - 5s/epoch - 7ms/step
# Epoch 61/100
# 611/611 - 5s - loss: 7.4330e-05 - val_loss: 1.2851e-05 - 5s/epoch - 7ms/step
# Epoch 62/100
# 611/611 - 5s - loss: 7.3482e-05 - val_loss: 1.2922e-05 - 5s/epoch - 7ms/step
# Epoch 63/100
# 611/611 - 5s - loss: 7.2649e-05 - val_loss: 1.3000e-05 - 5s/epoch - 7ms/step
# Epoch 64/100
# 611/611 - 5s - loss: 7.1989e-05 - val_loss: 1.3097e-05 - 5s/epoch - 7ms/step
# Epoch 65/100
# 611/611 - 5s - loss: 7.1409e-05 - val_loss: 1.3193e-05 - 5s/epoch - 7ms/step
# Epoch 66/100
# 611/611 - 5s - loss: 7.0654e-05 - val_loss: 1.3299e-05 - 5s/epoch - 7ms/step
# Epoch 67/100
# 611/611 - 5s - loss: 6.9811e-05 - val_loss: 1.3417e-05 - 5s/epoch - 7ms/step
# Epoch 68/100
# 611/611 - 5s - loss: 6.9160e-05 - val_loss: 1.3549e-05 - 5s/epoch - 7ms/step
# Epoch 69/100
# 611/611 - 5s - loss: 6.8565e-05 - val_loss: 1.3661e-05 - 5s/epoch - 8ms/step
# Epoch 70/100
# 611/611 - 5s - loss: 6.8089e-05 - val_loss: 1.3784e-05 - 5s/epoch - 7ms/step
# Epoch 71/100
# 611/611 - 5s - loss: 6.7489e-05 - val_loss: 1.3898e-05 - 5s/epoch - 8ms/step
# Epoch 72/100
# 611/611 - 5s - loss: 6.6969e-05 - val_loss: 1.4017e-05 - 5s/epoch - 8ms/step
# Epoch 73/100
# 611/611 - 5s - loss: 6.6435e-05 - val_loss: 1.4133e-05 - 5s/epoch - 7ms/step
# Epoch 74/100
# 611/611 - 5s - loss: 6.5958e-05 - val_loss: 1.4243e-05 - 5s/epoch - 8ms/step
# Epoch 75/100
# 611/611 - 5s - loss: 6.5512e-05 - val_loss: 1.4348e-05 - 5s/epoch - 8ms/step
# Epoch 76/100
# 611/611 - 5s - loss: 6.5113e-05 - val_loss: 1.4452e-05 - 5s/epoch - 7ms/step
# Epoch 77/100
# 611/611 - 5s - loss: 6.4652e-05 - val_loss: 1.4556e-05 - 5s/epoch - 8ms/step
# Epoch 78/100
# 611/611 - 5s - loss: 6.4175e-05 - val_loss: 1.4663e-05 - 5s/epoch - 8ms/step
# Epoch 79/100
# 611/611 - 5s - loss: 6.3820e-05 - val_loss: 1.4747e-05 - 5s/epoch - 8ms/step
# Epoch 80/100
# 611/611 - 5s - loss: 6.3417e-05 - val_loss: 1.4841e-05 - 5s/epoch - 8ms/step
# Epoch 81/100
# 611/611 - 5s - loss: 6.3030e-05 - val_loss: 1.4926e-05 - 5s/epoch - 8ms/step
# Epoch 82/100
# 611/611 - 5s - loss: 6.2658e-05 - val_loss: 1.5012e-05 - 5s/epoch - 8ms/step
# Epoch 83/100
# 611/611 - 5s - loss: 6.2303e-05 - val_loss: 1.5092e-05 - 5s/epoch - 8ms/step
# Epoch 84/100
# 611/611 - 4s - loss: 6.1987e-05 - val_loss: 1.5168e-05 - 4s/epoch - 7ms/step
# Epoch 85/100
# 611/611 - 5s - loss: 6.1662e-05 - val_loss: 1.5244e-05 - 5s/epoch - 8ms/step
# Epoch 86/100
# 611/611 - 5s - loss: 6.1301e-05 - val_loss: 1.5331e-05 - 5s/epoch - 8ms/step
# Epoch 87/100
# 611/611 - 5s - loss: 6.0968e-05 - val_loss: 1.5401e-05 - 5s/epoch - 8ms/step
# Epoch 88/100
# 611/611 - 5s - loss: 6.0654e-05 - val_loss: 1.5472e-05 - 5s/epoch - 8ms/step
# Epoch 89/100
# 611/611 - 5s - loss: 6.0336e-05 - val_loss: 1.5540e-05 - 5s/epoch - 8ms/step
# Epoch 90/100
# 611/611 - 5s - loss: 6.0028e-05 - val_loss: 1.5606e-05 - 5s/epoch - 8ms/step
# Epoch 91/100
# 611/611 - 5s - loss: 5.9719e-05 - val_loss: 1.5669e-05 - 5s/epoch - 8ms/step
# Epoch 92/100
# 611/611 - 5s - loss: 5.9434e-05 - val_loss: 1.5725e-05 - 5s/epoch - 7ms/step
# Epoch 93/100
# 611/611 - 5s - loss: 5.9133e-05 - val_loss: 1.5783e-05 - 5s/epoch - 8ms/step
# Epoch 94/100
# 611/611 - 5s - loss: 5.8839e-05 - val_loss: 1.5837e-05 - 5s/epoch - 7ms/step
# Epoch 95/100
# 611/611 - 4s - loss: 5.8559e-05 - val_loss: 1.5880e-05 - 4s/epoch - 7ms/step
# Epoch 96/100
# 611/611 - 5s - loss: 5.8285e-05 - val_loss: 1.5925e-05 - 5s/epoch - 8ms/step
# Epoch 97/100
# 611/611 - 5s - loss: 5.8010e-05 - val_loss: 1.5963e-05 - 5s/epoch - 8ms/step
# Epoch 98/100
# 611/611 - 5s - loss: 5.7738e-05 - val_loss: 1.5999e-05 - 5s/epoch - 8ms/step
# Epoch 99/100
# 611/611 - 5s - loss: 5.7473e-05 - val_loss: 1.6030e-05 - 5s/epoch - 8ms/step
# Epoch 100/100
# 611/611 - 5s - loss: 5.7198e-05 - val_loss: 1.6062e-05 - 5s/epoch - 8ms/step

# %%
i=0
wb1 = Workbook()
ws1 = wb1.active
for m in models1:
    # make a prediction
    test_x2 = test_X
    yhat = LSTMUnit.predict(test_x2, m)
    inv_yhat = Preprocessing.inverse_scaler(yhat, scaler)
    inv_y = Preprocessing.inverse_scaler(test_y.reshape(-1,1), scaler)
    print(hyperparam1[i])
    print("Epoch: "+ str(lstms1[i].params['epochs']))
    print("Neurons: "+str(m.layers[0].units))
    i = i+1
    ws1['A'+str(i)] = 'LSTM'
    ws1['B'+str(i)] = hyperparam1[i-1][0]
    ws1['C'+str(i)] = hyperparam1[i-1][1]
    ws1['D'+str(i)] = hyperparam1[i-1][2]
    print('RMSE')
    print(Evaluation.rmse(inv_y,inv_yhat)[0])
    ws1['E'+str(i)] = Evaluation.rmse(inv_y,inv_yhat)[0]
    print('MAE')
    print(Evaluation.mae(inv_y,inv_yhat)[0])
    ws1['F'+str(i)] = Evaluation.mae(inv_y,inv_yhat)[0]
    print('MAPE')
    print(Evaluation.mape(inv_y,inv_yhat)[0])
    ws1['G'+str(i)] = Evaluation.mape(inv_y,inv_yhat)[0]
    LSTMUnit.save_model(m, 0, 'ETH',hyperparam1[i-1])
wb1.save('LSTM_ETH_result1.xlsx')
# Out:
#  13/153 [=>............................] - ETA: 0s
# 2023-04-03 09:43:10.760114: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:10.820529: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (32, 25, 50)
# Epoch: 25
# Neurons: 50
# RMSE
# 32.90490734086203
# MAE
# 27.99310066199679
# MAPE
# 2.151224374634619
#  34/153 [=====>........................] - ETA: 0s
# 2023-04-03 09:43:11.591366: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:11.621572: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (32, 25, 60)
# Epoch: 25
# Neurons: 60
# RMSE
# 30.797957656979634
# MAE
# 26.125252173396923
# MAPE
# 2.0048741695509325
#  34/153 [=====>........................] - ETA: 0s
# 2023-04-03 09:43:12.265890: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:12.292302: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (32, 25, 100)
# Epoch: 25
# Neurons: 100
# RMSE
# 29.67325168972083
# MAE
# 25.11857025115204
# MAPE
# 1.9285417440852122
#  36/153 [======>.......................] - ETA: 0s
# 2023-04-03 09:43:12.924417: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:12.950806: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (32, 50, 50)
# Epoch: 50
# Neurons: 50
# RMSE
# 17.858519307855158
# MAE
# 13.421864835563602
# MAPE
# 0.9474924583285105
#  35/153 [=====>........................] - ETA: 0s
# 2023-04-03 09:43:13.589925: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:13.615974: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (32, 50, 60)
# Epoch: 50
# Neurons: 60
# RMSE
# 18.159887878637335
# MAE
# 13.59224782810417
# MAPE
# 0.9533037684020098
#  35/153 [=====>........................] - ETA: 0s
# 2023-04-03 09:43:14.255125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:14.281492: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (32, 50, 100)
# Epoch: 50
# Neurons: 100
# RMSE
# 17.38898294564523
# MAE
# 12.486620126995165
# MAPE
# 0.8619532499947364
#  35/153 [=====>........................] - ETA: 0s
# 2023-04-03 09:43:14.900970: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:14.926719: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (32, 100, 50)
# Epoch: 100
# Neurons: 50
# RMSE
# 17.42129655698313
# MAE
# 13.547026672926213
# MAPE
# 0.9489157025579577
#  35/153 [=====>........................] - ETA: 0s
# 2023-04-03 09:43:15.567055: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:15.593263: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (32, 100, 60)
# Epoch: 100
# Neurons: 60
# RMSE
# 17.580971450501206
# MAE
# 13.65033326171073
# MAPE
# 0.9531738648030561
#  36/153 [======>.......................] - ETA: 0s
# 2023-04-03 09:43:16.225537: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:16.251363: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (32, 100, 100)
# Epoch: 100
# Neurons: 100
# RMSE
# 19.036965252972852
# MAE
# 15.608541589773306
# MAPE
# 1.1098463301100658

# %%
lstms2 = []
models2 = []
for batch, epoch, neuron in hyperparam2:
    model, lstm = LSTMUnit.train_lstm(train_X, train_y, test_X, test_y, neuron, epoch, batch)
    lstms2.append(lstm)
    models2.append(model)
# Out:
# Epoch 1/25
# 2023-04-03 09:43:17.256482: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:17.344581: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:17.460982: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:19.988240: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:43:20.018372: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 306/306 - 3s - loss: 7.6961e-04 - val_loss: 0.0014 - 3s/epoch - 11ms/step
# Epoch 2/25
# 306/306 - 3s - loss: 0.0011 - val_loss: 0.0022 - 3s/epoch - 8ms/step
# Epoch 3/25
# 306/306 - 2s - loss: 0.0018 - val_loss: 0.0043 - 2s/epoch - 8ms/step
# Epoch 4/25
# 306/306 - 2s - loss: 0.0025 - val_loss: 0.0062 - 2s/epoch - 8ms/step
# Epoch 5/25
# 306/306 - 2s - loss: 0.0026 - val_loss: 0.0065 - 2s/epoch - 8ms/step
# Epoch 6/25
# 306/306 - 2s - loss: 0.0022 - val_loss: 0.0046 - 2s/epoch - 8ms/step
# Epoch 7/25
# 306/306 - 2s - loss: 0.0015 - val_loss: 0.0027 - 2s/epoch - 8ms/step
# Epoch 8/25
# 306/306 - 2s - loss: 9.6181e-04 - val_loss: 0.0014 - 2s/epoch - 8ms/step
# Epoch 9/25
# 306/306 - 2s - loss: 6.2370e-04 - val_loss: 8.0063e-04 - 2s/epoch - 8ms/step
# Epoch 10/25
# 306/306 - 2s - loss: 4.4215e-04 - val_loss: 5.2840e-04 - 2s/epoch - 8ms/step
# Epoch 11/25
# 306/306 - 2s - loss: 3.5228e-04 - val_loss: 4.1621e-04 - 2s/epoch - 8ms/step
# Epoch 12/25
# 306/306 - 2s - loss: 3.1357e-04 - val_loss: 3.7474e-04 - 2s/epoch - 8ms/step
# Epoch 13/25
# 306/306 - 2s - loss: 3.0687e-04 - val_loss: 3.7465e-04 - 2s/epoch - 8ms/step
# Epoch 14/25
# 306/306 - 2s - loss: 3.2413e-04 - val_loss: 4.1227e-04 - 2s/epoch - 8ms/step
# Epoch 15/25
# 306/306 - 2s - loss: 3.5666e-04 - val_loss: 4.7745e-04 - 2s/epoch - 8ms/step
# Epoch 16/25
# 306/306 - 2s - loss: 3.9187e-04 - val_loss: 5.3802e-04 - 2s/epoch - 8ms/step
# Epoch 17/25
# 306/306 - 2s - loss: 4.3594e-04 - val_loss: 6.5180e-04 - 2s/epoch - 8ms/step
# Epoch 18/25
# 306/306 - 3s - loss: 5.1768e-04 - val_loss: 8.4619e-04 - 3s/epoch - 8ms/step
# Epoch 19/25
# 306/306 - 3s - loss: 6.1896e-04 - val_loss: 0.0010 - 3s/epoch - 8ms/step
# Epoch 20/25
# 306/306 - 2s - loss: 6.9828e-04 - val_loss: 0.0011 - 2s/epoch - 8ms/step
# Epoch 21/25
# 306/306 - 2s - loss: 7.3285e-04 - val_loss: 0.0011 - 2s/epoch - 8ms/step
# Epoch 22/25
# 306/306 - 2s - loss: 6.8545e-04 - val_loss: 9.1770e-04 - 2s/epoch - 8ms/step
# Epoch 23/25
# 306/306 - 2s - loss: 5.8398e-04 - val_loss: 6.9215e-04 - 2s/epoch - 8ms/step
# Epoch 24/25
# 306/306 - 2s - loss: 4.7009e-04 - val_loss: 4.8972e-04 - 2s/epoch - 8ms/step
# Epoch 25/25
# 306/306 - 2s - loss: 3.8261e-04 - val_loss: 3.5768e-04 - 2s/epoch - 8ms/step
# Epoch 1/25
# 2023-04-03 09:44:19.406175: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:44:19.542986: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:44:19.685224: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:44:22.214123: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:44:22.244638: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 306/306 - 4s - loss: 7.4420e-04 - val_loss: 0.0013 - 4s/epoch - 12ms/step
# Epoch 2/25
# 306/306 - 2s - loss: 0.0010 - val_loss: 0.0016 - 2s/epoch - 8ms/step
# Epoch 3/25
# 306/306 - 2s - loss: 0.0013 - val_loss: 0.0027 - 2s/epoch - 8ms/step
# Epoch 4/25
# 306/306 - 2s - loss: 0.0021 - val_loss: 0.0053 - 2s/epoch - 8ms/step
# Epoch 5/25
# 306/306 - 2s - loss: 0.0029 - val_loss: 0.0074 - 2s/epoch - 8ms/step
# Epoch 6/25
# 306/306 - 2s - loss: 0.0027 - val_loss: 0.0067 - 2s/epoch - 8ms/step
# Epoch 7/25
# 306/306 - 2s - loss: 0.0021 - val_loss: 0.0045 - 2s/epoch - 8ms/step
# Epoch 8/25
# 306/306 - 2s - loss: 0.0014 - val_loss: 0.0024 - 2s/epoch - 8ms/step
# Epoch 9/25
# 306/306 - 2s - loss: 8.6610e-04 - val_loss: 0.0012 - 2s/epoch - 8ms/step
# Epoch 10/25
# 306/306 - 2s - loss: 5.5096e-04 - val_loss: 6.4992e-04 - 2s/epoch - 8ms/step
# Epoch 11/25
# 306/306 - 2s - loss: 3.8805e-04 - val_loss: 4.1634e-04 - 2s/epoch - 8ms/step
# Epoch 12/25
# 306/306 - 2s - loss: 3.1034e-04 - val_loss: 3.2714e-04 - 2s/epoch - 8ms/step
# Epoch 13/25
# 306/306 - 3s - loss: 2.7840e-04 - val_loss: 2.9796e-04 - 3s/epoch - 8ms/step
# Epoch 14/25
# 306/306 - 2s - loss: 2.7468e-04 - val_loss: 3.0238e-04 - 2s/epoch - 8ms/step
# Epoch 15/25
# 306/306 - 2s - loss: 2.9301e-04 - val_loss: 3.3937e-04 - 2s/epoch - 8ms/step
# Epoch 16/25
# 306/306 - 2s - loss: 3.2429e-04 - val_loss: 4.0463e-04 - 2s/epoch - 8ms/step
# Epoch 17/25
# 306/306 - 2s - loss: 3.5100e-04 - val_loss: 4.4315e-04 - 2s/epoch - 8ms/step
# Epoch 18/25
# 306/306 - 2s - loss: 3.9843e-04 - val_loss: 5.3927e-04 - 2s/epoch - 8ms/step
# Epoch 19/25
# 306/306 - 2s - loss: 4.5942e-04 - val_loss: 6.7641e-04 - 2s/epoch - 8ms/step
# Epoch 20/25
# 306/306 - 2s - loss: 5.3381e-04 - val_loss: 8.3034e-04 - 2s/epoch - 8ms/step
# Epoch 21/25
# 306/306 - 2s - loss: 6.2258e-04 - val_loss: 9.6577e-04 - 2s/epoch - 8ms/step
# Epoch 22/25
# 306/306 - 2s - loss: 6.8381e-04 - val_loss: 0.0010 - 2s/epoch - 8ms/step
# Epoch 23/25
# 306/306 - 2s - loss: 6.8388e-04 - val_loss: 9.4304e-04 - 2s/epoch - 8ms/step
# Epoch 24/25
# 306/306 - 2s - loss: 6.2226e-04 - val_loss: 7.7589e-04 - 2s/epoch - 8ms/step
# Epoch 25/25
# 306/306 - 2s - loss: 5.1766e-04 - val_loss: 5.6454e-04 - 2s/epoch - 8ms/step
# Epoch 1/25
# 2023-04-03 09:45:21.576781: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:45:21.667477: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:45:21.858131: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:45:24.373417: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:45:24.403575: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 306/306 - 4s - loss: 9.9828e-04 - val_loss: 0.0019 - 4s/epoch - 12ms/step
# Epoch 2/25
# 306/306 - 2s - loss: 0.0013 - val_loss: 0.0020 - 2s/epoch - 8ms/step
# Epoch 3/25
# 306/306 - 2s - loss: 0.0017 - val_loss: 0.0031 - 2s/epoch - 8ms/step
# Epoch 4/25
# 306/306 - 2s - loss: 0.0023 - val_loss: 0.0055 - 2s/epoch - 8ms/step
# Epoch 5/25
# 306/306 - 2s - loss: 0.0036 - val_loss: 0.0092 - 2s/epoch - 8ms/step
# Epoch 6/25
# 306/306 - 2s - loss: 0.0041 - val_loss: 0.0113 - 2s/epoch - 8ms/step
# Epoch 7/25
# 306/306 - 2s - loss: 0.0036 - val_loss: 0.0091 - 2s/epoch - 8ms/step
# Epoch 8/25
# 306/306 - 2s - loss: 0.0025 - val_loss: 0.0051 - 2s/epoch - 8ms/step
# Epoch 9/25
# 306/306 - 2s - loss: 0.0015 - val_loss: 0.0023 - 2s/epoch - 8ms/step
# Epoch 10/25
# 306/306 - 2s - loss: 8.4393e-04 - val_loss: 8.9854e-04 - 2s/epoch - 8ms/step
# Epoch 11/25
# 306/306 - 2s - loss: 5.3657e-04 - val_loss: 3.8861e-04 - 2s/epoch - 8ms/step
# Epoch 12/25
# 306/306 - 2s - loss: 4.0896e-04 - val_loss: 2.3381e-04 - 2s/epoch - 8ms/step
# Epoch 13/25
# 306/306 - 2s - loss: 3.6264e-04 - val_loss: 2.0396e-04 - 2s/epoch - 8ms/step
# Epoch 14/25
# 306/306 - 2s - loss: 3.5654e-04 - val_loss: 2.2683e-04 - 2s/epoch - 8ms/step
# Epoch 15/25
# 306/306 - 2s - loss: 3.7678e-04 - val_loss: 2.8404e-04 - 2s/epoch - 8ms/step
# Epoch 16/25
# 306/306 - 2s - loss: 4.1821e-04 - val_loss: 3.7382e-04 - 2s/epoch - 8ms/step
# Epoch 17/25
# 306/306 - 2s - loss: 4.6716e-04 - val_loss: 4.8822e-04 - 2s/epoch - 8ms/step
# Epoch 18/25
# 306/306 - 2s - loss: 4.8879e-04 - val_loss: 5.7067e-04 - 2s/epoch - 8ms/step
# Epoch 19/25
# 306/306 - 2s - loss: 5.2285e-04 - val_loss: 6.0728e-04 - 2s/epoch - 8ms/step
# Epoch 20/25
# 306/306 - 2s - loss: 5.6311e-04 - val_loss: 6.5372e-04 - 2s/epoch - 8ms/step
# Epoch 21/25
# 306/306 - 2s - loss: 5.9016e-04 - val_loss: 6.8551e-04 - 2s/epoch - 8ms/step
# Epoch 22/25
# 306/306 - 2s - loss: 6.0410e-04 - val_loss: 6.8835e-04 - 2s/epoch - 8ms/step
# Epoch 23/25
# 306/306 - 3s - loss: 5.9979e-04 - val_loss: 6.3754e-04 - 3s/epoch - 9ms/step
# Epoch 24/25
# 306/306 - 2s - loss: 5.6545e-04 - val_loss: 5.5420e-04 - 2s/epoch - 8ms/step
# Epoch 25/25
# 306/306 - 3s - loss: 5.0694e-04 - val_loss: 4.4567e-04 - 3s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-03 09:46:24.598300: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:46:24.677184: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:46:24.776002: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:46:27.306101: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:46:27.336248: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 306/306 - 3s - loss: 7.5790e-04 - val_loss: 0.0015 - 3s/epoch - 11ms/step
# Epoch 2/50
# 306/306 - 2s - loss: 0.0012 - val_loss: 0.0023 - 2s/epoch - 8ms/step
# Epoch 3/50
# 306/306 - 2s - loss: 0.0018 - val_loss: 0.0045 - 2s/epoch - 8ms/step
# Epoch 4/50
# 306/306 - 2s - loss: 0.0025 - val_loss: 0.0061 - 2s/epoch - 8ms/step
# Epoch 5/50
# 306/306 - 2s - loss: 0.0026 - val_loss: 0.0064 - 2s/epoch - 8ms/step
# Epoch 6/50
# 306/306 - 2s - loss: 0.0022 - val_loss: 0.0047 - 2s/epoch - 8ms/step
# Epoch 7/50
# 306/306 - 2s - loss: 0.0016 - val_loss: 0.0028 - 2s/epoch - 8ms/step
# Epoch 8/50
# 306/306 - 2s - loss: 0.0010 - val_loss: 0.0015 - 2s/epoch - 8ms/step
# Epoch 9/50
# 306/306 - 2s - loss: 6.5900e-04 - val_loss: 8.6226e-04 - 2s/epoch - 8ms/step
# Epoch 10/50
# 306/306 - 2s - loss: 4.6090e-04 - val_loss: 5.5880e-04 - 2s/epoch - 8ms/step
# Epoch 11/50
# 306/306 - 2s - loss: 3.5960e-04 - val_loss: 4.2821e-04 - 2s/epoch - 8ms/step
# Epoch 12/50
# 306/306 - 2s - loss: 3.1275e-04 - val_loss: 3.7246e-04 - 2s/epoch - 8ms/step
# Epoch 13/50
# 306/306 - 2s - loss: 2.9931e-04 - val_loss: 3.5868e-04 - 2s/epoch - 8ms/step
# Epoch 14/50
# 306/306 - 2s - loss: 3.1059e-04 - val_loss: 3.8104e-04 - 2s/epoch - 8ms/step
# Epoch 15/50
# 306/306 - 2s - loss: 3.4498e-04 - val_loss: 4.4819e-04 - 2s/epoch - 8ms/step
# Epoch 16/50
# 306/306 - 2s - loss: 4.0172e-04 - val_loss: 5.6951e-04 - 2s/epoch - 8ms/step
# Epoch 17/50
# 306/306 - 2s - loss: 4.4357e-04 - val_loss: 6.4676e-04 - 2s/epoch - 8ms/step
# Epoch 18/50
# 306/306 - 2s - loss: 4.9822e-04 - val_loss: 7.7093e-04 - 2s/epoch - 8ms/step
# Epoch 19/50
# 306/306 - 2s - loss: 5.9346e-04 - val_loss: 9.5811e-04 - 2s/epoch - 8ms/step
# Epoch 20/50
# 306/306 - 2s - loss: 6.8837e-04 - val_loss: 0.0011 - 2s/epoch - 8ms/step
# Epoch 21/50
# 306/306 - 2s - loss: 7.5339e-04 - val_loss: 0.0011 - 2s/epoch - 8ms/step
# Epoch 22/50
# 306/306 - 2s - loss: 7.0409e-04 - val_loss: 9.6366e-04 - 2s/epoch - 8ms/step
# Epoch 23/50
# 306/306 - 2s - loss: 6.0246e-04 - val_loss: 7.3137e-04 - 2s/epoch - 8ms/step
# Epoch 24/50
# 306/306 - 2s - loss: 4.8906e-04 - val_loss: 5.1496e-04 - 2s/epoch - 8ms/step
# Epoch 25/50
# 306/306 - 2s - loss: 3.9644e-04 - val_loss: 3.7025e-04 - 2s/epoch - 8ms/step
# Epoch 26/50
# 306/306 - 2s - loss: 3.3257e-04 - val_loss: 2.8806e-04 - 2s/epoch - 8ms/step
# Epoch 27/50
# 306/306 - 2s - loss: 2.9395e-04 - val_loss: 2.4988e-04 - 2s/epoch - 8ms/step
# Epoch 28/50
# 306/306 - 2s - loss: 2.7475e-04 - val_loss: 2.3848e-04 - 2s/epoch - 8ms/step
# Epoch 29/50
# 306/306 - 2s - loss: 2.6765e-04 - val_loss: 2.4474e-04 - 2s/epoch - 8ms/step
# Epoch 30/50
# 306/306 - 2s - loss: 2.6525e-04 - val_loss: 2.5225e-04 - 2s/epoch - 8ms/step
# Epoch 31/50
# 306/306 - 2s - loss: 2.7053e-04 - val_loss: 2.6470e-04 - 2s/epoch - 8ms/step
# Epoch 32/50
# 306/306 - 2s - loss: 2.8304e-04 - val_loss: 2.8807e-04 - 2s/epoch - 8ms/step
# Epoch 33/50
# 306/306 - 2s - loss: 3.0372e-04 - val_loss: 3.2100e-04 - 2s/epoch - 8ms/step
# Epoch 34/50
# 306/306 - 2s - loss: 3.2230e-04 - val_loss: 3.5015e-04 - 2s/epoch - 8ms/step
# Epoch 35/50
# 306/306 - 2s - loss: 3.4067e-04 - val_loss: 3.6962e-04 - 2s/epoch - 8ms/step
# Epoch 36/50
# 306/306 - 2s - loss: 3.5314e-04 - val_loss: 3.7343e-04 - 2s/epoch - 8ms/step
# Epoch 37/50
# 306/306 - 2s - loss: 3.4781e-04 - val_loss: 3.5422e-04 - 2s/epoch - 8ms/step
# Epoch 38/50
# 306/306 - 2s - loss: 3.3569e-04 - val_loss: 3.2507e-04 - 2s/epoch - 8ms/step
# Epoch 39/50
# 306/306 - 2s - loss: 3.1467e-04 - val_loss: 2.9187e-04 - 2s/epoch - 8ms/step
# Epoch 40/50
# 306/306 - 2s - loss: 2.8993e-04 - val_loss: 2.5675e-04 - 2s/epoch - 8ms/step
# Epoch 41/50
# 306/306 - 2s - loss: 2.6905e-04 - val_loss: 2.3011e-04 - 2s/epoch - 8ms/step
# Epoch 42/50
# 306/306 - 2s - loss: 2.5049e-04 - val_loss: 2.1149e-04 - 2s/epoch - 8ms/step
# Epoch 43/50
# 306/306 - 2s - loss: 2.3725e-04 - val_loss: 2.0077e-04 - 2s/epoch - 8ms/step
# Epoch 44/50
# 306/306 - 2s - loss: 2.2771e-04 - val_loss: 1.9395e-04 - 2s/epoch - 8ms/step
# Epoch 45/50
# 306/306 - 2s - loss: 2.2216e-04 - val_loss: 1.9200e-04 - 2s/epoch - 8ms/step
# Epoch 46/50
# 306/306 - 2s - loss: 2.1926e-04 - val_loss: 1.9334e-04 - 2s/epoch - 8ms/step
# Epoch 47/50
# 306/306 - 2s - loss: 2.1651e-04 - val_loss: 1.9184e-04 - 2s/epoch - 8ms/step
# Epoch 48/50
# 306/306 - 2s - loss: 2.1736e-04 - val_loss: 1.9442e-04 - 2s/epoch - 8ms/step
# Epoch 49/50
# 306/306 - 2s - loss: 2.1938e-04 - val_loss: 2.0286e-04 - 2s/epoch - 8ms/step
# Epoch 50/50
# 306/306 - 2s - loss: 2.2368e-04 - val_loss: 2.1129e-04 - 2s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-03 09:48:25.655264: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:48:25.734763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:48:25.832879: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:48:28.275893: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:48:28.306253: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 306/306 - 3s - loss: 6.7609e-04 - val_loss: 0.0012 - 3s/epoch - 11ms/step
# Epoch 2/50
# 306/306 - 2s - loss: 8.7227e-04 - val_loss: 0.0013 - 2s/epoch - 8ms/step
# Epoch 3/50
# 306/306 - 2s - loss: 0.0011 - val_loss: 0.0020 - 2s/epoch - 8ms/step
# Epoch 4/50
# 306/306 - 2s - loss: 0.0015 - val_loss: 0.0036 - 2s/epoch - 8ms/step
# Epoch 5/50
# 306/306 - 2s - loss: 0.0022 - val_loss: 0.0054 - 2s/epoch - 8ms/step
# Epoch 6/50
# 306/306 - 2s - loss: 0.0027 - val_loss: 0.0070 - 2s/epoch - 8ms/step
# Epoch 7/50
# 306/306 - 2s - loss: 0.0025 - val_loss: 0.0061 - 2s/epoch - 8ms/step
# Epoch 8/50
# 306/306 - 2s - loss: 0.0019 - val_loss: 0.0038 - 2s/epoch - 8ms/step
# Epoch 9/50
# 306/306 - 2s - loss: 0.0012 - val_loss: 0.0020 - 2s/epoch - 8ms/step
# Epoch 10/50
# 306/306 - 2s - loss: 7.6860e-04 - val_loss: 0.0010 - 2s/epoch - 8ms/step
# Epoch 11/50
# 306/306 - 2s - loss: 5.0058e-04 - val_loss: 5.6595e-04 - 2s/epoch - 8ms/step
# Epoch 12/50
# 306/306 - 2s - loss: 3.6606e-04 - val_loss: 3.8296e-04 - 2s/epoch - 8ms/step
# Epoch 13/50
# 306/306 - 2s - loss: 3.0423e-04 - val_loss: 3.1652e-04 - 2s/epoch - 8ms/step
# Epoch 14/50
# 306/306 - 2s - loss: 2.8242e-04 - val_loss: 3.0150e-04 - 2s/epoch - 8ms/step
# Epoch 15/50
# 306/306 - 2s - loss: 2.8700e-04 - val_loss: 3.2003e-04 - 2s/epoch - 8ms/step
# Epoch 16/50
# 306/306 - 2s - loss: 3.1260e-04 - val_loss: 3.7393e-04 - 2s/epoch - 8ms/step
# Epoch 17/50
# 306/306 - 2s - loss: 3.4311e-04 - val_loss: 4.2767e-04 - 2s/epoch - 8ms/step
# Epoch 18/50
# 306/306 - 2s - loss: 3.7888e-04 - val_loss: 4.8982e-04 - 2s/epoch - 8ms/step
# Epoch 19/50
# 306/306 - 2s - loss: 4.2195e-04 - val_loss: 5.9483e-04 - 2s/epoch - 8ms/step
# Epoch 20/50
# 306/306 - 2s - loss: 4.9568e-04 - val_loss: 7.6636e-04 - 2s/epoch - 8ms/step
# Epoch 21/50
# 306/306 - 2s - loss: 5.8853e-04 - val_loss: 9.3632e-04 - 2s/epoch - 8ms/step
# Epoch 22/50
# 306/306 - 2s - loss: 6.8008e-04 - val_loss: 0.0011 - 2s/epoch - 8ms/step
# Epoch 23/50
# 306/306 - 2s - loss: 7.0595e-04 - val_loss: 0.0010 - 2s/epoch - 8ms/step
# Epoch 24/50
# 306/306 - 2s - loss: 6.6309e-04 - val_loss: 8.8538e-04 - 2s/epoch - 8ms/step
# Epoch 25/50
# 306/306 - 2s - loss: 5.6333e-04 - val_loss: 6.6441e-04 - 2s/epoch - 8ms/step
# Epoch 26/50
# 306/306 - 2s - loss: 4.6060e-04 - val_loss: 4.7253e-04 - 2s/epoch - 8ms/step
# Epoch 27/50
# 306/306 - 2s - loss: 3.7853e-04 - val_loss: 3.4560e-04 - 2s/epoch - 8ms/step
# Epoch 28/50
# 306/306 - 2s - loss: 3.2295e-04 - val_loss: 2.7558e-04 - 2s/epoch - 8ms/step
# Epoch 29/50
# 306/306 - 2s - loss: 2.8972e-04 - val_loss: 2.4498e-04 - 2s/epoch - 8ms/step
# Epoch 30/50
# 306/306 - 2s - loss: 2.7195e-04 - val_loss: 2.3974e-04 - 2s/epoch - 8ms/step
# Epoch 31/50
# 306/306 - 2s - loss: 2.6076e-04 - val_loss: 2.4343e-04 - 2s/epoch - 8ms/step
# Epoch 32/50
# 306/306 - 2s - loss: 2.5882e-04 - val_loss: 2.4247e-04 - 2s/epoch - 8ms/step
# Epoch 33/50
# 306/306 - 2s - loss: 2.6421e-04 - val_loss: 2.5859e-04 - 2s/epoch - 8ms/step
# Epoch 34/50
# 306/306 - 2s - loss: 2.7501e-04 - val_loss: 2.8107e-04 - 2s/epoch - 8ms/step
# Epoch 35/50
# 306/306 - 2s - loss: 2.9012e-04 - val_loss: 3.0978e-04 - 2s/epoch - 8ms/step
# Epoch 36/50
# 306/306 - 2s - loss: 3.0972e-04 - val_loss: 3.3820e-04 - 2s/epoch - 8ms/step
# Epoch 37/50
# 306/306 - 2s - loss: 3.2796e-04 - val_loss: 3.6276e-04 - 2s/epoch - 8ms/step
# Epoch 38/50
# 306/306 - 2s - loss: 3.3443e-04 - val_loss: 3.6063e-04 - 2s/epoch - 8ms/step
# Epoch 39/50
# 306/306 - 2s - loss: 3.3214e-04 - val_loss: 3.4834e-04 - 2s/epoch - 8ms/step
# Epoch 40/50
# 306/306 - 2s - loss: 3.1497e-04 - val_loss: 3.1768e-04 - 2s/epoch - 8ms/step
# Epoch 41/50
# 306/306 - 2s - loss: 2.9442e-04 - val_loss: 2.8134e-04 - 2s/epoch - 8ms/step
# Epoch 42/50
# 306/306 - 2s - loss: 2.7055e-04 - val_loss: 2.4816e-04 - 2s/epoch - 8ms/step
# Epoch 43/50
# 306/306 - 2s - loss: 2.4838e-04 - val_loss: 2.2195e-04 - 2s/epoch - 8ms/step
# Epoch 44/50
# 306/306 - 2s - loss: 2.3181e-04 - val_loss: 2.0301e-04 - 2s/epoch - 8ms/step
# Epoch 45/50
# 306/306 - 2s - loss: 2.2040e-04 - val_loss: 1.9509e-04 - 2s/epoch - 8ms/step
# Epoch 46/50
# 306/306 - 2s - loss: 2.1287e-04 - val_loss: 1.8817e-04 - 2s/epoch - 8ms/step
# Epoch 47/50
# 306/306 - 2s - loss: 2.0951e-04 - val_loss: 1.9125e-04 - 2s/epoch - 8ms/step
# Epoch 48/50
# 306/306 - 2s - loss: 2.1067e-04 - val_loss: 1.9890e-04 - 2s/epoch - 8ms/step
# Epoch 49/50
# 306/306 - 2s - loss: 2.1280e-04 - val_loss: 2.0620e-04 - 2s/epoch - 8ms/step
# Epoch 50/50
# 306/306 - 2s - loss: 2.1698e-04 - val_loss: 2.1555e-04 - 2s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-03 09:50:27.240510: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:50:27.318402: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:50:27.436795: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:50:30.022067: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:50:30.052248: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 306/306 - 4s - loss: 9.8003e-04 - val_loss: 0.0019 - 4s/epoch - 12ms/step
# Epoch 2/50
# 306/306 - 2s - loss: 0.0014 - val_loss: 0.0022 - 2s/epoch - 8ms/step
# Epoch 3/50
# 306/306 - 3s - loss: 0.0018 - val_loss: 0.0039 - 3s/epoch - 8ms/step
# Epoch 4/50
# 306/306 - 2s - loss: 0.0026 - val_loss: 0.0064 - 2s/epoch - 8ms/step
# Epoch 5/50
# 306/306 - 2s - loss: 0.0038 - val_loss: 0.0099 - 2s/epoch - 8ms/step
# Epoch 6/50
# 306/306 - 2s - loss: 0.0038 - val_loss: 0.0103 - 2s/epoch - 8ms/step
# Epoch 7/50
# 306/306 - 2s - loss: 0.0031 - val_loss: 0.0070 - 2s/epoch - 8ms/step
# Epoch 8/50
# 306/306 - 2s - loss: 0.0020 - val_loss: 0.0037 - 2s/epoch - 8ms/step
# Epoch 9/50
# 306/306 - 2s - loss: 0.0012 - val_loss: 0.0017 - 2s/epoch - 8ms/step
# Epoch 10/50
# 306/306 - 2s - loss: 6.9425e-04 - val_loss: 7.0519e-04 - 2s/epoch - 8ms/step
# Epoch 11/50
# 306/306 - 2s - loss: 4.6700e-04 - val_loss: 3.6371e-04 - 2s/epoch - 8ms/step
# Epoch 12/50
# 306/306 - 2s - loss: 3.7255e-04 - val_loss: 2.6242e-04 - 2s/epoch - 8ms/step
# Epoch 13/50
# 306/306 - 2s - loss: 3.4099e-04 - val_loss: 2.5178e-04 - 2s/epoch - 8ms/step
# Epoch 14/50
# 306/306 - 2s - loss: 3.4426e-04 - val_loss: 2.8592e-04 - 2s/epoch - 8ms/step
# Epoch 15/50
# 306/306 - 2s - loss: 3.7292e-04 - val_loss: 3.5590e-04 - 2s/epoch - 8ms/step
# Epoch 16/50
# 306/306 - 2s - loss: 4.1795e-04 - val_loss: 4.5885e-04 - 2s/epoch - 8ms/step
# Epoch 17/50
# 306/306 - 2s - loss: 4.3767e-04 - val_loss: 5.1961e-04 - 2s/epoch - 8ms/step
# Epoch 18/50
# 306/306 - 2s - loss: 4.7545e-04 - val_loss: 5.7906e-04 - 2s/epoch - 8ms/step
# Epoch 19/50
# 306/306 - 2s - loss: 5.2984e-04 - val_loss: 6.9198e-04 - 2s/epoch - 8ms/step
# Epoch 20/50
# 306/306 - 2s - loss: 5.8405e-04 - val_loss: 7.6216e-04 - 2s/epoch - 8ms/step
# Epoch 21/50
# 306/306 - 2s - loss: 6.3071e-04 - val_loss: 7.9712e-04 - 2s/epoch - 8ms/step
# Epoch 22/50
# 306/306 - 2s - loss: 6.4918e-04 - val_loss: 7.8519e-04 - 2s/epoch - 8ms/step
# Epoch 23/50
# 306/306 - 2s - loss: 6.2929e-04 - val_loss: 7.1441e-04 - 2s/epoch - 8ms/step
# Epoch 24/50
# 306/306 - 2s - loss: 5.8317e-04 - val_loss: 5.9143e-04 - 2s/epoch - 8ms/step
# Epoch 25/50
# 306/306 - 2s - loss: 5.2296e-04 - val_loss: 4.7143e-04 - 2s/epoch - 8ms/step
# Epoch 26/50
# 306/306 - 2s - loss: 4.5661e-04 - val_loss: 3.6890e-04 - 2s/epoch - 8ms/step
# Epoch 27/50
# 306/306 - 2s - loss: 4.0233e-04 - val_loss: 2.9635e-04 - 2s/epoch - 8ms/step
# Epoch 28/50
# 306/306 - 2s - loss: 3.6189e-04 - val_loss: 2.5286e-04 - 2s/epoch - 8ms/step
# Epoch 29/50
# 306/306 - 2s - loss: 3.3159e-04 - val_loss: 2.2888e-04 - 2s/epoch - 8ms/step
# Epoch 30/50
# 306/306 - 2s - loss: 3.1291e-04 - val_loss: 2.1838e-04 - 2s/epoch - 8ms/step
# Epoch 31/50
# 306/306 - 2s - loss: 2.9528e-04 - val_loss: 2.1362e-04 - 2s/epoch - 8ms/step
# Epoch 32/50
# 306/306 - 2s - loss: 2.8987e-04 - val_loss: 2.1357e-04 - 2s/epoch - 8ms/step
# Epoch 33/50
# 306/306 - 2s - loss: 2.8419e-04 - val_loss: 2.0361e-04 - 2s/epoch - 8ms/step
# Epoch 34/50
# 306/306 - 2s - loss: 2.8238e-04 - val_loss: 2.1304e-04 - 2s/epoch - 8ms/step
# Epoch 35/50
# 306/306 - 2s - loss: 2.8808e-04 - val_loss: 2.2171e-04 - 2s/epoch - 8ms/step
# Epoch 36/50
# 306/306 - 2s - loss: 2.9303e-04 - val_loss: 2.4623e-04 - 2s/epoch - 8ms/step
# Epoch 37/50
# 306/306 - 2s - loss: 3.0088e-04 - val_loss: 2.5003e-04 - 2s/epoch - 8ms/step
# Epoch 38/50
# 306/306 - 2s - loss: 3.0250e-04 - val_loss: 2.5691e-04 - 2s/epoch - 8ms/step
# Epoch 39/50
# 306/306 - 2s - loss: 3.0165e-04 - val_loss: 2.5035e-04 - 2s/epoch - 8ms/step
# Epoch 40/50
# 306/306 - 2s - loss: 2.9325e-04 - val_loss: 2.4189e-04 - 2s/epoch - 8ms/step
# Epoch 41/50
# 306/306 - 2s - loss: 2.8220e-04 - val_loss: 2.2004e-04 - 2s/epoch - 8ms/step
# Epoch 42/50
# 306/306 - 2s - loss: 2.7167e-04 - val_loss: 2.1316e-04 - 2s/epoch - 8ms/step
# Epoch 43/50
# 306/306 - 2s - loss: 2.6109e-04 - val_loss: 2.0376e-04 - 2s/epoch - 8ms/step
# Epoch 44/50
# 306/306 - 2s - loss: 2.5023e-04 - val_loss: 1.9611e-04 - 2s/epoch - 8ms/step
# Epoch 45/50
# 306/306 - 2s - loss: 2.3921e-04 - val_loss: 1.8231e-04 - 2s/epoch - 8ms/step
# Epoch 46/50
# 306/306 - 2s - loss: 2.3004e-04 - val_loss: 1.8322e-04 - 2s/epoch - 8ms/step
# Epoch 47/50
# 306/306 - 2s - loss: 2.2422e-04 - val_loss: 1.8264e-04 - 2s/epoch - 8ms/step
# Epoch 48/50
# 306/306 - 2s - loss: 2.1950e-04 - val_loss: 1.8168e-04 - 2s/epoch - 8ms/step
# Epoch 49/50
# 306/306 - 2s - loss: 2.1572e-04 - val_loss: 1.8229e-04 - 2s/epoch - 8ms/step
# Epoch 50/50
# 306/306 - 2s - loss: 2.1257e-04 - val_loss: 1.8486e-04 - 2s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-03 09:52:30.697970: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:52:30.775508: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:52:30.882139: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:52:33.640414: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:52:33.672763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 306/306 - 4s - loss: 7.4893e-04 - val_loss: 0.0014 - 4s/epoch - 12ms/step
# Epoch 2/100
# 306/306 - 2s - loss: 0.0011 - val_loss: 0.0020 - 2s/epoch - 8ms/step
# Epoch 3/100
# 306/306 - 2s - loss: 0.0016 - val_loss: 0.0037 - 2s/epoch - 8ms/step
# Epoch 4/100
# 306/306 - 2s - loss: 0.0024 - val_loss: 0.0060 - 2s/epoch - 8ms/step
# Epoch 5/100
# 306/306 - 2s - loss: 0.0029 - val_loss: 0.0074 - 2s/epoch - 8ms/step
# Epoch 6/100
# 306/306 - 2s - loss: 0.0026 - val_loss: 0.0063 - 2s/epoch - 8ms/step
# Epoch 7/100
# 306/306 - 2s - loss: 0.0020 - val_loss: 0.0039 - 2s/epoch - 8ms/step
# Epoch 8/100
# 306/306 - 2s - loss: 0.0012 - val_loss: 0.0020 - 2s/epoch - 8ms/step
# Epoch 9/100
# 306/306 - 2s - loss: 7.5118e-04 - val_loss: 0.0010 - 2s/epoch - 8ms/step
# Epoch 10/100
# 306/306 - 2s - loss: 4.8439e-04 - val_loss: 5.6930e-04 - 2s/epoch - 8ms/step
# Epoch 11/100
# 306/306 - 2s - loss: 3.5281e-04 - val_loss: 3.9777e-04 - 2s/epoch - 8ms/step
# Epoch 12/100
# 306/306 - 2s - loss: 2.9245e-04 - val_loss: 3.3025e-04 - 2s/epoch - 8ms/step
# Epoch 13/100
# 306/306 - 2s - loss: 2.7109e-04 - val_loss: 3.0883e-04 - 2s/epoch - 8ms/step
# Epoch 14/100
# 306/306 - 2s - loss: 2.7577e-04 - val_loss: 3.2034e-04 - 2s/epoch - 8ms/step
# Epoch 15/100
# 306/306 - 2s - loss: 3.0190e-04 - val_loss: 3.6793e-04 - 2s/epoch - 8ms/step
# Epoch 16/100
# 306/306 - 2s - loss: 3.4379e-04 - val_loss: 4.4786e-04 - 2s/epoch - 8ms/step
# Epoch 17/100
# 306/306 - 2s - loss: 4.0355e-04 - val_loss: 5.7539e-04 - 2s/epoch - 8ms/step
# Epoch 18/100
# 306/306 - 2s - loss: 4.6491e-04 - val_loss: 6.9824e-04 - 2s/epoch - 8ms/step
# Epoch 19/100
# 306/306 - 2s - loss: 5.6113e-04 - val_loss: 9.4720e-04 - 2s/epoch - 8ms/step
# Epoch 20/100
# 306/306 - 2s - loss: 6.8458e-04 - val_loss: 0.0011 - 2s/epoch - 8ms/step
# Epoch 21/100
# 306/306 - 2s - loss: 7.7018e-04 - val_loss: 0.0012 - 2s/epoch - 8ms/step
# Epoch 22/100
# 306/306 - 2s - loss: 7.6299e-04 - val_loss: 0.0011 - 2s/epoch - 8ms/step
# Epoch 23/100
# 306/306 - 2s - loss: 6.7194e-04 - val_loss: 8.7060e-04 - 2s/epoch - 8ms/step
# Epoch 24/100
# 306/306 - 2s - loss: 5.3894e-04 - val_loss: 6.0577e-04 - 2s/epoch - 8ms/step
# Epoch 25/100
# 306/306 - 2s - loss: 4.2845e-04 - val_loss: 4.1733e-04 - 2s/epoch - 8ms/step
# Epoch 26/100
# 306/306 - 2s - loss: 3.5032e-04 - val_loss: 3.0811e-04 - 2s/epoch - 8ms/step
# Epoch 27/100
# 306/306 - 2s - loss: 3.0317e-04 - val_loss: 2.5565e-04 - 2s/epoch - 8ms/step
# Epoch 28/100
# 306/306 - 2s - loss: 2.7818e-04 - val_loss: 2.3804e-04 - 2s/epoch - 8ms/step
# Epoch 29/100
# 306/306 - 2s - loss: 2.6659e-04 - val_loss: 2.4127e-04 - 2s/epoch - 8ms/step
# Epoch 30/100
# 306/306 - 2s - loss: 2.6569e-04 - val_loss: 2.4975e-04 - 2s/epoch - 8ms/step
# Epoch 31/100
# 306/306 - 2s - loss: 2.7329e-04 - val_loss: 2.7286e-04 - 2s/epoch - 8ms/step
# Epoch 32/100
# 306/306 - 2s - loss: 2.8517e-04 - val_loss: 2.9085e-04 - 2s/epoch - 8ms/step
# Epoch 33/100
# 306/306 - 2s - loss: 3.0308e-04 - val_loss: 3.2447e-04 - 2s/epoch - 8ms/step
# Epoch 34/100
# 306/306 - 2s - loss: 3.2736e-04 - val_loss: 3.5672e-04 - 2s/epoch - 8ms/step
# Epoch 35/100
# 306/306 - 2s - loss: 3.5208e-04 - val_loss: 3.9718e-04 - 2s/epoch - 8ms/step
# Epoch 36/100
# 306/306 - 2s - loss: 3.6357e-04 - val_loss: 3.9435e-04 - 2s/epoch - 8ms/step
# Epoch 37/100
# 306/306 - 2s - loss: 3.6457e-04 - val_loss: 3.8668e-04 - 2s/epoch - 8ms/step
# Epoch 38/100
# 306/306 - 2s - loss: 3.5145e-04 - val_loss: 3.5170e-04 - 2s/epoch - 8ms/step
# Epoch 39/100
# 306/306 - 2s - loss: 3.2801e-04 - val_loss: 3.0806e-04 - 2s/epoch - 8ms/step
# Epoch 40/100
# 306/306 - 2s - loss: 3.0321e-04 - val_loss: 2.7112e-04 - 2s/epoch - 8ms/step
# Epoch 41/100
# 306/306 - 2s - loss: 2.7691e-04 - val_loss: 2.3731e-04 - 2s/epoch - 8ms/step
# Epoch 42/100
# 306/306 - 2s - loss: 2.5643e-04 - val_loss: 2.1388e-04 - 2s/epoch - 8ms/step
# Epoch 43/100
# 306/306 - 2s - loss: 2.4217e-04 - val_loss: 2.0331e-04 - 2s/epoch - 8ms/step
# Epoch 44/100
# 306/306 - 2s - loss: 2.3196e-04 - val_loss: 1.9725e-04 - 2s/epoch - 8ms/step
# Epoch 45/100
# 306/306 - 2s - loss: 2.2579e-04 - val_loss: 1.9792e-04 - 2s/epoch - 8ms/step
# Epoch 46/100
# 306/306 - 2s - loss: 2.2181e-04 - val_loss: 1.9461e-04 - 2s/epoch - 8ms/step
# Epoch 47/100
# 306/306 - 2s - loss: 2.1852e-04 - val_loss: 1.9223e-04 - 2s/epoch - 8ms/step
# Epoch 48/100
# 306/306 - 2s - loss: 2.2114e-04 - val_loss: 2.0214e-04 - 2s/epoch - 8ms/step
# Epoch 49/100
# 306/306 - 2s - loss: 2.2645e-04 - val_loss: 2.1130e-04 - 2s/epoch - 8ms/step
# Epoch 50/100
# 306/306 - 2s - loss: 2.3056e-04 - val_loss: 2.2087e-04 - 2s/epoch - 8ms/step
# Epoch 51/100
# 306/306 - 2s - loss: 2.3446e-04 - val_loss: 2.2768e-04 - 2s/epoch - 8ms/step
# Epoch 52/100
# 306/306 - 2s - loss: 2.3667e-04 - val_loss: 2.3086e-04 - 2s/epoch - 8ms/step
# Epoch 53/100
# 306/306 - 2s - loss: 2.3441e-04 - val_loss: 2.2296e-04 - 2s/epoch - 8ms/step
# Epoch 54/100
# 306/306 - 2s - loss: 2.3132e-04 - val_loss: 2.1800e-04 - 2s/epoch - 8ms/step
# Epoch 55/100
# 306/306 - 2s - loss: 2.2488e-04 - val_loss: 2.1257e-04 - 2s/epoch - 8ms/step
# Epoch 56/100
# 306/306 - 2s - loss: 2.1652e-04 - val_loss: 1.9528e-04 - 2s/epoch - 8ms/step
# Epoch 57/100
# 306/306 - 2s - loss: 2.0702e-04 - val_loss: 1.8628e-04 - 2s/epoch - 8ms/step
# Epoch 58/100
# 306/306 - 2s - loss: 1.9982e-04 - val_loss: 1.7890e-04 - 2s/epoch - 8ms/step
# Epoch 59/100
# 306/306 - 2s - loss: 1.9333e-04 - val_loss: 1.7432e-04 - 2s/epoch - 8ms/step
# Epoch 60/100
# 306/306 - 2s - loss: 1.8877e-04 - val_loss: 1.7092e-04 - 2s/epoch - 8ms/step
# Epoch 61/100
# 306/306 - 2s - loss: 1.8477e-04 - val_loss: 1.6912e-04 - 2s/epoch - 8ms/step
# Epoch 62/100
# 306/306 - 2s - loss: 1.8372e-04 - val_loss: 1.7126e-04 - 2s/epoch - 8ms/step
# Epoch 63/100
# 306/306 - 2s - loss: 1.8367e-04 - val_loss: 1.7328e-04 - 2s/epoch - 8ms/step
# Epoch 64/100
# 306/306 - 2s - loss: 1.8344e-04 - val_loss: 1.7768e-04 - 2s/epoch - 8ms/step
# Epoch 65/100
# 306/306 - 2s - loss: 1.8395e-04 - val_loss: 1.8140e-04 - 2s/epoch - 8ms/step
# Epoch 66/100
# 306/306 - 2s - loss: 1.8404e-04 - val_loss: 1.7990e-04 - 2s/epoch - 8ms/step
# Epoch 67/100
# 306/306 - 2s - loss: 1.8199e-04 - val_loss: 1.7979e-04 - 2s/epoch - 8ms/step
# Epoch 68/100
# 306/306 - 2s - loss: 1.8078e-04 - val_loss: 1.7809e-04 - 2s/epoch - 8ms/step
# Epoch 69/100
# 306/306 - 2s - loss: 1.7888e-04 - val_loss: 1.7592e-04 - 2s/epoch - 8ms/step
# Epoch 70/100
# 306/306 - 2s - loss: 1.7574e-04 - val_loss: 1.7223e-04 - 2s/epoch - 8ms/step
# Epoch 71/100
# 306/306 - 2s - loss: 1.7227e-04 - val_loss: 1.6974e-04 - 2s/epoch - 8ms/step
# Epoch 72/100
# 306/306 - 2s - loss: 1.6984e-04 - val_loss: 1.6742e-04 - 2s/epoch - 8ms/step
# Epoch 73/100
# 306/306 - 2s - loss: 1.6597e-04 - val_loss: 1.6621e-04 - 2s/epoch - 8ms/step
# Epoch 74/100
# 306/306 - 2s - loss: 1.6424e-04 - val_loss: 1.6319e-04 - 2s/epoch - 8ms/step
# Epoch 75/100
# 306/306 - 2s - loss: 1.6101e-04 - val_loss: 1.6181e-04 - 2s/epoch - 8ms/step
# Epoch 76/100
# 306/306 - 2s - loss: 1.5733e-04 - val_loss: 1.6052e-04 - 2s/epoch - 8ms/step
# Epoch 77/100
# 306/306 - 2s - loss: 1.5619e-04 - val_loss: 1.5976e-04 - 2s/epoch - 8ms/step
# Epoch 78/100
# 306/306 - 2s - loss: 1.5417e-04 - val_loss: 1.5889e-04 - 2s/epoch - 8ms/step
# Epoch 79/100
# 306/306 - 3s - loss: 1.5337e-04 - val_loss: 1.6169e-04 - 3s/epoch - 9ms/step
# Epoch 80/100
# 306/306 - 3s - loss: 1.5262e-04 - val_loss: 1.6213e-04 - 3s/epoch - 10ms/step
# Epoch 81/100
# 306/306 - 4s - loss: 1.5143e-04 - val_loss: 1.6162e-04 - 4s/epoch - 12ms/step
# Epoch 82/100
# 306/306 - 3s - loss: 1.4992e-04 - val_loss: 1.6071e-04 - 3s/epoch - 9ms/step
# Epoch 83/100
# 306/306 - 3s - loss: 1.4876e-04 - val_loss: 1.6182e-04 - 3s/epoch - 9ms/step
# Epoch 84/100
# 306/306 - 3s - loss: 1.4856e-04 - val_loss: 1.5990e-04 - 3s/epoch - 10ms/step
# Epoch 85/100
# 306/306 - 3s - loss: 1.4612e-04 - val_loss: 1.6004e-04 - 3s/epoch - 9ms/step
# Epoch 86/100
# 306/306 - 3s - loss: 1.4606e-04 - val_loss: 1.6086e-04 - 3s/epoch - 8ms/step
# Epoch 87/100
# 306/306 - 3s - loss: 1.4413e-04 - val_loss: 1.6243e-04 - 3s/epoch - 9ms/step
# Epoch 88/100
# 306/306 - 3s - loss: 1.4370e-04 - val_loss: 1.5856e-04 - 3s/epoch - 9ms/step
# Epoch 89/100
# 306/306 - 2s - loss: 1.4088e-04 - val_loss: 1.5528e-04 - 2s/epoch - 8ms/step
# Epoch 90/100
# 306/306 - 3s - loss: 1.3933e-04 - val_loss: 1.5479e-04 - 3s/epoch - 9ms/step
# Epoch 91/100
# 306/306 - 3s - loss: 1.3675e-04 - val_loss: 1.5481e-04 - 3s/epoch - 8ms/step
# Epoch 92/100
# 306/306 - 2s - loss: 1.3648e-04 - val_loss: 1.5384e-04 - 2s/epoch - 8ms/step
# Epoch 93/100
# 306/306 - 2s - loss: 1.3479e-04 - val_loss: 1.5340e-04 - 2s/epoch - 8ms/step
# Epoch 94/100
# 306/306 - 2s - loss: 1.3434e-04 - val_loss: 1.5295e-04 - 2s/epoch - 8ms/step
# Epoch 95/100
# 306/306 - 2s - loss: 1.3289e-04 - val_loss: 1.5386e-04 - 2s/epoch - 8ms/step
# Epoch 96/100
# 306/306 - 2s - loss: 1.3270e-04 - val_loss: 1.5284e-04 - 2s/epoch - 8ms/step
# Epoch 97/100
# 306/306 - 2s - loss: 1.3085e-04 - val_loss: 1.5189e-04 - 2s/epoch - 8ms/step
# Epoch 98/100
# 306/306 - 2s - loss: 1.3021e-04 - val_loss: 1.5260e-04 - 2s/epoch - 8ms/step
# Epoch 99/100
# 306/306 - 2s - loss: 1.2895e-04 - val_loss: 1.5190e-04 - 2s/epoch - 8ms/step
# Epoch 100/100
# 306/306 - 2s - loss: 1.2847e-04 - val_loss: 1.5055e-04 - 2s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-03 09:56:37.183002: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:56:37.293072: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:56:37.436475: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:56:40.034844: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 09:56:40.065165: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 306/306 - 4s - loss: 7.1963e-04 - val_loss: 0.0012 - 4s/epoch - 12ms/step
# Epoch 2/100
# 306/306 - 2s - loss: 9.3851e-04 - val_loss: 0.0015 - 2s/epoch - 8ms/step
# Epoch 3/100
# 306/306 - 2s - loss: 0.0012 - val_loss: 0.0024 - 2s/epoch - 8ms/step
# Epoch 4/100
# 306/306 - 2s - loss: 0.0018 - val_loss: 0.0045 - 2s/epoch - 8ms/step
# Epoch 5/100
# 306/306 - 2s - loss: 0.0026 - val_loss: 0.0063 - 2s/epoch - 8ms/step
# Epoch 6/100
# 306/306 - 2s - loss: 0.0026 - val_loss: 0.0065 - 2s/epoch - 8ms/step
# Epoch 7/100
# 306/306 - 2s - loss: 0.0022 - val_loss: 0.0046 - 2s/epoch - 8ms/step
# Epoch 8/100
# 306/306 - 2s - loss: 0.0015 - val_loss: 0.0027 - 2s/epoch - 8ms/step
# Epoch 9/100
# 306/306 - 3s - loss: 9.5008e-04 - val_loss: 0.0014 - 3s/epoch - 8ms/step
# Epoch 10/100
# 306/306 - 2s - loss: 6.0565e-04 - val_loss: 7.3731e-04 - 2s/epoch - 8ms/step
# Epoch 11/100
# 306/306 - 2s - loss: 4.1994e-04 - val_loss: 4.6335e-04 - 2s/epoch - 8ms/step
# Epoch 12/100
# 306/306 - 2s - loss: 3.2766e-04 - val_loss: 3.5197e-04 - 2s/epoch - 8ms/step
# Epoch 13/100
# 306/306 - 2s - loss: 2.8624e-04 - val_loss: 3.0838e-04 - 2s/epoch - 8ms/step
# Epoch 14/100
# 306/306 - 2s - loss: 2.7543e-04 - val_loss: 3.0046e-04 - 2s/epoch - 8ms/step
# Epoch 15/100
# 306/306 - 2s - loss: 2.8664e-04 - val_loss: 3.2295e-04 - 2s/epoch - 8ms/step
# Epoch 16/100
# 306/306 - 3s - loss: 3.0834e-04 - val_loss: 3.5764e-04 - 3s/epoch - 8ms/step
# Epoch 17/100
# 306/306 - 2s - loss: 3.3640e-04 - val_loss: 4.0689e-04 - 2s/epoch - 8ms/step
# Epoch 18/100
# 306/306 - 2s - loss: 3.8220e-04 - val_loss: 4.9846e-04 - 2s/epoch - 8ms/step
# Epoch 19/100
# 306/306 - 2s - loss: 4.3903e-04 - val_loss: 6.2968e-04 - 2s/epoch - 8ms/step
# Epoch 20/100
# 306/306 - 2s - loss: 5.1416e-04 - val_loss: 7.9070e-04 - 2s/epoch - 8ms/step
# Epoch 21/100
# 306/306 - 2s - loss: 6.1747e-04 - val_loss: 9.8145e-04 - 2s/epoch - 8ms/step
# Epoch 22/100
# 306/306 - 2s - loss: 7.1618e-04 - val_loss: 0.0011 - 2s/epoch - 8ms/step
# Epoch 23/100
# 306/306 - 2s - loss: 7.3847e-04 - val_loss: 0.0010 - 2s/epoch - 8ms/step
# Epoch 24/100
# 306/306 - 2s - loss: 6.6676e-04 - val_loss: 8.5551e-04 - 2s/epoch - 8ms/step
# Epoch 25/100
# 306/306 - 2s - loss: 5.5466e-04 - val_loss: 6.1711e-04 - 2s/epoch - 8ms/step
# Epoch 26/100
# 306/306 - 2s - loss: 4.4616e-04 - val_loss: 4.2523e-04 - 2s/epoch - 8ms/step
# Epoch 27/100
# 306/306 - 2s - loss: 3.6331e-04 - val_loss: 3.0627e-04 - 2s/epoch - 8ms/step
# Epoch 28/100
# 306/306 - 2s - loss: 3.1012e-04 - val_loss: 2.4480e-04 - 2s/epoch - 8ms/step
# Epoch 29/100
# 306/306 - 2s - loss: 2.7958e-04 - val_loss: 2.2023e-04 - 2s/epoch - 8ms/step
# Epoch 30/100
# 306/306 - 2s - loss: 2.6479e-04 - val_loss: 2.1866e-04 - 2s/epoch - 8ms/step
# Epoch 31/100
# 306/306 - 2s - loss: 2.5795e-04 - val_loss: 2.2727e-04 - 2s/epoch - 8ms/step
# Epoch 32/100
# 306/306 - 2s - loss: 2.5460e-04 - val_loss: 2.2727e-04 - 2s/epoch - 8ms/step
# Epoch 33/100
# 306/306 - 2s - loss: 2.6069e-04 - val_loss: 2.4245e-04 - 2s/epoch - 8ms/step
# Epoch 34/100
# 306/306 - 2s - loss: 2.7008e-04 - val_loss: 2.5908e-04 - 2s/epoch - 8ms/step
# Epoch 35/100
# 306/306 - 2s - loss: 2.8836e-04 - val_loss: 2.9818e-04 - 2s/epoch - 8ms/step
# Epoch 36/100
# 306/306 - 2s - loss: 3.0775e-04 - val_loss: 3.2591e-04 - 2s/epoch - 8ms/step
# Epoch 37/100
# 306/306 - 2s - loss: 3.2765e-04 - val_loss: 3.5544e-04 - 2s/epoch - 8ms/step
# Epoch 38/100
# 306/306 - 2s - loss: 3.3847e-04 - val_loss: 3.5657e-04 - 2s/epoch - 8ms/step
# Epoch 39/100
# 306/306 - 2s - loss: 3.3445e-04 - val_loss: 3.4170e-04 - 2s/epoch - 8ms/step
# Epoch 40/100
# 306/306 - 2s - loss: 3.1854e-04 - val_loss: 3.0592e-04 - 2s/epoch - 8ms/step
# Epoch 41/100
# 306/306 - 2s - loss: 2.9734e-04 - val_loss: 2.7056e-04 - 2s/epoch - 8ms/step
# Epoch 42/100
# 306/306 - 2s - loss: 2.7384e-04 - val_loss: 2.3573e-04 - 2s/epoch - 8ms/step
# Epoch 43/100
# 306/306 - 2s - loss: 2.5382e-04 - val_loss: 2.1302e-04 - 2s/epoch - 8ms/step
# Epoch 44/100
# 306/306 - 2s - loss: 2.3892e-04 - val_loss: 1.9940e-04 - 2s/epoch - 8ms/step
# Epoch 45/100
# 306/306 - 2s - loss: 2.2710e-04 - val_loss: 1.9249e-04 - 2s/epoch - 8ms/step
# Epoch 46/100
# 306/306 - 2s - loss: 2.1892e-04 - val_loss: 1.8589e-04 - 2s/epoch - 8ms/step
# Epoch 47/100
# 306/306 - 3s - loss: 2.1335e-04 - val_loss: 1.8788e-04 - 3s/epoch - 8ms/step
# Epoch 48/100
# 306/306 - 2s - loss: 2.1240e-04 - val_loss: 1.9126e-04 - 2s/epoch - 8ms/step
# Epoch 49/100
# 306/306 - 2s - loss: 2.0949e-04 - val_loss: 1.8980e-04 - 2s/epoch - 8ms/step
# Epoch 50/100
# 306/306 - 2s - loss: 2.1061e-04 - val_loss: 1.9634e-04 - 2s/epoch - 8ms/step
# Epoch 51/100
# 306/306 - 2s - loss: 2.1107e-04 - val_loss: 1.9747e-04 - 2s/epoch - 8ms/step
# Epoch 52/100
# 306/306 - 3s - loss: 2.1227e-04 - val_loss: 2.0243e-04 - 3s/epoch - 9ms/step
# Epoch 53/100
# 306/306 - 3s - loss: 2.1453e-04 - val_loss: 2.1074e-04 - 3s/epoch - 8ms/step
# Epoch 54/100
# 306/306 - 3s - loss: 2.1575e-04 - val_loss: 2.1138e-04 - 3s/epoch - 8ms/step
# Epoch 55/100
# 306/306 - 3s - loss: 2.1466e-04 - val_loss: 2.1089e-04 - 3s/epoch - 8ms/step
# Epoch 56/100
# 306/306 - 3s - loss: 2.1179e-04 - val_loss: 2.0742e-04 - 3s/epoch - 8ms/step
# Epoch 57/100
# 306/306 - 3s - loss: 2.0618e-04 - val_loss: 1.9675e-04 - 3s/epoch - 8ms/step
# Epoch 58/100
# 306/306 - 3s - loss: 1.9942e-04 - val_loss: 1.8729e-04 - 3s/epoch - 8ms/step
# Epoch 59/100
# 306/306 - 3s - loss: 1.9343e-04 - val_loss: 1.8072e-04 - 3s/epoch - 9ms/step
# Epoch 60/100
# 306/306 - 3s - loss: 1.8857e-04 - val_loss: 1.7614e-04 - 3s/epoch - 8ms/step
# Epoch 61/100
# 306/306 - 3s - loss: 1.8372e-04 - val_loss: 1.7268e-04 - 3s/epoch - 8ms/step
# Epoch 62/100
# 306/306 - 3s - loss: 1.7950e-04 - val_loss: 1.7196e-04 - 3s/epoch - 8ms/step
# Epoch 63/100
# 306/306 - 3s - loss: 1.7668e-04 - val_loss: 1.6991e-04 - 3s/epoch - 9ms/step
# Epoch 64/100
# 306/306 - 3s - loss: 1.7513e-04 - val_loss: 1.6889e-04 - 3s/epoch - 9ms/step
# Epoch 65/100
# 306/306 - 3s - loss: 1.7398e-04 - val_loss: 1.6970e-04 - 3s/epoch - 8ms/step
# Epoch 66/100
# 306/306 - 3s - loss: 1.7307e-04 - val_loss: 1.7165e-04 - 3s/epoch - 8ms/step
# Epoch 67/100
# 306/306 - 2s - loss: 1.7200e-04 - val_loss: 1.7370e-04 - 2s/epoch - 8ms/step
# Epoch 68/100
# 306/306 - 2s - loss: 1.7197e-04 - val_loss: 1.7534e-04 - 2s/epoch - 8ms/step
# Epoch 69/100
# 306/306 - 2s - loss: 1.7126e-04 - val_loss: 1.7585e-04 - 2s/epoch - 8ms/step
# Epoch 70/100
# 306/306 - 2s - loss: 1.6948e-04 - val_loss: 1.7564e-04 - 2s/epoch - 8ms/step
# Epoch 71/100
# 306/306 - 2s - loss: 1.6819e-04 - val_loss: 1.7488e-04 - 2s/epoch - 8ms/step
# Epoch 72/100
# 306/306 - 2s - loss: 1.6641e-04 - val_loss: 1.7163e-04 - 2s/epoch - 8ms/step
# Epoch 73/100
# 306/306 - 3s - loss: 1.6385e-04 - val_loss: 1.7102e-04 - 3s/epoch - 8ms/step
# Epoch 74/100
# 306/306 - 2s - loss: 1.6149e-04 - val_loss: 1.6836e-04 - 2s/epoch - 8ms/step
# Epoch 75/100
# 306/306 - 2s - loss: 1.5884e-04 - val_loss: 1.6666e-04 - 2s/epoch - 8ms/step
# Epoch 76/100
# 306/306 - 3s - loss: 1.5638e-04 - val_loss: 1.6481e-04 - 3s/epoch - 8ms/step
# Epoch 77/100
# 306/306 - 3s - loss: 1.5444e-04 - val_loss: 1.6462e-04 - 3s/epoch - 9ms/step
# Epoch 78/100
# 306/306 - 3s - loss: 1.5296e-04 - val_loss: 1.6132e-04 - 3s/epoch - 8ms/step
# Epoch 79/100
# 306/306 - 3s - loss: 1.5159e-04 - val_loss: 1.6118e-04 - 3s/epoch - 9ms/step
# Epoch 80/100
# 306/306 - 3s - loss: 1.5036e-04 - val_loss: 1.6097e-04 - 3s/epoch - 9ms/step
# Epoch 81/100
# 306/306 - 3s - loss: 1.4887e-04 - val_loss: 1.6234e-04 - 3s/epoch - 9ms/step
# Epoch 82/100
# 306/306 - 3s - loss: 1.4907e-04 - val_loss: 1.6344e-04 - 3s/epoch - 8ms/step
# Epoch 83/100
# 306/306 - 3s - loss: 1.4756e-04 - val_loss: 1.6274e-04 - 3s/epoch - 8ms/step
# Epoch 84/100
# 306/306 - 3s - loss: 1.4718e-04 - val_loss: 1.6248e-04 - 3s/epoch - 8ms/step
# Epoch 85/100
# 306/306 - 3s - loss: 1.4608e-04 - val_loss: 1.6161e-04 - 3s/epoch - 8ms/step
# Epoch 86/100
# 306/306 - 3s - loss: 1.4474e-04 - val_loss: 1.5997e-04 - 3s/epoch - 8ms/step
# Epoch 87/100
# 306/306 - 3s - loss: 1.4325e-04 - val_loss: 1.5976e-04 - 3s/epoch - 8ms/step
# Epoch 88/100
# 306/306 - 3s - loss: 1.4190e-04 - val_loss: 1.5900e-04 - 3s/epoch - 8ms/step
# Epoch 89/100
# 306/306 - 3s - loss: 1.4060e-04 - val_loss: 1.5727e-04 - 3s/epoch - 8ms/step
# Epoch 90/100
# 306/306 - 3s - loss: 1.3911e-04 - val_loss: 1.5661e-04 - 3s/epoch - 9ms/step
# Epoch 91/100
# 306/306 - 3s - loss: 1.3807e-04 - val_loss: 1.5561e-04 - 3s/epoch - 8ms/step
# Epoch 92/100
# 306/306 - 3s - loss: 1.3653e-04 - val_loss: 1.5526e-04 - 3s/epoch - 8ms/step
# Epoch 93/100
# 306/306 - 2s - loss: 1.3565e-04 - val_loss: 1.5561e-04 - 2s/epoch - 8ms/step
# Epoch 94/100
# 306/306 - 2s - loss: 1.3465e-04 - val_loss: 1.5595e-04 - 2s/epoch - 8ms/step
# Epoch 95/100
# 306/306 - 2s - loss: 1.3377e-04 - val_loss: 1.5423e-04 - 2s/epoch - 8ms/step
# Epoch 96/100
# 306/306 - 2s - loss: 1.3268e-04 - val_loss: 1.5500e-04 - 2s/epoch - 8ms/step
# Epoch 97/100
# 306/306 - 2s - loss: 1.3198e-04 - val_loss: 1.5504e-04 - 2s/epoch - 8ms/step
# Epoch 98/100
# 306/306 - 2s - loss: 1.3119e-04 - val_loss: 1.5526e-04 - 2s/epoch - 8ms/step
# Epoch 99/100
# 306/306 - 2s - loss: 1.3056e-04 - val_loss: 1.5542e-04 - 2s/epoch - 8ms/step
# Epoch 100/100
# 306/306 - 3s - loss: 1.2950e-04 - val_loss: 1.5541e-04 - 3s/epoch - 9ms/step
# Epoch 1/100
# 2023-04-03 10:00:47.840292: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:00:47.975593: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:00:48.125200: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:00:50.825245: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:00:50.855292: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 306/306 - 4s - loss: 9.5199e-04 - val_loss: 0.0019 - 4s/epoch - 12ms/step
# Epoch 2/100
# 306/306 - 3s - loss: 0.0013 - val_loss: 0.0019 - 3s/epoch - 8ms/step
# Epoch 3/100
# 306/306 - 3s - loss: 0.0015 - val_loss: 0.0029 - 3s/epoch - 8ms/step
# Epoch 4/100
# 306/306 - 2s - loss: 0.0021 - val_loss: 0.0047 - 2s/epoch - 8ms/step
# Epoch 5/100
# 306/306 - 3s - loss: 0.0033 - val_loss: 0.0081 - 3s/epoch - 8ms/step
# Epoch 6/100
# 306/306 - 2s - loss: 0.0037 - val_loss: 0.0099 - 2s/epoch - 8ms/step
# Epoch 7/100
# 306/306 - 2s - loss: 0.0034 - val_loss: 0.0084 - 2s/epoch - 8ms/step
# Epoch 8/100
# 306/306 - 2s - loss: 0.0024 - val_loss: 0.0048 - 2s/epoch - 8ms/step
# Epoch 9/100
# 306/306 - 2s - loss: 0.0014 - val_loss: 0.0023 - 2s/epoch - 8ms/step
# Epoch 10/100
# 306/306 - 2s - loss: 8.3453e-04 - val_loss: 9.5827e-04 - 2s/epoch - 8ms/step
# Epoch 11/100
# 306/306 - 2s - loss: 5.3078e-04 - val_loss: 4.5240e-04 - 2s/epoch - 8ms/step
# Epoch 12/100
# 306/306 - 3s - loss: 4.0020e-04 - val_loss: 2.9118e-04 - 3s/epoch - 8ms/step
# Epoch 13/100
# 306/306 - 2s - loss: 3.5154e-04 - val_loss: 2.5824e-04 - 2s/epoch - 8ms/step
# Epoch 14/100
# 306/306 - 2s - loss: 3.4482e-04 - val_loss: 2.8182e-04 - 2s/epoch - 8ms/step
# Epoch 15/100
# 306/306 - 2s - loss: 3.6610e-04 - val_loss: 3.4398e-04 - 2s/epoch - 8ms/step
# Epoch 16/100
# 306/306 - 2s - loss: 4.1034e-04 - val_loss: 4.4480e-04 - 2s/epoch - 8ms/step
# Epoch 17/100
# 306/306 - 2s - loss: 4.3941e-04 - val_loss: 5.5213e-04 - 2s/epoch - 8ms/step
# Epoch 18/100
# 306/306 - 2s - loss: 4.7069e-04 - val_loss: 5.9908e-04 - 2s/epoch - 8ms/step
# Epoch 19/100
# 306/306 - 2s - loss: 5.0361e-04 - val_loss: 6.5629e-04 - 2s/epoch - 8ms/step
# Epoch 20/100
# 306/306 - 2s - loss: 5.3912e-04 - val_loss: 7.1260e-04 - 2s/epoch - 8ms/step
# Epoch 21/100
# 306/306 - 2s - loss: 5.8534e-04 - val_loss: 7.6316e-04 - 2s/epoch - 8ms/step
# Epoch 22/100
# 306/306 - 2s - loss: 6.2311e-04 - val_loss: 7.7604e-04 - 2s/epoch - 8ms/step
# Epoch 23/100
# 306/306 - 2s - loss: 6.2339e-04 - val_loss: 7.3882e-04 - 2s/epoch - 8ms/step
# Epoch 24/100
# 306/306 - 2s - loss: 6.0319e-04 - val_loss: 6.6694e-04 - 2s/epoch - 8ms/step
# Epoch 25/100
# 306/306 - 2s - loss: 5.5067e-04 - val_loss: 5.5141e-04 - 2s/epoch - 8ms/step
# Epoch 26/100
# 306/306 - 3s - loss: 4.8532e-04 - val_loss: 4.3554e-04 - 3s/epoch - 8ms/step
# Epoch 27/100
# 306/306 - 2s - loss: 4.2709e-04 - val_loss: 3.4868e-04 - 2s/epoch - 8ms/step
# Epoch 28/100
# 306/306 - 2s - loss: 3.7503e-04 - val_loss: 2.8841e-04 - 2s/epoch - 8ms/step
# Epoch 29/100
# 306/306 - 2s - loss: 3.4124e-04 - val_loss: 2.5356e-04 - 2s/epoch - 8ms/step
# Epoch 30/100
# 306/306 - 2s - loss: 3.1782e-04 - val_loss: 2.4005e-04 - 2s/epoch - 8ms/step
# Epoch 31/100
# 306/306 - 3s - loss: 3.0301e-04 - val_loss: 2.2698e-04 - 3s/epoch - 8ms/step
# Epoch 32/100
# 306/306 - 2s - loss: 2.9757e-04 - val_loss: 2.3575e-04 - 2s/epoch - 8ms/step
# Epoch 33/100
# 306/306 - 2s - loss: 2.8983e-04 - val_loss: 2.3279e-04 - 2s/epoch - 8ms/step
# Epoch 34/100
# 306/306 - 2s - loss: 2.8673e-04 - val_loss: 2.2750e-04 - 2s/epoch - 8ms/step
# Epoch 35/100
# 306/306 - 2s - loss: 2.8347e-04 - val_loss: 2.3298e-04 - 2s/epoch - 8ms/step
# Epoch 36/100
# 306/306 - 2s - loss: 2.8796e-04 - val_loss: 2.5005e-04 - 2s/epoch - 8ms/step
# Epoch 37/100
# 306/306 - 2s - loss: 2.9140e-04 - val_loss: 2.5731e-04 - 2s/epoch - 8ms/step
# Epoch 38/100
# 306/306 - 2s - loss: 2.9786e-04 - val_loss: 2.6988e-04 - 2s/epoch - 8ms/step
# Epoch 39/100
# 306/306 - 2s - loss: 3.0114e-04 - val_loss: 2.7339e-04 - 2s/epoch - 8ms/step
# Epoch 40/100
# 306/306 - 2s - loss: 2.9751e-04 - val_loss: 2.6892e-04 - 2s/epoch - 8ms/step
# Epoch 41/100
# 306/306 - 2s - loss: 2.9154e-04 - val_loss: 2.5752e-04 - 2s/epoch - 8ms/step
# Epoch 42/100
# 306/306 - 2s - loss: 2.7847e-04 - val_loss: 2.3698e-04 - 2s/epoch - 8ms/step
# Epoch 43/100
# 306/306 - 2s - loss: 2.6684e-04 - val_loss: 2.2651e-04 - 2s/epoch - 8ms/step
# Epoch 44/100
# 306/306 - 2s - loss: 2.5319e-04 - val_loss: 2.0979e-04 - 2s/epoch - 8ms/step
# Epoch 45/100
# 306/306 - 2s - loss: 2.4265e-04 - val_loss: 2.0418e-04 - 2s/epoch - 8ms/step
# Epoch 46/100
# 306/306 - 2s - loss: 2.3380e-04 - val_loss: 2.0067e-04 - 2s/epoch - 8ms/step
# Epoch 47/100
# 306/306 - 2s - loss: 2.2751e-04 - val_loss: 1.9904e-04 - 2s/epoch - 8ms/step
# Epoch 48/100
# 306/306 - 2s - loss: 2.2018e-04 - val_loss: 1.9465e-04 - 2s/epoch - 8ms/step
# Epoch 49/100
# 306/306 - 2s - loss: 2.1620e-04 - val_loss: 1.9165e-04 - 2s/epoch - 8ms/step
# Epoch 50/100
# 306/306 - 2s - loss: 2.1287e-04 - val_loss: 1.9608e-04 - 2s/epoch - 8ms/step
# Epoch 51/100
# 306/306 - 2s - loss: 2.1205e-04 - val_loss: 1.9643e-04 - 2s/epoch - 8ms/step
# Epoch 52/100
# 306/306 - 2s - loss: 2.1149e-04 - val_loss: 2.0561e-04 - 2s/epoch - 8ms/step
# Epoch 53/100
# 306/306 - 2s - loss: 2.1184e-04 - val_loss: 2.0507e-04 - 2s/epoch - 8ms/step
# Epoch 54/100
# 306/306 - 2s - loss: 2.1039e-04 - val_loss: 2.1173e-04 - 2s/epoch - 8ms/step
# Epoch 55/100
# 306/306 - 2s - loss: 2.0897e-04 - val_loss: 2.1283e-04 - 2s/epoch - 8ms/step
# Epoch 56/100
# 306/306 - 2s - loss: 2.0542e-04 - val_loss: 2.0684e-04 - 2s/epoch - 8ms/step
# Epoch 57/100
# 306/306 - 2s - loss: 2.0108e-04 - val_loss: 2.0451e-04 - 2s/epoch - 8ms/step
# Epoch 58/100
# 306/306 - 2s - loss: 1.9730e-04 - val_loss: 2.0090e-04 - 2s/epoch - 8ms/step
# Epoch 59/100
# 306/306 - 2s - loss: 1.9317e-04 - val_loss: 1.9813e-04 - 2s/epoch - 8ms/step
# Epoch 60/100
# 306/306 - 2s - loss: 1.8854e-04 - val_loss: 1.9710e-04 - 2s/epoch - 8ms/step
# Epoch 61/100
# 306/306 - 2s - loss: 1.8586e-04 - val_loss: 1.9554e-04 - 2s/epoch - 8ms/step
# Epoch 62/100
# 306/306 - 2s - loss: 1.8243e-04 - val_loss: 1.9511e-04 - 2s/epoch - 8ms/step
# Epoch 63/100
# 306/306 - 2s - loss: 1.8068e-04 - val_loss: 1.9478e-04 - 2s/epoch - 8ms/step
# Epoch 64/100
# 306/306 - 2s - loss: 1.7773e-04 - val_loss: 1.9601e-04 - 2s/epoch - 8ms/step
# Epoch 65/100
# 306/306 - 2s - loss: 1.7712e-04 - val_loss: 1.9708e-04 - 2s/epoch - 8ms/step
# Epoch 66/100
# 306/306 - 2s - loss: 1.7552e-04 - val_loss: 2.0338e-04 - 2s/epoch - 8ms/step
# Epoch 67/100
# 306/306 - 2s - loss: 1.7555e-04 - val_loss: 2.0577e-04 - 2s/epoch - 8ms/step
# Epoch 68/100
# 306/306 - 2s - loss: 1.7475e-04 - val_loss: 2.0903e-04 - 2s/epoch - 8ms/step
# Epoch 69/100
# 306/306 - 2s - loss: 1.7305e-04 - val_loss: 2.0752e-04 - 2s/epoch - 8ms/step
# Epoch 70/100
# 306/306 - 2s - loss: 1.6968e-04 - val_loss: 2.0334e-04 - 2s/epoch - 8ms/step
# Epoch 71/100
# 306/306 - 2s - loss: 1.6570e-04 - val_loss: 1.9906e-04 - 2s/epoch - 8ms/step
# Epoch 72/100
# 306/306 - 2s - loss: 1.6140e-04 - val_loss: 1.9841e-04 - 2s/epoch - 8ms/step
# Epoch 73/100
# 306/306 - 2s - loss: 1.5891e-04 - val_loss: 1.9758e-04 - 2s/epoch - 8ms/step
# Epoch 74/100
# 306/306 - 2s - loss: 1.5665e-04 - val_loss: 2.0007e-04 - 2s/epoch - 8ms/step
# Epoch 75/100
# 306/306 - 2s - loss: 1.5546e-04 - val_loss: 2.0343e-04 - 2s/epoch - 8ms/step
# Epoch 76/100
# 306/306 - 2s - loss: 1.5463e-04 - val_loss: 2.0638e-04 - 2s/epoch - 8ms/step
# Epoch 77/100
# 306/306 - 2s - loss: 1.5370e-04 - val_loss: 2.0968e-04 - 2s/epoch - 8ms/step
# Epoch 78/100
# 306/306 - 2s - loss: 1.5318e-04 - val_loss: 2.1451e-04 - 2s/epoch - 8ms/step
# Epoch 79/100
# 306/306 - 2s - loss: 1.5267e-04 - val_loss: 2.1796e-04 - 2s/epoch - 8ms/step
# Epoch 80/100
# 306/306 - 2s - loss: 1.5121e-04 - val_loss: 2.2022e-04 - 2s/epoch - 8ms/step
# Epoch 81/100
# 306/306 - 2s - loss: 1.4990e-04 - val_loss: 2.2275e-04 - 2s/epoch - 8ms/step
# Epoch 82/100
# 306/306 - 2s - loss: 1.4791e-04 - val_loss: 2.2538e-04 - 2s/epoch - 8ms/step
# Epoch 83/100
# 306/306 - 2s - loss: 1.4635e-04 - val_loss: 2.2800e-04 - 2s/epoch - 8ms/step
# Epoch 84/100
# 306/306 - 2s - loss: 1.4447e-04 - val_loss: 2.3109e-04 - 2s/epoch - 8ms/step
# Epoch 85/100
# 306/306 - 2s - loss: 1.4328e-04 - val_loss: 2.3558e-04 - 2s/epoch - 8ms/step
# Epoch 86/100
# 306/306 - 2s - loss: 1.4177e-04 - val_loss: 2.4005e-04 - 2s/epoch - 8ms/step
# Epoch 87/100
# 306/306 - 2s - loss: 1.4090e-04 - val_loss: 2.4468e-04 - 2s/epoch - 8ms/step
# Epoch 88/100
# 306/306 - 2s - loss: 1.3968e-04 - val_loss: 2.5024e-04 - 2s/epoch - 8ms/step
# Epoch 89/100
# 306/306 - 2s - loss: 1.3907e-04 - val_loss: 2.5640e-04 - 2s/epoch - 8ms/step
# Epoch 90/100
# 306/306 - 2s - loss: 1.3836e-04 - val_loss: 2.6303e-04 - 2s/epoch - 8ms/step
# Epoch 91/100
# 306/306 - 2s - loss: 1.3760e-04 - val_loss: 2.6885e-04 - 2s/epoch - 8ms/step
# Epoch 92/100
# 306/306 - 2s - loss: 1.3701e-04 - val_loss: 2.7545e-04 - 2s/epoch - 8ms/step
# Epoch 93/100
# 306/306 - 2s - loss: 1.3613e-04 - val_loss: 2.8148e-04 - 2s/epoch - 8ms/step
# Epoch 94/100
# 306/306 - 2s - loss: 1.3541e-04 - val_loss: 2.8752e-04 - 2s/epoch - 8ms/step
# Epoch 95/100
# 306/306 - 2s - loss: 1.3422e-04 - val_loss: 2.9372e-04 - 2s/epoch - 8ms/step
# Epoch 96/100
# 306/306 - 2s - loss: 1.3325e-04 - val_loss: 2.9876e-04 - 2s/epoch - 8ms/step
# Epoch 97/100
# 306/306 - 2s - loss: 1.3207e-04 - val_loss: 3.0408e-04 - 2s/epoch - 8ms/step
# Epoch 98/100
# 306/306 - 2s - loss: 1.3105e-04 - val_loss: 3.0921e-04 - 2s/epoch - 8ms/step
# Epoch 99/100
# 306/306 - 2s - loss: 1.3008e-04 - val_loss: 3.1462e-04 - 2s/epoch - 8ms/step
# Epoch 100/100
# 306/306 - 2s - loss: 1.2926e-04 - val_loss: 3.2000e-04 - 2s/epoch - 8ms/step

# %%
i=0
wb2 = Workbook()
ws2 = wb2.active
for m in models2:
    # make a prediction
    test_x2 = test_X
    yhat = LSTMUnit.predict(test_x2, m)
    inv_yhat = Preprocessing.inverse_scaler(yhat, scaler)
    inv_y = Preprocessing.inverse_scaler(test_y.reshape(-1,1), scaler)
    print(hyperparam2[i])
    print("Epoch: "+ str(lstms2[i].params['epochs']))
    print("Neurons: "+str(m.layers[0].units))
    i = i+1
    ws2['A'+str(i)] = 'LSTM'
    ws2['B'+str(i)] = hyperparam2[i-1][0]
    ws2['C'+str(i)] = hyperparam2[i-1][1]
    ws2['D'+str(i)] = hyperparam2[i-1][2]
    print('RMSE')
    print(Evaluation.rmse(inv_y,inv_yhat)[0])
    ws2['E'+str(i)] = Evaluation.rmse(inv_y,inv_yhat)[0]
    print('MAE')
    print(Evaluation.mae(inv_y,inv_yhat)[0])
    ws2['F'+str(i)] = Evaluation.mae(inv_y,inv_yhat)[0]
    print('MAPE')
    print(Evaluation.mape(inv_y,inv_yhat)[0])
    ws2['G'+str(i)] = Evaluation.mape(inv_y,inv_yhat)[0]
    LSTMUnit.save_model(m, 0, 'ETH',hyperparam2[i-1])
wb2.save('LSTM_ETH_result2.xlsx')
# Out:
#  13/153 [=>............................] - ETA: 0s
# 2023-04-03 10:04:55.684067: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:04:55.712683: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (64, 25, 50)
# Epoch: 25
# Neurons: 50
# RMSE
# 89.83594285968604
# MAE
# 83.48566351907564
# MAPE
# 6.409854931811569
#  33/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:04:56.435329: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:04:56.468166: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (64, 25, 60)
# Epoch: 25
# Neurons: 60
# RMSE
# 112.86276356151384
# MAE
# 106.77218689752951
# MAPE
# 8.143688319072293
#  35/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:04:57.146072: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:04:57.174080: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (64, 25, 100)
# Epoch: 25
# Neurons: 100
# RMSE
# 100.27914959545974
# MAE
# 94.51829989856073
# MAPE
# 7.214042375546939
#  33/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:04:57.819186: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:04:57.845047: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (64, 50, 50)
# Epoch: 50
# Neurons: 50
# RMSE
# 69.04674758502674
# MAE
# 62.45892768173406
# MAPE
# 4.84473867546431
#  32/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:04:58.501622: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:04:58.527743: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (64, 50, 60)
# Epoch: 50
# Neurons: 60
# RMSE
# 69.73875792987917
# MAE
# 63.27472966892565
# MAPE
# 4.903729733848746
#  34/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:04:59.195821: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:04:59.221795: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (64, 50, 100)
# Epoch: 50
# Neurons: 100
# RMSE
# 64.58385456549452
# MAE
# 58.120142254072135
# MAPE
# 4.514709889703595
#  33/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:04:59.858596: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:04:59.884776: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (64, 100, 50)
# Epoch: 100
# Neurons: 50
# RMSE
# 58.28337302055246
# MAE
# 52.75825441955092
# MAPE
# 4.086385155364653
#  34/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:05:00.554751: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:05:00.580495: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (64, 100, 60)
# Epoch: 100
# Neurons: 60
# RMSE
# 59.21547107993553
# MAE
# 53.617701225116726
# MAPE
# 4.1535334413281
#  35/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:05:01.243201: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:05:01.269462: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (64, 100, 100)
# Epoch: 100
# Neurons: 100
# RMSE
# 84.97159722200249
# MAE
# 78.64330059310318
# MAPE
# 6.056984048866042

# %%
lstms3 = []
models3 = []
for batch, epoch, neuron in hyperparam3:
    model, lstm = LSTMUnit.train_lstm(train_X, train_y, test_X, test_y, neuron, epoch, batch)
    lstms3.append(lstm)
    models3.append(model)
# Out:
# Epoch 1/25
# 2023-04-03 10:05:02.301914: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:05:02.392822: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:05:02.600069: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:05:04.223650: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:05:04.254641: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 - 3s - loss: 0.0024 - val_loss: 0.0098 - 3s/epoch - 17ms/step
# Epoch 2/25
# 153/153 - 1s - loss: 0.0022 - val_loss: 0.0044 - 1s/epoch - 8ms/step
# Epoch 3/25
# 153/153 - 1s - loss: 0.0012 - val_loss: 0.0021 - 1s/epoch - 8ms/step
# Epoch 4/25
# 153/153 - 1s - loss: 7.2285e-04 - val_loss: 0.0011 - 1s/epoch - 9ms/step
# Epoch 5/25
# 153/153 - 1s - loss: 5.1531e-04 - val_loss: 7.1707e-04 - 1s/epoch - 9ms/step
# Epoch 6/25
# 153/153 - 1s - loss: 3.9985e-04 - val_loss: 5.0613e-04 - 1s/epoch - 8ms/step
# Epoch 7/25
# 153/153 - 1s - loss: 3.0836e-04 - val_loss: 3.4077e-04 - 1s/epoch - 8ms/step
# Epoch 8/25
# 153/153 - 1s - loss: 2.3270e-04 - val_loss: 2.0703e-04 - 1s/epoch - 8ms/step
# Epoch 9/25
# 153/153 - 1s - loss: 1.8283e-04 - val_loss: 1.3406e-04 - 1s/epoch - 8ms/step
# Epoch 10/25
# 153/153 - 1s - loss: 1.6000e-04 - val_loss: 1.1130e-04 - 1s/epoch - 8ms/step
# Epoch 11/25
# 153/153 - 1s - loss: 1.5709e-04 - val_loss: 1.1824e-04 - 1s/epoch - 8ms/step
# Epoch 12/25
# 153/153 - 1s - loss: 1.7267e-04 - val_loss: 1.4863e-04 - 1s/epoch - 8ms/step
# Epoch 13/25
# 153/153 - 1s - loss: 2.1904e-04 - val_loss: 2.0611e-04 - 1s/epoch - 8ms/step
# Epoch 14/25
# 153/153 - 1s - loss: 3.2948e-04 - val_loss: 2.8927e-04 - 1s/epoch - 8ms/step
# Epoch 15/25
# 153/153 - 1s - loss: 5.3499e-04 - val_loss: 5.2776e-04 - 1s/epoch - 8ms/step
# Epoch 16/25
# 153/153 - 1s - loss: 6.5906e-04 - val_loss: 9.6541e-04 - 1s/epoch - 8ms/step
# Epoch 17/25
# 153/153 - 1s - loss: 5.9232e-04 - val_loss: 8.5416e-04 - 1s/epoch - 8ms/step
# Epoch 18/25
# 153/153 - 1s - loss: 4.7511e-04 - val_loss: 6.2375e-04 - 1s/epoch - 8ms/step
# Epoch 19/25
# 153/153 - 1s - loss: 3.6255e-04 - val_loss: 4.2188e-04 - 1s/epoch - 8ms/step
# Epoch 20/25
# 153/153 - 1s - loss: 2.7637e-04 - val_loss: 2.7497e-04 - 1s/epoch - 9ms/step
# Epoch 21/25
# 153/153 - 1s - loss: 2.1881e-04 - val_loss: 1.8620e-04 - 1s/epoch - 8ms/step
# Epoch 22/25
# 153/153 - 1s - loss: 1.8335e-04 - val_loss: 1.4138e-04 - 1s/epoch - 8ms/step
# Epoch 23/25
# 153/153 - 1s - loss: 1.6237e-04 - val_loss: 1.2316e-04 - 1s/epoch - 8ms/step
# Epoch 24/25
# 153/153 - 1s - loss: 1.4953e-04 - val_loss: 1.3430e-04 - 1s/epoch - 8ms/step
# Epoch 25/25
# 153/153 - 1s - loss: 1.5113e-04 - val_loss: 1.5054e-04 - 1s/epoch - 8ms/step
# Epoch 1/25
# 2023-04-03 10:05:35.892965: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:05:35.983630: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:05:36.199337: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:05:37.838645: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:05:37.869416: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 - 3s - loss: 0.0012 - val_loss: 0.0073 - 3s/epoch - 17ms/step
# Epoch 2/25
# 153/153 - 1s - loss: 0.0027 - val_loss: 0.0088 - 1s/epoch - 8ms/step
# Epoch 3/25
# 153/153 - 1s - loss: 0.0023 - val_loss: 0.0060 - 1s/epoch - 8ms/step
# Epoch 4/25
# 153/153 - 1s - loss: 0.0015 - val_loss: 0.0033 - 1s/epoch - 8ms/step
# Epoch 5/25
# 153/153 - 1s - loss: 9.1343e-04 - val_loss: 0.0016 - 1s/epoch - 8ms/step
# Epoch 6/25
# 153/153 - 1s - loss: 5.5428e-04 - val_loss: 8.3563e-04 - 1s/epoch - 8ms/step
# Epoch 7/25
# 153/153 - 1s - loss: 3.8095e-04 - val_loss: 5.0087e-04 - 1s/epoch - 8ms/step
# Epoch 8/25
# 153/153 - 1s - loss: 2.8324e-04 - val_loss: 3.2866e-04 - 1s/epoch - 8ms/step
# Epoch 9/25
# 153/153 - 1s - loss: 2.1221e-04 - val_loss: 2.1137e-04 - 1s/epoch - 8ms/step
# Epoch 10/25
# 153/153 - 1s - loss: 1.5746e-04 - val_loss: 1.2581e-04 - 1s/epoch - 8ms/step
# Epoch 11/25
# 153/153 - 1s - loss: 1.2311e-04 - val_loss: 8.0383e-05 - 1s/epoch - 8ms/step
# Epoch 12/25
# 153/153 - 1s - loss: 1.0914e-04 - val_loss: 6.6607e-05 - 1s/epoch - 8ms/step
# Epoch 13/25
# 153/153 - 1s - loss: 1.1116e-04 - val_loss: 7.2757e-05 - 1s/epoch - 8ms/step
# Epoch 14/25
# 153/153 - 1s - loss: 1.3043e-04 - val_loss: 9.8657e-05 - 1s/epoch - 8ms/step
# Epoch 15/25
# 153/153 - 1s - loss: 1.8155e-04 - val_loss: 1.5235e-04 - 1s/epoch - 8ms/step
# Epoch 16/25
# 153/153 - 1s - loss: 3.0506e-04 - val_loss: 2.4941e-04 - 1s/epoch - 8ms/step
# Epoch 17/25
# 153/153 - 1s - loss: 5.3752e-04 - val_loss: 5.9821e-04 - 1s/epoch - 8ms/step
# Epoch 18/25
# 153/153 - 1s - loss: 6.4671e-04 - val_loss: 9.9655e-04 - 1s/epoch - 8ms/step
# Epoch 19/25
# 153/153 - 1s - loss: 5.7353e-04 - val_loss: 8.1878e-04 - 1s/epoch - 8ms/step
# Epoch 20/25
# 153/153 - 1s - loss: 4.4899e-04 - val_loss: 5.8859e-04 - 1s/epoch - 8ms/step
# Epoch 21/25
# 153/153 - 1s - loss: 3.3514e-04 - val_loss: 3.9406e-04 - 1s/epoch - 8ms/step
# Epoch 22/25
# 153/153 - 1s - loss: 2.4726e-04 - val_loss: 2.5137e-04 - 1s/epoch - 8ms/step
# Epoch 23/25
# 153/153 - 1s - loss: 1.8940e-04 - val_loss: 1.6554e-04 - 1s/epoch - 8ms/step
# Epoch 24/25
# 153/153 - 1s - loss: 1.5622e-04 - val_loss: 1.2401e-04 - 1s/epoch - 8ms/step
# Epoch 25/25
# 153/153 - 1s - loss: 1.3934e-04 - val_loss: 1.0966e-04 - 1s/epoch - 8ms/step
# Epoch 1/25
# 2023-04-03 10:06:09.159023: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:06:09.256522: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:06:09.399233: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:06:11.102028: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:06:11.133813: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 - 3s - loss: 6.2967e-04 - val_loss: 0.0020 - 3s/epoch - 19ms/step
# Epoch 2/25
# 153/153 - 1s - loss: 0.0038 - val_loss: 0.0103 - 1s/epoch - 8ms/step
# Epoch 3/25
# 153/153 - 1s - loss: 0.0037 - val_loss: 0.0123 - 1s/epoch - 8ms/step
# Epoch 4/25
# 153/153 - 1s - loss: 0.0034 - val_loss: 0.0082 - 1s/epoch - 9ms/step
# Epoch 5/25
# 153/153 - 1s - loss: 0.0022 - val_loss: 0.0043 - 1s/epoch - 8ms/step
# Epoch 6/25
# 153/153 - 1s - loss: 0.0012 - val_loss: 0.0019 - 1s/epoch - 8ms/step
# Epoch 7/25
# 153/153 - 1s - loss: 5.9014e-04 - val_loss: 8.1388e-04 - 1s/epoch - 8ms/step
# Epoch 8/25
# 153/153 - 1s - loss: 3.5118e-04 - val_loss: 4.2418e-04 - 1s/epoch - 8ms/step
# Epoch 9/25
# 153/153 - 1s - loss: 2.3901e-04 - val_loss: 2.5337e-04 - 1s/epoch - 8ms/step
# Epoch 10/25
# 153/153 - 1s - loss: 1.6985e-04 - val_loss: 1.5018e-04 - 1s/epoch - 8ms/step
# Epoch 11/25
# 153/153 - 1s - loss: 1.2325e-04 - val_loss: 8.3677e-05 - 1s/epoch - 8ms/step
# Epoch 12/25
# 153/153 - 1s - loss: 9.7185e-05 - val_loss: 5.2697e-05 - 1s/epoch - 8ms/step
# Epoch 13/25
# 153/153 - 1s - loss: 8.7289e-05 - val_loss: 4.3862e-05 - 1s/epoch - 8ms/step
# Epoch 14/25
# 153/153 - 1s - loss: 8.8407e-05 - val_loss: 4.7977e-05 - 1s/epoch - 8ms/step
# Epoch 15/25
# 153/153 - 1s - loss: 1.0095e-04 - val_loss: 6.6610e-05 - 1s/epoch - 8ms/step
# Epoch 16/25
# 153/153 - 1s - loss: 1.3501e-04 - val_loss: 1.1138e-04 - 1s/epoch - 8ms/step
# Epoch 17/25
# 153/153 - 1s - loss: 2.2434e-04 - val_loss: 2.0165e-04 - 1s/epoch - 8ms/step
# Epoch 18/25
# 153/153 - 1s - loss: 4.6145e-04 - val_loss: 3.8132e-04 - 1s/epoch - 8ms/step
# Epoch 19/25
# 153/153 - 1s - loss: 8.2803e-04 - val_loss: 0.0013 - 1s/epoch - 8ms/step
# Epoch 20/25
# 153/153 - 1s - loss: 8.4742e-04 - val_loss: 0.0014 - 1s/epoch - 8ms/step
# Epoch 21/25
# 153/153 - 1s - loss: 7.6126e-04 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 22/25
# 153/153 - 1s - loss: 5.5955e-04 - val_loss: 7.0755e-04 - 1s/epoch - 8ms/step
# Epoch 23/25
# 153/153 - 1s - loss: 3.8068e-04 - val_loss: 4.2888e-04 - 1s/epoch - 8ms/step
# Epoch 24/25
# 153/153 - 1s - loss: 2.5071e-04 - val_loss: 2.3426e-04 - 1s/epoch - 8ms/step
# Epoch 25/25
# 153/153 - 1s - loss: 1.6725e-04 - val_loss: 1.2576e-04 - 1s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-03 10:06:42.799561: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:06:42.887070: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:06:43.015754: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:06:44.629017: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:06:44.660806: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 - 3s - loss: 0.0025 - val_loss: 0.0115 - 3s/epoch - 17ms/step
# Epoch 2/50
# 153/153 - 1s - loss: 0.0025 - val_loss: 0.0051 - 1s/epoch - 8ms/step
# Epoch 3/50
# 153/153 - 1s - loss: 0.0013 - val_loss: 0.0023 - 1s/epoch - 8ms/step
# Epoch 4/50
# 153/153 - 1s - loss: 6.8320e-04 - val_loss: 0.0010 - 1s/epoch - 9ms/step
# Epoch 5/50
# 153/153 - 1s - loss: 4.3772e-04 - val_loss: 5.5739e-04 - 1s/epoch - 8ms/step
# Epoch 6/50
# 153/153 - 1s - loss: 3.2769e-04 - val_loss: 3.6754e-04 - 1s/epoch - 9ms/step
# Epoch 7/50
# 153/153 - 1s - loss: 2.5178e-04 - val_loss: 2.4232e-04 - 1s/epoch - 9ms/step
# Epoch 8/50
# 153/153 - 1s - loss: 1.8966e-04 - val_loss: 1.4539e-04 - 1s/epoch - 8ms/step
# Epoch 9/50
# 153/153 - 1s - loss: 1.4920e-04 - val_loss: 9.3457e-05 - 1s/epoch - 8ms/step
# Epoch 10/50
# 153/153 - 1s - loss: 1.3407e-04 - val_loss: 8.0321e-05 - 1s/epoch - 8ms/step
# Epoch 11/50
# 153/153 - 1s - loss: 1.4056e-04 - val_loss: 9.2523e-05 - 1s/epoch - 8ms/step
# Epoch 12/50
# 153/153 - 1s - loss: 1.7278e-04 - val_loss: 1.3021e-04 - 1s/epoch - 8ms/step
# Epoch 13/50
# 153/153 - 1s - loss: 2.5453e-04 - val_loss: 2.0075e-04 - 1s/epoch - 8ms/step
# Epoch 14/50
# 153/153 - 1s - loss: 4.3180e-04 - val_loss: 3.6988e-04 - 1s/epoch - 8ms/step
# Epoch 15/50
# 153/153 - 1s - loss: 6.2099e-04 - val_loss: 8.1885e-04 - 1s/epoch - 8ms/step
# Epoch 16/50
# 153/153 - 1s - loss: 5.9871e-04 - val_loss: 8.2428e-04 - 1s/epoch - 8ms/step
# Epoch 17/50
# 153/153 - 1s - loss: 4.9044e-04 - val_loss: 6.1431e-04 - 1s/epoch - 8ms/step
# Epoch 18/50
# 153/153 - 1s - loss: 3.7619e-04 - val_loss: 4.2229e-04 - 1s/epoch - 8ms/step
# Epoch 19/50
# 153/153 - 1s - loss: 2.8605e-04 - val_loss: 2.7694e-04 - 1s/epoch - 8ms/step
# Epoch 20/50
# 153/153 - 1s - loss: 2.2477e-04 - val_loss: 1.8669e-04 - 1s/epoch - 8ms/step
# Epoch 21/50
# 153/153 - 1s - loss: 1.8848e-04 - val_loss: 1.4167e-04 - 1s/epoch - 8ms/step
# Epoch 22/50
# 153/153 - 1s - loss: 1.6930e-04 - val_loss: 1.2483e-04 - 1s/epoch - 8ms/step
# Epoch 23/50
# 153/153 - 1s - loss: 1.6105e-04 - val_loss: 1.2499e-04 - 1s/epoch - 8ms/step
# Epoch 24/50
# 153/153 - 1s - loss: 1.6240e-04 - val_loss: 1.3832e-04 - 1s/epoch - 8ms/step
# Epoch 25/50
# 153/153 - 1s - loss: 1.7838e-04 - val_loss: 1.6859e-04 - 1s/epoch - 8ms/step
# Epoch 26/50
# 153/153 - 1s - loss: 2.2498e-04 - val_loss: 2.2253e-04 - 1s/epoch - 8ms/step
# Epoch 27/50
# 153/153 - 1s - loss: 3.3642e-04 - val_loss: 2.9574e-04 - 1s/epoch - 8ms/step
# Epoch 28/50
# 153/153 - 1s - loss: 5.0000e-04 - val_loss: 5.2751e-04 - 1s/epoch - 9ms/step
# Epoch 29/50
# 153/153 - 1s - loss: 5.2406e-04 - val_loss: 7.0355e-04 - 1s/epoch - 8ms/step
# Epoch 30/50
# 153/153 - 1s - loss: 4.5782e-04 - val_loss: 5.0156e-04 - 1s/epoch - 8ms/step
# Epoch 31/50
# 153/153 - 1s - loss: 3.1306e-04 - val_loss: 3.0998e-04 - 1s/epoch - 8ms/step
# Epoch 32/50
# 153/153 - 1s - loss: 2.3085e-04 - val_loss: 1.8452e-04 - 1s/epoch - 8ms/step
# Epoch 33/50
# 153/153 - 1s - loss: 1.7835e-04 - val_loss: 1.1691e-04 - 1s/epoch - 8ms/step
# Epoch 34/50
# 153/153 - 1s - loss: 1.4380e-04 - val_loss: 9.4900e-05 - 1s/epoch - 8ms/step
# Epoch 35/50
# 153/153 - 1s - loss: 1.2425e-04 - val_loss: 9.5810e-05 - 1s/epoch - 8ms/step
# Epoch 36/50
# 153/153 - 1s - loss: 1.1674e-04 - val_loss: 9.6445e-05 - 1s/epoch - 8ms/step
# Epoch 37/50
# 153/153 - 1s - loss: 1.1878e-04 - val_loss: 1.1442e-04 - 1s/epoch - 8ms/step
# Epoch 38/50
# 153/153 - 1s - loss: 1.3877e-04 - val_loss: 1.6932e-04 - 1s/epoch - 8ms/step
# Epoch 39/50
# 153/153 - 1s - loss: 2.2613e-04 - val_loss: 2.5653e-04 - 1s/epoch - 8ms/step
# Epoch 40/50
# 153/153 - 1s - loss: 4.5001e-04 - val_loss: 4.7613e-04 - 1s/epoch - 8ms/step
# Epoch 41/50
# 153/153 - 1s - loss: 5.9371e-04 - val_loss: 8.1448e-04 - 1s/epoch - 8ms/step
# Epoch 42/50
# 153/153 - 1s - loss: 4.3630e-04 - val_loss: 4.8111e-04 - 1s/epoch - 8ms/step
# Epoch 43/50
# 153/153 - 1s - loss: 2.8986e-04 - val_loss: 2.6651e-04 - 1s/epoch - 8ms/step
# Epoch 44/50
# 153/153 - 1s - loss: 1.8912e-04 - val_loss: 1.3469e-04 - 1s/epoch - 8ms/step
# Epoch 45/50
# 153/153 - 1s - loss: 1.2924e-04 - val_loss: 7.3892e-05 - 1s/epoch - 8ms/step
# Epoch 46/50
# 153/153 - 1s - loss: 1.0119e-04 - val_loss: 4.9816e-05 - 1s/epoch - 8ms/step
# Epoch 47/50
# 153/153 - 1s - loss: 8.7119e-05 - val_loss: 3.9741e-05 - 1s/epoch - 8ms/step
# Epoch 48/50
# 153/153 - 1s - loss: 7.7506e-05 - val_loss: 3.4515e-05 - 1s/epoch - 8ms/step
# Epoch 49/50
# 153/153 - 1s - loss: 7.0277e-05 - val_loss: 3.1094e-05 - 1s/epoch - 8ms/step
# Epoch 50/50
# 153/153 - 1s - loss: 6.5332e-05 - val_loss: 3.0244e-05 - 1s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-03 10:07:48.491497: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:07:48.577120: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:07:48.712171: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:07:50.323366: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:07:50.353982: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 - 3s - loss: 0.0011 - val_loss: 0.0060 - 3s/epoch - 17ms/step
# Epoch 2/50
# 153/153 - 1s - loss: 0.0023 - val_loss: 0.0069 - 1s/epoch - 8ms/step
# Epoch 3/50
# 153/153 - 1s - loss: 0.0020 - val_loss: 0.0053 - 1s/epoch - 8ms/step
# Epoch 4/50
# 153/153 - 1s - loss: 0.0014 - val_loss: 0.0030 - 1s/epoch - 8ms/step
# Epoch 5/50
# 153/153 - 1s - loss: 8.6812e-04 - val_loss: 0.0016 - 1s/epoch - 8ms/step
# Epoch 6/50
# 153/153 - 1s - loss: 5.6258e-04 - val_loss: 8.5781e-04 - 1s/epoch - 8ms/step
# Epoch 7/50
# 153/153 - 1s - loss: 4.0306e-04 - val_loss: 5.3276e-04 - 1s/epoch - 8ms/step
# Epoch 8/50
# 153/153 - 1s - loss: 3.0655e-04 - val_loss: 3.5713e-04 - 1s/epoch - 8ms/step
# Epoch 9/50
# 153/153 - 1s - loss: 2.3329e-04 - val_loss: 2.3559e-04 - 1s/epoch - 8ms/step
# Epoch 10/50
# 153/153 - 1s - loss: 1.7423e-04 - val_loss: 1.4392e-04 - 1s/epoch - 8ms/step
# Epoch 11/50
# 153/153 - 1s - loss: 1.3474e-04 - val_loss: 9.0849e-05 - 1s/epoch - 8ms/step
# Epoch 12/50
# 153/153 - 1s - loss: 1.1695e-04 - val_loss: 7.2292e-05 - 1s/epoch - 8ms/step
# Epoch 13/50
# 153/153 - 1s - loss: 1.1683e-04 - val_loss: 7.5749e-05 - 1s/epoch - 8ms/step
# Epoch 14/50
# 153/153 - 1s - loss: 1.3449e-04 - val_loss: 9.9050e-05 - 1s/epoch - 8ms/step
# Epoch 15/50
# 153/153 - 1s - loss: 1.8244e-04 - val_loss: 1.4880e-04 - 1s/epoch - 8ms/step
# Epoch 16/50
# 153/153 - 1s - loss: 2.9578e-04 - val_loss: 2.4023e-04 - 1s/epoch - 8ms/step
# Epoch 17/50
# 153/153 - 1s - loss: 5.0434e-04 - val_loss: 5.4063e-04 - 1s/epoch - 8ms/step
# Epoch 18/50
# 153/153 - 1s - loss: 6.1154e-04 - val_loss: 8.9664e-04 - 1s/epoch - 8ms/step
# Epoch 19/50
# 153/153 - 1s - loss: 5.5108e-04 - val_loss: 7.2967e-04 - 1s/epoch - 8ms/step
# Epoch 20/50
# 153/153 - 1s - loss: 4.1738e-04 - val_loss: 5.0199e-04 - 1s/epoch - 8ms/step
# Epoch 21/50
# 153/153 - 1s - loss: 3.0466e-04 - val_loss: 3.2847e-04 - 1s/epoch - 8ms/step
# Epoch 22/50
# 153/153 - 1s - loss: 2.2922e-04 - val_loss: 2.1053e-04 - 1s/epoch - 8ms/step
# Epoch 23/50
# 153/153 - 1s - loss: 1.8148e-04 - val_loss: 1.4566e-04 - 1s/epoch - 8ms/step
# Epoch 24/50
# 153/153 - 1s - loss: 1.5592e-04 - val_loss: 1.1755e-04 - 1s/epoch - 8ms/step
# Epoch 25/50
# 153/153 - 1s - loss: 1.4432e-04 - val_loss: 1.1408e-04 - 1s/epoch - 8ms/step
# Epoch 26/50
# 153/153 - 1s - loss: 1.4665e-04 - val_loss: 1.3902e-04 - 1s/epoch - 8ms/step
# Epoch 27/50
# 153/153 - 1s - loss: 1.7296e-04 - val_loss: 2.1779e-04 - 1s/epoch - 8ms/step
# Epoch 28/50
# 153/153 - 1s - loss: 2.9377e-04 - val_loss: 3.3187e-04 - 1s/epoch - 8ms/step
# Epoch 29/50
# 153/153 - 1s - loss: 5.6645e-04 - val_loss: 7.3304e-04 - 1s/epoch - 8ms/step
# Epoch 30/50
# 153/153 - 1s - loss: 5.7362e-04 - val_loss: 7.6873e-04 - 1s/epoch - 8ms/step
# Epoch 31/50
# 153/153 - 1s - loss: 4.1286e-04 - val_loss: 4.7611e-04 - 1s/epoch - 8ms/step
# Epoch 32/50
# 153/153 - 1s - loss: 2.8256e-04 - val_loss: 2.8018e-04 - 1s/epoch - 8ms/step
# Epoch 33/50
# 153/153 - 1s - loss: 1.9634e-04 - val_loss: 1.5649e-04 - 1s/epoch - 8ms/step
# Epoch 34/50
# 153/153 - 1s - loss: 1.4500e-04 - val_loss: 9.6936e-05 - 1s/epoch - 8ms/step
# Epoch 35/50
# 153/153 - 1s - loss: 1.1761e-04 - val_loss: 7.7828e-05 - 1s/epoch - 8ms/step
# Epoch 36/50
# 153/153 - 1s - loss: 1.0327e-04 - val_loss: 7.2060e-05 - 1s/epoch - 8ms/step
# Epoch 37/50
# 153/153 - 1s - loss: 9.5413e-05 - val_loss: 7.3033e-05 - 1s/epoch - 8ms/step
# Epoch 38/50
# 153/153 - 1s - loss: 9.3834e-05 - val_loss: 7.9132e-05 - 1s/epoch - 8ms/step
# Epoch 39/50
# 153/153 - 1s - loss: 1.0150e-04 - val_loss: 1.0880e-04 - 1s/epoch - 8ms/step
# Epoch 40/50
# 153/153 - 1s - loss: 1.3594e-04 - val_loss: 1.8927e-04 - 1s/epoch - 8ms/step
# Epoch 41/50
# 153/153 - 1s - loss: 2.3953e-04 - val_loss: 3.6480e-04 - 1s/epoch - 8ms/step
# Epoch 42/50
# 153/153 - 1s - loss: 6.8267e-04 - val_loss: 0.0015 - 1s/epoch - 8ms/step
# Epoch 43/50
# 153/153 - 1s - loss: 0.0011 - val_loss: 0.0015 - 1s/epoch - 8ms/step
# Epoch 44/50
# 153/153 - 1s - loss: 7.2362e-04 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 45/50
# 153/153 - 1s - loss: 4.6568e-04 - val_loss: 6.6300e-04 - 1s/epoch - 8ms/step
# Epoch 46/50
# 153/153 - 1s - loss: 3.1546e-04 - val_loss: 3.8010e-04 - 1s/epoch - 8ms/step
# Epoch 47/50
# 153/153 - 1s - loss: 2.1639e-04 - val_loss: 2.1673e-04 - 1s/epoch - 8ms/step
# Epoch 48/50
# 153/153 - 1s - loss: 1.5438e-04 - val_loss: 1.2820e-04 - 1s/epoch - 8ms/step
# Epoch 49/50
# 153/153 - 1s - loss: 1.1311e-04 - val_loss: 7.6611e-05 - 1s/epoch - 8ms/step
# Epoch 50/50
# 153/153 - 1s - loss: 8.6660e-05 - val_loss: 4.6240e-05 - 1s/epoch - 8ms/step
# Epoch 1/50
# 2023-04-03 10:08:52.368924: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:08:52.452289: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:08:52.586979: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:08:54.184590: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:08:54.215412: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 - 3s - loss: 6.3995e-04 - val_loss: 0.0019 - 3s/epoch - 17ms/step
# Epoch 2/50
# 153/153 - 1s - loss: 0.0036 - val_loss: 0.0092 - 1s/epoch - 9ms/step
# Epoch 3/50
# 153/153 - 1s - loss: 0.0035 - val_loss: 0.0111 - 1s/epoch - 9ms/step
# Epoch 4/50
# 153/153 - 1s - loss: 0.0033 - val_loss: 0.0086 - 1s/epoch - 9ms/step
# Epoch 5/50
# 153/153 - 1s - loss: 0.0023 - val_loss: 0.0047 - 1s/epoch - 9ms/step
# Epoch 6/50
# 153/153 - 1s - loss: 0.0012 - val_loss: 0.0021 - 1s/epoch - 8ms/step
# Epoch 7/50
# 153/153 - 1s - loss: 6.4837e-04 - val_loss: 9.1658e-04 - 1s/epoch - 8ms/step
# Epoch 8/50
# 153/153 - 1s - loss: 3.8376e-04 - val_loss: 4.6122e-04 - 1s/epoch - 9ms/step
# Epoch 9/50
# 153/153 - 1s - loss: 2.6096e-04 - val_loss: 2.7031e-04 - 1s/epoch - 9ms/step
# Epoch 10/50
# 153/153 - 1s - loss: 1.8626e-04 - val_loss: 1.6213e-04 - 1s/epoch - 8ms/step
# Epoch 11/50
# 153/153 - 1s - loss: 1.3382e-04 - val_loss: 9.0263e-05 - 1s/epoch - 8ms/step
# Epoch 12/50
# 153/153 - 1s - loss: 1.0254e-04 - val_loss: 5.3404e-05 - 1s/epoch - 8ms/step
# Epoch 13/50
# 153/153 - 1s - loss: 9.0462e-05 - val_loss: 4.1791e-05 - 1s/epoch - 8ms/step
# Epoch 14/50
# 153/153 - 1s - loss: 9.2475e-05 - val_loss: 4.4532e-05 - 1s/epoch - 8ms/step
# Epoch 15/50
# 153/153 - 1s - loss: 1.0877e-04 - val_loss: 6.2248e-05 - 1s/epoch - 8ms/step
# Epoch 16/50
# 153/153 - 1s - loss: 1.5080e-04 - val_loss: 1.0608e-04 - 1s/epoch - 8ms/step
# Epoch 17/50
# 153/153 - 1s - loss: 2.5550e-04 - val_loss: 1.9338e-04 - 1s/epoch - 8ms/step
# Epoch 18/50
# 153/153 - 1s - loss: 5.0910e-04 - val_loss: 4.2388e-04 - 1s/epoch - 8ms/step
# Epoch 19/50
# 153/153 - 1s - loss: 8.1439e-04 - val_loss: 0.0013 - 1s/epoch - 8ms/step
# Epoch 20/50
# 153/153 - 1s - loss: 8.2277e-04 - val_loss: 0.0013 - 1s/epoch - 8ms/step
# Epoch 21/50
# 153/153 - 1s - loss: 7.0654e-04 - val_loss: 8.9989e-04 - 1s/epoch - 8ms/step
# Epoch 22/50
# 153/153 - 1s - loss: 4.8484e-04 - val_loss: 5.8683e-04 - 1s/epoch - 9ms/step
# Epoch 23/50
# 153/153 - 1s - loss: 3.3426e-04 - val_loss: 3.5172e-04 - 1s/epoch - 8ms/step
# Epoch 24/50
# 153/153 - 1s - loss: 2.2507e-04 - val_loss: 1.9349e-04 - 1s/epoch - 8ms/step
# Epoch 25/50
# 153/153 - 1s - loss: 1.5919e-04 - val_loss: 1.1003e-04 - 1s/epoch - 8ms/step
# Epoch 26/50
# 153/153 - 1s - loss: 1.2506e-04 - val_loss: 7.6122e-05 - 1s/epoch - 9ms/step
# Epoch 27/50
# 153/153 - 1s - loss: 1.0916e-04 - val_loss: 6.6386e-05 - 1s/epoch - 8ms/step
# Epoch 28/50
# 153/153 - 1s - loss: 1.0382e-04 - val_loss: 6.9897e-05 - 1s/epoch - 8ms/step
# Epoch 29/50
# 153/153 - 1s - loss: 1.0780e-04 - val_loss: 8.7023e-05 - 1s/epoch - 8ms/step
# Epoch 30/50
# 153/153 - 1s - loss: 1.2950e-04 - val_loss: 1.3201e-04 - 1s/epoch - 8ms/step
# Epoch 31/50
# 153/153 - 1s - loss: 1.9508e-04 - val_loss: 2.3520e-04 - 1s/epoch - 8ms/step
# Epoch 32/50
# 153/153 - 1s - loss: 4.0569e-04 - val_loss: 4.9153e-04 - 1s/epoch - 8ms/step
# Epoch 33/50
# 153/153 - 1s - loss: 0.0010 - val_loss: 0.0021 - 1s/epoch - 8ms/step
# Epoch 34/50
# 153/153 - 1s - loss: 0.0011 - val_loss: 0.0014 - 1s/epoch - 8ms/step
# Epoch 35/50
# 153/153 - 1s - loss: 6.9303e-04 - val_loss: 7.4197e-04 - 1s/epoch - 8ms/step
# Epoch 36/50
# 153/153 - 1s - loss: 4.1180e-04 - val_loss: 4.3867e-04 - 1s/epoch - 8ms/step
# Epoch 37/50
# 153/153 - 1s - loss: 2.6956e-04 - val_loss: 2.5157e-04 - 1s/epoch - 8ms/step
# Epoch 38/50
# 153/153 - 1s - loss: 1.8148e-04 - val_loss: 1.3666e-04 - 1s/epoch - 8ms/step
# Epoch 39/50
# 153/153 - 1s - loss: 1.2045e-04 - val_loss: 7.1817e-05 - 1s/epoch - 8ms/step
# Epoch 40/50
# 153/153 - 1s - loss: 8.5871e-05 - val_loss: 3.9306e-05 - 1s/epoch - 8ms/step
# Epoch 41/50
# 153/153 - 1s - loss: 6.8538e-05 - val_loss: 2.6401e-05 - 1s/epoch - 8ms/step
# Epoch 42/50
# 153/153 - 1s - loss: 6.1523e-05 - val_loss: 2.2381e-05 - 1s/epoch - 8ms/step
# Epoch 43/50
# 153/153 - 1s - loss: 5.9932e-05 - val_loss: 2.2566e-05 - 1s/epoch - 8ms/step
# Epoch 44/50
# 153/153 - 1s - loss: 6.2969e-05 - val_loss: 2.6817e-05 - 1s/epoch - 8ms/step
# Epoch 45/50
# 153/153 - 1s - loss: 7.3248e-05 - val_loss: 3.9067e-05 - 1s/epoch - 8ms/step
# Epoch 46/50
# 153/153 - 1s - loss: 9.9875e-05 - val_loss: 6.9000e-05 - 1s/epoch - 8ms/step
# Epoch 47/50
# 153/153 - 1s - loss: 1.7228e-04 - val_loss: 1.3149e-04 - 1s/epoch - 8ms/step
# Epoch 48/50
# 153/153 - 1s - loss: 3.6728e-04 - val_loss: 3.4978e-04 - 1s/epoch - 8ms/step
# Epoch 49/50
# 153/153 - 1s - loss: 5.4133e-04 - val_loss: 8.1814e-04 - 1s/epoch - 8ms/step
# Epoch 50/50
# 153/153 - 1s - loss: 4.8863e-04 - val_loss: 5.3468e-04 - 1s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-03 10:09:58.022555: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:09:58.104920: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:09:58.237216: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:09:59.846470: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:09:59.877801: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 - 3s - loss: 0.0024 - val_loss: 0.0092 - 3s/epoch - 17ms/step
# Epoch 2/100
# 153/153 - 1s - loss: 0.0020 - val_loss: 0.0040 - 1s/epoch - 8ms/step
# Epoch 3/100
# 153/153 - 1s - loss: 0.0011 - val_loss: 0.0021 - 1s/epoch - 8ms/step
# Epoch 4/100
# 153/153 - 1s - loss: 7.0712e-04 - val_loss: 0.0011 - 1s/epoch - 9ms/step
# Epoch 5/100
# 153/153 - 1s - loss: 5.0688e-04 - val_loss: 6.9749e-04 - 1s/epoch - 8ms/step
# Epoch 6/100
# 153/153 - 1s - loss: 3.9621e-04 - val_loss: 4.9162e-04 - 1s/epoch - 10ms/step
# Epoch 7/100
# 153/153 - 1s - loss: 3.0833e-04 - val_loss: 3.3327e-04 - 1s/epoch - 8ms/step
# Epoch 8/100
# 153/153 - 1s - loss: 2.3403e-04 - val_loss: 2.0331e-04 - 1s/epoch - 9ms/step
# Epoch 9/100
# 153/153 - 1s - loss: 1.8346e-04 - val_loss: 1.3039e-04 - 1s/epoch - 8ms/step
# Epoch 10/100
# 153/153 - 1s - loss: 1.5945e-04 - val_loss: 1.0690e-04 - 1s/epoch - 8ms/step
# Epoch 11/100
# 153/153 - 1s - loss: 1.5545e-04 - val_loss: 1.1259e-04 - 1s/epoch - 8ms/step
# Epoch 12/100
# 153/153 - 1s - loss: 1.6989e-04 - val_loss: 1.4109e-04 - 1s/epoch - 8ms/step
# Epoch 13/100
# 153/153 - 1s - loss: 2.1510e-04 - val_loss: 1.9620e-04 - 1s/epoch - 9ms/step
# Epoch 14/100
# 153/153 - 1s - loss: 3.2590e-04 - val_loss: 2.7776e-04 - 1s/epoch - 8ms/step
# Epoch 15/100
# 153/153 - 1s - loss: 5.3609e-04 - val_loss: 5.2471e-04 - 1s/epoch - 8ms/step
# Epoch 16/100
# 153/153 - 1s - loss: 6.5692e-04 - val_loss: 9.3917e-04 - 1s/epoch - 8ms/step
# Epoch 17/100
# 153/153 - 1s - loss: 5.8790e-04 - val_loss: 8.1163e-04 - 1s/epoch - 8ms/step
# Epoch 18/100
# 153/153 - 1s - loss: 4.6888e-04 - val_loss: 5.8209e-04 - 1s/epoch - 8ms/step
# Epoch 19/100
# 153/153 - 1s - loss: 3.5435e-04 - val_loss: 3.9032e-04 - 1s/epoch - 8ms/step
# Epoch 20/100
# 153/153 - 1s - loss: 2.7110e-04 - val_loss: 2.5292e-04 - 1s/epoch - 9ms/step
# Epoch 21/100
# 153/153 - 2s - loss: 2.1562e-04 - val_loss: 1.7233e-04 - 2s/epoch - 10ms/step
# Epoch 22/100
# 153/153 - 1s - loss: 1.8186e-04 - val_loss: 1.3251e-04 - 1s/epoch - 9ms/step
# Epoch 23/100
# 153/153 - 1s - loss: 1.6107e-04 - val_loss: 1.1688e-04 - 1s/epoch - 8ms/step
# Epoch 24/100
# 153/153 - 1s - loss: 1.4842e-04 - val_loss: 1.1718e-04 - 1s/epoch - 8ms/step
# Epoch 25/100
# 153/153 - 1s - loss: 1.4497e-04 - val_loss: 1.3751e-04 - 1s/epoch - 8ms/step
# Epoch 26/100
# 153/153 - 1s - loss: 1.6466e-04 - val_loss: 1.8488e-04 - 1s/epoch - 8ms/step
# Epoch 27/100
# 153/153 - 1s - loss: 2.3705e-04 - val_loss: 2.6867e-04 - 1s/epoch - 8ms/step
# Epoch 28/100
# 153/153 - 1s - loss: 4.3915e-04 - val_loss: 4.2370e-04 - 1s/epoch - 8ms/step
# Epoch 29/100
# 153/153 - 1s - loss: 6.4653e-04 - val_loss: 9.1653e-04 - 1s/epoch - 8ms/step
# Epoch 30/100
# 153/153 - 1s - loss: 5.7458e-04 - val_loss: 6.5184e-04 - 1s/epoch - 8ms/step
# Epoch 31/100
# 153/153 - 1s - loss: 3.5602e-04 - val_loss: 3.8638e-04 - 1s/epoch - 8ms/step
# Epoch 32/100
# 153/153 - 1s - loss: 2.4609e-04 - val_loss: 2.2718e-04 - 1s/epoch - 8ms/step
# Epoch 33/100
# 153/153 - 1s - loss: 1.7891e-04 - val_loss: 1.2868e-04 - 1s/epoch - 8ms/step
# Epoch 34/100
# 153/153 - 1s - loss: 1.3695e-04 - val_loss: 8.4688e-05 - 1s/epoch - 8ms/step
# Epoch 35/100
# 153/153 - 1s - loss: 1.1401e-04 - val_loss: 6.7544e-05 - 1s/epoch - 8ms/step
# Epoch 36/100
# 153/153 - 1s - loss: 1.0033e-04 - val_loss: 5.9823e-05 - 1s/epoch - 8ms/step
# Epoch 37/100
# 153/153 - 1s - loss: 9.1087e-05 - val_loss: 5.5901e-05 - 1s/epoch - 8ms/step
# Epoch 38/100
# 153/153 - 1s - loss: 8.5298e-05 - val_loss: 5.7323e-05 - 1s/epoch - 8ms/step
# Epoch 39/100
# 153/153 - 1s - loss: 8.6649e-05 - val_loss: 7.1444e-05 - 1s/epoch - 8ms/step
# Epoch 40/100
# 153/153 - 1s - loss: 1.0434e-04 - val_loss: 1.1749e-04 - 1s/epoch - 9ms/step
# Epoch 41/100
# 153/153 - 1s - loss: 1.7823e-04 - val_loss: 2.6716e-04 - 1s/epoch - 8ms/step
# Epoch 42/100
# 153/153 - 1s - loss: 4.8302e-04 - val_loss: 6.8404e-04 - 1s/epoch - 8ms/step
# Epoch 43/100
# 153/153 - 1s - loss: 9.7396e-04 - val_loss: 0.0016 - 1s/epoch - 8ms/step
# Epoch 44/100
# 153/153 - 1s - loss: 7.7519e-04 - val_loss: 0.0010 - 1s/epoch - 8ms/step
# Epoch 45/100
# 153/153 - 1s - loss: 5.1936e-04 - val_loss: 6.9400e-04 - 1s/epoch - 8ms/step
# Epoch 46/100
# 153/153 - 1s - loss: 3.5401e-04 - val_loss: 4.1746e-04 - 1s/epoch - 8ms/step
# Epoch 47/100
# 153/153 - 1s - loss: 2.4184e-04 - val_loss: 2.4336e-04 - 1s/epoch - 8ms/step
# Epoch 48/100
# 153/153 - 1s - loss: 1.6994e-04 - val_loss: 1.3656e-04 - 1s/epoch - 8ms/step
# Epoch 49/100
# 153/153 - 1s - loss: 1.1918e-04 - val_loss: 7.3702e-05 - 1s/epoch - 8ms/step
# Epoch 50/100
# 153/153 - 1s - loss: 8.6661e-05 - val_loss: 4.4467e-05 - 1s/epoch - 8ms/step
# Epoch 51/100
# 153/153 - 1s - loss: 7.2354e-05 - val_loss: 3.1107e-05 - 1s/epoch - 8ms/step
# Epoch 52/100
# 153/153 - 1s - loss: 6.4784e-05 - val_loss: 2.5617e-05 - 1s/epoch - 8ms/step
# Epoch 53/100
# 153/153 - 1s - loss: 6.0380e-05 - val_loss: 2.3957e-05 - 1s/epoch - 8ms/step
# Epoch 54/100
# 153/153 - 1s - loss: 5.8566e-05 - val_loss: 2.4865e-05 - 1s/epoch - 8ms/step
# Epoch 55/100
# 153/153 - 1s - loss: 5.9918e-05 - val_loss: 2.9332e-05 - 1s/epoch - 8ms/step
# Epoch 56/100
# 153/153 - 1s - loss: 6.7264e-05 - val_loss: 4.1468e-05 - 1s/epoch - 8ms/step
# Epoch 57/100
# 153/153 - 1s - loss: 8.9011e-05 - val_loss: 7.0282e-05 - 1s/epoch - 8ms/step
# Epoch 58/100
# 153/153 - 1s - loss: 1.5254e-04 - val_loss: 1.2332e-04 - 1s/epoch - 8ms/step
# Epoch 59/100
# 153/153 - 1s - loss: 3.2706e-04 - val_loss: 3.2466e-04 - 1s/epoch - 8ms/step
# Epoch 60/100
# 153/153 - 1s - loss: 4.2051e-04 - val_loss: 5.6197e-04 - 1s/epoch - 8ms/step
# Epoch 61/100
# 153/153 - 1s - loss: 3.2665e-04 - val_loss: 3.1224e-04 - 1s/epoch - 9ms/step
# Epoch 62/100
# 153/153 - 1s - loss: 2.0347e-04 - val_loss: 1.6121e-04 - 1s/epoch - 8ms/step
# Epoch 63/100
# 153/153 - 1s - loss: 1.2946e-04 - val_loss: 8.1084e-05 - 1s/epoch - 8ms/step
# Epoch 64/100
# 153/153 - 1s - loss: 9.1207e-05 - val_loss: 4.8657e-05 - 1s/epoch - 9ms/step
# Epoch 65/100
# 153/153 - 1s - loss: 7.5299e-05 - val_loss: 4.1995e-05 - 1s/epoch - 8ms/step
# Epoch 66/100
# 153/153 - 1s - loss: 7.1937e-05 - val_loss: 4.6763e-05 - 1s/epoch - 8ms/step
# Epoch 67/100
# 153/153 - 1s - loss: 7.9029e-05 - val_loss: 5.8183e-05 - 1s/epoch - 8ms/step
# Epoch 68/100
# 153/153 - 1s - loss: 9.9582e-05 - val_loss: 8.1861e-05 - 1s/epoch - 8ms/step
# Epoch 69/100
# 153/153 - 1s - loss: 1.5532e-04 - val_loss: 1.1807e-04 - 1s/epoch - 8ms/step
# Epoch 70/100
# 153/153 - 1s - loss: 2.5883e-04 - val_loss: 2.5615e-04 - 1s/epoch - 8ms/step
# Epoch 71/100
# 153/153 - 1s - loss: 2.8310e-04 - val_loss: 2.9099e-04 - 1s/epoch - 8ms/step
# Epoch 72/100
# 153/153 - 1s - loss: 1.9853e-04 - val_loss: 1.6789e-04 - 1s/epoch - 8ms/step
# Epoch 73/100
# 153/153 - 1s - loss: 1.3281e-04 - val_loss: 9.0980e-05 - 1s/epoch - 8ms/step
# Epoch 74/100
# 153/153 - 1s - loss: 9.9120e-05 - val_loss: 5.7442e-05 - 1s/epoch - 8ms/step
# Epoch 75/100
# 153/153 - 1s - loss: 8.3414e-05 - val_loss: 5.4210e-05 - 1s/epoch - 8ms/step
# Epoch 76/100
# 153/153 - 1s - loss: 8.4169e-05 - val_loss: 7.0406e-05 - 1s/epoch - 9ms/step
# Epoch 77/100
# 153/153 - 1s - loss: 1.0600e-04 - val_loss: 8.0865e-05 - 1s/epoch - 8ms/step
# Epoch 78/100
# 153/153 - 1s - loss: 1.4243e-04 - val_loss: 1.1058e-04 - 1s/epoch - 8ms/step
# Epoch 79/100
# 153/153 - 1s - loss: 2.1198e-04 - val_loss: 1.8900e-04 - 1s/epoch - 8ms/step
# Epoch 80/100
# 153/153 - 1s - loss: 2.3395e-04 - val_loss: 2.1361e-04 - 1s/epoch - 8ms/step
# Epoch 81/100
# 153/153 - 1s - loss: 1.7005e-04 - val_loss: 1.2829e-04 - 1s/epoch - 8ms/step
# Epoch 82/100
# 153/153 - 1s - loss: 1.1539e-04 - val_loss: 7.5033e-05 - 1s/epoch - 8ms/step
# Epoch 83/100
# 153/153 - 1s - loss: 9.0063e-05 - val_loss: 5.2457e-05 - 1s/epoch - 8ms/step
# Epoch 84/100
# 153/153 - 1s - loss: 7.9125e-05 - val_loss: 5.0301e-05 - 1s/epoch - 8ms/step
# Epoch 85/100
# 153/153 - 1s - loss: 7.7938e-05 - val_loss: 5.4932e-05 - 1s/epoch - 8ms/step
# Epoch 86/100
# 153/153 - 1s - loss: 8.4837e-05 - val_loss: 6.6447e-05 - 1s/epoch - 8ms/step
# Epoch 87/100
# 153/153 - 1s - loss: 1.0492e-04 - val_loss: 9.4731e-05 - 1s/epoch - 8ms/step
# Epoch 88/100
# 153/153 - 1s - loss: 1.6555e-04 - val_loss: 1.3241e-04 - 1s/epoch - 8ms/step
# Epoch 89/100
# 153/153 - 1s - loss: 2.6083e-04 - val_loss: 2.7006e-04 - 1s/epoch - 8ms/step
# Epoch 90/100
# 153/153 - 1s - loss: 2.2843e-04 - val_loss: 2.0186e-04 - 1s/epoch - 8ms/step
# Epoch 91/100
# 153/153 - 1s - loss: 1.4182e-04 - val_loss: 1.0006e-04 - 1s/epoch - 8ms/step
# Epoch 92/100
# 153/153 - 1s - loss: 9.5347e-05 - val_loss: 5.5113e-05 - 1s/epoch - 8ms/step
# Epoch 93/100
# 153/153 - 1s - loss: 7.3373e-05 - val_loss: 3.9960e-05 - 1s/epoch - 8ms/step
# Epoch 94/100
# 153/153 - 1s - loss: 6.5125e-05 - val_loss: 3.5288e-05 - 1s/epoch - 8ms/step
# Epoch 95/100
# 153/153 - 1s - loss: 6.1982e-05 - val_loss: 3.4645e-05 - 1s/epoch - 8ms/step
# Epoch 96/100
# 153/153 - 1s - loss: 6.1463e-05 - val_loss: 3.7517e-05 - 1s/epoch - 8ms/step
# Epoch 97/100
# 153/153 - 1s - loss: 6.5281e-05 - val_loss: 4.6098e-05 - 1s/epoch - 8ms/step
# Epoch 98/100
# 153/153 - 1s - loss: 7.7647e-05 - val_loss: 6.8257e-05 - 1s/epoch - 8ms/step
# Epoch 99/100
# 153/153 - 1s - loss: 1.1545e-04 - val_loss: 1.0688e-04 - 1s/epoch - 8ms/step
# Epoch 100/100
# 153/153 - 1s - loss: 2.3469e-04 - val_loss: 2.4584e-04 - 1s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-03 10:12:08.055573: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:12:08.136111: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:12:08.257706: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:12:09.856108: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:12:09.888030: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 - 3s - loss: 0.0011 - val_loss: 0.0066 - 3s/epoch - 16ms/step
# Epoch 2/100
# 153/153 - 1s - loss: 0.0025 - val_loss: 0.0076 - 1s/epoch - 8ms/step
# Epoch 3/100
# 153/153 - 1s - loss: 0.0022 - val_loss: 0.0058 - 1s/epoch - 8ms/step
# Epoch 4/100
# 153/153 - 1s - loss: 0.0015 - val_loss: 0.0032 - 1s/epoch - 8ms/step
# Epoch 5/100
# 153/153 - 1s - loss: 9.3925e-04 - val_loss: 0.0017 - 1s/epoch - 8ms/step
# Epoch 6/100
# 153/153 - 1s - loss: 6.0001e-04 - val_loss: 9.3120e-04 - 1s/epoch - 9ms/step
# Epoch 7/100
# 153/153 - 1s - loss: 4.2297e-04 - val_loss: 5.7994e-04 - 1s/epoch - 8ms/step
# Epoch 8/100
# 153/153 - 1s - loss: 3.1796e-04 - val_loss: 3.9043e-04 - 1s/epoch - 8ms/step
# Epoch 9/100
# 153/153 - 1s - loss: 2.4035e-04 - val_loss: 2.5612e-04 - 1s/epoch - 8ms/step
# Epoch 10/100
# 153/153 - 1s - loss: 1.7920e-04 - val_loss: 1.5391e-04 - 1s/epoch - 8ms/step
# Epoch 11/100
# 153/153 - 1s - loss: 1.3820e-04 - val_loss: 9.5442e-05 - 1s/epoch - 8ms/step
# Epoch 12/100
# 153/153 - 1s - loss: 1.1745e-04 - val_loss: 7.3752e-05 - 1s/epoch - 8ms/step
# Epoch 13/100
# 153/153 - 1s - loss: 1.1139e-04 - val_loss: 7.3485e-05 - 1s/epoch - 8ms/step
# Epoch 14/100
# 153/153 - 1s - loss: 1.1745e-04 - val_loss: 8.9719e-05 - 1s/epoch - 8ms/step
# Epoch 15/100
# 153/153 - 1s - loss: 1.4187e-04 - val_loss: 1.2812e-04 - 1s/epoch - 8ms/step
# Epoch 16/100
# 153/153 - 1s - loss: 2.0812e-04 - val_loss: 1.9910e-04 - 1s/epoch - 8ms/step
# Epoch 17/100
# 153/153 - 1s - loss: 3.7579e-04 - val_loss: 3.1832e-04 - 1s/epoch - 8ms/step
# Epoch 18/100
# 153/153 - 1s - loss: 6.4451e-04 - val_loss: 8.6598e-04 - 1s/epoch - 8ms/step
# Epoch 19/100
# 153/153 - 1s - loss: 6.6668e-04 - val_loss: 0.0010 - 1s/epoch - 8ms/step
# Epoch 20/100
# 153/153 - 1s - loss: 5.6726e-04 - val_loss: 7.3606e-04 - 1s/epoch - 8ms/step
# Epoch 21/100
# 153/153 - 1s - loss: 4.0557e-04 - val_loss: 4.8404e-04 - 1s/epoch - 8ms/step
# Epoch 22/100
# 153/153 - 1s - loss: 2.8413e-04 - val_loss: 3.0542e-04 - 1s/epoch - 8ms/step
# Epoch 23/100
# 153/153 - 1s - loss: 2.0710e-04 - val_loss: 1.8576e-04 - 1s/epoch - 8ms/step
# Epoch 24/100
# 153/153 - 1s - loss: 1.5885e-04 - val_loss: 1.2240e-04 - 1s/epoch - 8ms/step
# Epoch 25/100
# 153/153 - 1s - loss: 1.3328e-04 - val_loss: 9.5549e-05 - 1s/epoch - 8ms/step
# Epoch 26/100
# 153/153 - 1s - loss: 1.2052e-04 - val_loss: 8.9280e-05 - 1s/epoch - 8ms/step
# Epoch 27/100
# 153/153 - 1s - loss: 1.1684e-04 - val_loss: 9.6778e-05 - 1s/epoch - 8ms/step
# Epoch 28/100
# 153/153 - 1s - loss: 1.2400e-04 - val_loss: 1.2441e-04 - 1s/epoch - 8ms/step
# Epoch 29/100
# 153/153 - 1s - loss: 1.5527e-04 - val_loss: 2.0148e-04 - 1s/epoch - 8ms/step
# Epoch 30/100
# 153/153 - 1s - loss: 2.6680e-04 - val_loss: 3.5272e-04 - 1s/epoch - 8ms/step
# Epoch 31/100
# 153/153 - 1s - loss: 6.6813e-04 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 32/100
# 153/153 - 1s - loss: 7.4250e-04 - val_loss: 0.0011 - 1s/epoch - 8ms/step
# Epoch 33/100
# 153/153 - 1s - loss: 5.3865e-04 - val_loss: 6.7113e-04 - 1s/epoch - 8ms/step
# Epoch 34/100
# 153/153 - 1s - loss: 3.6856e-04 - val_loss: 4.2814e-04 - 1s/epoch - 8ms/step
# Epoch 35/100
# 153/153 - 1s - loss: 2.5190e-04 - val_loss: 2.5077e-04 - 1s/epoch - 8ms/step
# Epoch 36/100
# 153/153 - 1s - loss: 1.6833e-04 - val_loss: 1.3541e-04 - 1s/epoch - 8ms/step
# Epoch 37/100
# 153/153 - 1s - loss: 1.1767e-04 - val_loss: 7.7939e-05 - 1s/epoch - 8ms/step
# Epoch 38/100
# 153/153 - 1s - loss: 9.3723e-05 - val_loss: 5.3719e-05 - 1s/epoch - 8ms/step
# Epoch 39/100
# 153/153 - 1s - loss: 8.1701e-05 - val_loss: 4.4006e-05 - 1s/epoch - 8ms/step
# Epoch 40/100
# 153/153 - 1s - loss: 7.4178e-05 - val_loss: 4.0882e-05 - 1s/epoch - 8ms/step
# Epoch 41/100
# 153/153 - 1s - loss: 6.9504e-05 - val_loss: 4.1073e-05 - 1s/epoch - 8ms/step
# Epoch 42/100
# 153/153 - 1s - loss: 6.7880e-05 - val_loss: 4.5728e-05 - 1s/epoch - 8ms/step
# Epoch 43/100
# 153/153 - 1s - loss: 7.2348e-05 - val_loss: 6.0624e-05 - 1s/epoch - 8ms/step
# Epoch 44/100
# 153/153 - 1s - loss: 9.2237e-05 - val_loss: 1.0234e-04 - 1s/epoch - 8ms/step
# Epoch 45/100
# 153/153 - 1s - loss: 1.6114e-04 - val_loss: 2.1148e-04 - 1s/epoch - 8ms/step
# Epoch 46/100
# 153/153 - 1s - loss: 3.9673e-04 - val_loss: 4.3513e-04 - 1s/epoch - 8ms/step
# Epoch 47/100
# 153/153 - 1s - loss: 6.8232e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 48/100
# 153/153 - 1s - loss: 6.0789e-04 - val_loss: 6.3612e-04 - 1s/epoch - 8ms/step
# Epoch 49/100
# 153/153 - 1s - loss: 3.4604e-04 - val_loss: 3.4916e-04 - 1s/epoch - 8ms/step
# Epoch 50/100
# 153/153 - 1s - loss: 2.1804e-04 - val_loss: 1.8997e-04 - 1s/epoch - 8ms/step
# Epoch 51/100
# 153/153 - 1s - loss: 1.3910e-04 - val_loss: 9.8249e-05 - 1s/epoch - 8ms/step
# Epoch 52/100
# 153/153 - 1s - loss: 9.2948e-05 - val_loss: 5.4014e-05 - 1s/epoch - 8ms/step
# Epoch 53/100
# 153/153 - 1s - loss: 7.3427e-05 - val_loss: 3.6775e-05 - 1s/epoch - 8ms/step
# Epoch 54/100
# 153/153 - 1s - loss: 6.4696e-05 - val_loss: 3.0535e-05 - 1s/epoch - 8ms/step
# Epoch 55/100
# 153/153 - 1s - loss: 6.0185e-05 - val_loss: 2.8588e-05 - 1s/epoch - 8ms/step
# Epoch 56/100
# 153/153 - 1s - loss: 5.7825e-05 - val_loss: 2.9473e-05 - 1s/epoch - 8ms/step
# Epoch 57/100
# 153/153 - 1s - loss: 5.7894e-05 - val_loss: 3.3641e-05 - 1s/epoch - 8ms/step
# Epoch 58/100
# 153/153 - 1s - loss: 6.2585e-05 - val_loss: 4.5723e-05 - 1s/epoch - 8ms/step
# Epoch 59/100
# 153/153 - 1s - loss: 7.8771e-05 - val_loss: 7.7353e-05 - 1s/epoch - 8ms/step
# Epoch 60/100
# 153/153 - 1s - loss: 1.2629e-04 - val_loss: 1.6366e-04 - 1s/epoch - 8ms/step
# Epoch 61/100
# 153/153 - 1s - loss: 3.1267e-04 - val_loss: 4.0997e-04 - 1s/epoch - 8ms/step
# Epoch 62/100
# 153/153 - 1s - loss: 8.2222e-04 - val_loss: 0.0014 - 1s/epoch - 8ms/step
# Epoch 63/100
# 153/153 - 1s - loss: 7.0308e-04 - val_loss: 8.0782e-04 - 1s/epoch - 8ms/step
# Epoch 64/100
# 153/153 - 1s - loss: 3.6265e-04 - val_loss: 5.0609e-04 - 1s/epoch - 8ms/step
# Epoch 65/100
# 153/153 - 1s - loss: 2.4192e-04 - val_loss: 2.7315e-04 - 1s/epoch - 8ms/step
# Epoch 66/100
# 153/153 - 1s - loss: 1.6400e-04 - val_loss: 1.4068e-04 - 1s/epoch - 8ms/step
# Epoch 67/100
# 153/153 - 1s - loss: 1.1259e-04 - val_loss: 8.0202e-05 - 1s/epoch - 8ms/step
# Epoch 68/100
# 153/153 - 1s - loss: 8.2749e-05 - val_loss: 4.8522e-05 - 1s/epoch - 8ms/step
# Epoch 69/100
# 153/153 - 1s - loss: 6.5189e-05 - val_loss: 3.1117e-05 - 1s/epoch - 8ms/step
# Epoch 70/100
# 153/153 - 1s - loss: 5.4883e-05 - val_loss: 2.2526e-05 - 1s/epoch - 8ms/step
# Epoch 71/100
# 153/153 - 1s - loss: 4.9685e-05 - val_loss: 1.9140e-05 - 1s/epoch - 8ms/step
# Epoch 72/100
# 153/153 - 1s - loss: 4.7837e-05 - val_loss: 1.8516e-05 - 1s/epoch - 8ms/step
# Epoch 73/100
# 153/153 - 1s - loss: 4.8664e-05 - val_loss: 2.0031e-05 - 1s/epoch - 8ms/step
# Epoch 74/100
# 153/153 - 1s - loss: 5.3154e-05 - val_loss: 2.5021e-05 - 1s/epoch - 8ms/step
# Epoch 75/100
# 153/153 - 1s - loss: 6.4968e-05 - val_loss: 3.7320e-05 - 1s/epoch - 8ms/step
# Epoch 76/100
# 153/153 - 1s - loss: 9.4478e-05 - val_loss: 6.2919e-05 - 1s/epoch - 8ms/step
# Epoch 77/100
# 153/153 - 1s - loss: 1.6950e-04 - val_loss: 1.2227e-04 - 1s/epoch - 8ms/step
# Epoch 78/100
# 153/153 - 1s - loss: 2.8073e-04 - val_loss: 3.3063e-04 - 1s/epoch - 8ms/step
# Epoch 79/100
# 153/153 - 1s - loss: 2.5718e-04 - val_loss: 2.7471e-04 - 1s/epoch - 8ms/step
# Epoch 80/100
# 153/153 - 1s - loss: 1.7761e-04 - val_loss: 1.5449e-04 - 1s/epoch - 8ms/step
# Epoch 81/100
# 153/153 - 1s - loss: 1.1773e-04 - val_loss: 8.2913e-05 - 1s/epoch - 8ms/step
# Epoch 82/100
# 153/153 - 1s - loss: 8.5857e-05 - val_loss: 5.3182e-05 - 1s/epoch - 8ms/step
# Epoch 83/100
# 153/153 - 1s - loss: 7.3739e-05 - val_loss: 5.8260e-05 - 1s/epoch - 8ms/step
# Epoch 84/100
# 153/153 - 1s - loss: 8.5161e-05 - val_loss: 7.9297e-05 - 1s/epoch - 8ms/step
# Epoch 85/100
# 153/153 - 1s - loss: 1.2563e-04 - val_loss: 1.0630e-04 - 1s/epoch - 8ms/step
# Epoch 86/100
# 153/153 - 1s - loss: 1.9907e-04 - val_loss: 1.9210e-04 - 1s/epoch - 8ms/step
# Epoch 87/100
# 153/153 - 1s - loss: 1.9595e-04 - val_loss: 1.7289e-04 - 1s/epoch - 8ms/step
# Epoch 88/100
# 153/153 - 1s - loss: 1.3350e-04 - val_loss: 9.9135e-05 - 1s/epoch - 8ms/step
# Epoch 89/100
# 153/153 - 1s - loss: 9.3679e-05 - val_loss: 5.9670e-05 - 1s/epoch - 8ms/step
# Epoch 90/100
# 153/153 - 1s - loss: 7.5012e-05 - val_loss: 4.5218e-05 - 1s/epoch - 8ms/step
# Epoch 91/100
# 153/153 - 1s - loss: 6.8454e-05 - val_loss: 4.4195e-05 - 1s/epoch - 8ms/step
# Epoch 92/100
# 153/153 - 1s - loss: 6.9329e-05 - val_loss: 5.0270e-05 - 1s/epoch - 8ms/step
# Epoch 93/100
# 153/153 - 1s - loss: 7.8181e-05 - val_loss: 6.3772e-05 - 1s/epoch - 8ms/step
# Epoch 94/100
# 153/153 - 1s - loss: 1.0188e-04 - val_loss: 9.1239e-05 - 1s/epoch - 8ms/step
# Epoch 95/100
# 153/153 - 1s - loss: 1.6603e-04 - val_loss: 1.4523e-04 - 1s/epoch - 8ms/step
# Epoch 96/100
# 153/153 - 1s - loss: 2.6679e-04 - val_loss: 2.9577e-04 - 1s/epoch - 8ms/step
# Epoch 97/100
# 153/153 - 1s - loss: 2.0031e-04 - val_loss: 1.7038e-04 - 1s/epoch - 8ms/step
# Epoch 98/100
# 153/153 - 1s - loss: 1.1878e-04 - val_loss: 8.0940e-05 - 1s/epoch - 8ms/step
# Epoch 99/100
# 153/153 - 1s - loss: 7.7632e-05 - val_loss: 4.5296e-05 - 1s/epoch - 8ms/step
# Epoch 100/100
# 153/153 - 1s - loss: 6.1293e-05 - val_loss: 3.2858e-05 - 1s/epoch - 8ms/step
# Epoch 1/100
# 2023-04-03 10:14:15.103791: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:14:15.184895: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:14:15.306650: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:14:16.906535: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:14:16.938239: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 - 3s - loss: 6.8216e-04 - val_loss: 0.0022 - 3s/epoch - 16ms/step
# Epoch 2/100
# 153/153 - 1s - loss: 0.0037 - val_loss: 0.0103 - 1s/epoch - 8ms/step
# Epoch 3/100
# 153/153 - 1s - loss: 0.0036 - val_loss: 0.0119 - 1s/epoch - 8ms/step
# Epoch 4/100
# 153/153 - 1s - loss: 0.0033 - val_loss: 0.0084 - 1s/epoch - 8ms/step
# Epoch 5/100
# 153/153 - 1s - loss: 0.0022 - val_loss: 0.0045 - 1s/epoch - 9ms/step
# Epoch 6/100
# 153/153 - 1s - loss: 0.0012 - val_loss: 0.0020 - 1s/epoch - 8ms/step
# Epoch 7/100
# 153/153 - 1s - loss: 6.1855e-04 - val_loss: 8.7535e-04 - 1s/epoch - 8ms/step
# Epoch 8/100
# 153/153 - 1s - loss: 3.6941e-04 - val_loss: 4.5201e-04 - 1s/epoch - 8ms/step
# Epoch 9/100
# 153/153 - 1s - loss: 2.5371e-04 - val_loss: 2.7135e-04 - 1s/epoch - 8ms/step
# Epoch 10/100
# 153/153 - 1s - loss: 1.8287e-04 - val_loss: 1.6479e-04 - 1s/epoch - 8ms/step
# Epoch 11/100
# 153/153 - 1s - loss: 1.3324e-04 - val_loss: 9.3151e-05 - 1s/epoch - 8ms/step
# Epoch 12/100
# 153/153 - 1s - loss: 1.0358e-04 - val_loss: 5.6842e-05 - 1s/epoch - 8ms/step
# Epoch 13/100
# 153/153 - 1s - loss: 9.1409e-05 - val_loss: 4.5271e-05 - 1s/epoch - 8ms/step
# Epoch 14/100
# 153/153 - 1s - loss: 9.1657e-05 - val_loss: 4.7864e-05 - 1s/epoch - 8ms/step
# Epoch 15/100
# 153/153 - 1s - loss: 1.0415e-04 - val_loss: 6.4978e-05 - 1s/epoch - 8ms/step
# Epoch 16/100
# 153/153 - 1s - loss: 1.3858e-04 - val_loss: 1.0722e-04 - 1s/epoch - 8ms/step
# Epoch 17/100
# 153/153 - 1s - loss: 2.2756e-04 - val_loss: 1.9214e-04 - 1s/epoch - 8ms/step
# Epoch 18/100
# 153/153 - 1s - loss: 4.5838e-04 - val_loss: 3.7518e-04 - 1s/epoch - 8ms/step
# Epoch 19/100
# 153/153 - 1s - loss: 8.0376e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 20/100
# 153/153 - 1s - loss: 8.4243e-04 - val_loss: 0.0013 - 1s/epoch - 8ms/step
# Epoch 21/100
# 153/153 - 1s - loss: 7.0235e-04 - val_loss: 9.6936e-04 - 1s/epoch - 8ms/step
# Epoch 22/100
# 153/153 - 1s - loss: 5.2593e-04 - val_loss: 6.0873e-04 - 1s/epoch - 8ms/step
# Epoch 23/100
# 153/153 - 1s - loss: 3.4143e-04 - val_loss: 3.6018e-04 - 1s/epoch - 8ms/step
# Epoch 24/100
# 153/153 - 1s - loss: 2.2712e-04 - val_loss: 1.9532e-04 - 1s/epoch - 8ms/step
# Epoch 25/100
# 153/153 - 1s - loss: 1.5814e-04 - val_loss: 1.0884e-04 - 1s/epoch - 8ms/step
# Epoch 26/100
# 153/153 - 1s - loss: 1.2238e-04 - val_loss: 7.5276e-05 - 1s/epoch - 8ms/step
# Epoch 27/100
# 153/153 - 1s - loss: 1.0638e-04 - val_loss: 6.5306e-05 - 1s/epoch - 8ms/step
# Epoch 28/100
# 153/153 - 1s - loss: 1.0034e-04 - val_loss: 6.7040e-05 - 1s/epoch - 8ms/step
# Epoch 29/100
# 153/153 - 1s - loss: 1.0215e-04 - val_loss: 7.9315e-05 - 1s/epoch - 8ms/step
# Epoch 30/100
# 153/153 - 1s - loss: 1.1670e-04 - val_loss: 1.1089e-04 - 1s/epoch - 8ms/step
# Epoch 31/100
# 153/153 - 1s - loss: 1.6294e-04 - val_loss: 1.8637e-04 - 1s/epoch - 8ms/step
# Epoch 32/100
# 153/153 - 1s - loss: 2.9257e-04 - val_loss: 3.5505e-04 - 1s/epoch - 8ms/step
# Epoch 33/100
# 153/153 - 1s - loss: 7.8237e-04 - val_loss: 0.0014 - 1s/epoch - 8ms/step
# Epoch 34/100
# 153/153 - 1s - loss: 0.0012 - val_loss: 0.0020 - 1s/epoch - 8ms/step
# Epoch 35/100
# 153/153 - 1s - loss: 9.4028e-04 - val_loss: 0.0012 - 1s/epoch - 8ms/step
# Epoch 36/100
# 153/153 - 1s - loss: 5.6074e-04 - val_loss: 7.3274e-04 - 1s/epoch - 8ms/step
# Epoch 37/100
# 153/153 - 1s - loss: 3.7457e-04 - val_loss: 4.1489e-04 - 1s/epoch - 8ms/step
# Epoch 38/100
# 153/153 - 1s - loss: 2.4685e-04 - val_loss: 2.1968e-04 - 1s/epoch - 8ms/step
# Epoch 39/100
# 153/153 - 1s - loss: 1.6098e-04 - val_loss: 1.1720e-04 - 1s/epoch - 8ms/step
# Epoch 40/100
# 153/153 - 1s - loss: 1.0806e-04 - val_loss: 6.4077e-05 - 1s/epoch - 8ms/step
# Epoch 41/100
# 153/153 - 1s - loss: 8.0466e-05 - val_loss: 3.7253e-05 - 1s/epoch - 8ms/step
# Epoch 42/100
# 153/153 - 1s - loss: 6.6414e-05 - val_loss: 2.6078e-05 - 1s/epoch - 8ms/step
# Epoch 43/100
# 153/153 - 1s - loss: 6.0242e-05 - val_loss: 2.2411e-05 - 1s/epoch - 8ms/step
# Epoch 44/100
# 153/153 - 1s - loss: 5.8750e-05 - val_loss: 2.2533e-05 - 1s/epoch - 8ms/step
# Epoch 45/100
# 153/153 - 1s - loss: 6.1484e-05 - val_loss: 2.6428e-05 - 1s/epoch - 8ms/step
# Epoch 46/100
# 153/153 - 1s - loss: 7.0985e-05 - val_loss: 3.7763e-05 - 1s/epoch - 8ms/step
# Epoch 47/100
# 153/153 - 1s - loss: 9.5660e-05 - val_loss: 6.5483e-05 - 1s/epoch - 8ms/step
# Epoch 48/100
# 153/153 - 1s - loss: 1.6210e-04 - val_loss: 1.2298e-04 - 1s/epoch - 8ms/step
# Epoch 49/100
# 153/153 - 1s - loss: 3.4193e-04 - val_loss: 3.0997e-04 - 1s/epoch - 8ms/step
# Epoch 50/100
# 153/153 - 1s - loss: 5.1666e-04 - val_loss: 7.7392e-04 - 1s/epoch - 8ms/step
# Epoch 51/100
# 153/153 - 1s - loss: 4.6125e-04 - val_loss: 5.0892e-04 - 1s/epoch - 8ms/step
# Epoch 52/100
# 153/153 - 1s - loss: 3.0167e-04 - val_loss: 2.2432e-04 - 1s/epoch - 8ms/step
# Epoch 53/100
# 153/153 - 1s - loss: 1.5312e-04 - val_loss: 1.0261e-04 - 1s/epoch - 8ms/step
# Epoch 54/100
# 153/153 - 1s - loss: 1.0231e-04 - val_loss: 5.2347e-05 - 1s/epoch - 9ms/step
# Epoch 55/100
# 153/153 - 1s - loss: 7.8805e-05 - val_loss: 4.6099e-05 - 1s/epoch - 8ms/step
# Epoch 56/100
# 153/153 - 1s - loss: 7.8698e-05 - val_loss: 6.0236e-05 - 1s/epoch - 8ms/step
# Epoch 57/100
# 153/153 - 1s - loss: 9.8656e-05 - val_loss: 6.8632e-05 - 1s/epoch - 8ms/step
# Epoch 58/100
# 153/153 - 1s - loss: 1.3073e-04 - val_loss: 1.0132e-04 - 1s/epoch - 8ms/step
# Epoch 59/100
# 153/153 - 1s - loss: 2.2124e-04 - val_loss: 2.0421e-04 - 1s/epoch - 8ms/step
# Epoch 60/100
# 153/153 - 1s - loss: 4.0958e-04 - val_loss: 5.6449e-04 - 1s/epoch - 8ms/step
# Epoch 61/100
# 153/153 - 1s - loss: 3.9770e-04 - val_loss: 3.5630e-04 - 1s/epoch - 8ms/step
# Epoch 62/100
# 153/153 - 1s - loss: 2.1736e-04 - val_loss: 1.4335e-04 - 1s/epoch - 8ms/step
# Epoch 63/100
# 153/153 - 1s - loss: 1.2201e-04 - val_loss: 6.4328e-05 - 1s/epoch - 8ms/step
# Epoch 64/100
# 153/153 - 1s - loss: 7.9321e-05 - val_loss: 3.4933e-05 - 1s/epoch - 8ms/step
# Epoch 65/100
# 153/153 - 1s - loss: 6.4612e-05 - val_loss: 2.5942e-05 - 1s/epoch - 8ms/step
# Epoch 66/100
# 153/153 - 1s - loss: 5.9980e-05 - val_loss: 2.4447e-05 - 1s/epoch - 8ms/step
# Epoch 67/100
# 153/153 - 1s - loss: 6.0723e-05 - val_loss: 2.7824e-05 - 1s/epoch - 8ms/step
# Epoch 68/100
# 153/153 - 1s - loss: 6.7833e-05 - val_loss: 3.9225e-05 - 1s/epoch - 8ms/step
# Epoch 69/100
# 153/153 - 1s - loss: 8.9140e-05 - val_loss: 6.5848e-05 - 1s/epoch - 8ms/step
# Epoch 70/100
# 153/153 - 1s - loss: 1.4907e-04 - val_loss: 1.2432e-04 - 1s/epoch - 8ms/step
# Epoch 71/100
# 153/153 - 1s - loss: 3.5178e-04 - val_loss: 4.5445e-04 - 1s/epoch - 8ms/step
# Epoch 72/100
# 153/153 - 1s - loss: 5.4716e-04 - val_loss: 7.3621e-04 - 1s/epoch - 8ms/step
# Epoch 73/100
# 153/153 - 1s - loss: 3.9453e-04 - val_loss: 2.3109e-04 - 1s/epoch - 8ms/step
# Epoch 74/100
# 153/153 - 1s - loss: 1.8983e-04 - val_loss: 1.0663e-04 - 1s/epoch - 8ms/step
# Epoch 75/100
# 153/153 - 1s - loss: 1.1545e-04 - val_loss: 5.5851e-05 - 1s/epoch - 8ms/step
# Epoch 76/100
# 153/153 - 1s - loss: 7.9481e-05 - val_loss: 3.1377e-05 - 1s/epoch - 8ms/step
# Epoch 77/100
# 153/153 - 1s - loss: 6.0678e-05 - val_loss: 2.0327e-05 - 1s/epoch - 8ms/step
# Epoch 78/100
# 153/153 - 1s - loss: 5.2261e-05 - val_loss: 1.6421e-05 - 1s/epoch - 8ms/step
# Epoch 79/100
# 153/153 - 1s - loss: 4.9797e-05 - val_loss: 1.5465e-05 - 1s/epoch - 8ms/step
# Epoch 80/100
# 153/153 - 1s - loss: 5.0514e-05 - val_loss: 1.6300e-05 - 1s/epoch - 8ms/step
# Epoch 81/100
# 153/153 - 1s - loss: 5.5118e-05 - val_loss: 1.9683e-05 - 1s/epoch - 8ms/step
# Epoch 82/100
# 153/153 - 1s - loss: 6.6698e-05 - val_loss: 2.8825e-05 - 1s/epoch - 8ms/step
# Epoch 83/100
# 153/153 - 1s - loss: 9.4598e-05 - val_loss: 5.0204e-05 - 1s/epoch - 8ms/step
# Epoch 84/100
# 153/153 - 1s - loss: 1.6402e-04 - val_loss: 1.0513e-04 - 1s/epoch - 8ms/step
# Epoch 85/100
# 153/153 - 1s - loss: 2.8191e-04 - val_loss: 2.9157e-04 - 1s/epoch - 8ms/step
# Epoch 86/100
# 153/153 - 1s - loss: 2.6467e-04 - val_loss: 2.4130e-04 - 1s/epoch - 8ms/step
# Epoch 87/100
# 153/153 - 1s - loss: 1.6965e-04 - val_loss: 1.0418e-04 - 1s/epoch - 8ms/step
# Epoch 88/100
# 153/153 - 1s - loss: 9.8175e-05 - val_loss: 4.8347e-05 - 1s/epoch - 8ms/step
# Epoch 89/100
# 153/153 - 1s - loss: 7.0321e-05 - val_loss: 3.4449e-05 - 1s/epoch - 8ms/step
# Epoch 90/100
# 153/153 - 1s - loss: 6.4830e-05 - val_loss: 3.6923e-05 - 1s/epoch - 8ms/step
# Epoch 91/100
# 153/153 - 1s - loss: 7.2579e-05 - val_loss: 4.0415e-05 - 1s/epoch - 8ms/step
# Epoch 92/100
# 153/153 - 1s - loss: 8.7948e-05 - val_loss: 5.0172e-05 - 1s/epoch - 8ms/step
# Epoch 93/100
# 153/153 - 1s - loss: 1.2334e-04 - val_loss: 7.8081e-05 - 1s/epoch - 8ms/step
# Epoch 94/100
# 153/153 - 1s - loss: 1.9442e-04 - val_loss: 1.4835e-04 - 1s/epoch - 8ms/step
# Epoch 95/100
# 153/153 - 1s - loss: 2.1864e-04 - val_loss: 1.6677e-04 - 1s/epoch - 8ms/step
# Epoch 96/100
# 153/153 - 1s - loss: 1.4884e-04 - val_loss: 8.5254e-05 - 1s/epoch - 8ms/step
# Epoch 97/100
# 153/153 - 1s - loss: 9.2498e-05 - val_loss: 4.3079e-05 - 1s/epoch - 8ms/step
# Epoch 98/100
# 153/153 - 1s - loss: 6.9511e-05 - val_loss: 2.9856e-05 - 1s/epoch - 8ms/step
# Epoch 99/100
# 153/153 - 1s - loss: 6.2943e-05 - val_loss: 2.7591e-05 - 1s/epoch - 8ms/step
# Epoch 100/100
# 153/153 - 1s - loss: 6.4270e-05 - val_loss: 3.1431e-05 - 1s/epoch - 8ms/step

# %%
i=0
wb3 = Workbook()
ws3 = wb3.active
for m in models3:
    # make a prediction
    test_x2 = test_X
    yhat = LSTMUnit.predict(test_x2, m)
    inv_yhat = Preprocessing.inverse_scaler(yhat, scaler)
    inv_y = Preprocessing.inverse_scaler(test_y.reshape(-1,1), scaler)
    print(hyperparam3[i])
    print("Epoch: "+ str(lstms3[i].params['epochs']))
    print("Neurons: "+str(m.layers[0].units))
    i = i+1
    ws3['A'+str(i)] = 'LSTM'
    ws3['B'+str(i)] = hyperparam3[i-1][0]
    ws3['C'+str(i)] = hyperparam3[i-1][1]
    ws3['D'+str(i)] = hyperparam3[i-1][2]
    print('RMSE')
    print(Evaluation.rmse(inv_y,inv_yhat)[0])
    ws3['E'+str(i)] = Evaluation.rmse(inv_y,inv_yhat)[0]
    print('MAE')
    print(Evaluation.mae(inv_y,inv_yhat)[0])
    ws3['F'+str(i)] = Evaluation.mae(inv_y,inv_yhat)[0]
    print('MAPE')
    print(Evaluation.mape(inv_y,inv_yhat)[0])
    ws3['G'+str(i)] = Evaluation.mape(inv_y,inv_yhat)[0]
    LSTMUnit.save_model(m, 0, 'ETH',hyperparam3[i-1])
wb3.save('LSTM_ETH_result3.xlsx')
# Out:
#  10/153 [>.............................] - ETA: 0s
# 2023-04-03 10:16:23.854435: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:16:23.888854: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (128, 25, 50)
# Epoch: 25
# Neurons: 50
# RMSE
# 58.2804937743834
# MAE
# 52.128262713526865
# MAPE
# 4.031406249701368
#  33/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:16:24.622276: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:16:24.648528: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (128, 25, 60)
# Epoch: 25
# Neurons: 60
# RMSE
# 49.741738530149235
# MAE
# 43.886712650237385
# MAPE
# 3.40089226626515
#  32/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:16:25.311914: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:16:25.339109: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (128, 25, 100)
# Epoch: 25
# Neurons: 100
# RMSE
# 53.26976354783527
# MAE
# 48.12594446243642
# MAPE
# 3.695938603148773
#  33/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:16:25.989254: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:16:26.016049: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (128, 50, 50)
# Epoch: 50
# Neurons: 50
# RMSE
# 26.12279912378093
# MAE
# 21.24079489015018
# MAPE
# 1.624595637561679
#  33/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:16:26.683214: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:16:26.709407: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (128, 50, 60)
# Epoch: 50
# Neurons: 60
# RMSE
# 32.30055087430374
# MAE
# 27.72760390763103
# MAPE
# 2.1259643188127546
#  30/153 [====>.........................] - ETA: 0s
# 2023-04-03 10:16:27.376468: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:16:27.402926: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (128, 50, 100)
# Epoch: 50
# Neurons: 100
# RMSE
# 109.8367756249745
# MAE
# 105.66663325024169
# MAPE
# 7.975494631027449
#  31/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:16:28.060796: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:16:28.087125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (128, 100, 50)
# Epoch: 100
# Neurons: 50
# RMSE
# 74.47837616922564
# MAE
# 69.29661769109332
# MAPE
# 5.309192367137765
#  31/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:16:28.759979: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:16:28.785870: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (128, 100, 60)
# Epoch: 100
# Neurons: 60
# RMSE
# 27.228336059957037
# MAE
# 22.924673663696556
# MAPE
# 1.7667549346281324
#  35/153 [=====>........................] - ETA: 0s
# 2023-04-03 10:16:29.461735: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:16:29.487715: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 1s 3ms/step
# (128, 100, 100)
# Epoch: 100
# Neurons: 100
# RMSE
# 26.630500636556157
# MAE
# 22.019442450665416
# MAPE
# 1.7040227390688234

# %%
test_X
# Out:
# array([[[0.35243332],
#         [0.35114703],
#         [0.35150913],
#         [0.35544379],
#         [0.3500881 ]],
#
#        [[0.35114703],
#         [0.35150913],
#         [0.35544379],
#         [0.3500881 ],
#         [0.352547  ]],
#
#        [[0.35150913],
#         [0.35544379],
#         [0.3500881 ],
#         [0.352547  ],
#         [0.36117421]],
#
#        ...,
#
#        [[0.23301032],
#         [0.23287348],
#         [0.23245033],
#         [0.23220192],
#         [0.23284401]],
#
#        [[0.23287348],
#         [0.23245033],
#         [0.23220192],
#         [0.23284401],
#         [0.23277875]],
#
#        [[0.23245033],
#         [0.23220192],
#         [0.23284401],
#         [0.23277875],
#         [0.23148404]]])
